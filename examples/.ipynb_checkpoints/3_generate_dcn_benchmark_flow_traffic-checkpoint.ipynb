# %% [markdown]
# # Generate Flow-Centric DCN Benchmark Traffic
#
# In this example, we will use `TrafPy` to generate the flow-centric data centre network benchmark traffic traces (University, Private Enterprise, Commercial Cloud, and Social Media Cloud) for a custom network topology. We will then save these traffic traces as .pickle files, which can then be imported into any simulation, emulation, or experimentation environment/test bed independently of `TrafPy`. We will also organise the demonstrated traffic into time slots and generate an sqlite data base which we can save to our disk and access during a simulation, thereby enabling us to scale to very large simulation sizes.
#
# To do this, we will need to use the `trafpy.generator` and `trafpy.benchmarker` modules.

# %%
import trafpy.generator as tpg
from trafpy.benchmarker import BenchmarkImporter
# Out:
# /home/hsd/anaconda3/envs/trafpy-env/lib/python3.13/site-packages/nxviz/__init__.py:18: UserWarning:
# nxviz has a new API! Version 0.7.3 onwards, the old class-based API is being
# deprecated in favour of a new API focused on advancing a grammar of network
# graphics. If your plotting code depends on the old API, please consider
# pinning nxviz at version 0.7.3, as the new API will break your old code.
#
# To check out the new API, please head over to the docs at
# https://ericmjl.github.io/nxviz/ to learn more. We hope you enjoy using it!
#
# (This deprecation message will go away in version 1.0.)
#
#   warnings.warn(

# %% [markdown]
# ## 1. Define the Network
#
# Consider that you have a network with $n_{n}=64$ end points/machines/leaf nodes, and that you've defined your network externally to TrafPy, but you would like to use TrafPy to generate the University, Private Enterprise, Commercial Cloud, and Social Media Cloud traffic traces for your network. Regardless of your network's topology, we can use the `trafpy.generator.gen_arbitrary_network()` function to initialise an arbitrary representation of your network which TrafPy can recognise and create traffic data for.
#
# Start by setting how many end points are in your network:

# %%
num_eps = 4

# %% [markdown]
# ### (Optional) End Point Clusters/Racks
# In the context of data centre networks, it is common to cluster end points/machines into *racks*. This can lead to varying levels of end point and end point pair traffic loads (e.g. inter vs. intra-rack traffic load). `TrafPy` lets you group your end points into racks by providing a `racks_dict` dictionary which maps racks (keys) to the list of end points (values) within each rack. If your network did not have any clustering/racks, you could simply set `racks_dict=None`, but consider that your $n_{n}=64$ network has 8 servers per rack (8 racks overall).

# %%
racks_dict, num_racks = {}, 2
eps_per_rack = int(num_eps/num_racks)
for rack in range(num_racks):
    racks_dict[rack] = [ep for ep in range(rack*eps_per_rack, (rack*eps_per_rack)+eps_per_rack)]
print(racks_dict)
# Out:
# {0: [0, 1], 1: [2, 3]}

# %% [markdown]
# ### Network Bandwidth Capacity
#
# Each link in your network will have (1) some bandwidth capacity per link channel (the maximum rate of information transfer per unit time on each channel) $C_{c}$, and (2) some number of channels per link $n_{c}$. `TrafPy` will assume that your links are *bidirectional*, meaning traffic can simultaneously be outbound and inbound from/to a given end point, therefore each link channel's bandwidth is split between the end points' transceiver (source) and receiver (destination) port. Consider that your network has link channel capacity $C_{c}=1250$ and $n_{c}=1$ channels:

# %%
ep_capacity = 1000000000

# %% [markdown]
# You can now initialise your network in a format recognised by `TrafPy` using the `trafpy.generator.gen_arbitrary_network()` function:

# %%
net = tpg.gen_arbitrary_network(num_eps=num_eps, ep_capacity=ep_capacity, racks_dict=racks_dict)

# %% [markdown]
# The *total network capacity* $C_{t}$ is the maximum amount of information which can be transmitted through the entire network per unit time. If 2 end points are connected, the most amount of information they can transfer along a single channel per unit time is the end point bandwidth capacity per channel $C_{c}$ (*not* $2 \cdot C_{c}$), therefore the network's total capacity $C_{t}$ can be evaluated as:
#
# \begin{equation}
#     C_{t} = \frac{n_{n} \cdot C_{c} \cdot n_{c}}{2}
# \end{equation}

# %% [markdown]
# All `TrafPy` networks and graphs are `NetworkX` graphs (see [here](https://networkx.org/documentation/stable/tutorial.html) for details) which can be treated as Python dictionaries. All `TrafPy` networks have the following 'global' graph keys:

# %%
print(net.graph.keys())
print(net.graph['topology_type'])
# Out:
# dict_keys(['endpoints', 'endpoint_label', 'num_channels_per_link', 'ep_link_capacity', 'ep_link_port_capacity', 'max_nw_capacity', 'curr_nw_capacity_used', 'num_active_connections', 'total_connections_blocked', 'node_labels', 'topology_type', 'channel_names', 'rack_to_ep_dict', 'ep_to_rack_dict'])
# arbitrary_endpoints_4_chancap_1000_channels_1

# %% [markdown]
# Notice that TrafPy has automatically evaluated the maximum capacity of your network:

# %%
print(net.graph['max_nw_capacity'])
print(net.graph['topology_type'])
# Out:
# 2000.0
# arbitrary_endpoints_4_chancap_1000_channels_1

# %% [markdown]
# Notice also that all references to capacity have been unitless. $C_{c}=1250$ could refer to e.g. 1250 B/s, 1250 $\mu$B/ms, 1250 Gbps, and so on. This is intentional, and allows you to plug in whatever values you find convenient. Just ensure the information and time units you use are consistent.

# %% [markdown]
# ## 2. Define the Load Configuration
#
# The network load refers to the overall amount of traffic received by the network. This is commonly referred to as a load rate (information units arriving per unit time) or as a load fraction (the fraction of the total network capacity being requested for a given duration). `TrafPy` typically uses the load fraction definition for load, therefore loads can be varied between 0 and 1.
#
# A key feature of `TrafPy` is that you can generate any load for your custom network. To do this, you should provide `TrafPy` with a `network_load_config` dictionary which tells `TrafPy` (1) the end point capacity of your network, (2) the maximum capacity of your network, and (3) the overall load fraction you would like `TrafPy` to generate for your network. Consider that you would like `TrafPy` to generate a 0.1 load traffic trace for your network (i.e. around 10% of your total network capacity will be requested per unit time):

# %%
network_load_config = {'network_rate_capacity': net.graph['max_nw_capacity'], 
                       'ep_link_capacity': net.graph['ep_link_capacity'],
                       'target_load_fraction': 0.6}

# %% [markdown]
# ## 3. Load the TrafPy Benchmarks
#
# The `trafpy.benchmarker.BenchmarkImporter` can be used to load pre-defined `TrafPy` benchmarks which are compatible with the end points we previously defined for our custom network.
#
# `TrafPy` is able to generate arbitrary distributions and therefore arbitrary traffic traces. As the nature of applications handled by real data centres changes, so too will the resultant traffic traces. Therefore, the initial benchmarks established for `TrafPy` have been stored under `benchmark_version='v001'` with the anticipation that future benchmark versions will be established with new and evolving traffic traces.

# %%
importer = BenchmarkImporter(benchmark_version='v001', load_prev_dists=False)
# Out:
# load_prev_dist=False. Will re-generate dists with given network params and override any previously saved distributions.

# %% [markdown]
# We can now import the University, Private Enterprise, Commercial Cloud, and Social Media Cloud `TrafPy` benchmark distributions adapted for our network's endpoints:

# %%
dcn_dists = {}
for dcn in ['university', 'private_enterprise', 'commercial_cloud', 'social_media_cloud']:
    dcn_dists[dcn] = importer.get_benchmark_dists(benchmark_name=dcn, 
                                                  eps=net.graph['endpoints'], 
                                                  racks_dict=net.graph['rack_to_ep_dict'])
# Out:
# Set to save benchmark university distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/university/
# Saved node_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/university/
# Saved flow_size_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/university/
# Saved interarrival_time_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/university/
# Set to save benchmark private_enterprise distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/private_enterprise/
# Saved node_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/private_enterprise/
# Saved flow_size_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/private_enterprise/
# Saved interarrival_time_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/private_enterprise/
# Set to save benchmark commercial_cloud distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/commercial_cloud/
# Saved node_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/commercial_cloud/
# Saved flow_size_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/commercial_cloud/
# Saved interarrival_time_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/commercial_cloud/
# Set to save benchmark social_media_cloud distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/social_media_cloud/
# Saved node_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/social_media_cloud/
# Saved flow_size_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/social_media_cloud/
# Saved interarrival_time_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/social_media_cloud/

# %% [markdown]
# Each benchmark contains the following distributions (stored as dictionaries with key (distribution name) value (distribution hash table) pairs):

# %%
print(list(dcn_dists['university'].keys()))
# Out:
# ['node_dist', 'flow_size_dist', 'interarrival_time_dist', 'num_ops_dist']

# %% [markdown]
# For flow-centric traffic, we only need to worry about flow size, inter-arrival time, and node distributions.

# %% [markdown]
# 32## 4. (Optional) Define Additional Trace Parameters
#
# `TrafPy` generates traffic trace data for your network using the `trafpy.generator.create_demand_data()` function. This function has some useful additional parameters you can define to further customise the trace generated for your network (see documentation for details).
#
# An important parameter in `TrafPy` traffic generation is the `jensen_shannon_distance_threshold`. Since `TrafPy` traffic data are generated by sampling from some pre-defined distributions, how similar the sampled data are to the original distributions will depend on the number of demands generated/sampled by the law of large numbers. `TrafPy` lets you set the `jensen_shannon_distance_threshold`, which must be between 0 and 1. A lower value will result in more demands being generated and therefore a data set more similar to the original distributions (in the example, benchmarks) you are sampling from, whereas a higher value will be less reliably similar but will result in fewer demands (which can reduce the memory and time size of your tests).
#
# Other useful additional parameters include `min_last_demand_arrival_time`, `min_num_demands`, and `max_num_demands`. See documentation for details.
#
# Here, we will set `jensen_shannon_distance_threshold=0.9` (a high value so that we don't generate many demands and therefore save time).

# %%
jsd_threshold = 0.9

# %% [markdown]
# ## 5. Generate the Traffic Traces
#
# With our network defined and our benchmark distributions loaded, we are now ready to generate some traffic for our custom network using the `trafpy.generator.create_demand_data()` function. We will save our traffic into separate .pickle files. These files can then be imported into your own simulation, emulation, and/or experimentation test beds to test your own systems under these `TrafPy` benchmarks.

# %%
from pathlib import Path
import gzip
import pickle
import time

path_to_data = 'data/generate_flow_benchmark_traffic/'
Path(path_to_data).mkdir(exist_ok=True, parents=True)
for dcn in dcn_dists.keys():
    print('Generating \'{}\' traffic demands for {} network'.format(dcn, net.graph['topology_type']))
    time.sleep(1)
    
    # get node, flow size, and flow inter-arrival time benchmark dists
    dists = dcn_dists[dcn]
    
    # generate traffic demands
    demand_data = tpg.create_demand_data(eps=net.graph['endpoints'],
                                         node_dist=dists['node_dist'],
                                         flow_size_dist=dists['flow_size_dist'],
                                         interarrival_time_dist=dists['interarrival_time_dist'],
                                         network_load_config=network_load_config,
                                         jensen_shannon_distance_threshold=jsd_threshold)
    print()
    print()
    print(demand_data)
    print()
    
    # save demands as pickle file
    filename = path_to_data+'{}_demand_data.pickle'.format(dcn)
    with gzip.open(filename, 'wb') as f:
        pickle.dump(demand_data, f)
# Out:
# Generating 'university' traffic demands for arbitrary_endpoints_4_chancap_1000_channels_1 network
# Packed 6000 flows in 0.446 s | Node distribution Jensen Shannon distance from target achieved: 0.0005098551957309269
#
#
# {'flow_id': ['flow_3367', 'flow_936', 'flow_3189', 'flow_3836', 'flow_5611', 'flow_3714', 'flow_1725', 'flow_4305', 'flow_5461', 'flow_3460', 'flow_3973', 'flow_2302', 'flow_4840', 'flow_820', 'flow_3589', 'flow_20', 'flow_291', 'flow_1669', 'flow_5847', 'flow_4925', 'flow_5923', 'flow_5102', 'flow_5098', 'flow_3523', 'flow_1839', 'flow_3102', 'flow_3793', 'flow_3867', 'flow_1206', 'flow_1692', 'flow_2429', 'flow_1716', 'flow_5190', 'flow_1541', 'flow_4618', 'flow_4488', 'flow_1400', 'flow_1198', 'flow_2084', 'flow_150', 'flow_1602', 'flow_3817', 'flow_4249', 'flow_5654', 'flow_5663', 'flow_3255', 'flow_3527', 'flow_1806', 'flow_4141', 'flow_46', 'flow_4103', 'flow_357', 'flow_3104', 'flow_3241', 'flow_4316', 'flow_4325', 'flow_3002', 'flow_2090', 'flow_540', 'flow_3346', 'flow_2577', 'flow_412', 'flow_1973', 'flow_1494', 'flow_1922', 'flow_5759', 'flow_3250', 'flow_5782', 'flow_1677', 'flow_3636', 'flow_3009', 'flow_524', 'flow_1272', 'flow_299', 'flow_5784', 'flow_1371', 'flow_1253', 'flow_2654', 'flow_1988', 'flow_5136', 'flow_4528', 'flow_2452', 'flow_3426', 'flow_1974', 'flow_5066', 'flow_776', 'flow_2969', 'flow_5767', 'flow_3748', 'flow_2737', 'flow_2113', 'flow_2780', 'flow_4446', 'flow_4493', 'flow_3639', 'flow_931', 'flow_1348', 'flow_4920', 'flow_3', 'flow_4842', 'flow_543', 'flow_3090', 'flow_5326', 'flow_1366', 'flow_62', 'flow_4047', 'flow_1702', 'flow_4474', 'flow_2925', 'flow_1466', 'flow_4773', 'flow_3769', 'flow_2410', 'flow_4893', 'flow_1429', 'flow_1603', 'flow_795', 'flow_5256', 'flow_3556', 'flow_5719', 'flow_711', 'flow_5736', 'flow_4816', 'flow_3397', 'flow_4264', 'flow_4518', 'flow_3394', 'flow_5432', 'flow_1403', 'flow_2088', 'flow_3309', 'flow_2892', 'flow_2042', 'flow_2212', 'flow_4515', 'flow_2116', 'flow_2305', 'flow_1191', 'flow_5554', 'flow_2511', 'flow_158', 'flow_5235', 'flow_498', 'flow_1002', 'flow_3570', 'flow_5074', 'flow_4512', 'flow_287', 'flow_2109', 'flow_4828', 'flow_5003', 'flow_1978', 'flow_2039', 'flow_1104', 'flow_547', 'flow_3056', 'flow_218', 'flow_3119', 'flow_4659', 'flow_3743', 'flow_290', 'flow_5911', 'flow_3526', 'flow_4948', 'flow_1176', 'flow_4554', 'flow_2890', 'flow_1046', 'flow_437', 'flow_1072', 'flow_93', 'flow_635', 'flow_3799', 'flow_5169', 'flow_4260', 'flow_5547', 'flow_1459', 'flow_930', 'flow_351', 'flow_5181', 'flow_4670', 'flow_1246', 'flow_1190', 'flow_4783', 'flow_2060', 'flow_5097', 'flow_1779', 'flow_4360', 'flow_1418', 'flow_1207', 'flow_1997', 'flow_4295', 'flow_2358', 'flow_468', 'flow_5982', 'flow_5161', 'flow_4732', 'flow_4730', 'flow_562', 'flow_5403', 'flow_5834', 'flow_2804', 'flow_4375', 'flow_5912', 'flow_1147', 'flow_616', 'flow_120', 'flow_5906', 'flow_3412', 'flow_1618', 'flow_3890', 'flow_3971', 'flow_2344', 'flow_5652', 'flow_4594', 'flow_5648', 'flow_4572', 'flow_3525', 'flow_4288', 'flow_2461', 'flow_845', 'flow_2748', 'flow_3967', 'flow_2800', 'flow_474', 'flow_5670', 'flow_1131', 'flow_774', 'flow_848', 'flow_5527', 'flow_5309', 'flow_4867', 'flow_5614', 'flow_2241', 'flow_3323', 'flow_5812', 'flow_233', 'flow_5476', 'flow_5999', 'flow_3874', 'flow_5139', 'flow_3773', 'flow_4244', 'flow_1175', 'flow_4161', 'flow_1477', 'flow_5811', 'flow_3147', 'flow_5899', 'flow_500', 'flow_3989', 'flow_1083', 'flow_5619', 'flow_3545', 'flow_2123', 'flow_3894', 'flow_2249', 'flow_5083', 'flow_4650', 'flow_3329', 'flow_761', 'flow_1564', 'flow_1744', 'flow_2492', 'flow_4013', 'flow_1442', 'flow_902', 'flow_5020', 'flow_630', 'flow_2519', 'flow_2257', 'flow_2518', 'flow_1506', 'flow_1460', 'flow_4205', 'flow_709', 'flow_1401', 'flow_306', 'flow_1257', 'flow_3995', 'flow_4711', 'flow_1606', 'flow_5917', 'flow_0', 'flow_5365', 'flow_3947', 'flow_1011', 'flow_3978', 'flow_5327', 'flow_402', 'flow_4879', 'flow_838', 'flow_1453', 'flow_5681', 'flow_3573', 'flow_2844', 'flow_2453', 'flow_1180', 'flow_275', 'flow_1939', 'flow_5333', 'flow_1753', 'flow_3406', 'flow_5489', 'flow_1152', 'flow_4335', 'flow_2395', 'flow_2635', 'flow_2348', 'flow_3880', 'flow_3021',  ...
#        8.22262371e+01, 1.55745111e+02, 1.82316034e+02, 2.83752331e+02,
#        2.99641026e+02, 3.05206557e+02, 3.25314283e+02, 3.62298136e+02,
#        3.92459726e+02, 4.17594383e+02, 4.29712879e+02, 4.41651841e+02,
#        4.64632100e+02, 4.67055799e+02, 5.09694950e+02, 5.33662642e+02,
#        5.40125839e+02, 5.45332304e+02, 5.79174325e+02, 6.16607012e+02,
#        6.20466977e+02, 6.44075602e+02, 6.45781168e+02, 7.19210275e+02,
#        7.81957152e+02, 7.83213885e+02, 7.85098985e+02, 8.10772242e+02,
#        8.24416770e+02, 8.25045137e+02, 8.63644790e+02, 9.81418614e+02,
#        9.90754344e+02, 9.91652010e+02, 1.01265740e+03, 1.01930013e+03,
#        1.10915653e+03, 1.13536839e+03, 1.15933608e+03, 1.16032352e+03,
#        1.16256768e+03, 1.16777415e+03, 1.16903088e+03, 1.20709193e+03,
#        1.22414759e+03, 1.23877955e+03, 1.25395012e+03, 1.26032355e+03,
#        1.27316018e+03, 1.28752284e+03, 1.29407580e+03, 1.30332177e+03,
#        1.30403990e+03, 1.32630202e+03, 1.36705608e+03, 1.45000045e+03,
#        1.45089811e+03, 1.48698430e+03, 1.51175989e+03, 1.52055702e+03,
#        1.52387839e+03, 1.53231645e+03, 1.57782813e+03, 1.59649959e+03,
#        1.61382455e+03, 1.66615850e+03, 1.67809746e+03, 1.70610465e+03,
#        1.72450681e+03, 1.73267558e+03, 1.74183177e+03, 1.74730754e+03,
#        1.75601490e+03, 1.84084437e+03, 1.89138299e+03, 1.90071872e+03,
#        1.91705624e+03, 1.92809754e+03, 1.93384261e+03, 1.93384620e+03,
#        2.02980673e+03, 2.05359489e+03, 2.08725737e+03, 2.09084804e+03,
#        2.15296655e+03, 2.19632383e+03, 2.21598273e+03, 2.22208686e+03,
#        2.23294862e+03, 2.23537232e+03, 2.25790375e+03, 2.29856803e+03,
#        2.30539030e+03, 2.30592890e+03, 2.39183556e+03, 2.39776016e+03,
#        2.43384635e+03, 2.45898101e+03, 2.46499537e+03, 2.47819107e+03,
#        2.50323596e+03, 2.50754476e+03, 2.63698824e+03, 2.66266150e+03,
#        2.68079436e+03, 2.72109958e+03, 2.73671897e+03, 2.73779617e+03,
#        2.76580336e+03, 2.77020193e+03, 2.80269745e+03, 2.82056101e+03,
#        2.82289494e+03, 2.84219477e+03, 2.86364900e+03, 2.88438509e+03,
#        2.90907091e+03, 2.96176393e+03, 2.97666519e+03, 3.02522894e+03,
#        3.03312840e+03, 3.05592913e+03, 3.07343362e+03, 3.07504942e+03,
#        3.10126128e+03, 3.11741927e+03, 3.12567780e+03, 3.14282323e+03,
#        3.14461856e+03, 3.16203329e+03, 3.17343365e+03, 3.19847854e+03,
#        3.20835287e+03, 3.22899920e+03, 3.26732955e+03, 3.28214104e+03,
#        3.34955579e+03, 3.35000462e+03, 3.39416980e+03, 3.44273355e+03,
#        3.48124344e+03, 3.48429551e+03, 3.49102800e+03, 3.49542657e+03,
#        3.50171023e+03, 3.50197953e+03, 3.51580359e+03, 3.52056123e+03,
#        3.57953790e+03, 3.61643199e+03, 3.62262589e+03, 3.65512141e+03,
#        3.68555230e+03, 3.70054333e+03, 3.70305679e+03, 3.71418786e+03,
#        3.71750922e+03, 3.75772467e+03, 3.81661159e+03, 3.81876599e+03,
#        3.86364930e+03, 3.87172830e+03, 3.87226690e+03, 3.91212329e+03,
#        3.91750928e+03, 4.00332619e+03, 4.03205151e+03, 4.09901742e+03,
#        4.10907128e+03, 4.11598331e+03, 4.11670144e+03, 4.12370324e+03,
#        4.13384687e+03, 4.14497793e+03, 4.15233880e+03, 4.17406232e+03,
#        4.18618082e+03, 4.18788639e+03, 4.24677330e+03, 4.28716828e+03,
#        4.28806595e+03, 4.28815572e+03, 4.29417008e+03, 4.30009468e+03,
#        4.32092054e+03, 4.40018448e+03, 4.40996904e+03, 4.43393673e+03,
#        4.47998701e+03, 4.50718630e+03, 4.57020248e+03, 4.57603731e+03,
#        4.58303911e+03, 4.62783266e+03, 4.65206965e+03, 4.66257235e+03,
#        4.67433178e+03, 4.69785064e+03, 4.74811995e+03, 4.76616304e+03,
#        4.79040004e+03, 4.79183630e+03, 4.87567834e+03, 5.00018466e+03,
#        5.00386509e+03, 5.05126188e+03, 5.06553477e+03, 5.09443963e+03,
#        5.10458326e+03, 5.10530139e+03, 5.10934089e+03, 5.13205185e+03,
#        5.13788668e+03, 5.19434989e+03, 5.20215959e+03, 5.28627092e+03,
#        5.30153125e+03, 5.33268027e+03, 5.35987956e+03, 5.36715066e+03,
#        5.37208783e+03, 5.38824582e+03, 5.41382931e+03, 5.41741998e+03,
#        5.47549899e+03, 5.48151335e+03, 5.48725842e+03, 5.51822791e+03,
#        5.51831767e+03, 5.51840744e+03, 5.55215970e+03, 5.57926922e+03,
#        5.64937696e+03, 5.65494249e+03, 5.65871269e+03, 5.65978989e+03,
#        5.66454752e+03, 5.66526566e+03, 5.68411665e+03, 5.71912564e+03,
#        5.77226748e+03, 5.78420645e+03, 5.85826392e+03, 5.87110055e+03,
#        5.90081330e+03, 5.93052606e+03, 5.96975408e+03, 5.97253684e+03,
#        5.97810238e+03, 5.98348837e+03, 6.00862303e+03, 6.00898210e+03,
#        6.02002339e+03, 6.06625321e+03, 6.09686363e+03, 6.11221373e+03,
#        6.12487082e+03, 6.14174695e+03, 6.19524786e+03, 6.20745613e+03,
#        6.20835379e+03, 6.21023889e+03, 6.22496062e+03, 6.22962849e+03,
#        6.24291395e+03, 6.24632508e+03, 6.30925149e+03, 6.34075958e+03,
#        6.34596604e+03, 6.36804864e+03, 6.40494272e+03, 6.40987989e+03,
#        6.44713304e+03, 6.46409893e+03, 6.47576860e+03, 6.48169320e+03,
#        6.53824617e+03, 6.55413487e+03, 6.55673810e+03, 6.57271656e+03,
#        6.57917976e+03, 6.65126237e+03, 6.65162143e+03, 6.66517620e+03,
#        6.68366812e+03, 6.69192665e+03, 6.73043654e+03, 6.77469149e+03,
#        6.80584051e+03, 6.84883873e+03, 6.86436836e+03, 6.89623551e+03,
#        6.90054431e+03, 6.91813857e+03, 6.94022116e+03, 6.95018526e+03,
#        6.95180106e+03, 6.98214218e+03, 7.02289623e+03, 7.03007756e+03,
#        7.04641509e+03, 7.05305782e+03, 7.07137022e+03, 7.08896448e+03,
#        7.09219608e+03, 7.09390164e+03, 7.13564313e+03, 7.19686397e+03,
#        7.20934153e+03, 7.23591246e+03, 7.25539182e+03, 7.25566112e+03,
#        7.25772575e+03, 7.30602020e+03, 7.32558933e+03, 7.33106509e+03,
#        7.44847985e+03, 7.46320158e+03, 7.47038291e+03, 7.47711540e+03,
#        7.50996999e+03, 7.54883895e+03, 7.55359658e+03, 7.60970072e+03,
#        7.61418905e+03, 7.65368637e+03, 7.69246556e+03, 7.69399159e+03,
#        7.70485336e+03, 7.72181925e+03, 7.73286055e+03, 7.75350687e+03,
#        7.81023938e+03, 7.83761821e+03, 7.86122683e+03, 7.86930583e+03,
#        7.88663079e+03, 7.90036509e+03, 7.96014966e+03, 7.99910838e+03,
#        8.01185525e+03, 8.07756442e+03, 8.07900069e+03, 8.11643337e+03,
#        8.14435080e+03, 8.14874936e+03, 8.15781579e+03, 8.17128079e+03,
#        8.18043698e+03, 8.20072424e+03, 8.24076016e+03, 8.29345318e+03,
#        8.29713361e+03, 8.29740291e+03, 8.30225031e+03, 8.30655911e+03,
#        8.38124495e+03, 8.39165788e+03, 8.39623597e+03, 8.46858788e+03,
#        8.53456636e+03, 8.61733119e+03, 8.64596675e+03, 8.65117322e+03,
#        8.68402780e+03, 8.73672082e+03, 8.73779802e+03, 8.76499731e+03,
#        8.77765440e+03, 8.78977290e+03, 8.79264543e+03, 8.80251976e+03,
#        8.83483575e+03, 8.83860595e+03, 8.87208890e+03, 8.95512304e+03,
#        8.99982682e+03, 9.01167602e+03, 9.04865987e+03, 9.09910872e+03,
#        9.12424338e+03, 9.21418955e+03, 9.26688256e+03, 9.27684666e+03,
#        9.29219675e+03, 9.29497952e+03, 9.30135295e+03, 9.30970125e+03,
#        9.32137091e+03, 9.32603877e+03, 9.32729551e+03, 9.33330987e+03,
#        9.34399210e+03, 9.34435117e+03, 9.35162226e+03, 9.35377666e+03,
#        9.38609265e+03, 9.40898314e+03, 9.43770847e+03, 9.48259178e+03,
#        9.48313038e+03, 9.48770848e+03, 9.49740328e+03, 9.52199934e+03,
#        9.54955769e+03, 9.56625429e+03, 9.60332791e+03, 9.60467441e+03,
#        9.61221480e+03, 9.65225072e+03, 9.69300477e+03, 9.70377677e+03,
#        9.70871394e+03, 9.74623639e+03, 9.77882168e+03, 9.78052724e+03,
#        9.78636207e+03, 9.82783426e+03, 9.84471039e+03, 9.84848059e+03,
#        9.85476425e+03, 9.87164038e+03, 9.87316641e+03, 9.89255600e+03,
#        9.92002459e+03, 9.92837289e+03, 9.93160449e+03, 9.97325621e+03,
#        9.99417183e+03, 1.00606889e+04, 1.00718200e+04, 1.01570983e+04,
#        1.01659852e+04, 1.01763083e+04, 1.01771162e+04, 1.02164340e+04,
#        1.02165238e+04, 1.02247823e+04, 1.02398631e+04, 1.02579062e+04,
#        1.03097016e+04, 1.03193066e+04, 1.03521612e+04, 1.03604197e+04,
#        1.03703838e+04, 1.03708326e+04, 1.03739745e+04, 1.03790014e+04,
#        1.03801684e+04, 1.03911199e+04, 1.04369906e+04, 1.04414790e+04,
#        1.04422869e+04, 1.04689476e+04, 1.04893246e+04, 1.04975831e+04,
#        1.05234359e+04, 1.05328614e+04, 1.06144593e+04, 1.06184090e+04,
#        1.06342977e+04, 1.06553929e+04, 1.06593426e+04, 1.06965060e+04,
#        1.06997376e+04, 1.07029692e+04, 1.07056622e+04, 1.07183193e+04,
#        1.07419279e+04, 1.07948004e+04, 1.08049441e+04, 1.08092529e+04,
#        1.08165240e+04, 1.08202942e+04, 1.08798094e+04, 1.09014432e+04,
#        1.10001865e+04, 1.10247826e+04, 1.10250519e+04, 1.10695761e+04,
#        1.10811560e+04, 1.11302584e+04, 1.11372602e+04, 1.11591632e+04,
#        1.11623948e+04, 1.11902225e+04, 1.12163446e+04, 1.12310663e+04,
#        1.12334002e+04, 1.12705636e+04, 1.12786426e+04, 1.13264882e+04,
#        1.13272961e+04, 1.13669730e+04, 1.13767575e+04, 1.14791813e+04,
#        1.14820538e+04, 1.14957881e+04, 1.15019820e+04, 1.15067396e+04,
#        1.15480323e+04, 1.15543159e+04, 1.15623052e+04, 1.15745134e+04,
#        1.15997379e+04, 1.16108689e+04, 1.16215511e+04, 1.16309766e+04,
#        1.16514434e+04, 1.16697558e+04, 1.16845673e+04, 1.17018025e+04,
#        1.17237953e+04, 1.17463268e+04, 1.17712819e+04, 1.18049444e+04,
#        1.19301688e+04, 1.19359139e+04, 1.19462371e+04, 1.19573681e+04,
#        1.19885171e+04, 1.20701150e+04, 1.20792712e+04, 1.21150881e+04,
#        1.21157165e+04, 1.21256806e+04, 1.22667937e+04, 1.22801689e+04,
#        1.23144598e+04, 1.23166142e+04, 1.23276555e+04, 1.23364526e+04,
#        1.24348369e+04, 1.24720002e+04, 1.25014437e+04, 1.25082660e+04,
#        1.25153575e+04, 1.25169733e+04, 1.25604204e+04, 1.25618566e+04,
#        1.26109590e+04, 1.26157166e+04, 1.26525209e+04, 1.26850165e+04,
#        1.27257705e+04, 1.27269375e+04, 1.27385174e+04, 1.27418387e+04,
#        1.27530596e+04, 1.28174223e+04, 1.28406718e+04, 1.28538675e+04,
#        1.28620363e+04, 1.28683199e+04, 1.28702050e+04, 1.28763989e+04,
#        1.29726288e+04, 1.29757706e+04, 1.30047652e+04, 1.30339394e+04,
#        1.30777455e+04, 1.31120363e+04, 1.31439933e+04, 1.31543164e+04,
#        1.31572787e+04, 1.31992895e+04, 1.32162554e+04, 1.32350166e+04,
#        1.32507258e+04, 1.32811567e+04, 1.32830418e+04, 1.32852860e+04,
#        1.32880687e+04, 1.32904924e+04, 1.33400436e+04, 1.33410310e+04,
#        1.33458784e+04, 1.33636522e+04, 1.34041370e+04, 1.34111388e+04,
#        1.34432752e+04, 1.34596128e+04, 1.35205643e+04, 1.35652681e+04,
#        1.35722699e+04, 1.35799000e+04, 1.35816056e+04, 1.35931855e+04,
#        1.36192178e+04, 1.36641011e+04, 1.36668839e+04, 1.36923776e+04,
#        1.37246936e+04, 1.37502771e+04, 1.38285536e+04, 1.38449809e+04,
#        1.38526111e+04, 1.38568301e+04, 1.38688588e+04, 1.38864531e+04,
#        1.38901335e+04, 1.38920186e+04, 1.39518930e+04, 1.39912108e+04,
#        1.40247835e+04, 1.40343885e+04, 1.40920187e+04, 1.40956991e+04,
#        1.40961480e+04, 1.41519828e+04, 1.41623060e+04, 1.41884281e+04,
#        1.42058428e+04, 1.42190385e+04, 1.42484819e+04, 1.42859146e+04,
#        1.43237961e+04, 1.43570098e+04, 1.43579972e+04, 1.43733473e+04,
#        1.44052145e+04, 1.44842989e+04, 1.44849273e+04, 1.45943528e+04,
#        1.46001876e+04, 1.46351068e+04, 1.46791822e+04, 1.47253223e+04,
#        1.47369022e+04, 1.47535988e+04, 1.47623062e+04, 1.47902236e+04,
#        1.48301697e+04, 1.48528807e+04, 1.48620369e+04, 1.49279256e+04,
#        1.51290029e+04, 1.51762201e+04, 1.51788233e+04, 1.52645505e+04,
#        1.52727192e+04, 1.52816959e+04, 1.54002776e+04, 1.54538683e+04,
#        1.54866331e+04, 1.54904931e+04, 1.55947122e+04, 1.56133836e+04,
#        1.56236170e+04, 1.56323244e+04, 1.56325937e+04, 1.56421987e+04,
#        1.56525219e+04, 1.56878002e+04, 1.57107804e+04, 1.57160766e+04,
#        1.57356458e+04, 1.57428271e+04, 1.57522526e+04, 1.57693083e+04,
#        1.57725399e+04, 1.58032400e+04, 1.58059330e+04, 1.58738864e+04,
#        1.58931862e+04, 1.58988415e+04, 1.59484825e+04, 1.59490211e+04,
#        1.59613191e+04, 1.59992904e+04, 1.60029708e+04, 1.60111396e+04,
#        1.60547662e+04, 1.60608703e+04, 1.61057536e+04, 1.61239762e+04,
#        1.61652689e+04, 1.62468668e+04, 1.62860948e+04, 1.62898650e+04,
#        1.63123964e+04, 1.63149099e+04, 1.63693982e+04, 1.63992905e+04,
#        1.64033300e+04, 1.64473156e+04, 1.64825042e+04, 1.65030607e+04,
#        1.65948022e+04, 1.65953408e+04, 1.66140123e+04, 1.66235276e+04,
#        1.66490213e+04, 1.66817861e+04, 1.67727197e+04, 1.68256820e+04,
#        1.69370824e+04, 1.69375312e+04, 1.69725402e+04, 1.70202961e+04,
#        1.70345690e+04, 1.70471363e+04, 1.70504577e+04, 1.70584469e+04,
#        1.71189496e+04, 1.72254128e+04, 1.72305295e+04, 1.72559335e+04,
#        1.72627558e+04, 1.72635637e+04, 1.72658976e+04, 1.73377109e+04,
#        1.73381597e+04, 1.73454308e+04, 1.73597935e+04, 1.73854667e+04,
#        1.74086265e+04, 1.74464183e+04, 1.74515350e+04, 1.74557540e+04,
#        1.74993806e+04, 1.75141023e+04, 1.75404040e+04, 1.75694883e+04,
#        1.75744255e+04, 1.75958797e+04, 1.76213735e+04, 1.76341203e+04,
#        1.77302604e+04, 1.77423789e+04, 1.77547667e+04, 1.77700270e+04,
#        1.78288242e+04, 1.78306195e+04, 1.78382496e+04, 1.78554848e+04,
#        1.78561132e+04, 1.78828637e+04, 1.78834920e+04, 1.78996500e+04,
#        1.79212838e+04, 1.79305297e+04, 1.79669750e+04, 1.79709247e+04,
#        1.80220019e+04, 1.80484831e+04, 1.80782856e+04, 1.81237973e+04,
#        1.81350181e+04, 1.81534203e+04, 1.81965083e+04, 1.81995604e+04,
#        1.82423790e+04, 1.82492911e+04, 1.82607812e+04, 1.83026124e+04,
#        1.83264006e+04, 1.83272085e+04, 1.83655389e+04, 1.83751439e+04,
#        1.83754132e+04, 1.83987525e+04, 1.84382498e+04, 1.84492014e+04,
#        1.84716430e+04, 1.85201170e+04, 1.85325048e+04, 1.86851978e+04,
#        1.86983935e+04, 1.87077293e+04, 1.87272086e+04, 1.87796323e+04,
#        1.88398658e+04, 1.88810686e+04, 1.88859160e+04, 1.88895965e+04,
#        1.89024331e+04, 1.89274780e+04, 1.89424690e+04, 1.89498299e+04,
#        1.89534205e+04, 1.89605121e+04, 1.89610507e+04, 1.89747850e+04,
#        1.90373524e+04, 1.90445337e+04, 1.90550364e+04, 1.90755929e+04,
#        1.90775678e+04, 1.90779269e+04, 1.90783757e+04, 1.90826845e+04,
#        1.91048569e+04, 1.91096145e+04, 1.91552159e+04, 1.91826845e+04,
#        1.92274781e+04, 1.92447133e+04, 1.93579988e+04, 1.93829539e+04,
#        1.94047672e+04, 1.94793633e+04, 1.94813381e+04, 1.95130257e+04,
#        1.95434566e+04, 1.96237080e+04, 1.96880707e+04, 1.97329540e+04,
#        1.97362754e+04, 1.97512664e+04, 1.97860061e+04, 1.97905842e+04,
#        1.97932772e+04, 1.98250546e+04, 1.98295429e+04, 1.98654496e+04,
#        1.98704765e+04, 1.98796327e+04, 1.99155393e+04, 1.99244262e+04,
#        1.99740672e+04, 1.99770295e+04, 2.01281067e+04, 2.01551265e+04,
#        2.01559344e+04, 2.01791839e+04, 2.02144622e+04, 2.03356472e+04,
#        2.03494712e+04, 2.03567423e+04, 2.03718231e+04, 2.04140135e+04,
#        2.04266706e+04, 2.04548573e+04, 2.04642828e+04, 2.04855575e+04,
#        2.05176939e+04, 2.05232595e+04, 2.05319668e+04, 2.05393277e+04,
#        2.05728106e+04, 2.05886096e+04, 2.06546778e+04, 2.06718232e+04,
#        2.06857371e+04, 2.06929184e+04, 2.07055755e+04, 2.07794534e+04,
#        2.08656294e+04, 2.09027928e+04, 2.09199382e+04, 2.09334032e+04,
#        2.10018054e+04, 2.10074607e+04, 2.10172452e+04, 2.10679634e+04,
#        2.10729006e+04, 2.10917515e+04, 2.11061142e+04, 2.11331340e+04,
#        2.11412130e+04, 2.11604230e+04, 2.11619491e+04, 2.11669760e+04,
#        2.11819670e+04, 2.12097049e+04, 2.12231699e+04, 2.12285559e+04,
#        2.12346600e+04, 2.12420209e+04, 2.12479455e+04, 2.12513566e+04,
#        2.12524338e+04, 2.12974069e+04, 2.13409437e+04, 2.13465093e+04,
#        2.13765811e+04, 2.14132956e+04, 2.14410335e+04, 2.14621287e+04,
#        2.14645524e+04, 2.14845703e+04, 2.15245165e+04, 2.15530623e+04,
#        2.15538702e+04, 2.16005488e+04, 2.16007284e+04, 2.16188612e+04,
#        2.16468684e+04, 2.16784663e+04, 2.17200282e+04, 2.17223622e+04,
#        2.17313388e+04, 2.17578200e+04, 2.17640139e+04, 2.17925597e+04,
#        2.17974071e+04, 2.18447141e+04, 2.18569223e+04, 2.18786459e+04,
#        2.19096154e+04, 2.19158092e+04, 2.19234394e+04, 2.19463299e+04,
#        2.19834933e+04, 2.19975867e+04, 2.20050373e+04, 2.20273892e+04,
#        2.20333138e+04, 2.20334035e+04, 2.20426495e+04, 2.20738883e+04,
#        2.21021648e+04, 2.21238883e+04, 2.21308003e+04, 2.21626675e+04,
#        2.21650912e+04, 2.21806208e+04, 2.21903156e+04, 2.21942653e+04,
#        2.22321469e+04, 2.22544090e+04, 2.22665275e+04, 2.22759530e+04,
#        2.23016262e+04, 2.23066532e+04, 2.23170661e+04, 2.23339422e+04,
#        2.23457914e+04, 2.23460607e+04, 2.23847501e+04, 2.23897771e+04,
#        2.24957017e+04, 2.25049477e+04, 2.25050374e+04, 2.25178741e+04,
#        2.25207466e+04, 2.25478561e+04, 2.25627574e+04, 2.25649118e+04,
#        2.25772996e+04, 2.25986640e+04, 2.26014468e+04, 2.26057556e+04,
#        2.26066533e+04, 2.26283768e+04, 2.26380716e+04, 2.26559352e+04,
#        2.26777484e+04, 2.27048580e+04, 2.27058454e+04, 2.27293643e+04,
#        2.27391488e+04, 2.27821470e+04, 2.27978562e+04, 2.28022548e+04,
#        2.28054864e+04, 2.28219137e+04, 2.28222727e+04, 2.28372638e+04,
#        2.28699388e+04, 2.28701183e+04, 2.28772099e+04, 2.28866354e+04,
#        2.29193105e+04, 2.29294541e+04, 2.29327755e+04, 2.29422009e+04,
#        2.29778383e+04, 2.29816983e+04, 2.29982153e+04, 2.30293643e+04,
#        2.30533320e+04, 2.30584487e+04, 2.30727216e+04, 2.30742477e+04,
#        2.30839425e+04, 2.30895080e+04, 2.31007288e+04, 2.31140143e+04,
#        2.31563841e+04, 2.31566534e+04, 2.31605134e+04, 2.31980359e+04,
#        2.32327755e+04, 2.32535116e+04, 2.33157199e+04, 2.33198492e+04,
#        2.33391490e+04, 2.33499210e+04, 2.33546786e+04, 2.33641041e+04,
#        2.33816086e+04, 2.33854686e+04, 2.34369049e+04, 2.34434578e+04,
#        2.34543196e+04, 2.35049480e+04, 2.35268510e+04, 2.35769408e+04,
#        2.36614112e+04, 2.36645531e+04, 2.36765818e+04, 2.36975872e+04,
#        2.37150019e+04, 2.37323269e+04, 2.37755046e+04, 2.38283772e+04,
#        2.38362766e+04, 2.38413933e+04, 2.38566537e+04, 2.39132066e+04,
#        2.39140145e+04, 2.39252354e+04, 2.39761330e+04, 2.40223629e+04,
#        2.40379823e+04, 2.40422013e+04, 2.40453431e+04, 2.40619499e+04,
#        2.40938171e+04, 2.40978566e+04, 2.41001008e+04, 2.41033324e+04,
#        2.41713755e+04, 2.41742480e+04, 2.42001906e+04, 2.42045891e+04,
#        2.42077310e+04, 2.42413037e+04, 2.42595263e+04, 2.42906753e+04,
#        2.42914832e+04, 2.43098854e+04, 2.43103342e+04, 2.43112319e+04,
#        2.43485748e+04, 2.43943558e+04, 2.43994725e+04, 2.44308908e+04,
#        2.44318782e+04, 2.44503702e+04, 2.44765820e+04, 2.45536018e+04,
#        2.45624887e+04, 2.45658998e+04, 2.45972284e+04, 2.46381620e+04,
#        2.46527042e+04, 2.46609627e+04, 2.46657203e+04, 2.46701189e+04,
#        2.46740686e+04, 2.46891494e+04, 2.46922015e+04, 2.47260435e+04,
#        2.47478568e+04, 2.47570130e+04, 2.48501010e+04, 2.48523452e+04,
#        2.48629376e+04, 2.49638353e+04, 2.49696702e+04, 2.50371747e+04,
#        2.50523452e+04, 2.50569233e+04, 2.50657205e+04, 2.50675158e+04,
#        2.51203883e+04, 2.51416630e+04, 2.51425607e+04, 2.52131173e+04,
#        2.52580006e+04, 2.52605140e+04, 2.52864566e+04, 2.53020760e+04,
#        2.53187726e+04, 2.53517169e+04, 2.53590778e+04, 2.54249665e+04,
#        2.54317888e+04, 2.54358283e+04, 2.54425608e+04, 2.54742484e+04,
#        2.54922915e+04, 2.55061156e+04, 2.55077314e+04, 2.55359181e+04,
#        2.55744280e+04, 2.55762233e+04, 2.55942664e+04, 2.55955231e+04,
#        2.55956129e+04, 2.56081802e+04, 2.56351102e+04, 2.56466901e+04,
#        2.56844819e+04, 2.56847512e+04, 2.57123095e+04, 2.57191318e+04,
#        2.57757745e+04, 2.58113221e+04, 2.58728123e+04, 2.58913940e+04,
#        2.59446256e+04, 2.59458823e+04, 2.59674263e+04, 2.59701193e+04,
#        2.59736202e+04, 2.60122198e+04, 2.60253258e+04, 2.60358285e+04,
#        2.60931893e+04, 2.61095269e+04, 2.61133868e+04, 2.61194012e+04,
#        2.61569237e+04, 2.61632971e+04, 2.62030637e+04, 2.62304425e+04,
#        2.62388806e+04, 2.62424713e+04, 2.63130278e+04, 2.63245180e+04,
#        2.63568340e+04, 2.63673367e+04, 2.63730817e+04, 2.64008196e+04,
#        2.64033331e+04, 2.64054875e+04, 2.64080009e+04, 2.64150027e+04,
#        2.64164390e+04, 2.64242487e+04, 2.64379830e+04, 2.64545001e+04,
#        2.64597963e+04, 2.64660799e+04, 2.64678753e+04, 2.64692218e+04,
#        2.65083600e+04, 2.65273906e+04, 2.65696706e+04, 2.65702092e+04,
#        2.66357389e+04, 2.66380728e+04, 2.66487550e+04, 2.66557568e+04,
#        2.67603350e+04, 2.67607838e+04, 2.67694014e+04, 2.67728125e+04,
#        2.67760441e+04, 2.67779292e+04, 2.67874445e+04, 2.68000118e+04,
#        2.68106941e+04, 2.68111429e+04, 2.68564750e+04, 2.68862776e+04,
#        2.69285576e+04, 2.69795451e+04, 2.70157211e+04, 2.70428306e+04,
#        2.70827767e+04, 2.70828665e+04, 2.70874446e+04, 2.71198503e+04,
#        2.71395990e+04, 2.71715559e+04, 2.71769419e+04, 2.72480371e+04,
#        2.72568342e+04, 2.72706583e+04, 2.73009994e+04, 2.73068342e+04,
#        2.73082705e+04, 2.74299043e+04, 2.74953442e+04, 2.74968702e+04,
#        2.75143747e+04, 2.75308020e+04, 2.75632975e+04, 2.75657212e+04,
#        2.75735309e+04, 2.75779295e+04, 2.75922921e+04, 2.76420229e+04,
#        2.76512688e+04, 2.76847518e+04, 2.77016279e+04, 2.77418434e+04,
#        2.77434592e+04, 2.77522563e+04, 2.77605148e+04, 2.77623999e+04,
#        2.77695812e+04, 2.77834951e+04, 2.78088093e+04, 2.78359188e+04,
#        2.78441773e+04, 2.79574628e+04, 2.80056675e+04, 2.80509996e+04,
#        2.80582707e+04, 2.80594377e+04, 2.80661702e+04, 2.81097070e+04,
#        2.81245185e+04, 2.83305329e+04, 2.83464216e+04, 2.83512690e+04,
#        2.83811613e+04, 2.84218256e+04, 2.84480375e+04, 2.84852009e+04,
#        2.85513589e+04, 2.85515384e+04, 2.85655420e+04, 2.85964217e+04,
#        2.86079118e+04, 2.86263140e+04, 2.86934594e+04, 2.87001919e+04,
#        2.87024361e+04, 2.87106049e+04, 2.87126695e+04, 2.87413051e+04,
#        2.87546803e+04, 2.87678760e+04, 2.87757755e+04, 2.88253266e+04,
#        2.88278401e+04, 2.88365475e+04, 2.88451651e+04, 2.88676965e+04,
#        2.88775708e+04, 2.88810717e+04, 2.88852907e+04, 2.88930107e+04,
#        2.89031543e+04, 2.89255960e+04, 2.89378042e+04, 2.89384326e+04,
#        2.89529748e+04, 2.89907665e+04, 2.90097971e+04, 2.90245188e+04,
#        2.91007307e+04, 2.91261346e+04, 2.91635673e+04, 2.91667989e+04,
#        2.92578223e+04, 2.92641059e+04, 2.93275710e+04, 2.93809821e+04,
#        2.93887918e+04, 2.94407667e+04, 2.95081814e+04, 2.95083610e+04,
#        2.95400486e+04, 2.95432802e+04, 2.95643753e+04, 2.95977685e+04,
#        2.96540522e+04, 2.96908565e+04, 2.97395998e+04, 2.97594382e+04,
#        2.97667093e+04, 2.97684149e+04, 2.98283790e+04, 2.98416645e+04,
#        2.98446268e+04, 2.98460630e+04, 2.98526160e+04, 2.98671582e+04,
#        2.98852013e+04, 2.99027058e+04, 2.99047704e+04, 2.99258656e+04,
#        2.99468710e+04, 2.99575532e+04, 2.99895101e+04, 3.00290972e+04,
#        3.00359195e+04, 3.00650039e+04, 3.01181457e+04, 3.01283791e+04,
#        3.01595281e+04, 3.01823288e+04, 3.01864581e+04, 3.02076430e+04,
#        3.02592589e+04, 3.02604258e+04, 3.02990255e+04, 3.03001924e+04,
#        3.03125802e+04, 3.03621314e+04, 3.03639267e+04, 3.04302643e+04,
#        3.04741602e+04, 3.04786485e+04, 3.05592589e+04, 3.05769430e+04,
#        3.05847527e+04, 3.07152734e+04, 3.07473200e+04, 3.07614134e+04,
#        3.07778407e+04, 3.07817007e+04, 3.07829574e+04, 3.07975894e+04,
#        3.08516289e+04, 3.08528856e+04, 3.08592590e+04, 3.08620418e+04,
#        3.09336756e+04, 3.09344835e+04, 3.09597079e+04, 3.09611442e+04,
#        3.10031550e+04, 3.10811622e+04, 3.10817905e+04, 3.11073740e+04,
#        3.11105158e+04, 3.11246990e+04, 3.11411263e+04, 3.11525266e+04,
#        3.11716469e+04, 3.11766739e+04, 3.11903184e+04, 3.12288283e+04,
#        3.12349324e+04, 3.13099773e+04, 3.13300850e+04, 3.13622215e+04,
#        3.13953454e+04, 3.14448966e+04, 3.14764944e+04, 3.14781102e+04,
#        3.14797260e+04, 3.15103364e+04, 3.15468715e+04, 3.15626704e+04,
#        3.15979487e+04, 3.16020779e+04, 3.16080923e+04, 3.16370869e+04,
#        3.16422036e+04, 3.16424729e+04, 3.16485771e+04, 3.16720959e+04,
#        3.16979487e+04, 3.17090798e+04, 3.17180564e+04, 3.17808931e+04,
#        3.17881642e+04, 3.18173383e+04, 3.18507315e+04, 3.18602468e+04,
#        3.18646453e+04, 3.18664407e+04, 3.18711983e+04, 3.18985771e+04,
#        3.19155430e+04, 3.19254174e+04, 3.19369075e+04, 3.19438195e+04,
#        3.19676974e+04, 3.19850224e+04, 3.20292773e+04, 3.20442684e+04,
#        3.20726346e+04, 3.20896903e+04, 3.21079129e+04, 3.21247890e+04,
#        3.21625808e+04, 3.22000135e+04, 3.22044121e+04, 3.22290081e+04,
#        3.22290117e+04, 3.22596221e+04, 3.22662649e+04, 3.22705737e+04,
#        3.23037873e+04, 3.23143798e+04, 3.23977730e+04, 3.24202146e+04,
#        3.24238053e+04, 3.24529795e+04, 3.25172524e+04, 3.25201249e+04,
#        3.25219202e+04, 3.25224588e+04, 3.26262291e+04, 3.26405917e+04,
#        3.27309867e+04, 3.27649185e+04, 3.27817049e+04, 3.27892453e+04,
#        3.28168934e+04, 3.28405020e+04, 3.28405918e+04, 3.28411304e+04,
#        3.29178809e+04, 3.29469652e+04, 3.29908611e+04, 3.30956188e+04,
#        3.30957086e+04, 3.31250622e+04, 3.31509150e+04, 3.31582759e+04,
#        3.31853854e+04, 3.31928361e+04, 3.32183298e+04, 3.32214716e+04,
#        3.32590838e+04, 3.33526207e+04, 3.33561216e+04, 3.33624052e+04,
#        3.33773963e+04, 3.33791916e+04, 3.33796404e+04, 3.35269475e+04,
#        3.35269511e+04, 3.35333245e+04, 3.35416728e+04, 3.35908649e+04,
#        3.36277590e+04, 3.36296441e+04, 3.36348506e+04, 3.36766818e+04,
#        3.37203982e+04, 3.37287465e+04, 3.38045993e+04, 3.38232707e+04,
#        3.38861971e+04, 3.39186029e+04, 3.39220140e+04, 3.39285670e+04,
#        3.39635760e+04, 3.39936478e+04, 3.39948148e+04, 3.41120500e+04,
#        3.41202187e+04, 3.41826066e+04, 3.42042403e+04, 3.42142044e+04,
#        3.42337735e+04, 3.42624091e+04, 3.42625886e+04, 3.43167179e+04,
#        3.43698598e+04, 3.43744379e+04, 3.43942763e+04, 3.43980465e+04,
#        3.44201291e+04, 3.44460716e+04, 3.44590878e+04, 3.44737198e+04,
#        3.45199496e+04, 3.45309909e+04, 3.45709370e+04, 3.46273105e+04,
#        3.46548688e+04, 3.47065744e+04, 3.47606139e+04, 3.47646534e+04,
#        3.47684236e+04, 3.47732710e+04, 3.47913141e+04, 3.47921220e+04,
#        3.47996624e+04, 3.48104344e+04, 3.49077414e+04, 3.49124093e+04,
#        3.49387109e+04, 3.49626786e+04, 3.49765027e+04, 3.50168079e+04,
#        3.50320682e+04, 3.50331454e+04, 3.50402370e+04, 3.50425709e+04,
#        3.50440969e+04, 3.50465206e+04, 3.50782980e+04, 3.50805422e+04,
#        3.50834147e+04, 3.50925709e+04, 3.51119605e+04, 3.51148331e+04,
#        3.51395189e+04, 3.51660898e+04, 3.51923914e+04, 3.51944561e+04,
#        3.52369157e+04, 3.52444561e+04, 3.52564848e+04, 3.52843125e+04,
#        3.52947254e+04, 3.53025351e+04, 3.53050486e+04, 3.53180647e+04,
#        3.54390701e+04, 3.54394292e+04, 3.54397883e+04, 3.54434687e+04,
#        3.54785675e+04, 3.54941869e+04, 3.55036123e+04, 3.55156411e+04,
#        3.55235405e+04, 3.55395190e+04, 3.55514580e+04, 3.55660899e+04,
#        3.56499320e+04, 3.56685137e+04, 3.57416735e+04, 3.57528045e+04,
#        3.57663593e+04, 3.57901474e+04, 3.58131277e+04, 3.58258746e+04,
#        3.58384419e+04, 3.58442767e+04, 3.59911349e+04, 3.59916735e+04,
#        3.60133073e+04, 3.60147436e+04, 3.60277597e+04, 3.60298244e+04,
#        3.60327867e+04, 3.60431996e+04, 3.60647436e+04, 3.61019070e+04,
#        3.62142050e+04, 3.62468801e+04, 3.62568442e+04, 3.62571135e+04,
#        3.62814402e+04, 3.62890704e+04, 3.62914941e+04, 3.63201297e+04,
#        3.63210273e+04, 3.63572930e+04, 3.63661799e+04, 3.63701297e+04,
#        3.63872751e+04, 3.63999322e+04, 3.64226432e+04, 3.64733613e+04,
#        3.64814403e+04, 3.65280292e+04, 3.65329663e+04, 3.65635768e+04,
#        3.65651028e+04, 3.65704888e+04, 3.65751567e+04, 3.65759646e+04,
#        3.66080113e+04, 3.66572034e+04, 3.66773111e+04, 3.67674368e+04,
#        3.68373650e+04, 3.68753363e+04, 3.68870060e+04, 3.68949054e+04,
#        3.68954440e+04, 3.69160006e+04, 3.69747977e+04, 3.69796451e+04,
#        3.69947259e+04, 3.70116918e+04, 3.70126792e+04, 3.70261442e+04,
#        3.70653723e+04, 3.70998426e+04, 3.71039719e+04, 3.71649235e+04,
#        3.71937385e+04, 3.72079217e+04, 3.72711174e+04, 3.73113328e+04,
#        3.73177960e+04, 3.73211174e+04, 3.73351210e+04, 3.73404172e+04,
#        3.73597170e+04, 3.73614226e+04, 3.73695016e+04, 3.73722844e+04,
#        3.73745285e+04, 3.73773113e+04, 3.73778499e+04, 3.73984065e+04,
#        3.74151031e+04, 3.74235411e+04, 3.74370061e+04, 3.74379038e+04,
#        3.74411354e+04, 3.74829666e+04, 3.74984963e+04, 3.75413150e+04,
#        3.75710277e+04, 3.76050493e+04, 3.76085502e+04, 3.76501121e+04,
#        3.76556776e+04, 3.76791965e+04, 3.76873653e+04, 3.76995735e+04,
#        3.77623204e+04, 3.77835053e+04, 3.78113330e+04, 3.78243491e+04,
#        3.78893402e+04, 3.79057675e+04, 3.79392504e+04, 3.79963420e+04,
#        3.80013690e+04, 3.80028950e+04, 3.80322487e+04, 3.80822487e+04,
#        3.81326078e+04, 3.81417640e+04, 3.81721051e+04, 3.81926616e+04,
#        3.82528951e+04, 3.82783888e+04, 3.82790172e+04, 3.82794660e+04,
#        3.82916742e+04, 3.83001123e+04, 3.83326078e+04, 3.83337748e+04,
#        3.83472398e+04, 3.83988556e+04, 3.84095378e+04, 3.84568449e+04,
#        3.84782991e+04, 3.84798251e+04, 3.84967910e+04, 3.85073835e+04,
#        3.85575630e+04, 3.85642057e+04, 3.85672578e+04, 3.85917641e+04,
#        3.85959831e+04, 3.86127695e+04, 3.86609742e+04, 3.86614230e+04,
#        3.87481376e+04, 3.87485864e+04, 3.87696816e+04, 3.87742597e+04,
#        3.88082812e+04, 3.88228234e+04, 3.88400586e+04, 3.89587301e+04,
#        3.90070246e+04, 3.90429312e+04, 3.90622310e+04, 3.91304537e+04,
#        3.91939187e+04, 3.92100767e+04, 3.92419438e+04, 3.92494842e+04,
#        3.92673478e+04, 3.92840444e+04, 3.93176171e+04, 3.93272221e+04,
#        3.93469708e+04, 3.93691432e+04, 3.93882635e+04, 3.94333263e+04,
#        3.94407769e+04, 3.94618721e+04, 3.94624107e+04, 3.95437393e+04,
#        3.95528057e+04, 3.95605256e+04, 3.96202204e+04, 3.96272222e+04,
#        3.96329673e+04, 3.96407770e+04, 3.96599871e+04, 3.97408668e+04,
#        3.97555885e+04, 3.97743497e+04, 3.98310823e+04, 3.98427519e+04,
#        3.99341344e+04, 3.99358399e+04, 3.99432906e+04, 3.99762349e+04,
#        3.99967017e+04, 4.00612439e+04, 4.01230931e+04, 4.01941883e+04,
#        4.02160914e+04, 4.02344935e+04, 4.02838652e+04, 4.03148347e+04,
#        4.03759657e+04, 4.03786587e+04, 4.03848526e+04, 4.04076534e+04,
#        4.04534343e+04, 4.04826085e+04, 4.05016390e+04, 4.06158222e+04,
#        4.06307234e+04, 4.07110646e+04, 4.07143859e+04, 4.07825188e+04,
#        4.07912262e+04, 4.07966122e+04, 4.07987666e+04, 4.08018186e+04,
#        4.08186050e+04, 4.08244398e+04, 4.08484075e+04, 4.08597181e+04,
#        4.08774022e+04, 4.08810826e+04, 4.09330575e+04, 4.09542424e+04,
#        4.09676176e+04, 4.09855709e+04, 4.09863788e+04, 4.10107056e+04,
#        4.10192334e+04, 4.10449067e+04, 4.11032550e+04, 4.11192335e+04,
#        4.11248888e+04, 4.11281204e+04, 4.11304543e+04, 4.12018188e+04,
#        4.12269534e+04, 4.12331473e+04, 4.12673484e+04, 4.13527165e+04,
#        4.13535244e+04, 4.13831474e+04, 4.13949966e+04, 4.14183359e+04,
#        4.14663610e+04, 4.14677973e+04, 4.14848530e+04, 4.14881743e+04,
#        4.14932910e+04, 4.14987668e+04, 4.15140271e+04, 4.15196824e+04,
#        4.15423934e+04, 4.15512803e+04, 4.15600774e+04, 4.16088207e+04,
#        4.17249787e+04, 4.17364688e+04, 4.17802750e+04, 4.17904186e+04,
#        4.18009213e+04, 4.18014599e+04, 4.18128602e+04, 4.18571152e+04,
#        4.18620524e+04, 4.18986772e+04, 4.18987669e+04, 4.19299159e+04,
#        4.19556790e+04, 4.19965228e+04, 4.19984079e+04, 4.20259662e+04,
#        4.20718370e+04, 4.21952661e+04, 4.22291979e+04, 4.22408676e+04,
#        4.22590004e+04, 4.22740812e+04, 4.22743505e+04, 4.22881746e+04,
#        4.22891620e+04, 4.22984080e+04, 4.23099879e+04, 4.23410471e+04,
#        4.23573847e+04, 4.23699520e+04, 4.23773128e+04, 4.23818909e+04,
#        4.24669897e+04, 4.25511011e+04, 4.25538838e+04, 4.25555894e+04,
#        4.25987671e+04, 4.26043327e+04, 4.26833273e+04, 4.27230939e+04,
#        4.27406882e+04, 4.27444584e+04, 4.27655535e+04, 4.27873668e+04,
#        4.27897008e+04, 4.28383543e+04, 4.28448175e+04, 4.28540634e+04,
#        4.28912268e+04, 4.29076541e+04, 4.29148355e+04, 4.29503830e+04,
#        4.30193238e+04, 4.30410473e+04, 4.30477798e+04, 4.30553202e+04,
#        4.30625016e+04, 4.30639378e+04, 4.30654639e+04, 4.30953562e+04,
#        4.31269540e+04, 4.31589109e+04, 4.32186057e+04, 4.32191443e+04,
#        4.32306345e+04, 4.32326093e+04, 4.32380851e+04, 4.32613347e+04,
#        4.32691444e+04, 4.33355717e+04, 4.34061282e+04, 4.34212988e+04,
#        4.34243509e+04, 4.34651049e+04, 4.34716579e+04, 4.34938302e+04,
#        4.35126812e+04, 4.35173491e+04, 4.35189649e+04, 4.35209398e+04,
#        4.36000242e+04, 4.36340457e+04, 4.36525377e+04, 4.36633994e+04,
#        4.36669003e+04, 4.36698626e+04, 4.36699524e+04, 4.37132199e+04,
#        4.37148357e+04, 4.37519991e+04, 4.37750691e+04, 4.37852127e+04,
#        4.37997549e+04, 4.37999345e+04, 4.38098986e+04, 4.38132199e+04,
#        4.38194138e+04, 4.38291086e+04, 4.38388932e+04, 4.38412271e+04,
#        4.38836867e+04, 4.39372774e+04, 4.39851230e+04, 4.40217478e+04,
#        4.41413170e+04, 4.41466132e+04, 4.42256976e+04, 4.42382649e+04,
#        4.42438305e+04, 4.42459849e+04, 4.43000244e+04, 4.43440998e+04,
#        4.44170801e+04, 4.44211196e+04, 4.44521788e+04, 4.44543332e+04,
#        4.44607964e+04, 4.45262363e+04, 4.45561286e+04, 4.45835074e+04,
#        4.45914069e+04, 4.46503836e+04, 4.46668109e+04, 4.46682471e+04,
#        4.46746206e+04, 4.46759671e+04, 4.46837768e+04, 4.46949976e+04,
#        4.47047821e+04, 4.47275829e+04, 4.47362902e+04, 4.48161825e+04,
#        4.48373675e+04, 4.48417660e+04, 4.48644770e+04, 4.48691449e+04,
#        4.48706709e+04, 4.49043334e+04, 4.49449079e+04, 4.51160031e+04,
#        4.51314430e+04, 4.51826099e+04, 4.51856620e+04, 4.51899708e+04,
#        4.52174394e+04, 4.52262365e+04, 4.52275830e+04, 4.52355723e+04,
#        4.52380857e+04, 4.52434717e+04, 4.52493963e+04, 4.52495758e+04,
#        4.52596297e+04, 4.53638488e+04, 4.53664520e+04, 4.53752491e+04,
#        4.53834179e+04, 4.54265059e+04, 4.54358416e+04, 4.54441001e+04,
#        4.54457159e+04, 4.54479601e+04, 4.54503838e+04, 4.54707608e+04,
#        4.54749799e+04, 4.54765059e+04, 4.54791091e+04, 4.55174395e+04,
#        4.55318021e+04, 4.55528973e+04, 4.55666316e+04, 4.56508327e+04,
#        4.56760571e+04, 4.56832385e+04, 4.57113354e+04, 4.57340464e+04,
#        4.57718381e+04, 4.58560392e+04, 4.58611559e+04, 4.59197735e+04,
#        4.59690554e+04, 4.60106174e+04, 4.60178885e+04, 4.60254289e+04,
#        4.60700429e+04, 4.60974217e+04, 4.61163625e+04, 4.61499352e+04,
#        4.61536156e+04, 4.61651058e+04, 4.61919460e+04, 4.62022691e+04,
#        4.62372781e+04, 4.62395223e+04, 4.63117844e+04, 4.63226462e+04,
#        4.63261471e+04, 4.63843159e+04, 4.63865600e+04, 4.63914972e+04,
#        4.64307252e+04, 4.64323410e+04, 4.64386247e+04, 4.64412279e+04,
#        4.64743518e+04, 4.64830592e+04, 4.66566678e+04, 4.66591813e+04,
#        4.66638492e+04, 4.66683375e+04, 4.66738133e+04, 4.67309048e+04,
#        4.67353034e+04, 4.67391634e+04, 4.68485889e+04, 4.68828798e+04,
#        4.69340467e+04, 4.69850342e+04, 4.69880863e+04, 4.70230055e+04,
#        4.70264166e+04, 4.70373681e+04, 4.70506536e+04, 4.70544238e+04,
#        4.70645674e+04, 4.71652856e+04, 4.71692353e+04, 4.71809948e+04,
#        4.71853036e+04, 4.71884454e+04, 4.71921258e+04, 4.71962551e+04,
#        4.72041545e+04, 4.72163628e+04, 4.72299176e+04, 4.72522695e+04,
#        4.72592713e+04, 4.73949086e+04, 4.74723772e+04, 4.74767758e+04,
#        4.75019105e+04, 4.75036160e+04, 4.75116950e+04, 4.75370092e+04,
#        4.75629518e+04, 4.76279428e+04, 4.76286610e+04, 4.76745317e+04,
#        4.76839572e+04, 4.77142983e+04, 4.77154653e+04, 4.77530775e+04,
#        4.78380865e+04, 4.78669016e+04, 4.78834187e+04, 4.78835982e+04,
#        4.78980506e+04, 4.79477813e+04, 4.79716593e+04, 4.80022697e+04,
#        4.80484995e+04, 4.81203128e+04, 4.81262374e+04, 4.81673505e+04,
#        4.81677096e+04, 4.81985893e+04, 4.82215696e+04, 4.82276737e+04,
#        4.82300076e+04, 4.82586432e+04, 4.82625929e+04, 4.82684278e+04,
#        4.82894332e+04, 4.82905104e+04, 4.83072967e+04, 4.83123236e+04,
#        4.83705822e+04, 4.83749808e+04, 4.83909592e+04, 4.83923955e+04,
#        4.83972429e+04, 4.84138497e+04, 4.84298282e+04, 4.85364709e+04,
#        4.85594512e+04, 4.85659144e+04, 4.85923058e+04, 4.86236343e+04,
#        4.86475123e+04, 4.86484099e+04, 4.86520904e+04, 4.86563992e+04,
#        4.86596308e+04, 4.86637600e+04, 4.86663633e+04, 4.87090024e+04,
#        4.87127726e+04, 4.87361119e+04, 4.88497565e+04, 4.88642089e+04,
#        4.88648373e+04, 4.88856631e+04, 4.88878175e+04, 4.88886254e+04,
#        4.89144782e+04, 4.89407799e+04, 4.89439217e+04, 4.89459863e+04,
#        4.89538858e+04, 4.90013723e+04, 4.90126829e+04, 4.90698643e+04,
#        4.90764172e+04, 4.90773149e+04, 4.90992180e+04, 4.91024496e+04,
#        4.91125932e+04, 4.91952683e+04, 4.91970636e+04, 4.91984999e+04,
#        4.92332395e+04, 4.92420367e+04, 4.92557710e+04, 4.92609774e+04,
#        4.92993976e+04, 4.93126830e+04, 4.93309954e+04, 4.93977818e+04,
#        4.94099901e+04, 4.94335987e+04, 4.94553222e+04, 4.94652863e+04,
#        4.94948195e+04, 4.94993976e+04, 4.95387154e+04, 4.95455377e+04,
#        4.95827011e+04, 4.96476921e+04, 4.97019111e+04, 4.97028088e+04,
#        4.97041553e+04, 4.97069381e+04, 4.97693259e+04, 4.97728268e+04,
#        4.97834193e+04, 4.97858430e+04, 4.98031679e+04, 4.98116957e+04,
#        4.98619651e+04, 4.98827011e+04, 4.99328807e+04, 4.99384462e+04,
#        4.99620549e+04, 5.00056814e+04, 5.00204929e+04, 5.00400621e+04,
#        5.00747120e+04, 5.01344068e+04, 5.01535271e+04, 5.01791106e+04,
#        5.01872793e+04, 5.02130424e+04, 5.02333296e+04, 5.02454481e+04,
#        5.02806366e+04, 5.04255200e+04, 5.04372794e+04, 5.04411394e+04,
#        5.04418575e+04, 5.04433835e+04, 5.04861125e+04, 5.04977821e+04,
#        5.05031681e+04, 5.05617857e+04, 5.05707624e+04, 5.05751610e+04,
#        5.06169025e+04, 5.06913190e+04, 5.06995775e+04, 5.07078361e+04,
#        5.07419474e+04, 5.07637607e+04, 5.08022706e+04, 5.08072975e+04,
#        5.08089133e+04, 5.08258792e+04, 5.08375488e+04, 5.08693262e+04,
#        5.09052329e+04, 5.09228271e+04, 5.09284824e+04, 5.09537966e+04,
#        5.09575668e+04, 5.09593622e+04, 5.09611575e+04, 5.09665435e+04,
#        5.09762383e+04, 5.09974232e+04, 5.09983209e+04, 5.10052329e+04,
#        5.10382670e+04, 5.10800983e+04, 5.10908703e+04, 5.10994879e+04,
#        5.11159152e+04, 5.11372796e+04, 5.11905112e+04, 5.12724682e+04,
#        5.12726477e+04, 5.12762384e+04, 5.13029888e+04, 5.13353048e+04,
#        5.13448201e+04, 5.13642097e+04, 5.13706729e+04, 5.13892546e+04,
#        5.14626837e+04, 5.14664539e+04, 5.14764180e+04, 5.15052331e+04,
#        5.15081056e+04, 5.15137609e+04, 5.15617860e+04, 5.15707627e+04,
#        5.15713013e+04, 5.15809063e+04, 5.16125940e+04, 5.16141200e+04,
#        5.16247125e+04, 5.16663642e+04, 5.16693265e+04, 5.17214809e+04,
#        5.17368310e+04, 5.17800985e+04, 5.17888059e+04, 5.17921272e+04,
#        5.18230070e+04, 5.18445509e+04, 5.18634917e+04, 5.19434738e+04,
#        5.19453589e+04, 5.19545151e+04, 5.20823428e+04, 5.20893446e+04,
#        5.21186085e+04, 5.21260591e+04, 5.21554128e+04, 5.22163643e+04,
#        5.22284828e+04, 5.22285726e+04, 5.22518222e+04, 5.22619658e+04,
#        5.22620556e+04, 5.24203141e+04, 5.24250718e+04, 5.24734560e+04,
#        5.25001167e+04, 5.25328815e+04, 5.25510144e+04, 5.25581059e+04,
#        5.25681598e+04, 5.25713016e+04, 5.25822531e+04, 5.25827020e+04,
#        5.26183393e+04, 5.26251616e+04, 5.26330611e+04, 5.26687882e+04,
#        5.26969749e+04, 5.27061311e+04, 5.27125943e+04, 5.27200449e+04,
#        5.27748026e+04, 5.27811760e+04, 5.27990396e+04, 5.28268672e+04,
#        5.28469750e+04, 5.28824328e+04, 5.28885369e+04, 5.29825226e+04,
#        5.30240845e+04, 5.31187883e+04, 5.32672623e+04, 5.32748027e+04,
#        5.33037974e+04, 5.33210325e+04, 5.33343180e+04, 5.33357543e+04,
#        5.33388961e+04, 5.33475137e+04, 5.33486807e+04, 5.33556825e+04,
#        5.33622354e+04, 5.33853952e+04, 5.33868315e+04, 5.34151977e+04,
#        5.34451798e+04, 5.34457184e+04, 5.34651080e+04, 5.35449105e+04,
#        5.35451798e+04, 5.35671727e+04, 5.36172624e+04, 5.36215712e+04,
#        5.36279447e+04, 5.36421278e+04, 5.36530793e+04, 5.36966161e+04,
#        5.37054133e+04, 5.37539770e+04, 5.37541566e+04, 5.37657365e+04,
#        5.37730076e+04, 5.38186090e+04, 5.38384474e+04, 5.38386270e+04,
#        5.38389860e+04, 5.38599914e+04, 5.38827921e+04, 5.38888065e+04,
#        5.38978729e+04, 5.39272266e+04, 5.39537078e+04, 5.39538873e+04,
#        5.39640309e+04, 5.39707634e+04, 5.39807275e+04, 5.39834205e+04,
#        5.40146593e+04, 5.40176216e+04, 5.40450902e+04, 5.40475139e+04,
#        5.40540669e+04, 5.40570292e+04, 5.40898838e+04, 5.40912303e+04,
#        5.41235463e+04, 5.41492195e+04, 5.41581064e+04, 5.41908712e+04,
#        5.42545158e+04, 5.42888964e+04, 5.42929359e+04, 5.43205840e+04,
#        5.43282142e+04, 5.43369215e+04, 5.43616074e+04, 5.43689682e+04,
#        5.43827025e+04, 5.44031693e+04, 5.44318946e+04, 5.45335105e+04,
#        5.45423076e+04, 5.45800096e+04, 5.46051443e+04, 5.46053238e+04,
#        5.46127744e+04, 5.46491299e+04, 5.46662753e+04, 5.46697762e+04,
#        5.46928463e+04, 5.46996685e+04, 5.47199558e+04, 5.47200455e+04,
#        5.47484118e+04, 5.47572987e+04, 5.47926668e+04, 5.48063113e+04,
#        5.48221102e+04, 5.48326129e+04, 5.48450905e+04, 5.48751623e+04,
#        5.48874603e+04, 5.49184298e+04, 5.49447314e+04, 5.49985016e+04,
#        5.50165447e+04, 5.50691480e+04, 5.50989505e+04, 5.51203150e+04,
#        5.51268679e+04, 5.51468859e+04, 5.51738159e+04, 5.52073886e+04,
#        5.52076579e+04, 5.52141211e+04, 5.52182504e+04, 5.52184299e+04,
#        5.52204048e+04, 5.52733671e+04, 5.52783042e+04, 5.52799200e+04,
#        5.53317154e+04, 5.53429362e+04, 5.53907818e+04, 5.54314461e+04,
#        5.54396149e+04, 5.54564910e+04, 5.54927567e+04, 5.55028106e+04,
#        5.55318950e+04, 5.55587352e+04, 5.55906024e+04, 5.55923079e+04,
#        5.56107101e+04, 5.56163654e+04, 5.56441930e+04, 5.56739956e+04,
#        5.56801895e+04, 5.56981428e+04, 5.57452703e+04, 5.57717514e+04,
#        5.58045163e+04, 5.58141213e+04, 5.58257909e+04, 5.58756114e+04,
#        5.58874606e+04, 5.58994894e+04, 5.59154678e+04, 5.59251626e+04,
#        5.60422183e+04, 5.60537982e+04, 5.60712129e+04, 5.60928467e+04,
#        5.60963476e+04, 5.61044266e+04, 5.61140316e+04, 5.61371914e+04,
#        5.61400639e+04, 5.61679814e+04, 5.61836905e+04, 5.62004769e+04,
#        5.62222004e+04, 5.62916798e+04, 5.63225595e+04, 5.63445523e+04,
#        5.63581969e+04, 5.64388073e+04, 5.64499384e+04, 5.64540676e+04,
#        5.64643010e+04, 5.64876403e+04, 5.64926673e+04, 5.64974249e+04,
#        5.65118773e+04, 5.65121466e+04, 5.65125057e+04, 5.65362041e+04,
#        5.65510156e+04, 5.65751628e+04, 5.65772274e+04, 5.65827032e+04,
#        5.66127750e+04, 5.66139420e+04, 5.67436548e+04, 5.68378200e+04,
#        5.68794717e+04, 5.68798308e+04, 5.69180714e+04, 5.69195076e+04,
#        5.69248039e+04, 5.69423981e+04, 5.69581073e+04, 5.69726495e+04,
#        5.69868326e+04, 5.70071199e+04, 5.70072994e+04, 5.70106208e+04,
#        5.71252527e+04, 5.71350373e+04, 5.72230984e+04, 5.72654682e+04,
#        5.72936550e+04, 5.73100822e+04, 5.73565814e+04, 5.73608004e+04,
#        5.73632241e+04, 5.73672636e+04, 5.73727394e+04, 5.73732780e+04,
#        5.73902439e+04, 5.73924880e+04, 5.74265993e+04, 5.74301002e+04,
#        5.74324342e+04, 5.74399746e+04, 5.74976047e+04, 5.75090051e+04,
#        5.75247143e+04, 5.75485024e+04, 5.76146604e+04, 5.76297412e+04,
#        5.76783947e+04, 5.77169046e+04, 5.77183409e+04, 5.77490411e+04,
#        5.77617880e+04, 5.77783948e+04, 5.77885384e+04, 5.78144810e+04,
#        5.78320752e+04, 5.78811776e+04, 5.79608903e+04, 5.79715726e+04,
# ...
#        3597, 3598, 3599, 3600, 3601, 3602, 3603, 3604, 3605, 3606, 3607,
#        3608, 3609, 3610, 3611, 3612, 3613, 3614, 3615, 3616, 3617, 3618,
#        3619, 3620, 3621, 3622, 3623, 3624, 3625, 3626, 3627, 3628, 3629,
#        3630, 3631, 3632, 3633, 3634, 3635, 3636, 3637, 3638, 3639, 3640,
#        3641, 3642, 3643, 3644, 3645, 3646, 3647, 3648, 3649, 3650, 3651,
#        3652, 3653, 3654, 3655, 3656, 3657, 3658, 3659, 3660, 3661, 3662,
#        3663, 3664, 3665, 3666, 3667, 3668, 3669, 3670, 3671, 3672, 3673,
#        3674, 3675, 3676, 3677, 3678, 3679, 3680, 3681, 3682, 3683, 3684,
#        3685, 3686, 3687, 3688, 3689, 3690, 3691, 3692, 3693, 3694, 3695,
#        3696, 3697, 3698, 3699, 3700, 3701, 3702, 3703, 3704, 3705, 3706,
#        3707, 3708, 3709, 3710, 3711, 3712, 3713, 3714, 3715, 3716, 3717,
#        3718, 3719, 3720, 3721, 3722, 3723, 3724, 3725, 3726, 3727, 3728,
#        3729, 3730, 3731, 3732, 3733, 3734, 3735, 3736, 3737, 3738, 3739,
#        3740, 3741, 3742, 3743, 3744, 3745, 3746, 3747, 3748, 3749, 3750,
#        3751, 3752, 3753, 3754, 3755, 3756, 3757, 3758, 3759, 3760, 3761,
#        3762, 3763, 3764, 3765, 3766, 3767, 3768, 3769, 3770, 3771, 3772,
#        3773, 3774, 3775, 3776, 3777, 3778, 3779, 3780, 3781, 3782, 3783,
#        3784, 3785, 3786, 3787, 3788, 3789, 3790, 3791, 3792, 3793, 3794,
#        3795, 3796, 3797, 3798, 3799, 3800, 3801, 3802, 3803, 3804, 3805,
#        3806, 3807, 3808, 3809, 3810, 3811, 3812, 3813, 3814, 3815, 3816,
#        3817, 3818, 3819, 3820, 3821, 3822, 3823, 3824, 3825, 3826, 3827,
#        3828, 3829, 3830, 3831, 3832, 3833, 3834, 3835, 3836, 3837, 3838,
#        3839, 3840, 3841, 3842, 3843, 3844, 3845, 3846, 3847, 3848, 3849,
#        3850, 3851, 3852, 3853, 3854, 3855, 3856, 3857, 3858, 3859, 3860,
#        3861, 3862, 3863, 3864, 3865, 3866, 3867, 3868, 3869, 3870, 3871,
#        3872, 3873, 3874, 3875, 3876, 3877, 3878, 3879, 3880, 3881, 3882,
#        3883, 3884, 3885, 3886, 3887, 3888, 3889, 3890, 3891, 3892, 3893,
#        3894, 3895, 3896, 3897, 3898, 3899, 3900, 3901, 3902, 3903, 3904,
#        3905, 3906, 3907, 3908, 3909, 3910, 3911, 3912, 3913, 3914, 3915,
#        3916, 3917, 3918, 3919, 3920, 3921, 3922, 3923, 3924, 3925, 3926,
#        3927, 3928, 3929, 3930, 3931, 3932, 3933, 3934, 3935, 3936, 3937,
#        3938, 3939, 3940, 3941, 3942, 3943, 3944, 3945, 3946, 3947, 3948,
#        3949, 3950, 3951, 3952, 3953, 3954, 3955, 3956, 3957, 3958, 3959,
#        3960, 3961, 3962, 3963, 3964, 3965, 3966, 3967, 3968, 3969, 3970,
#        3971, 3972, 3973, 3974, 3975, 3976, 3977, 3978, 3979, 3980, 3981,
#        3982, 3983, 3984, 3985, 3986, 3987, 3988, 3989, 3990, 3991, 3992,
#        3993, 3994, 3995, 3996, 3997, 3998, 3999, 4000, 4001, 4002, 4003,
#        4004, 4005, 4006, 4007, 4008, 4009, 4010, 4011, 4012, 4013, 4014,
#        4015, 4016, 4017, 4018, 4019, 4020, 4021, 4022, 4023, 4024, 4025,
#        4026, 4027, 4028, 4029, 4030, 4031, 4032, 4033, 4034, 4035, 4036,
#        4037, 4038, 4039, 4040, 4041, 4042, 4043, 4044, 4045, 4046, 4047,
#        4048, 4049, 4050, 4051, 4052, 4053, 4054, 4055, 4056, 4057, 4058,
#        4059, 4060, 4061, 4062, 4063, 4064, 4065, 4066, 4067, 4068, 4069,
#        4070, 4071, 4072, 4073, 4074, 4075, 4076, 4077, 4078, 4079, 4080,
#        4081, 4082, 4083, 4084, 4085, 4086, 4087, 4088, 4089, 4090, 4091,
#        4092, 4093, 4094, 4095, 4096, 4097, 4098, 4099, 4100, 4101, 4102,
#        4103, 4104, 4105, 4106, 4107, 4108, 4109, 4110, 4111, 4112, 4113,
#        4114, 4115, 4116, 4117, 4118, 4119, 4120, 4121, 4122, 4123, 4124,
#        4125, 4126, 4127, 4128, 4129, 4130, 4131, 4132, 4133, 4134, 4135,
#        4136, 4137, 4138, 4139, 4140, 4141, 4142, 4143, 4144, 4145, 4146,
#        4147, 4148, 4149, 4150, 4151, 4152, 4153, 4154, 4155, 4156, 4157,
#        4158, 4159, 4160, 4161, 4162, 4163, 4164, 4165, 4166, 4167, 4168,
#        4169, 4170, 4171, 4172, 4173, 4174, 4175, 4176, 4177, 4178, 4179,
#        4180, 4181, 4182, 4183, 4184, 4185, 4186, 4187, 4188, 4189, 4190,
#        4191, 4192, 4193, 4194, 4195, 4196, 4197, 4198, 4199, 4200, 4201,
#        4202, 4203, 4204, 4205, 4206, 4207, 4208, 4209, 4210, 4211, 4212,
#        4213, 4214, 4215, 4216, 4217, 4218, 4219, 4220, 4221, 4222, 4223,
#        4224, 4225, 4226, 4227, 4228, 4229, 4230, 4231, 4232, 4233, 4234,
#        4235, 4236, 4237, 4238, 4239, 4240, 4241, 4242, 4243, 4244, 4245,
#        4246, 4247, 4248, 4249, 4250, 4251, 4252, 4253, 4254, 4255, 4256,
#        4257, 4258, 4259, 4260, 4261, 4262, 4263, 4264, 4265, 4266, 4267,
#        4268, 4269, 4270, 4271, 4272, 4273, 4274, 4275, 4276, 4277, 4278,
#        4279, 4280, 4281, 4282, 4283, 4284, 4285, 4286, 4287, 4288, 4289,
#        4290, 4291, 4292, 4293, 4294, 4295, 4296, 4297, 4298, 4299, 4300,
#        4301, 4302, 4303, 4304, 4305, 4306, 4307, 4308, 4309, 4310, 4311,
#        4312, 4313, 4314, 4315, 4316, 4317, 4318, 4319, 4320, 4321, 4322,
#        4323, 4324, 4325, 4326, 4327, 4328, 4329, 4330, 4331, 4332, 4333,
#        4334, 4335, 4336, 4337, 4338, 4339, 4340, 4341, 4342, 4343, 4344,
#        4345, 4346, 4347, 4348, 4349, 4350, 4351, 4352, 4353, 4354, 4355,
#        4356, 4357, 4358, 4359, 4360, 4361, 4362, 4363, 4364, 4365, 4366,
#        4367, 4368, 4369, 4370, 4371, 4372, 4373, 4374, 4375, 4376, 4377,
#        4378, 4379, 4380, 4381, 4382, 4383, 4384, 4385, 4386, 4387, 4388,
#        4389, 4390, 4391, 4392, 4393, 4394, 4395, 4396, 4397, 4398, 4399,
#        4400, 4401, 4402, 4403, 4404, 4405, 4406, 4407, 4408, 4409, 4410,
#        4411, 4412, 4413, 4414, 4415, 4416, 4417, 4418, 4419, 4420, 4421,
#        4422, 4423, 4424, 4425, 4426, 4427, 4428, 4429, 4430, 4431, 4432,
#        4433, 4434, 4435, 4436, 4437, 4438, 4439, 4440, 4441, 4442, 4443,
#        4444, 4445, 4446, 4447, 4448, 4449, 4450, 4451, 4452, 4453, 4454,
#        4455, 4456, 4457, 4458, 4459, 4460, 4461, 4462, 4463, 4464, 4465,
#        4466, 4467, 4468, 4469, 4470, 4471, 4472, 4473, 4474, 4475, 4476,
#        4477, 4478, 4479, 4480, 4481, 4482, 4483, 4484, 4485, 4486, 4487,
#        4488, 4489, 4490, 4491, 4492, 4493, 4494, 4495, 4496, 4497, 4498,
#        4499, 4500, 4501, 4502, 4503, 4504, 4505, 4506, 4507, 4508, 4509,
#        4510, 4511, 4512, 4513, 4514, 4515, 4516, 4517, 4518, 4519, 4520,
#        4521, 4522, 4523, 4524, 4525, 4526, 4527, 4528, 4529, 4530, 4531,
#        4532, 4533, 4534, 4535, 4536, 4537, 4538, 4539, 4540, 4541, 4542,
#        4543, 4544, 4545, 4546, 4547, 4548, 4549, 4550, 4551, 4552, 4553,
#        4554, 4555, 4556, 4557, 4558, 4559, 4560, 4561, 4562, 4563, 4564,
#        4565, 4566, 4567, 4568, 4569, 4570, 4571, 4572, 4573, 4574, 4575,
#        4576, 4577, 4578, 4579, 4580, 4581, 4582, 4583, 4584, 4585, 4586,
#        4587, 4588, 4589, 4590, 4591, 4592, 4593, 4594, 4595, 4596, 4597,
#        4598, 4599, 4600, 4601, 4602, 4603, 4604, 4605, 4606, 4607, 4608,
#        4609, 4610, 4611, 4612, 4613, 4614, 4615, 4616, 4617, 4618, 4619,
#        4620, 4621, 4622, 4623, 4624, 4625, 4626, 4627, 4628, 4629, 4630,
#        4631, 4632, 4633, 4634, 4635, 4636, 4637, 4638, 4639, 4640, 4641,
#        4642, 4643, 4644, 4645, 4646, 4647, 4648, 4649, 4650, 4651, 4652,
#        4653, 4654, 4655, 4656, 4657, 4658, 4659, 4660, 4661, 4662, 4663,
#        4664, 4665, 4666, 4667, 4668, 4669, 4670, 4671, 4672, 4673, 4674,
#        4675, 4676, 4677, 4678, 4679, 4680, 4681, 4682, 4683, 4684, 4685,
#        4686, 4687, 4688, 4689, 4690, 4691, 4692, 4693, 4694, 4695, 4696,
#        4697, 4698, 4699, 4700, 4701, 4702, 4703, 4704, 4705, 4706, 4707,
#        4708, 4709, 4710, 4711, 4712, 4713, 4714, 4715, 4716, 4717, 4718,
#        4719, 4720, 4721, 4722, 4723, 4724, 4725, 4726, 4727, 4728, 4729,
#        4730, 4731, 4732, 4733, 4734, 4735, 4736, 4737, 4738, 4739, 4740,
#        4741, 4742, 4743, 4744, 4745, 4746, 4747, 4748, 4749, 4750, 4751,
#        4752, 4753, 4754, 4755, 4756, 4757, 4758, 4759, 4760, 4761, 4762,
#        4763, 4764, 4765, 4766, 4767, 4768, 4769, 4770, 4771, 4772, 4773,
#        4774, 4775, 4776, 4777, 4778, 4779, 4780, 4781, 4782, 4783, 4784,
#        4785, 4786, 4787, 4788, 4789, 4790, 4791, 4792, 4793, 4794, 4795,
#        4796, 4797, 4798, 4799, 4800, 4801, 4802, 4803, 4804, 4805, 4806,
#        4807, 4808, 4809, 4810, 4811, 4812, 4813, 4814, 4815, 4816, 4817,
#        4818, 4819, 4820, 4821, 4822, 4823, 4824, 4825, 4826, 4827, 4828,
#        4829, 4830, 4831, 4832, 4833, 4834, 4835, 4836, 4837, 4838, 4839,
#        4840, 4841, 4842, 4843, 4844, 4845, 4846, 4847, 4848, 4849, 4850,
#        4851, 4852, 4853, 4854, 4855, 4856, 4857, 4858, 4859, 4860, 4861,
#        4862, 4863, 4864, 4865, 4866, 4867, 4868, 4869, 4870, 4871, 4872,
#        4873, 4874, 4875, 4876, 4877, 4878, 4879, 4880, 4881, 4882, 4883,
#        4884, 4885, 4886, 4887, 4888, 4889, 4890, 4891, 4892, 4893, 4894,
#        4895, 4896, 4897, 4898, 4899, 4900, 4901, 4902, 4903, 4904, 4905,
#        4906, 4907, 4908, 4909, 4910, 4911, 4912, 4913, 4914, 4915, 4916,
#        4917, 4918, 4919, 4920, 4921, 4922, 4923, 4924, 4925, 4926, 4927,
#        4928, 4929, 4930, 4931, 4932, 4933, 4934, 4935, 4936, 4937, 4938,
#        4939, 4940, 4941, 4942, 4943, 4944, 4945, 4946, 4947, 4948, 4949,
#        4950, 4951, 4952, 4953, 4954, 4955, 4956, 4957, 4958, 4959, 4960,
#        4961, 4962, 4963, 4964, 4965, 4966, 4967, 4968, 4969, 4970, 4971,
#        4972, 4973, 4974, 4975, 4976, 4977, 4978, 4979, 4980, 4981, 4982,
#        4983, 4984, 4985, 4986, 4987, 4988, 4989, 4990, 4991, 4992, 4993,
#        4994, 4995, 4996, 4997, 4998, 4999, 5000, 5001, 5002, 5003, 5004,
#        5005, 5006, 5007, 5008, 5009, 5010, 5011, 5012, 5013, 5014, 5015,
#        5016, 5017, 5018, 5019, 5020, 5021, 5022, 5023, 5024, 5025, 5026,
#        5027, 5028, 5029, 5030, 5031, 5032, 5033, 5034, 5035, 5036, 5037,
#        5038, 5039, 5040, 5041, 5042, 5043, 5044, 5045, 5046, 5047, 5048,
#        5049, 5050, 5051, 5052, 5053, 5054, 5055, 5056, 5057, 5058, 5059,
#        5060, 5061, 5062, 5063, 5064, 5065, 5066, 5067, 5068, 5069, 5070,
#        5071, 5072, 5073, 5074, 5075, 5076, 5077, 5078, 5079, 5080, 5081,
#        5082, 5083, 5084, 5085, 5086, 5087, 5088, 5089, 5090, 5091, 5092,
#        5093, 5094, 5095, 5096, 5097, 5098, 5099, 5100, 5101, 5102, 5103,
#        5104, 5105, 5106, 5107, 5108, 5109, 5110, 5111, 5112, 5113, 5114,
#        5115, 5116, 5117, 5118, 5119, 5120, 5121, 5122, 5123, 5124, 5125,
#        5126, 5127, 5128, 5129, 5130, 5131, 5132, 5133, 5134, 5135, 5136,
#        5137, 5138, 5139, 5140, 5141, 5142, 5143, 5144, 5145, 5146, 5147,
#        5148, 5149, 5150, 5151, 5152, 5153, 5154, 5155, 5156, 5157, 5158,
#        5159, 5160, 5161, 5162, 5163, 5164, 5165, 5166, 5167, 5168, 5169,
#        5170, 5171, 5172, 5173, 5174, 5175, 5176, 5177, 5178, 5179, 5180,
#        5181, 5182, 5183, 5184, 5185, 5186, 5187, 5188, 5189, 5190, 5191,
#        5192, 5193, 5194, 5195, 5196, 5197, 5198, 5199, 5200, 5201, 5202,
#        5203, 5204, 5205, 5206, 5207, 5208, 5209, 5210, 5211, 5212, 5213,
#        5214, 5215, 5216, 5217, 5218, 5219, 5220, 5221, 5222, 5223, 5224,
#        5225, 5226, 5227, 5228, 5229, 5230, 5231, 5232, 5233, 5234, 5235,
#        5236, 5237, 5238, 5239, 5240, 5241, 5242, 5243, 5244, 5245, 5246,
#        5247, 5248, 5249, 5250, 5251, 5252, 5253, 5254, 5255, 5256, 5257,
#        5258, 5259, 5260, 5261, 5262, 5263, 5264, 5265, 5266, 5267, 5268,
#        5269, 5270, 5271, 5272, 5273, 5274, 5275, 5276, 5277, 5278, 5279,
#        5280, 5281, 5282, 5283, 5284, 5285, 5286, 5287, 5288, 5289, 5290,
#        5291, 5292, 5293, 5294, 5295, 5296, 5297, 5298, 5299, 5300, 5301,
#        5302, 5303, 5304, 5305, 5306, 5307, 5308, 5309, 5310, 5311, 5312,
#        5313, 5314, 5315, 5316, 5317, 5318, 5319, 5320, 5321, 5322, 5323,
#        5324, 5325, 5326, 5327, 5328, 5329, 5330, 5331, 5332, 5333, 5334,
#        5335, 5336, 5337, 5338, 5339, 5340, 5341, 5342, 5343, 5344, 5345,
#        5346, 5347, 5348, 5349, 5350, 5351, 5352, 5353, 5354, 5355, 5356,
#        5357, 5358, 5359, 5360, 5361, 5362, 5363, 5364, 5365, 5366, 5367,
#        5368, 5369, 5370, 5371, 5372, 5373, 5374, 5375, 5376, 5377, 5378,
#        5379, 5380, 5381, 5382, 5383, 5384, 5385, 5386, 5387, 5388, 5389,
#        5390, 5391, 5392, 5393, 5394, 5395, 5396, 5397, 5398, 5399, 5400,
#        5401, 5402, 5403, 5404, 5405, 5406, 5407, 5408, 5409, 5410, 5411,
#        5412, 5413, 5414, 5415, 5416, 5417, 5418, 5419, 5420, 5421, 5422,
#        5423, 5424, 5425, 5426, 5427, 5428, 5429, 5430, 5431, 5432, 5433,
#        5434, 5435, 5436, 5437, 5438, 5439, 5440, 5441, 5442, 5443, 5444,
#        5445, 5446, 5447, 5448, 5449, 5450, 5451, 5452, 5453, 5454, 5455,
#        5456, 5457, 5458, 5459, 5460, 5461, 5462, 5463, 5464, 5465, 5466,
#        5467, 5468, 5469, 5470, 5471, 5472, 5473, 5474, 5475, 5476, 5477,
#        5478, 5479, 5480, 5481, 5482, 5483, 5484, 5485, 5486, 5487, 5488,
#        5489, 5490, 5491, 5492, 5493, 5494, 5495, 5496, 5497, 5498, 5499,
#        5500, 5501, 5502, 5503, 5504, 5505, 5506, 5507, 5508, 5509, 5510,
#        5511, 5512, 5513, 5514, 5515, 5516, 5517, 5518, 5519, 5520, 5521,
#        5522, 5523, 5524, 5525, 5526, 5527, 5528, 5529, 5530, 5531, 5532,
#        5533, 5534, 5535, 5536, 5537, 5538, 5539, 5540, 5541, 5542, 5543,
#        5544, 5545, 5546, 5547, 5548, 5549, 5550, 5551, 5552, 5553, 5554,
#        5555, 5556, 5557, 5558, 5559, 5560, 5561, 5562, 5563, 5564, 5565,
#        5566, 5567, 5568, 5569, 5570, 5571, 5572, 5573, 5574, 5575, 5576,
#        5577, 5578, 5579, 5580, 5581, 5582, 5583, 5584, 5585, 5586, 5587,
#        5588, 5589, 5590, 5591, 5592, 5593, 5594, 5595, 5596, 5597, 5598,
#        5599, 5600, 5601, 5602, 5603, 5604, 5605, 5606, 5607, 5608, 5609,
#        5610, 5611, 5612, 5613, 5614, 5615, 5616, 5617, 5618, 5619, 5620,
#        5621, 5622, 5623, 5624, 5625, 5626, 5627, 5628, 5629, 5630, 5631,
#        5632, 5633, 5634, 5635, 5636, 5637, 5638, 5639, 5640, 5641, 5642,
#        5643, 5644, 5645, 5646, 5647, 5648, 5649, 5650, 5651, 5652, 5653,
#        5654, 5655, 5656, 5657, 5658, 5659, 5660, 5661, 5662, 5663, 5664,
#        5665, 5666, 5667, 5668, 5669, 5670, 5671, 5672, 5673, 5674, 5675,
#        5676, 5677, 5678, 5679, 5680, 5681, 5682, 5683, 5684, 5685, 5686,
#        5687, 5688, 5689, 5690, 5691, 5692, 5693, 5694, 5695, 5696, 5697,
#        5698, 5699, 5700, 5701, 5702, 5703, 5704, 5705, 5706, 5707, 5708,
#        5709, 5710, 5711, 5712, 5713, 5714, 5715, 5716, 5717, 5718, 5719,
#        5720, 5721, 5722, 5723, 5724, 5725, 5726, 5727, 5728, 5729, 5730,
#        5731, 5732, 5733, 5734, 5735, 5736, 5737, 5738, 5739, 5740, 5741,
#        5742, 5743, 5744, 5745, 5746, 5747, 5748, 5749, 5750, 5751, 5752,
#        5753, 5754, 5755, 5756, 5757, 5758, 5759, 5760, 5761, 5762, 5763,
#        5764, 5765, 5766, 5767, 5768, 5769, 5770, 5771, 5772, 5773, 5774,
#        5775, 5776, 5777, 5778, 5779, 5780, 5781, 5782, 5783, 5784, 5785,
#        5786, 5787, 5788, 5789, 5790, 5791, 5792, 5793, 5794, 5795, 5796,
#        5797, 5798, 5799, 5800, 5801, 5802, 5803, 5804, 5805, 5806, 5807,
#        5808, 5809, 5810, 5811, 5812, 5813, 5814, 5815, 5816, 5817, 5818,
#        5819, 5820, 5821, 5822, 5823, 5824, 5825, 5826, 5827, 5828, 5829,
#        5830, 5831, 5832, 5833, 5834, 5835, 5836, 5837, 5838, 5839, 5840,
#        5841, 5842, 5843, 5844, 5845, 5846, 5847, 5848, 5849, 5850, 5851,
#        5852, 5853, 5854, 5855, 5856, 5857, 5858, 5859, 5860, 5861, 5862,
#        5863, 5864, 5865, 5866, 5867, 5868, 5869, 5870, 5871, 5872, 5873,
#        5874, 5875, 5876, 5877, 5878, 5879, 5880, 5881, 5882, 5883, 5884,
#        5885, 5886, 5887, 5888, 5889, 5890, 5891, 5892, 5893, 5894, 5895,
#        5896, 5897, 5898, 5899, 5900, 5901, 5902, 5903, 5904, 5905, 5906,
#        5907, 5908, 5909, 5910, 5911, 5912, 5913, 5914, 5915, 5916, 5917,
#        5918, 5919, 5920, 5921, 5922, 5923, 5924, 5925, 5926, 5927, 5928,
#        5929, 5930, 5931, 5932, 5933, 5934, 5935, 5936, 5937, 5938, 5939,
#        5940, 5941, 5942, 5943, 5944, 5945, 5946, 5947, 5948, 5949, 5950,
#        5951, 5952, 5953, 5954, 5955, 5956, 5957, 5958, 5959, 5960, 5961,
#        5962, 5963, 5964, 5965, 5966, 5967, 5968, 5969, 5970, 5971, 5972,
#        5973, 5974, 5975, 5976, 5977, 5978, 5979, 5980, 5981, 5982, 5983,
#        5984, 5985, 5986, 5987, 5988, 5989, 5990, 5991, 5992, 5993, 5994,
#        5995, 5996, 5997, 5998, 5999])}

# %% [markdown]
# `demand_data` is a dictionary storing the following information for each flow (where the values are a list of values corresponding to the values assigned to each flow):

# %%
print(demand_data.keys())
# Out:
# dict_keys(['flow_id', 'sn', 'dn', 'flow_size', 'event_time', 'establish', 'index'])

# %% [markdown]
# ## 6. (Optional) Analyse the Generated Traffic
#
# At this point, you could do your own analysis of the traffic you've generated by loading the saved data into your own scripts. However, `TrafPy` provides some useful tools for this.
#
# We can encode our saved `demand_data` files as `trafpy.generator.Demand()` objects, and then use the `trafpy.generator.DemandsAnalyser` and `trafpy.generator.DemandPlotter` objects to analyse them:

# %%
from trafpy.generator import Demand, DemandsAnalyser, DemandPlotter

# %% [markdown]
# First collect the demand objects from each demand_data file:

# %%
# collect demand objects
demands = {}
for dcn in dcn_dists.keys():
    with gzip.open(path_to_data+'{}_demand_data.pickle'.format(dcn), 'rb') as f:
        demand_data = pickle.load(f)
    demands[dcn] = Demand(demand_data, net.graph['endpoints'], name=dcn)

# %% [markdown]
# Then use `trafpy.generator.DemandsAnalyser()` to print a summary table of all the demand data sets you generated:

# %%
# print summary table
analyser = DemandsAnalyser(*list(demands.values()), jobcentric=False)
analyser.compute_metrics(print_summary=True)
# Out:
#                  Name  Flows  1st           Last       Duration         Info  \
# 0    commercial_cloud   6000  0.0  120199.859167  120199.859167  144239831.0
# 1  social_media_cloud   6000  0.0  212944.965000  212944.965000  255533958.0
# 2          university   6000  0.0  139194.434167  139194.434167  167033321.0
# 3  private_enterprise   6000  0.0  126114.477500  126114.477500  151337373.0
#
#      Load  Smallest     Largest
# 0  1200.0       1.0  11089575.0
# 1  1200.0       1.0   1896000.0
# 2  1200.0       1.0  16172425.0
# 3  1200.0       1.0  15710250.0

# %% [markdown]
# Finally, visualise your data:

# %%
# visualise distributions
for dcn, demand in demands.items():
    print(dcn)
    plotter = DemandPlotter(demand)
    plotter.plot_flow_size_dist(logscale=True, figsize=(12,6))
    plotter.plot_interarrival_time_dist(logscale=True, figsize=(12,6))
    plotter.plot_node_dist(eps=net.graph['endpoints'],
                           chord_edge_width_range=[1,25],
                           chord_edge_display_threshold=0.005)
    plotter.plot_node_load_dists(eps=net.graph['endpoints'], 
                                 ep_link_bandwidth=net.graph['ep_link_capacity'],
                                 plot_extras=False)
# Out:
# university
# Characteristics of Flow Size distribution: DescribeResult(nobs=np.int64(6000), minmax=(np.float64(1.0), np.float64(16172425.0)), mean=np.float64(27838.886833333334), variance=np.float64(81898754851.868), skewness=np.float64(37.35465436368564), kurtosis=np.float64(1845.6336105033836))
# Characteristics of Interarrival Time distribution: DescribeResult(nobs=np.int64(5999), minmax=(np.float64(0.0035906653756683227), np.float64(333.84211338520254)), mean=np.float64(23.20293951769746), variance=np.float64(658.7937568212814), skewness=np.float64(2.364817760424063), kurtosis=np.float64(9.592134950732937))
# private_enterprise
# Characteristics of Flow Size distribution: DescribeResult(nobs=np.int64(6000), minmax=(np.float64(1.0), np.float64(15710250.0)), mean=np.float64(25222.8955), variance=np.float64(71655463638.13127), skewness=np.float64(40.82047841918612), kurtosis=np.float64(2125.8596702159357))
# Characteristics of Interarrival Time distribution: DescribeResult(nobs=np.int64(5999), minmax=(np.float64(0.007601385190355359), np.float64(752.6276635595204)), mean=np.float64(21.022583347224415), variance=np.float64(8274.242620699557), skewness=np.float64(5.683260412115651), kurtosis=np.float64(33.29933100481038))
# commercial_cloud
# Characteristics of Flow Size distribution: DescribeResult(nobs=np.int64(6000), minmax=(np.float64(1.0), np.float64(11089575.0)), mean=np.float64(24039.971833333333), variance=np.float64(53087895521.86968), skewness=np.float64(34.58122964331865), kurtosis=np.float64(1483.0373950270064))
# Characteristics of Interarrival Time distribution: DescribeResult(nobs=np.int64(5999), minmax=(np.float64(0.2274060541221843), np.float64(2247.7745931222016)), mean=np.float64(20.03664930266288), variance=np.float64(19281.294026754418), skewness=np.float64(13.081877778914015), kurtosis=np.float64(179.92223064868546))
# social_media_cloud
# Characteristics of Flow Size distribution: DescribeResult(nobs=np.int64(6000), minmax=(np.float64(1.0), np.float64(1896000.0)), mean=np.float64(42588.993), variance=np.float64(9661350213.941273), skewness=np.float64(6.3744763021726), kurtosis=np.float64(64.83456085328672))
# Characteristics of Interarrival Time distribution: DescribeResult(nobs=np.int64(5999), minmax=(np.float64(0.0067389564337645425), np.float64(25501.895886254802)), mean=np.float64(35.49674362393784), variance=np.float64(137650.13940567808), skewness=np.float64(55.60516580694324), kurtosis=np.float64(3716.422378399738))

# %% [markdown]
# # 7. (Optional) Generate a slots dict data base
#
#
# Many network experiments are based on time slots. I.e. during a time slot of e.g. 10 time units, some number of flows arrive. The `trafpy.generator.Demand()` class has a useful `get_slots_dict()` method to automatically organise your generated traffic demands into time slots given the `slot_size` you want to use:

# %%
slots_dict = demand.get_slots_dict(slot_size=1000)

# %% [markdown]
# The `slots_dict` dictionary contains indices 0-n for `n` slots, as well as some other useful information:

# %%
print(slots_dict.keys())
# Out:
# dict_keys([0, 1, 2, 3, 4, 5, 6, 'slot_keys', 'slot_size', 'time_first_demand_arrived', 'time_last_demand_arrived', 'job_centric', 'num_control_deps', 'num_data_deps', 'num_flows', 'num_demands'])

# %% [markdown]
# E.g. To access the flows which arrived in the first time slot (with upper bound and lower bound times on the time slot also given since this is often useful):

# %%
print(slots_dict[0])
# Out:
# {'lb_time': np.float64(0.0), 'ub_time': np.float64(1000.0), 'new_event_dicts': [{'flow_id': 'flow_3945', 'unique_id': 'flow_3945', 'size': np.float64(3800.0), 'src': '7', 'dst': '11', 'establish': 1, 'parent_deps': None, 'completed_parent_deps': [], 'child_deps': None, 'parent_op_run_time': None, 'time_parent_op_started': None, 'parent_op': None, 'dependency_type': None, 'child_op': None, 'can_schedule': 1, 'job_id': None, 'path': None, 'channel': None, 'packets': None, 'packet_size': None, 'packets_this_slot': 0, 'time_arrived': np.float64(0.0), 'time_completed': None, 'k_shortest_paths': None}, {'flow_id': 'flow_2060', 'unique_id': 'flow_2060', 'size': np.float64(23475.0), 'src': '1', 'dst': '9', 'establish': 1, 'parent_deps': None, 'completed_parent_deps': [], 'child_deps': None, 'parent_op_run_time': None, 'time_parent_op_started': None, 'parent_op': None, 'dependency_type': None, 'child_op': None, 'can_schedule': 1, 'job_id': None, 'path': None, 'channel': None, 'packets': None, 'packet_size': None, 'packets_this_slot': 0, 'time_arrived': np.float64(0.07199336434665299), 'time_completed': None, 'k_shortest_paths': None}, {'flow_id': 'flow_1150', 'unique_id': 'flow_1150', 'size': np.float64(54700.0), 'src': '7', 'dst': '10', 'establish': 1, 'parent_deps': None, 'completed_parent_deps': [], 'child_deps': None, 'parent_op_run_time': None, 'time_parent_op_started': None, 'parent_op': None, 'dependency_type': None, 'child_op': None, 'can_schedule': 1, 'job_id': None, 'path': None, 'channel': None, 'packets': None, 'packet_size': None, 'packets_this_slot': 0, 'time_arrived': np.float64(3.642864235940641), 'time_completed': None, 'k_shortest_paths': None}, {'flow_id': 'flow_660', 'unique_id': 'flow_660', 'size': np.float64(100125.0), 'src': '1', 'dst': '5', 'establish': 1, 'parent_deps': None, 'completed_parent_deps': [], 'child_deps': None, 'parent_op_run_time': None, 'time_parent_op_started': None, 'parent_op': None, 'dependency_type': None, 'child_op': None, 'can_schedule': 1, 'job_id': None, 'path': None, 'channel': None, 'packets': None, 'packet_size': None, 'packets_this_slot': 0, 'time_arrived': np.float64(4.028028735195234), 'time_completed': None, 'k_shortest_paths': None}, {'flow_id': 'flow_1186', 'unique_id': 'flow_1186', 'size': np.float64(52975.0), 'src': '7', 'dst': '3', 'establish': 1, 'parent_deps': None, 'completed_parent_deps': [], 'child_deps': None, 'parent_op_run_time': None, 'time_parent_op_started': None, 'parent_op': None, 'dependency_type': None, 'child_op': None, 'can_schedule': 1, 'job_id': None, 'path': None, 'channel': None, 'packets': None, 'packet_size': None, 'packets_this_slot': 0, 'time_arrived': np.float64(4.038827739847233), 'time_completed': None, 'k_shortest_paths': None}, {'flow_id': 'flow_5864', 'unique_id': 'flow_5864', 'size': np.float64(25.0), 'src': '2', 'dst': '4', 'establish': 1, 'parent_deps': None, 'completed_parent_deps': [], 'child_deps': None, 'parent_op_run_time': None, 'time_parent_op_started': None, 'parent_op': None, 'dependency_type': None, 'child_op': None, 'can_schedule': 1, 'job_id': None, 'path': None, 'channel': None, 'packets': None, 'packet_size': None, 'packets_this_slot': 0, 'time_arrived': np.float64(4.071224753803227), 'time_completed': None, 'k_shortest_paths': None}, {'flow_id': 'flow_1940', 'unique_id': 'flow_1940', 'size': np.float64(25850.0), 'src': '6', 'dst': '10', 'establish': 1, 'parent_deps': None, 'completed_parent_deps': [], 'child_deps': None, 'parent_op_run_time': None, 'time_parent_op_started': None, 'parent_op': None, 'dependency_type': None, 'child_op': None, 'can_schedule': 1, 'job_id': None, 'path': None, 'channel': None, 'packets': None, 'packet_size': None, 'packets_this_slot': 0, 'time_arrived': np.float64(4.074824422020559), 'time_completed': None, 'k_shortest_paths': None}, {'flow_id': 'flow_134', 'unique_id': 'flow_134', 'size': np.float64(313750.0), 'src': '1', 'dst': '4', 'establish': 1, 'parent_deps': None, 'completed_parent_deps': [], ...

# %% [markdown]
# Next time slot flows:

# %%
print(slots_dict[1])
# Out:
# {'lb_time': np.float64(1000.0), 'ub_time': np.float64(2000.0), 'new_event_dicts': [{'flow_id': 'flow_4076', 'unique_id': 'flow_4076', 'size': np.float64(3225.0), 'src': '4', 'dst': '3', 'establish': 1, 'parent_deps': None, 'completed_parent_deps': [], 'child_deps': None, 'parent_op_run_time': None, 'time_parent_op_started': None, 'parent_op': None, 'dependency_type': None, 'child_op': None, 'can_schedule': 1, 'job_id': None, 'path': None, 'channel': None, 'packets': None, 'packet_size': None, 'packets_this_slot': 0, 'time_arrived': np.float64(1017.2614866561588), 'time_completed': None, 'k_shortest_paths': None}, {'flow_id': 'flow_5316', 'unique_id': 'flow_5316', 'size': np.float64(325.0), 'src': '1', 'dst': '8', 'establish': 1, 'parent_deps': None, 'completed_parent_deps': [], 'child_deps': None, 'parent_op_run_time': None, 'time_parent_op_started': None, 'parent_op': None, 'dependency_type': None, 'child_op': None, 'can_schedule': 1, 'job_id': None, 'path': None, 'channel': None, 'packets': None, 'packet_size': None, 'packets_this_slot': 0, 'time_arrived': np.float64(1017.751041533716), 'time_completed': None, 'k_shortest_paths': None}, {'flow_id': 'flow_739', 'unique_id': 'flow_739', 'size': np.float64(89925.0), 'src': '1', 'dst': '4', 'establish': 1, 'parent_deps': None, 'completed_parent_deps': [], 'child_deps': None, 'parent_op_run_time': None, 'time_parent_op_started': None, 'parent_op': None, 'dependency_type': None, 'child_op': None, 'can_schedule': 1, 'job_id': None, 'path': None, 'channel': None, 'packets': None, 'packet_size': None, 'packets_this_slot': 0, 'time_arrived': np.float64(1017.761840538368), 'time_completed': None, 'k_shortest_paths': None}, {'flow_id': 'flow_1990', 'unique_id': 'flow_1990', 'size': np.float64(24675.0), 'src': '10', 'dst': '2', 'establish': 1, 'parent_deps': None, 'completed_parent_deps': [], 'child_deps': None, 'parent_op_run_time': None, 'time_parent_op_started': None, 'parent_op': None, 'dependency_type': None, 'child_op': None, 'can_schedule': 1, 'job_id': None, 'path': None, 'channel': None, 'packets': None, 'packet_size': None, 'packets_this_slot': 0, 'time_arrived': np.float64(1017.77263954302), 'time_completed': None, 'k_shortest_paths': None}, {'flow_id': 'flow_1068', 'unique_id': 'flow_1068', 'size': np.float64(60475.0), 'src': '1', 'dst': '7', 'establish': 1, 'parent_deps': None, 'completed_parent_deps': [], 'child_deps': None, 'parent_op_run_time': None, 'time_parent_op_started': None, 'parent_op': None, 'dependency_type': None, 'child_op': None, 'can_schedule': 1, 'job_id': None, 'path': None, 'channel': None, 'packets': None, 'packet_size': None, 'packets_this_slot': 0, 'time_arrived': np.float64(1017.9058272670613), 'time_completed': None, 'k_shortest_paths': None}, {'flow_id': 'flow_3540', 'unique_id': 'flow_3540', 'size': np.float64(5850.0), 'src': '0', 'dst': '1', 'establish': 1, 'parent_deps': None, 'completed_parent_deps': [], 'child_deps': None, 'parent_op_run_time': None, 'time_parent_op_started': None, 'parent_op': None, 'dependency_type': None, 'child_op': None, 'can_schedule': 1, 'job_id': None, 'path': None, 'channel': None, 'packets': None, 'packet_size': None, 'packets_this_slot': 0, 'time_arrived': np.float64(1018.5429685415293), 'time_completed': None, 'k_shortest_paths': None}, {'flow_id': 'flow_1996', 'unique_id': 'flow_1996', 'size': np.float64(24600.0), 'src': '3', 'dst': '2', 'establish': 1, 'parent_deps': None, 'completed_parent_deps': [], 'child_deps': None, 'parent_op_run_time': None, 'time_parent_op_started': None, 'parent_op': None, 'dependency_type': None, 'child_op': None, 'can_schedule': 1, 'job_id': None, 'path': None, 'channel': None, 'packets': None, 'packet_size': None, 'packets_this_slot': 0, 'time_arrived': np.float64(1019.6120700020771), 'time_completed': None, 'k_shortest_paths': None}, {'flow_id': 'flow_3716', 'unique_id': 'flow_3716', 'size': np.float64(4900.0), 'src': '7', 'dst': '11', 'establish': 1, 'parent_deps': None, 'completed_p ...

# %% [markdown]
# And so on.
#
# For large simulations, it is recommended to save the `slots_dict` as a database on your disk which you can query during your simulation. The `SqliteDict` library is particularly useful for this since it lets you save a database in .sqlite file format whilst still allowing you to query the database as if it were a normal Python dictionary. See [here](https://pypi.org/project/sqlitedict/) for more details.
#
# To save your `slots_dict` as a .sqlite database with `SqliteDict`, run:

# %%
from sqlitedict import SqliteDict
import json

with SqliteDict(path_to_data+'{}_demand_data_slots_dict.sqlite'.format(dcn)) as _slots_dict:
    for key, val in slots_dict.items():
        if type(key) is not str:
            _slots_dict[json.dumps(key)] = val
        else:
            _slots_dict[key] = val
    _slots_dict.commit()
    _slots_dict.close()

# %% [markdown]
# # To store the traffic in CSV format

# %%
import pandas as pd

# Convert dictionary to DataFrame
df = pd.DataFrame({
    'src': demand_data['sn'],
    'dst': demand_data['dn'],
    'flow_size_bytes': demand_data['flow_size'],
    'start_time': demand_data['event_time'],
})

# Optional: sort flows by start time
df = df.sort_values(by='start_time')

# Save for ns-3
df.to_csv('trafpy_flows.csv', index=False)

print("Saved", len(df), "flows to trafpy_flows.csv")
# Out:
# Saved 6000 flows to trafpy_flows.csv

# %%
df = df
