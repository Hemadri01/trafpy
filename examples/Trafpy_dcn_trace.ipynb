# %%
import trafpy.generator as tpg

from pathlib import Path
import gzip
import pickle

PATH = 'data/trafpy_dcn_trace/'
Path(PATH).mkdir(exist_ok=True, parents=True)
# Out:
# /home/hsd/anaconda3/envs/trafpy-env/lib/python3.13/site-packages/nxviz/__init__.py:18: UserWarning:
# nxviz has a new API! Version 0.7.3 onwards, the old class-based API is being
# deprecated in favour of a new API focused on advancing a grammar of network
# graphics. If your plotting code depends on the old API, please consider
# pinning nxviz at version 0.7.3, as the new API will break your old code.
#
# To check out the new API, please head over to the docs at
# https://ericmjl.github.io/nxviz/ to learn more. We hope you enjoy using it!
#
# (This deprecation message will go away in version 1.0.)
#
#   warnings.warn(

# %% [markdown]
# # Heavy Tail Try

# %%
dist = tpg.gen_named_val_dist(dist='weibull',
                              params={'_alpha': 0.9, '_lambda': 600},
                              min_val=1,
                              max_val=1e9,
                             # xlim=[0,80000],
                              round_to_nearest=25,
                              show_fig=True,
                              plot_fig=True,
                              print_data=False)

# %%
dist = tpg.gen_named_val_dist(dist='lognormal',
                              params={'_mu': 7, '_sigma': 1.5},
                              min_val=10,
                              max_val=1e9,
                              round_to_nearest=10,
                              show_fig=True,
                              plot_fig=True,
                              logscale=True,
                              print_data=False)

# %%
dist = tpg.gen_named_val_dist(dist='pareto',
                              params={'_alpha': 0.4, '_mode': 7},
                              min_val=10,
                              max_val=1e9,
                              round_to_nearest=25,
                              show_fig=True,
                              plot_fig=True,
                              logscale=True,
                              print_data=False)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Dist to broad for required min-max range. Increase min-max range or reduce dist broadness.
# /home/hsd/anaconda3/envs/trafpy-env/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3709: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
dist = tpg.gen_named_val_dist(dist='lognormal',
                              params={'_mu': 5, '_sigma': 1.5},
                              min_val=1,
                              max_val=1e9,
                              round_to_nearest=25,
                              size=150000,
                              num_bins=0,
                              rand_var_name='Random Variable',
                              xlim=None,
                              show_fig=True,
                              plot_fig=True,
                              logscale=True,
                              print_data=False)

# %% [markdown]
# # University

# %% [markdown]
# ### Inter-Arrival Distribution

# %%
dist = tpg.gen_named_val_dist(dist='weibull',
                              params={'_alpha': 0.9, '_lambda': 6000},
                              min_val=1,
                              max_val=80000,
                             # xlim=[0,80000],
                              round_to_nearest=25,
                              show_fig=True,
                              plot_fig=True,
                              print_data=False)

# %% [markdown]
# ### Flow-Size Distribution

# %%
dist = tpg.gen_named_val_dist(dist='lognormal',
                              params={'_mu': 7, '_sigma': 2.5},
                              min_val=1,
                              max_val=2e7,
                              round_to_nearest=25,
                              show_fig=True,
                              plot_fig=True,
                              logscale=True,
                              print_data=False)

# %%
dist = tpg.gen_named_val_dist(dist='lognormal',
                              params={'_mu': 9, '_sigma': 5},
                              min_val=1,
                              max_val=1e9,
                              round_to_nearest=2,
                              show_fig=True,
                              plot_fig=True,
                              logscale=True,
                              print_data=False)

# %% [markdown]
# # Private Enterprise

# %% [markdown]
# ### Inter-Arrival Distribution

# %%
dist = tpg.gen_multimodal_val_dist(min_val=1,
                                   show_fig=True,
                                #   xlim=[0,80000],
                                   max_val=80000,
                                   locations=[40,1],
                                   skews=[-1,4],
                                   scales=[60,1000],
                                   num_skew_samples=[10000,10000],
                                   round_to_nearest=25,
                                   bg_factor=0.05)

# %% [markdown]
# ### Flow-Size Distribution

# %%
dist = tpg.gen_named_val_dist(dist='lognormal',
                              params={'_mu': 7, '_sigma': 2.5},
                              min_val=1,
                              max_val=2e7,
                              round_to_nearest=25,
                              show_fig=True,
                              logscale=True,
                              print_data=False)

# %% [markdown]
# # Commercial Cloud

# %% [markdown]
# ### Inter-Arrival Distribution

# %%
dist = tpg.gen_multimodal_val_dist(min_val=1,
                                   show_fig=True,
                        #           xlim=[0,80000],
                                   max_val=80000,
                                   locations=[10,20,100,1],
                                   skews=[0,0,0,100],
                                   scales=[1,3,4,50],
                                   num_skew_samples=[10000,7000,5000,20000],
                                   round_to_nearest=25,
                                   bg_factor=0.01)

# %% [markdown]
# ### Flow-Size Distribution

# %%
dist = tpg.gen_named_val_dist(dist='lognormal',
                              params={'_mu': 7, '_sigma': 2.5},
                              min_val=1,
                              max_val=2e7,
                              round_to_nearest=10,
                              show_fig=True,
                              logscale=True,
                              print_data=False)

# %% [markdown]
# # Social Media Cloud

# %% [markdown]
# ### Inter-Arrival Distribution

# %%
dist = tpg.gen_named_val_dist(dist='lognormal',
                      #        xlim=[0,80000],
                              max_val=80000,
                              params={'_mu': 6, '_sigma': 2.3},
                              min_val=1,
                              round_to_nearest=25,
                              show_fig=True,
                              print_data=False)

# %% [markdown]
# ### Flow-Size Distribution

# %%
dist = tpg.gen_named_val_dist(dist='weibull',
                              params={'_alpha': 0.5, '_lambda': 21000},
                              min_val=1,
                              max_val=2e6,
                              round_to_nearest=25,
                              show_fig=True,
                              logscale=True,
                              print_data=False)
