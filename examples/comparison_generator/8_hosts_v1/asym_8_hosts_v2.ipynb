# %%
import pandas as pd
from pathlib import Path
import numpy as np


# ============================================================
# CONFIG
# ============================================================

benchmarks = [
    "private_enterprise",
    "social_media_cloud",
    "commercial_cloud",
    "university"
]

# benchmarks = [
#     "private_enterprise",
#     "social_media_cloud"
# ]

loads = range(1, 10)

# Input TrafPy flow files
input_dir = "/home/hsd/workspace/trafpy/examples/comparison_generator/8_hosts_v2"

# CONGA / ECMP ns-3 outputs
conga_dir = "/home/hsd/workspace/ns3-load-balance/conga_asym_8_hosts_v2"

# RTT ns-3 outputs
rtt_dir = "/home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2"

# Output directory
save_dir = "/home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results"

Path(save_dir).mkdir(
    parents=True,
    exist_ok=True
)


# ============================================================
# MATCHING CONFIG
# ============================================================

PORT_START = 10000
PORT_END = 50000

ip_pattern = r'^\d+\.\d+\.\d+\.\d+$'


# ============================================================
# FUNCTIONS
# ============================================================

def clean(df):
    """
    Keep only rows that contain valid IP addresses.
    """

    required = [
        "Src",
        "Dest"
    ]

    for col in required:

        if col not in df.columns:

            raise ValueError(
                f"Required column '{col}' not found."
            )

    return df[
        df["Src"].astype(str).str.match(
            ip_pattern,
            na=False
        )
        &
        df["Dest"].astype(str).str.match(
            ip_pattern,
            na=False
        )
    ].copy()


# ============================================================

def ip_to_node(ip):
    """
    Convert ns-3 server IP to input trace node ID.

    Leaf 0:
        10.1.1.2 -> 0
        10.1.1.4 -> 1
        10.1.1.6 -> 2
        10.1.1.8 -> 3

    Leaf 1:
        10.1.2.2 -> 4
        10.1.2.4 -> 5
        10.1.2.6 -> 6
        10.1.2.8 -> 7
    """

    parts = ip.split(".")

    subnet = int(parts[-2])
    host = int(parts[-1])

    base = (host // 2) - 1

    if subnet == 1:

        return base

    elif subnet == 2:

        return base + 4

    else:

        raise ValueError(
            f"Unexpected IP address: {ip}"
        )


# ============================================================

def add_time(df):
    """
    Convert ns-3 TimeFirstTxPacket to seconds.
    """

    df = df.copy()

    df["start_time"] = (
        df["TimeFirstTxPacket"]
        .astype(str)
        .str.replace("+", "", regex=False)
        .str.replace("ns", "", regex=False)
        .astype(float)
        / 1e9
    )

    return df


# ============================================================

def expected_port(flow_index):
    """
    Reproduce the C++ destination-port calculation.

        port = PORT_START + flow.index

    with wrapping after PORT_END.
    """

    port = PORT_START + int(flow_index)

    if port > PORT_END:

        port = port - (
            PORT_END - PORT_START
        )

    return port


# ============================================================
# FLOW COLUMNS
# ============================================================

flow_columns = [
    "FlowID",
    "Src",
    "Dest",
    "TimeFirstRxPacket",
    "TimeFirstTxPacket",
    "TimeLastRxPacket",
    "TimeLastTxPacket",
    "FCT(s)",
    "TxPackets",
    "RxPackets",
    "LostPackets",
    "LossRate",
    "PDR",
    "LossPercent",
    "TxBytes",
    "RxBytes",
    "Throughput(Kbps)",
    "MeanDelay(ms)",
    "Jitter(ms)",
    "HopCount"
]


# ============================================================
# MATCHING FUNCTION
# ============================================================

def match_df(output_df, input_df, label):
    """
    Match input TrafPy flows to ns-3 flows.

    Matching is based on:

        1. source node
        2. destination node
        3. destination port

    If multiple ns-3 flows have the same tuple, the candidate
    with the closest start time to the input event time is used.

    Time is NOT a hard matching criterion.
    """

    matches = []

    # --------------------------------------------------------
    # Make copies
    # --------------------------------------------------------

    output_df = output_df.copy()
    input_df = input_df.copy()

    # --------------------------------------------------------
    # Numeric conversion
    # --------------------------------------------------------

    for col in [
        "SrcPort",
        "DestPort",
        "TxPackets",
        "RxPackets",
        "TxBytes",
        "RxBytes",
        "start_time",
        "sn",
        "dn"
    ]:

        if col in output_df.columns:

            output_df[col] = pd.to_numeric(
                output_df[col],
                errors="coerce"
            )

    for col in [
        "sn",
        "dn",
        "index",
        "flow_size",
        "event_time"
    ]:

        input_df[col] = pd.to_numeric(
            input_df[col],
            errors="coerce"
        )

    # --------------------------------------------------------
    # Remove invalid rows
    # --------------------------------------------------------

    output_df = output_df.dropna(
        subset=[
            "SrcPort",
            "DestPort",
            "TxPackets",
            "RxPackets",
            "TxBytes",
            "RxBytes",
            "start_time",
            "sn",
            "dn"
        ]
    ).copy()

    input_df = input_df.dropna(
        subset=[
            "sn",
            "dn",
            "index",
            "flow_size",
            "event_time"
        ]
    ).copy()

    # --------------------------------------------------------
    # Sort input by event time
    # --------------------------------------------------------

    input_df = input_df.sort_values(
        "event_time"
    ).reset_index(
        drop=True
    )

    # --------------------------------------------------------
    # Create lookup key
    #
    # (source node, destination node, destination port)
    # --------------------------------------------------------

    output_df["_match_key"] = list(
        zip(
            output_df["sn"].astype(int),
            output_df["dn"].astype(int),
            output_df["DestPort"].astype(int)
        )
    )

    # --------------------------------------------------------
    # Group ns-3 flows by matching key
    # --------------------------------------------------------

    grouped = {
        key: group
        for key, group in output_df.groupby(
            "_match_key",
            sort=False
        )
    }

    # --------------------------------------------------------
    # Process every input flow
    # --------------------------------------------------------

    for _, in_row in input_df.iterrows():

        input_flow_id = in_row["flow_id"]

        input_index = int(
            in_row["index"]
        )

        input_src = int(
            in_row["sn"]
        )

        input_dst = int(
            in_row["dn"]
        )

        input_time = float(
            in_row["event_time"]
        )

        input_size = float(
            in_row["flow_size"]
        )

        # ----------------------------------------------------
        # Expected destination port
        # ----------------------------------------------------

        expected_dst_port = expected_port(
            input_index
        )

        # ----------------------------------------------------
        # Lookup
        # ----------------------------------------------------

        key = (
            input_src,
            input_dst,
            expected_dst_port
        )

        candidates = grouped.get(
            key
        )

        # ----------------------------------------------------
        # No matching ns-3 flow
        # ----------------------------------------------------

        if candidates is None or len(candidates) == 0:

            continue

        # ----------------------------------------------------
        # Find closest start time
        # ----------------------------------------------------

        if len(candidates) == 1:

            best = candidates.iloc[0]

            time_diff = abs(
                best["start_time"]
                - input_time
            )

        else:

            time_diffs = (
                candidates["start_time"]
                - input_time
            ).abs()

            best_index = time_diffs.idxmin()

            best = candidates.loc[
                best_index
            ]

            time_diff = time_diffs.loc[
                best_index
            ]

        # ----------------------------------------------------
        # Size difference
        # ----------------------------------------------------

        if input_size > 0:

            size_diff = (
                abs(
                    best["TxBytes"]
                    - input_size
                )
                /
                max(
                    input_size,
                    best["TxBytes"],
                    1
                )
            )

        else:

            size_diff = np.nan

        # ----------------------------------------------------
        # Combined result
        # ----------------------------------------------------

        combined = {

            "flow_id":
                input_flow_id,

            "sn":
                input_src,

            "dn":
                input_dst,

            "input_time":
                input_time,

            "flow_size":
                input_size,

            #"expected_dest_port":
            #    expected_dst_port,

            f"time_diff_{label}":
                time_diff,

            f"size_diff_{label}":
                size_diff,

            f"TxPackets_{label}":
                best["TxPackets"],

            f"RxPackets_{label}":
                best["RxPackets"],

            f"TxBytes_calc_{label}":
                best["TxPackets"] * 1400,

            f"RxBytes_calc_{label}":
                best["RxPackets"] * 1400
        }

        # ----------------------------------------------------
        # Add all FlowMonitor columns
        # ----------------------------------------------------

        for col in flow_columns:

            combined[
                f"{col}_{label}"
            ] = best[col]

        matches.append(
            combined
        )

    return pd.DataFrame(
        matches
    )


# ============================================================
# MAIN
# ============================================================

for benchmark in benchmarks:

    for load in loads:

        print()
        print(
            "=" * 80
        )

        print(
            f"{benchmark} | Load 0.{load}"
        )

        print(
            "=" * 80
        )

        # ====================================================
        # INPUT TRACE
        # ====================================================

        input_path = (
            f"{input_dir}/"
            f"{benchmark}_load_{load}.csv"
        )

        try:

            input_df = pd.read_csv(
                input_path
            )

            print(
                f"Input flows: "
                f"{len(input_df):,}"
            )

        except Exception as e:

            print(
                f"Could not read input: {e}"
            )

            continue

        # ====================================================
        # ALGORITHMS
        #
        # COMMENT / UNCOMMENT ANYTHING YOU WANT
        # ====================================================

        try:

            algorithms = {

                # ------------------------------------------------
                # CONGA
                # ------------------------------------------------

                "conga": pd.read_csv(
                    f"{conga_dir}/"
                    f"{benchmark}_load_{load}_Conga.csv",
                    nrows=12000
                ),

                # ------------------------------------------------
                # CONGA variants
                # ------------------------------------------------

                # "conga_new": pd.read_csv(
                #     f"{conga_dir}/"
                #     f"{benchmark}_load_{load}_Conga_new.csv",
                #     nrows=12000
                # ),

                # "conga-ecmp": pd.read_csv(
                #     f"{conga_dir}/"
                #     f"{benchmark}_load_{load}_Conga-ECMP_new.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # ECMP
                # ------------------------------------------------

                "ecmp": pd.read_csv(
                    f"{conga_dir}/"
                    f"{benchmark}_load_{load}_ECMP.csv",
                    nrows=12000
                ),

                # ------------------------------------------------
                # ECMP variants
                # ------------------------------------------------

                # "ecmp_new": pd.read_csv(
                #     f"{conga_dir}/"
                #     f"{benchmark}_load_{load}_ECMP_new.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # Basic RTT
                # ------------------------------------------------

                # "rtt": pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_RTT.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # Weighted ECMP
                # ------------------------------------------------

                # "weighted": pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_WEIGHTED_ECMP_RTT.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # Power-of-2 Random
                # ------------------------------------------------

                # "random": pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_POWER_OF_2_RANDOM_RTT.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # Power-of-2 Top2
                # ------------------------------------------------

                # "top2": pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_POWER_OF_2_TOP2_RTT.csv",
                #     nrows=12000
                # ),
            }

            # ====================================================
            # TIMEOUT VARIANTS
            # ====================================================

            timeout_values = [
                "true",
                "false"
            ]

            for timeout in timeout_values:

                # ------------------------------------------------
                # Weighted ECMP + timeout
                # ------------------------------------------------

                algorithms[
                    f"weighted_{timeout}"
                    ] = pd.read_csv(
                    f"{rtt_dir}/"
                    f"{benchmark}_load_{load}_"
                    f"WEIGHTED_ECMP_timeout_{timeout}_RTT.csv",
                    nrows=12000
                )

                # ------------------------------------------------
                # Lowest RTT + timeout
                # ------------------------------------------------

                #algorithms[
                #    f"lrtt_{timeout}"
                #] = pd.read_csv(
                #    f"{rtt_dir}/"
                #    f"{benchmark}_load_{load}_"
                #    f"LOWEST_RTT_timeout_{timeout}_RTT.csv",
                #    nrows=12000
                #)

                # ------------------------------------------------
                # Power-of-2 Random + timeout
                # ------------------------------------------------

                algorithms[
                     f"random_{timeout}"
                     ] = pd.read_csv(
                     f"{rtt_dir}/"
                     f"{benchmark}_load_{load}_"
                     f"POWER_OF_2_RANDOM_timeout_{timeout}_RTT.csv",
                     nrows=12000
                 )

                # ------------------------------------------------
                # Power-of-2 Top2 + timeout
                # ------------------------------------------------

                # algorithms[
                #     f"top2_{timeout}"
                # ] = pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_"
                #     f"POWER_OF_2_TOP2_timeout_{timeout}_RTT.csv",
                #     nrows=12000
                # )

        except Exception as e:

            print(
                "Skipping:",
                e
            )

            continue

        # ====================================================
        # CLEAN + PREPARE
        # ====================================================

        for label, df in algorithms.items():

            try:

                df = clean(
                    df
                )

                df = add_time(
                    df
                )

                df["sn"] = df["Src"].apply(
                    ip_to_node
                )

                df["dn"] = df["Dest"].apply(
                    ip_to_node
                )

                algorithms[label] = df

                print(
                    f"{label}: "
                    f"{len(df):,} IP flows"
                )

            except Exception as e:

                print(
                    f"ERROR processing "
                    f"{label}: {e}"
                )

                algorithms[label] = (
                    pd.DataFrame()
                )

        # ====================================================
        # MATCH
        # ====================================================

        matched = {}

        for label, df in algorithms.items():

            if df.empty:

                print(
                    f"Skipping matching for "
                    f"{label}: empty dataframe"
                )

                continue

            print(
                f"Matching {label}..."
            )

            matched[label] = match_df(
                df,
                input_df,
                label
            )

            print(
                f"{label}: "
                f"{len(matched[label]):,} matches"
            )

        # ====================================================
        # REMOVE EMPTY ALGORITHMS
        # ====================================================

        matched = {
            label: df
            for label, df in matched.items()
            if not df.empty
        }

        if len(matched) == 0:

            print(
                "No matches."
            )

            continue

        # ====================================================
        # MERGE RESULTS
        # ====================================================

        merge_keys = [
            "flow_id",
            "sn",
            "dn",
            "input_time",
            "flow_size"
        ]

        algorithms_list = list(
            matched.keys()
        )

        final_df = matched[
            algorithms_list[0]
        ]

        for algo in algorithms_list[1:]:

            final_df = pd.merge(
                final_df,
                matched[algo],
                on=merge_keys,
                how="inner"
            )

        # ====================================================
        # CHECK RESULT
        # ====================================================

        if len(final_df) == 0:

            print(
                "No common matches across "
                "the selected algorithms."
            )

            continue

        print()
        print(
            f"Final matched flows: "
            f"{len(final_df):,}"
        )


        # ============================================================
        # MATCHING TIME-DIFFERENCE SANITY CHECK
        # ============================================================
        
        print("\n" + "=" * 80)
        print("MATCHING TIME-DIFFERENCE CHECK")
        print("=" * 80)
        
        for algo in algorithms:
        
            col = f"time_diff_{algo}"
        
            if col not in final_df.columns:
                continue
        
            max_diff = final_df[col].max()
            mean_diff = final_df[col].mean()
            p95_diff = final_df[col].quantile(0.95)
            p99_diff = final_df[col].quantile(0.99)
        
            max_idx = final_df[col].idxmax()
            worst = final_df.loc[max_idx]
        
            print(f"\n{algo}")
            print(f"  Maximum : {max_diff:.9f} s "
                  f"({max_diff * 1000:.6f} ms)")
            print(f"  Mean    : {mean_diff:.9f} s "
                  f"({mean_diff * 1000:.6f} ms)")
            print(f"  P95     : {p95_diff:.9f} s "
                  f"({p95_diff * 1000:.6f} ms)")
            print(f"  P99     : {p99_diff:.9f} s "
                  f"({p99_diff * 1000:.6f} ms)")
        
            print(f"  Worst matching flow:")
            print(f"    flow_id     : {worst['flow_id']}")
            print(f"    sn          : {worst['sn']}")
            print(f"    dn          : {worst['dn']}")
            print(f"    input_time  : {worst['input_time']:.9f} s")
            print(f"    time_diff   : {worst[col]:.9f} s")

        
        # ====================================================
        # DIFFERENCES
        # ====================================================

        reference = "ecmp"

        if reference in matched:

            for algo in algorithms:

                if algo == reference:
                    continue

                if (
                    f"FCT(s)_{reference}" in final_df.columns
                    and
                    f"FCT(s)_{algo}" in final_df.columns
                ):

                    final_df[
                        f"fct_diff_{reference}_{algo}"
                    ] = (
                        final_df[
                            f"FCT(s)_{reference}"
                        ]
                        -
                        final_df[
                            f"FCT(s)_{algo}"
                        ]
                    )

        # ====================================================
        # SAVE
        # ====================================================

        csv_path = (
            f"{save_dir}/"
            f"{benchmark}_load_{load}_full.csv"
        )

        final_df.to_csv(
            csv_path,
            index=False
        )

        print(
            f"Saved: {csv_path}"
        )

        # ====================================================
        # STATS
        # ====================================================

        print()
        print(
            "-" * 80
        )

        print(
            f"Statistics: "
            f"{benchmark} | Load 0.{load}"
        )

        print(
            "-" * 80
        )

        for algo in matched:

            column = (
                f"FCT(s)_{algo}"
            )

            if column not in final_df.columns:
                continue

            fct = final_df[
                column
            ]

            print(
                f"{algo:20s}"
                f"Avg: {fct.mean():.6f}  "
                f"P75: {fct.quantile(0.75):.6f}  "
                f"P90: {fct.quantile(0.90):.6f}  "
                f"P95: {fct.quantile(0.95):.6f}  "
                f"P99: {fct.quantile(0.99):.6f}"
            )


# ============================================================
# DONE
# ============================================================

print()
print(
    "=" * 80
)

print(
    "MATCHING COMPLETE"
)

print(
    "=" * 80
)
# Out:
# ================================================================================
# private_enterprise | Load 0.1
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3284
#     sn          : 4
#     dn          : 1
#     input_time  : 27.977796869 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3284
#     sn          : 4
#     dn          : 1
#     input_time  : 27.977796869 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3284
#     sn          : 4
#     dn          : 1
#     input_time  : 27.977796869 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3284
#     sn          : 4
#     dn          : 1
#     input_time  : 27.977796869 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3284
#     sn          : 4
#     dn          : 1
#     input_time  : 27.977796869 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3284
#     sn          : 4
#     dn          : 1
#     input_time  : 27.977796869 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/private_enterprise_load_1_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.1
# --------------------------------------------------------------------------------
# conga               Avg: 0.006470  P75: 0.003135  P90: 0.015537  P95: 0.027519  P99: 0.069239
# ecmp                Avg: 0.006547  P75: 0.003285  P90: 0.015766  P95: 0.027756  P99: 0.069752
# weighted_true       Avg: 0.006529  P75: 0.003203  P90: 0.015724  P95: 0.027403  P99: 0.069807
# random_true         Avg: 0.006513  P75: 0.003172  P90: 0.015731  P95: 0.027662  P99: 0.069651
# weighted_false      Avg: 0.006504  P75: 0.003211  P90: 0.015334  P95: 0.027290  P99: 0.069357
# random_false        Avg: 0.006502  P75: 0.003192  P90: 0.015376  P95: 0.027369  P99: 0.069358
#
# ================================================================================
# private_enterprise | Load 0.2
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4075
#     sn          : 3
#     dn          : 6
#     input_time  : 4.987554623 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4075
#     sn          : 3
#     dn          : 6
#     input_time  : 4.987554623 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4075
#     sn          : 3
#     dn          : 6
#     input_time  : 4.987554623 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4075
#     sn          : 3
#     dn          : 6
#     input_time  : 4.987554623 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4075
#     sn          : 3
#     dn          : 6
#     input_time  : 4.987554623 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4075
#     sn          : 3
#     dn          : 6
#     input_time  : 4.987554623 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/private_enterprise_load_2_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.2
# --------------------------------------------------------------------------------
# conga               Avg: 0.007944  P75: 0.006186  P90: 0.021904  P95: 0.034246  P99: 0.073324
# ecmp                Avg: 0.008053  P75: 0.006396  P90: 0.021709  P95: 0.034156  P99: 0.075373
# weighted_true       Avg: 0.008196  P75: 0.006553  P90: 0.022265  P95: 0.034578  P99: 0.076006
# random_true         Avg: 0.007892  P75: 0.006354  P90: 0.021630  P95: 0.033748  P99: 0.073801
# weighted_false      Avg: 0.007753  P75: 0.006271  P90: 0.020795  P95: 0.032809  P99: 0.073421
# random_false        Avg: 0.007848  P75: 0.006256  P90: 0.021007  P95: 0.032770  P99: 0.074860
#
# ================================================================================
# private_enterprise | Load 0.3
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2629
#     sn          : 4
#     dn          : 3
#     input_time  : 9.664454465 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2629
#     sn          : 4
#     dn          : 3
#     input_time  : 9.664454465 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2629
#     sn          : 4
#     dn          : 3
#     input_time  : 9.664454465 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2629
#     sn          : 4
#     dn          : 3
#     input_time  : 9.664454465 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2629
#     sn          : 4
#     dn          : 3
#     input_time  : 9.664454465 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2629
#     sn          : 4
#     dn          : 3
#     input_time  : 9.664454465 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/private_enterprise_load_3_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.3
# --------------------------------------------------------------------------------
# conga               Avg: 0.010544  P75: 0.010654  P90: 0.028929  P95: 0.042391  P99: 0.086065
# ecmp                Avg: 0.010508  P75: 0.010775  P90: 0.028130  P95: 0.041829  P99: 0.085586
# weighted_true       Avg: 0.010483  P75: 0.010604  P90: 0.028284  P95: 0.042035  P99: 0.083203
# random_true         Avg: 0.010512  P75: 0.010595  P90: 0.028672  P95: 0.041723  P99: 0.083787
# weighted_false      Avg: 0.010571  P75: 0.010506  P90: 0.028473  P95: 0.043218  P99: 0.087718
# random_false        Avg: 0.010580  P75: 0.010427  P90: 0.028746  P95: 0.043133  P99: 0.087960
#
# ================================================================================
# private_enterprise | Load 0.4
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4344
#     sn          : 5
#     dn          : 0
#     input_time  : 7.415190500 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4344
#     sn          : 5
#     dn          : 0
#     input_time  : 7.415190500 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4344
#     sn          : 5
#     dn          : 0
#     input_time  : 7.415190500 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4344
#     sn          : 5
#     dn          : 0
#     input_time  : 7.415190500 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4344
#     sn          : 5
#     dn          : 0
#     input_time  : 7.415190500 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4344
#     sn          : 5
#     dn          : 0
#     input_time  : 7.415190500 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/private_enterprise_load_4_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.4
# --------------------------------------------------------------------------------
# conga               Avg: 0.012246  P75: 0.015042  P90: 0.032134  P95: 0.046862  P99: 0.089763
# ecmp                Avg: 0.012213  P75: 0.014762  P90: 0.031782  P95: 0.046981  P99: 0.088751
# weighted_true       Avg: 0.012487  P75: 0.015018  P90: 0.032266  P95: 0.047622  P99: 0.095411
# random_true         Avg: 0.012409  P75: 0.015032  P90: 0.032323  P95: 0.046686  P99: 0.095577
# weighted_false      Avg: 0.012291  P75: 0.014509  P90: 0.032112  P95: 0.047007  P99: 0.096284
# random_false        Avg: 0.012203  P75: 0.014378  P90: 0.031677  P95: 0.046638  P99: 0.097257
#
# ================================================================================
# private_enterprise | Load 0.5
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2602
#     sn          : 0
#     dn          : 3
#     input_time  : 4.250564431 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2602
#     sn          : 0
#     dn          : 3
#     input_time  : 4.250564431 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2602
#     sn          : 0
#     dn          : 3
#     input_time  : 4.250564431 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2602
#     sn          : 0
#     dn          : 3
#     input_time  : 4.250564431 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2602
#     sn          : 0
#     dn          : 3
#     input_time  : 4.250564431 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2602
#     sn          : 0
#     dn          : 3
#     input_time  : 4.250564431 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/private_enterprise_load_5_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.5
# --------------------------------------------------------------------------------
# conga               Avg: 0.015225  P75: 0.018082  P90: 0.038978  P95: 0.060413  P99: 0.112056
# ecmp                Avg: 0.015699  P75: 0.018548  P90: 0.040050  P95: 0.061536  P99: 0.119333
# weighted_true       Avg: 0.015405  P75: 0.017816  P90: 0.040932  P95: 0.061013  P99: 0.115414
# random_true         Avg: 0.015087  P75: 0.017400  P90: 0.037677  P95: 0.058286  P99: 0.114912
# weighted_false      Avg: 0.014922  P75: 0.017015  P90: 0.037300  P95: 0.056974  P99: 0.112891
# random_false        Avg: 0.014999  P75: 0.017296  P90: 0.038576  P95: 0.059374  P99: 0.115785
#
# ================================================================================
# private_enterprise | Load 0.6
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1230
#     sn          : 3
#     dn          : 0
#     input_time  : 2.221919343 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1230
#     sn          : 3
#     dn          : 0
#     input_time  : 2.221919343 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1230
#     sn          : 3
#     dn          : 0
#     input_time  : 2.221919343 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1230
#     sn          : 3
#     dn          : 0
#     input_time  : 2.221919343 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1230
#     sn          : 3
#     dn          : 0
#     input_time  : 2.221919343 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1230
#     sn          : 3
#     dn          : 0
#     input_time  : 2.221919343 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/private_enterprise_load_6_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.6
# --------------------------------------------------------------------------------
# conga               Avg: 0.018872  P75: 0.023342  P90: 0.049100  P95: 0.070339  P99: 0.134189
# ecmp                Avg: 0.019487  P75: 0.024024  P90: 0.053067  P95: 0.073866  P99: 0.139483
# weighted_true       Avg: 0.018994  P75: 0.022940  P90: 0.049779  P95: 0.071211  P99: 0.138609
# random_true         Avg: 0.019145  P75: 0.023537  P90: 0.050541  P95: 0.071392  P99: 0.138335
# weighted_false      Avg: 0.018753  P75: 0.022710  P90: 0.047008  P95: 0.071423  P99: 0.142594
# random_false        Avg: 0.018221  P75: 0.020627  P90: 0.046424  P95: 0.070158  P99: 0.145382
#
# ================================================================================
# private_enterprise | Load 0.7
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3797
#     sn          : 1
#     dn          : 3
#     input_time  : 0.521445732 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3797
#     sn          : 1
#     dn          : 3
#     input_time  : 0.521445732 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3797
#     sn          : 1
#     dn          : 3
#     input_time  : 0.521445732 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3797
#     sn          : 1
#     dn          : 3
#     input_time  : 0.521445732 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3797
#     sn          : 1
#     dn          : 3
#     input_time  : 0.521445732 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3797
#     sn          : 1
#     dn          : 3
#     input_time  : 0.521445732 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/private_enterprise_load_7_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.7
# --------------------------------------------------------------------------------
# conga               Avg: 0.021444  P75: 0.028718  P90: 0.053260  P95: 0.076100  P99: 0.145861
# ecmp                Avg: 0.020514  P75: 0.028838  P90: 0.049969  P95: 0.066322  P99: 0.120770
# weighted_true       Avg: 0.019816  P75: 0.027141  P90: 0.046878  P95: 0.065413  P99: 0.121176
# random_true         Avg: 0.021270  P75: 0.028352  P90: 0.053022  P95: 0.071786  P99: 0.141475
# weighted_false      Avg: 0.020634  P75: 0.028188  P90: 0.050749  P95: 0.068200  P99: 0.132477
# random_false        Avg: 0.021898  P75: 0.027304  P90: 0.056284  P95: 0.077721  P99: 0.152407
#
# ================================================================================
# private_enterprise | Load 0.8
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1559
#     sn          : 0
#     dn          : 4
#     input_time  : 0.761235665 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1559
#     sn          : 0
#     dn          : 4
#     input_time  : 0.761235665 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1559
#     sn          : 0
#     dn          : 4
#     input_time  : 0.761235665 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1559
#     sn          : 0
#     dn          : 4
#     input_time  : 0.761235665 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1559
#     sn          : 0
#     dn          : 4
#     input_time  : 0.761235665 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1559
#     sn          : 0
#     dn          : 4
#     input_time  : 0.761235665 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/private_enterprise_load_8_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.8
# --------------------------------------------------------------------------------
# conga               Avg: 0.026859  P75: 0.034526  P90: 0.061129  P95: 0.083997  P99: 0.170943
# ecmp                Avg: 0.026381  P75: 0.034191  P90: 0.060812  P95: 0.080508  P99: 0.157186
# weighted_true       Avg: 0.026977  P75: 0.035039  P90: 0.061122  P95: 0.083767  P99: 0.178257
# random_true         Avg: 0.029769  P75: 0.034358  P90: 0.062693  P95: 0.085558  P99: 0.186772
# weighted_false      Avg: 0.022576  P75: 0.028535  P90: 0.048272  P95: 0.065722  P99: 0.132737
# random_false        Avg: 0.027448  P75: 0.032336  P90: 0.063613  P95: 0.088808  P99: 0.200284
#
# ================================================================================
# private_enterprise | Load 0.9
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_873
#     sn          : 4
#     dn          : 3
#     input_time  : 2.420250289 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_873
#     sn          : 4
#     dn          : 3
#     input_time  : 2.420250289 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_873
#     sn          : 4
#     dn          : 3
#     input_time  : 2.420250289 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_873
#     sn          : 4
#     dn          : 3
#     input_time  : 2.420250289 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_873
#     sn          : 4
#     dn          : 3
#     input_time  : 2.420250289 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_873
#     sn          : 4
#     dn          : 3
#     input_time  : 2.420250289 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/private_enterprise_load_9_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.9
# --------------------------------------------------------------------------------
# conga               Avg: 0.034792  P75: 0.045471  P90: 0.075922  P95: 0.101278  P99: 0.188693
# ecmp                Avg: 0.033145  P75: 0.044878  P90: 0.074366  P95: 0.097896  P99: 0.190223
# weighted_true       Avg: 0.032774  P75: 0.045144  P90: 0.072851  P95: 0.099134  P99: 0.192176
# random_true         Avg: 0.035179  P75: 0.048412  P90: 0.080003  P95: 0.104506  P99: 0.208907
# weighted_false      Avg: 0.033072  P75: 0.045545  P90: 0.075027  P95: 0.100463  P99: 0.193406
# random_false        Avg: 0.033717  P75: 0.044714  P90: 0.074349  P95: 0.096452  P99: 0.198694
#
# ================================================================================
# social_media_cloud | Load 0.1
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1106
#     sn          : 5
#     dn          : 6
#     input_time  : 30.678284129 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1106
#     sn          : 5
#     dn          : 6
#     input_time  : 30.678284129 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1106
#     sn          : 5
#     dn          : 6
#     input_time  : 30.678284129 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1106
#     sn          : 5
#     dn          : 6
#     input_time  : 30.678284129 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1106
#     sn          : 5
#     dn          : 6
#     input_time  : 30.678284129 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1106
#     sn          : 5
#     dn          : 6
#     input_time  : 30.678284129 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/social_media_cloud_load_1_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.1
# --------------------------------------------------------------------------------
# conga               Avg: 0.007666  P75: 0.008738  P90: 0.020228  P95: 0.031417  P99: 0.059890
# ecmp                Avg: 0.007656  P75: 0.008767  P90: 0.020269  P95: 0.031489  P99: 0.060056
# weighted_true       Avg: 0.007650  P75: 0.008744  P90: 0.020301  P95: 0.031740  P99: 0.060060
# random_true         Avg: 0.007655  P75: 0.008731  P90: 0.020303  P95: 0.031428  P99: 0.060004
# weighted_false      Avg: 0.007651  P75: 0.008759  P90: 0.020292  P95: 0.031386  P99: 0.059890
# random_false        Avg: 0.007663  P75: 0.008768  P90: 0.020292  P95: 0.031389  P99: 0.060501
#
# ================================================================================
# social_media_cloud | Load 0.2
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_950
#     sn          : 3
#     dn          : 2
#     input_time  : 8.438710180 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_950
#     sn          : 3
#     dn          : 2
#     input_time  : 8.438710180 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_950
#     sn          : 3
#     dn          : 2
#     input_time  : 8.438710180 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_950
#     sn          : 3
#     dn          : 2
#     input_time  : 8.438710180 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_950
#     sn          : 3
#     dn          : 2
#     input_time  : 8.438710180 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_950
#     sn          : 3
#     dn          : 2
#     input_time  : 8.438710180 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/social_media_cloud_load_2_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.2
# --------------------------------------------------------------------------------
# conga               Avg: 0.008994  P75: 0.010850  P90: 0.023846  P95: 0.033925  P99: 0.064502
# ecmp                Avg: 0.009007  P75: 0.010840  P90: 0.023761  P95: 0.034162  P99: 0.063724
# weighted_true       Avg: 0.009010  P75: 0.010844  P90: 0.023644  P95: 0.033986  P99: 0.064399
# random_true         Avg: 0.009011  P75: 0.010811  P90: 0.023841  P95: 0.034190  P99: 0.064394
# weighted_false      Avg: 0.009001  P75: 0.010844  P90: 0.023674  P95: 0.033921  P99: 0.064594
# random_false        Avg: 0.009002  P75: 0.010861  P90: 0.023674  P95: 0.034151  P99: 0.064581
#
# ================================================================================
# social_media_cloud | Load 0.3
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_547
#     sn          : 5
#     dn          : 6
#     input_time  : 5.000835369 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_547
#     sn          : 5
#     dn          : 6
#     input_time  : 5.000835369 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_547
#     sn          : 5
#     dn          : 6
#     input_time  : 5.000835369 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_547
#     sn          : 5
#     dn          : 6
#     input_time  : 5.000835369 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_547
#     sn          : 5
#     dn          : 6
#     input_time  : 5.000835369 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_547
#     sn          : 5
#     dn          : 6
#     input_time  : 5.000835369 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/social_media_cloud_load_3_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.3
# --------------------------------------------------------------------------------
# conga               Avg: 0.013896  P75: 0.019165  P90: 0.036069  P95: 0.048810  P99: 0.082581
# ecmp                Avg: 0.013817  P75: 0.018760  P90: 0.035677  P95: 0.048611  P99: 0.082892
# weighted_true       Avg: 0.013895  P75: 0.019153  P90: 0.035682  P95: 0.049082  P99: 0.082530
# random_true         Avg: 0.013822  P75: 0.019124  P90: 0.035989  P95: 0.048492  P99: 0.082529
# weighted_false      Avg: 0.013801  P75: 0.018939  P90: 0.035854  P95: 0.048302  P99: 0.082531
# random_false        Avg: 0.013794  P75: 0.018906  P90: 0.035585  P95: 0.048594  P99: 0.082532
#
# ================================================================================
# social_media_cloud | Load 0.4
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5724
#     sn          : 7
#     dn          : 5
#     input_time  : 12.675429750 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5724
#     sn          : 7
#     dn          : 5
#     input_time  : 12.675429750 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5724
#     sn          : 7
#     dn          : 5
#     input_time  : 12.675429750 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5724
#     sn          : 7
#     dn          : 5
#     input_time  : 12.675429750 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5724
#     sn          : 7
#     dn          : 5
#     input_time  : 12.675429750 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5724
#     sn          : 7
#     dn          : 5
#     input_time  : 12.675429750 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/social_media_cloud_load_4_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.4
# ...
#     dn          : 6
#     input_time  : 2.392299764 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/university_load_5_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.5
# --------------------------------------------------------------------------------
# conga               Avg: 0.016331  P75: 0.019942  P90: 0.043806  P95: 0.063571  P99: 0.124708
# ecmp                Avg: 0.016544  P75: 0.020488  P90: 0.044009  P95: 0.063261  P99: 0.128756
# weighted_true       Avg: 0.015541  P75: 0.019215  P90: 0.038887  P95: 0.056388  P99: 0.106798
# random_true         Avg: 0.015194  P75: 0.018371  P90: 0.038811  P95: 0.055022  P99: 0.113491
# weighted_false      Avg: 0.014267  P75: 0.015754  P90: 0.035842  P95: 0.051994  P99: 0.110333
# random_false        Avg: 0.014122  P75: 0.015553  P90: 0.036283  P95: 0.053666  P99: 0.112783
#
# ================================================================================
# university | Load 0.6
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_612
#     sn          : 3
#     dn          : 6
#     input_time  : 0.121280322 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_612
#     sn          : 3
#     dn          : 6
#     input_time  : 0.121280322 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_612
#     sn          : 3
#     dn          : 6
#     input_time  : 0.121280322 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_612
#     sn          : 3
#     dn          : 6
#     input_time  : 0.121280322 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_612
#     sn          : 3
#     dn          : 6
#     input_time  : 0.121280322 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_612
#     sn          : 3
#     dn          : 6
#     input_time  : 0.121280322 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/university_load_6_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.6
# --------------------------------------------------------------------------------
# conga               Avg: 0.025636  P75: 0.024168  P90: 0.055710  P95: 0.084837  P99: 0.167918
# ecmp                Avg: 0.022489  P75: 0.025708  P90: 0.061101  P95: 0.084489  P99: 0.169045
# weighted_true       Avg: 0.020548  P75: 0.023836  P90: 0.050798  P95: 0.076404  P99: 0.154175
# random_true         Avg: 0.027038  P75: 0.023934  P90: 0.053285  P95: 0.078825  P99: 0.174356
# weighted_false      Avg: 0.017566  P75: 0.016954  P90: 0.044732  P95: 0.067973  P99: 0.147054
# random_false        Avg: 0.019078  P75: 0.016762  P90: 0.043229  P95: 0.069335  P99: 0.149968
#
# ================================================================================
# university | Load 0.7
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1686
#     sn          : 4
#     dn          : 1
#     input_time  : 2.806719533 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1686
#     sn          : 4
#     dn          : 1
#     input_time  : 2.806719533 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1686
#     sn          : 4
#     dn          : 1
#     input_time  : 2.806719533 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1686
#     sn          : 4
#     dn          : 1
#     input_time  : 2.806719533 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1686
#     sn          : 4
#     dn          : 1
#     input_time  : 2.806719533 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1686
#     sn          : 4
#     dn          : 1
#     input_time  : 2.806719533 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/university_load_7_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.7
# --------------------------------------------------------------------------------
# conga               Avg: 0.021000  P75: 0.029605  P90: 0.050754  P95: 0.067305  P99: 0.124532
# ecmp                Avg: 0.026491  P75: 0.032913  P90: 0.061584  P95: 0.083686  P99: 0.164664
# weighted_true       Avg: 0.019828  P75: 0.026250  P90: 0.044903  P95: 0.062033  P99: 0.117968
# random_true         Avg: 0.020296  P75: 0.026578  P90: 0.047268  P95: 0.065166  P99: 0.142204
# weighted_false      Avg: 0.016185  P75: 0.020136  P90: 0.037310  P95: 0.051960  P99: 0.109602
# random_false        Avg: 0.016175  P75: 0.019917  P90: 0.037548  P95: 0.053563  P99: 0.114802
#
# ================================================================================
# university | Load 0.8
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5790
#     sn          : 1
#     dn          : 6
#     input_time  : 0.027026184 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5790
#     sn          : 1
#     dn          : 6
#     input_time  : 0.027026184 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5790
#     sn          : 1
#     dn          : 6
#     input_time  : 0.027026184 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5790
#     sn          : 1
#     dn          : 6
#     input_time  : 0.027026184 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5790
#     sn          : 1
#     dn          : 6
#     input_time  : 0.027026184 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5790
#     sn          : 1
#     dn          : 6
#     input_time  : 0.027026184 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/university_load_8_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.8
# --------------------------------------------------------------------------------
# conga               Avg: 0.017236  P75: 0.021944  P90: 0.037904  P95: 0.050858  P99: 0.106270
# ecmp                Avg: 0.022491  P75: 0.025908  P90: 0.052676  P95: 0.072864  P99: 0.155649
# weighted_true       Avg: 0.017430  P75: 0.020876  P90: 0.037455  P95: 0.051737  P99: 0.108069
# random_true         Avg: 0.017108  P75: 0.020873  P90: 0.037387  P95: 0.050874  P99: 0.107532
# weighted_false      Avg: 0.014430  P75: 0.015783  P90: 0.029688  P95: 0.042469  P99: 0.102357
# random_false        Avg: 0.014653  P75: 0.016258  P90: 0.030541  P95: 0.042673  P99: 0.112225
#
# ================================================================================
# university | Load 0.9
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_715
#     sn          : 3
#     dn          : 7
#     input_time  : 0.104824366 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_715
#     sn          : 3
#     dn          : 7
#     input_time  : 0.104824366 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_715
#     sn          : 3
#     dn          : 7
#     input_time  : 0.104824366 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_715
#     sn          : 3
#     dn          : 7
#     input_time  : 0.104824366 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_715
#     sn          : 3
#     dn          : 7
#     input_time  : 0.104824366 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_715
#     sn          : 3
#     dn          : 7
#     input_time  : 0.104824366 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/university_load_9_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.9
# --------------------------------------------------------------------------------
# conga               Avg: 0.023476  P75: 0.028907  P90: 0.050072  P95: 0.068307  P99: 0.168600
# ecmp                Avg: 0.033420  P75: 0.043619  P90: 0.075888  P95: 0.109225  P99: 0.236339
# weighted_true       Avg: 0.022839  P75: 0.026170  P90: 0.045629  P95: 0.063583  P99: 0.158224
# random_true         Avg: 0.022436  P75: 0.024067  P90: 0.041302  P95: 0.059207  P99: 0.196835
# weighted_false      Avg: 0.016796  P75: 0.015848  P90: 0.030894  P95: 0.046989  P99: 0.164869
# random_false        Avg: 0.017899  P75: 0.017614  P90: 0.034951  P95: 0.053559  P99: 0.159307
#
# ================================================================================
# MATCHING COMPLETE
# ================================================================================

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

# ------------------ CONFIG ------------------

save_dir = Path(
    "/home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results"
)

graph_dir = save_dir / "graph"
graph_dir.mkdir(parents=True, exist_ok=True)

benchmarks = [
    "private_enterprise",
    "social_media_cloud",
    "commercial_cloud",
    "university"
]

loads = range(1, 10)

SMALL = 100 * 1024        # 100 KB
LARGE = 1 * 1024 * 1024   # 1 MB

algorithms = [
    "conga",
    #"conga_new",
    #"conga-ecmp",
    "ecmp",
    #"ecmp_new",
    
    #"lrtt_true",
    #"lrtt_false",
    
    #"weighted",
    #"random",
    #"top2"
    
    "weighted_true",
    "weighted_false",

    "random_true",
    "random_false",

    #"top2_true",
    #"top2_false"
]

label_map = {
    "conga": "Conga",
    #"conga_new": "Conga_New",
    #"conga-ecmp": "Conga-ECMP",
    "ecmp": "ECMP",
    #"ecmp_new": "ECMP_New",
    #"rtt": "RTT",

    "lrtt_true": "Lowest RTT (Timeout)",
    "lrtt_false": "Lowest RTT (No Timeout)",
    
    "weighted": "Weighted ECMP",
    "random": "Power-of-2 Random",
    "top2": "Power-of-2 Top2",
    
    "weighted_true": "Weighted ECMP (Timeout)",
    "weighted_false": "Weighted ECMP (No Timeout)",

    "random_true": "Power-of-2 Random (Timeout)",
    "random_false": "Power-of-2 Random (No Timeout)",

    "top2_true": "Power-of-2 Top2 (Timeout)",
    "top2_false": "Power-of-2 Top2 (No Timeout)"
}

color_map = {
    "conga": "tab:blue",
    #"conga_new": "tab:orange",
    #"conga-ecmp": "tab:green",
    "ecmp": "tab:red",
    #"ecmp_new": "tab:purple",
    #"rtt": "tab:brown",

    "lrtt_true": "tab:cyan",
    "lrtt_false": "tab:cyan",
    
    "weighted": "tab:pink",
    "random": "tab:gray",
    "top2": "tab:olive",
    
    "weighted_true": "tab:brown",
    "weighted_false": "tab:brown",

    "random_true": "tab:orange",
    "random_false": "tab:orange",

    "top2_true": "tab:gray",
    "top2_false": "tab:gray",
}

marker_map = {
    "conga": "o",
    #"conga_new": "x",
    #"conga-ecmp": "X",
    "ecmp": "s",
    #"ecmp_new": "*",
    #"rtt": "^",

    "lrtt_true": "1",
    "lrtt_false": "2",
    
    "weighted": "D",
    "random": "v",
    "top2": "P",
    
    "weighted_true": "D",
    "weighted_false": "d",

    "random_true": "^",
    "random_false": "v",

    "top2_true": "P",
    "top2_false": "X"
}

# ------------------ GLOBAL Y-LIMITS ------------------

small_global = []
large_global = []

for benchmark in benchmarks:
    for load in loads:

        csv_path = save_dir / f"{benchmark}_load_{load}_full.csv"

        if not csv_path.exists():
            continue

        df = pd.read_csv(csv_path)

        if df.empty:
            continue

        small_df = df[df["flow_size"] < SMALL]
        large_df = df[df["flow_size"] > LARGE]

        for algo in algorithms:
            col = f"FCT(s)_{algo}"

            if not small_df.empty:
                small_global.append(small_df[col].mean())

            if not large_df.empty:
                large_global.append(large_df[col].mean())

small_min = min(small_global)
small_max = max(small_global)

large_min = min(large_global)
large_max = max(large_global)

small_margin = 0.05 * (small_max - small_min)
large_margin = 0.05 * (large_max - large_min)

small_ylim = (small_min - small_margin, small_max + small_margin)
large_ylim = (large_min - large_margin, large_max + large_margin)

# ------------------ ANALYSIS ------------------

for benchmark in benchmarks:

    print(f"\n===== {benchmark} =====")

    load_vals = []

    small_results = {algo: [] for algo in algorithms}
    large_results = {algo: [] for algo in algorithms}

    for load in loads:

        csv_path = save_dir / f"{benchmark}_load_{load}_full.csv"

        if not csv_path.exists():
            print(f"Missing: {csv_path}")
            continue

        df = pd.read_csv(csv_path)

        if df.empty:
            continue

        small_df = df[df["flow_size"] < SMALL]
        large_df = df[df["flow_size"] > LARGE]

        # ---------- Small Flows ----------

        for algo in algorithms:

            col = f"FCT(s)_{algo}"

            if not small_df.empty:
                small_results[algo].append(
                    small_df[col].mean()
                )
            else:
                small_results[algo].append(np.nan)

        # ---------- Large Flows ----------

        for algo in algorithms:

            col = f"FCT(s)_{algo}"

            if not large_df.empty:
                large_results[algo].append(
                    large_df[col].mean()
                )
            else:
                large_results[algo].append(np.nan)

        load_vals.append(load / 10)

    # ==================================================
    # SMALL FLOWS
    # ==================================================

    plt.figure(figsize=(8, 5))

    for algo in algorithms:

        plt.plot(
            load_vals,
            small_results[algo],
            marker=marker_map[algo],
            color=color_map[algo],
            linestyle="--" if algo.endswith("_false") else "-",
            linewidth=2,
            label=label_map[algo]
        )

    plt.xlabel("Network Load")
    plt.ylabel("Average FCT (s)")
    plt.title(f"{benchmark}: Small Flows (<100 KB)")
    #plt.ylim(small_ylim)
    plt.grid(True)
    plt.legend()

    out_path = graph_dir / f"{benchmark}_SMALL_vs_load.png"

    plt.tight_layout()
    plt.savefig(out_path, dpi=300)
    plt.close()

    print(f"Saved: {out_path}")

    # ==================================================
    # LARGE FLOWS
    # ==================================================

    plt.figure(figsize=(8, 5))

    for algo in algorithms:

        plt.plot(
            load_vals,
            large_results[algo],
            marker=marker_map[algo],
            color=color_map[algo],
            linestyle="--" if algo.endswith("_false") else "-",
            linewidth=2,
            label=label_map[algo]
        )

    plt.xlabel("Network Load")
    plt.ylabel("Average FCT (s)")
    plt.title(f"{benchmark}: Large Flows (>1 MB)")
    #plt.ylim(large_ylim)
    plt.grid(True)
    plt.legend()

    out_path = graph_dir / f"{benchmark}_LARGE_vs_load.png"

    plt.tight_layout()
    plt.savefig(out_path, dpi=300)
    plt.close()

    print(f"Saved: {out_path}")

print("\nDone: Small vs Large flow comparison for all algorithms.")
# Out:
# ===== private_enterprise =====
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/graph/private_enterprise_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/graph/private_enterprise_LARGE_vs_load.png
#
# ===== social_media_cloud =====
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/graph/social_media_cloud_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/graph/social_media_cloud_LARGE_vs_load.png
#
# ===== commercial_cloud =====
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/graph/commercial_cloud_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/graph/commercial_cloud_LARGE_vs_load.png
#
# ===== university =====
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/graph/university_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/graph/university_LARGE_vs_load.png
#
# Done: Small vs Large flow comparison for all algorithms.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

# ============================================================
# CONFIG
# ============================================================

save_dir = Path(
    "/home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results"
)

baseline = "ecmp"

graph_dir = save_dir / "graph" / f"normalised_vs_{baseline}"
graph_dir.mkdir(parents=True, exist_ok=True)

benchmarks = [
    "private_enterprise",
    "social_media_cloud",
    "commercial_cloud",
    "university"
]

# ------------------------------------------------------------
# Loads
# ------------------------------------------------------------

loads = range(1, 8)

# ------------------------------------------------------------
# Flow size thresholds
# ------------------------------------------------------------

SMALL = 100 * 1024          # 100 KB
LARGE = 1 * 1024 * 1024     # 1 MB


# ============================================================
# ALGORITHMS
#
# Comment/uncomment algorithms here as required.
# ECMP is the baseline and therefore does NOT need to be here.
# ============================================================

algorithms = [

    "conga",

    # "lrtt_true",
    # "lrtt_false",

    "weighted_true",
    "weighted_false",

    "random_true",
    "random_false",

    # "top2_true",
    # "top2_false",

    # "weighted",
    # "random",
    # "top2",
]


# ============================================================
# LABELS
# ============================================================

label_map = {

    "conga":
        "Conga",

    "lrtt_true":
        "Lowest RTT (Timeout)",

    "lrtt_false":
        "Lowest RTT (No Timeout)",

    "weighted":
        "Weighted ECMP",

    "random":
        "Power-of-2 Random",

    "top2":
        "Power-of-2 Top2",

    "weighted_true":
        "Weighted ECMP (Timeout)",

    "weighted_false":
        "Weighted ECMP (No Timeout)",

    "random_true":
        "Power-of-2 Random (Timeout)",

    "random_false":
        "Power-of-2 Random (No Timeout)",

    "top2_true":
        "Power-of-2 Top2 (Timeout)",

    "top2_false":
        "Power-of-2 Top2 (No Timeout)",
}


# ============================================================
# COLORS
# ============================================================

color_map = {

    "conga":
        "tab:blue",

    "lrtt_true":
        "tab:cyan",

    "lrtt_false":
        "tab:cyan",

    "weighted":
        "tab:purple",

    "random":
        "tab:gray",

    "top2":
        "tab:olive",

    "weighted_true":
        "tab:brown",

    "weighted_false":
        "tab:brown",

    "random_true":
        "tab:orange",

    "random_false":
        "tab:orange",

    "top2_true":
        "tab:gray",

    "top2_false":
        "tab:gray",
}


# ============================================================
# MARKERS
# ============================================================

marker_map = {

    "conga":
        "o",

    "lrtt_true":
        "1",

    "lrtt_false":
        "2",

    "weighted":
        "^",

    "random":
        "D",

    "top2":
        "P",

    "weighted_true":
        "D",

    "weighted_false":
        "d",

    "random_true":
        "^",

    "random_false":
        "v",

    "top2_true":
        "P",

    "top2_false":
        "X",
}


# ============================================================
# RESULT STORAGE
# ============================================================

summary_results = {}


# ============================================================
# MAIN ANALYSIS
# ============================================================

for benchmark in benchmarks:

    print()
    print("=" * 80)
    print(f"BENCHMARK: {benchmark}")
    print("=" * 80)

    # --------------------------------------------------------
    # Store load values
    # --------------------------------------------------------

    load_vals = []

    # --------------------------------------------------------
    # Results for each algorithm
    #
    # Each entry will contain one value per network load.
    # --------------------------------------------------------

    small_results = {
        algo: []
        for algo in algorithms
    }

    large_results = {
        algo: []
        for algo in algorithms
    }

    # ========================================================
    # PROCESS EACH LOAD
    # ========================================================

    for load in loads:

        print()
        print(
            f"Processing {benchmark} | Load 0.{load}"
        )

        csv_path = (
            save_dir /
            f"{benchmark}_load_{load}_full.csv"
        )

        # ----------------------------------------------------
        # Check file
        # ----------------------------------------------------

        if not csv_path.exists():

            print(
                f"Missing: {csv_path}"
            )

            continue

        # ----------------------------------------------------
        # Read CSV
        # ----------------------------------------------------

        df = pd.read_csv(
            csv_path
        )

        if df.empty:

            print(
                "Empty dataframe."
            )

            continue

        # ====================================================
        # CHECK REQUIRED COLUMNS
        # ====================================================

        baseline_col = (
            f"FCT(s)_{baseline}"
        )

        if baseline_col not in df.columns:

            print(
                f"ERROR: Missing baseline column "
                f"{baseline_col}"
            )

            continue

        missing_algorithms = []

        for algo in algorithms:

            col = f"FCT(s)_{algo}"

            if col not in df.columns:

                missing_algorithms.append(
                    col
                )

        if missing_algorithms:

            print(
                "ERROR: Missing algorithm columns:"
            )

            for col in missing_algorithms:

                print(
                    f"    {col}"
                )

            continue

        # ====================================================
        # REMOVE INVALID BASELINE FCT VALUES
        # ====================================================

        df = df[
            df[baseline_col] > 0
        ].copy()

        if df.empty:

            print(
                "No valid flows after removing "
                "zero/negative ECMP FCT."
            )

            continue

        # ====================================================
        # FLOW SIZE SPLIT
        # ====================================================

        small_df = df[
            df["flow_size"] < SMALL
        ].copy()

        large_df = df[
            df["flow_size"] > LARGE
        ].copy()

        print(
            f"Small flows: {len(small_df):,}"
        )

        print(
            f"Large flows: {len(large_df):,}"
        )

        # ====================================================
        # BASELINE AVERAGES
        #
        # IMPORTANT:
        #
        # We calculate:
        #
        #     mean(FCT_algorithm)
        #     --------------------
        #     mean(FCT_ECMP)
        #
        # NOT:
        #
        #     mean(FCT_algorithm / FCT_ECMP)
        #
        # This makes the normalized graph consistent with
        # the Average FCT graph.
        # ====================================================

        # ----------------------------------------------------
        # SMALL FLOWS
        # ----------------------------------------------------

        if not small_df.empty:

            baseline_small_avg = (
                small_df[baseline_col].mean()
            )

        else:

            baseline_small_avg = np.nan

        # ----------------------------------------------------
        # LARGE FLOWS
        # ----------------------------------------------------

        if not large_df.empty:

            baseline_large_avg = (
                large_df[baseline_col].mean()
            )

        else:

            baseline_large_avg = np.nan

        # ====================================================
        # NORMALIZED RESULTS
        # ====================================================

        for algo in algorithms:

            algo_col = (
                f"FCT(s)_{algo}"
            )

            # ------------------------------------------------
            # SMALL FLOWS
            # ------------------------------------------------

            if (
                not small_df.empty
                and baseline_small_avg > 0
            ):

                algo_small_avg = (
                    small_df[algo_col].mean()
                )

                normalized_small = (
                    algo_small_avg /
                    baseline_small_avg
                )

                small_results[algo].append(
                    normalized_small
                )

            else:

                small_results[algo].append(
                    np.nan
                )

            # ------------------------------------------------
            # LARGE FLOWS
            # ------------------------------------------------

            if (
                not large_df.empty
                and baseline_large_avg > 0
            ):

                algo_large_avg = (
                    large_df[algo_col].mean()
                )

                normalized_large = (
                    algo_large_avg /
                    baseline_large_avg
                )

                large_results[algo].append(
                    normalized_large
                )

            else:

                large_results[algo].append(
                    np.nan
                )

        # ----------------------------------------------------
        # Store load
        # ----------------------------------------------------

        load_vals.append(
            load / 10
        )

        # ====================================================
        # PRINT NORMALIZED VALUES
        # ====================================================

        print()
        print(
            "Normalized Average FCT:"
        )

        if not small_df.empty:

            print(
                f"  Small flows "
                f"(ECMP avg = "
                f"{baseline_small_avg:.6f}s)"
            )

            for algo in algorithms:

                value = (
                    small_results[algo][-1]
                )

                print(
                    f"    {label_map[algo]:35s}: "
                    f"{value:.4f}"
                )

        if not large_df.empty:

            print(
                f"  Large flows "
                f"(ECMP avg = "
                f"{baseline_large_avg:.6f}s)"
            )

            for algo in algorithms:

                value = (
                    large_results[algo][-1]
                )

                print(
                    f"    {label_map[algo]:35s}: "
                    f"{value:.4f}"
                )


    # ========================================================
    # STORE RESULTS
    # ========================================================

    summary_results[benchmark] = {

        "loads":
            load_vals,

        "small":
            small_results,

        "large":
            large_results
    }


    # ========================================================
    # SMALL FLOWS PLOT
    # ========================================================

    plt.figure(
        figsize=(10, 7),
        dpi=120
    )

    for algo in algorithms:

        plt.plot(

            load_vals,

            small_results[algo],

            marker=marker_map[algo],

            color=color_map[algo],

            linestyle=(
                "--"
                if algo.endswith("_false")
                else "-"
            ),

            linewidth=2,

            markersize=7,

            label=(
                f"{label_map[algo]} / ECMP"
            )
        )

    # --------------------------------------------------------
    # ECMP baseline
    # --------------------------------------------------------

    plt.axhline(
        y=1,
        linestyle="--",
        color="black",
        linewidth=1.5,
        label="ECMP baseline"
    )

    # --------------------------------------------------------
    # Labels
    # --------------------------------------------------------

    plt.xlabel(
        "Network Load"
    )

    plt.ylabel(
        "Normalized Average FCT"
    )

    plt.title(
        f"{benchmark}: "
        f"Small Flows (<100 KB)"
    )

    # --------------------------------------------------------
    # Y-axis
    # --------------------------------------------------------

    plt.ylim(
        0,
        1.8
    )

    plt.yticks(
        np.arange(
            0,
            1.81,
            0.2
        )
    )

    # --------------------------------------------------------
    # Grid
    # --------------------------------------------------------

    plt.grid(
        True,
        alpha=0.3
    )

    plt.legend()

    plt.tight_layout()

    out_path = (
        graph_dir /
        f"{benchmark}_SMALL_relative_vs_load.png"
    )

    plt.savefig(
        out_path,
        dpi=300,
        bbox_inches="tight"
    )

    plt.close()

    print()
    print(
        f"Saved: {out_path}"
    )


    # ========================================================
    # LARGE FLOWS PLOT
    # ========================================================

    plt.figure(
        figsize=(10, 7),
        dpi=120
    )

    for algo in algorithms:

        plt.plot(

            load_vals,

            large_results[algo],

            marker=marker_map[algo],

            color=color_map[algo],

            linestyle=(
                "--"
                if algo.endswith("_false")
                else "-"
            ),

            linewidth=2,

            markersize=7,

            label=(
                f"{label_map[algo]} / ECMP"
            )
        )

    # --------------------------------------------------------
    # ECMP baseline
    # --------------------------------------------------------

    plt.axhline(
        y=1,
        linestyle="--",
        color="black",
        linewidth=1.5,
        label="ECMP baseline"
    )

    # --------------------------------------------------------
    # Labels
    # --------------------------------------------------------

    plt.xlabel(
        "Network Load"
    )

    plt.ylabel(
        "Normalized Average FCT"
    )

    plt.title(
        f"{benchmark}: "
        f"Large Flows (>1 MB)"
    )

    # --------------------------------------------------------
    # Y-axis
    # --------------------------------------------------------

    plt.ylim(
        0,
        1.4
    )

    plt.yticks(
        np.arange(
            0,
            1.41,
            0.2
        )
    )

    # --------------------------------------------------------
    # Grid
    # --------------------------------------------------------

    plt.grid(
        True,
        alpha=0.3
    )

    plt.legend()

    plt.tight_layout()

    out_path = (
        graph_dir /
        f"{benchmark}_LARGE_relative_vs_load.png"
    )

    plt.savefig(
        out_path,
        dpi=300,
        bbox_inches="tight"
    )

    plt.close()

    print(
        f"Saved: {out_path}"
    )


# ============================================================
# DONE
# ============================================================

print()
print("=" * 80)
print(
    "DONE: Normalized Average FCT graphs generated."
)
print("=" * 80)
# Out:
# ================================================================================
# BENCHMARK: private_enterprise
# ================================================================================
#
# Processing private_enterprise | Load 0.1
# Small flows: 5,787
# Large flows: 24
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.004123s)
#     Conga                              : 0.9834
#     Weighted ECMP (Timeout)            : 0.9904
#     Weighted ECMP (No Timeout)         : 0.9902
#     Power-of-2 Random (Timeout)        : 0.9919
#     Power-of-2 Random (No Timeout)     : 0.9880
#   Large flows (ECMP avg = 0.383606s)
#     Conga                              : 0.9997
#     Weighted ECMP (Timeout)            : 0.9996
#     Weighted ECMP (No Timeout)         : 1.0003
#     Power-of-2 Random (Timeout)        : 1.0000
#     Power-of-2 Random (No Timeout)     : 1.0000
#
# Processing private_enterprise | Load 0.2
# Small flows: 5,791
# Large flows: 16
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.005850s)
#     Conga                              : 0.9847
#     Weighted ECMP (Timeout)            : 1.0085
#     Weighted ECMP (No Timeout)         : 0.9423
#     Power-of-2 Random (Timeout)        : 0.9786
#     Power-of-2 Random (No Timeout)     : 0.9477
#   Large flows (ECMP avg = 0.376814s)
#     Conga                              : 1.0015
#     Weighted ECMP (Timeout)            : 1.0937
#     Weighted ECMP (No Timeout)         : 1.0048
#     Power-of-2 Random (Timeout)        : 0.9965
#     Power-of-2 Random (No Timeout)     : 1.0724
#
# Processing private_enterprise | Load 0.3
# Small flows: 5,830
# Large flows: 16
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.008327s)
#     Conga                              : 1.0056
#     Weighted ECMP (Timeout)            : 0.9974
#     Weighted ECMP (No Timeout)         : 1.0032
#     Power-of-2 Random (Timeout)        : 0.9992
#     Power-of-2 Random (No Timeout)     : 1.0018
#   Large flows (ECMP avg = 0.491647s)
#     Conga                              : 0.9990
#     Weighted ECMP (Timeout)            : 1.0003
#     Weighted ECMP (No Timeout)         : 1.0017
#     Power-of-2 Random (Timeout)        : 0.9987
#     Power-of-2 Random (No Timeout)     : 1.0011
#
# Processing private_enterprise | Load 0.4
# Small flows: 5,786
# Large flows: 16
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.009791s)
#     Conga                              : 1.0056
#     Weighted ECMP (Timeout)            : 1.0291
#     Weighted ECMP (No Timeout)         : 1.0043
#     Power-of-2 Random (Timeout)        : 1.0215
#     Power-of-2 Random (No Timeout)     : 0.9945
#   Large flows (ECMP avg = 0.449075s)
#     Conga                              : 0.9998
#     Weighted ECMP (Timeout)            : 1.0058
#     Weighted ECMP (No Timeout)         : 1.0041
#     Power-of-2 Random (Timeout)        : 0.9973
#     Power-of-2 Random (No Timeout)     : 1.0153
#
# Processing private_enterprise | Load 0.5
# Small flows: 5,784
# Large flows: 20
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.012654s)
#     Conga                              : 0.9641
#     Weighted ECMP (Timeout)            : 0.9828
#     Weighted ECMP (No Timeout)         : 0.9385
#     Power-of-2 Random (Timeout)        : 0.9419
#     Power-of-2 Random (No Timeout)     : 0.9410
#   Large flows (ECMP avg = 0.477085s)
#     Conga                              : 1.0588
#     Weighted ECMP (Timeout)            : 1.0213
#     Weighted ECMP (No Timeout)         : 1.0233
#     Power-of-2 Random (Timeout)        : 1.0515
#     Power-of-2 Random (No Timeout)     : 1.0049
#
# Processing private_enterprise | Load 0.6
# Small flows: 5,801
# Large flows: 21
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.016396s)
#     Conga                              : 0.9625
#     Weighted ECMP (Timeout)            : 0.9677
#     Weighted ECMP (No Timeout)         : 0.9427
#     Power-of-2 Random (Timeout)        : 0.9796
#     Power-of-2 Random (No Timeout)     : 0.9109
#   Large flows (ECMP avg = 0.429686s)
#     Conga                              : 1.0272
#     Weighted ECMP (Timeout)            : 1.0276
#     Weighted ECMP (No Timeout)         : 1.0526
#     Power-of-2 Random (Timeout)        : 1.0163
#     Power-of-2 Random (No Timeout)     : 1.0584
#
# Processing private_enterprise | Load 0.7
# Small flows: 5,802
# Large flows: 14
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.017762s)
#     Conga                              : 1.0432
#     Weighted ECMP (Timeout)            : 0.9459
#     Weighted ECMP (No Timeout)         : 0.9854
#     Power-of-2 Random (Timeout)        : 1.0340
#     Power-of-2 Random (No Timeout)     : 1.0544
#   Large flows (ECMP avg = 0.462984s)
#     Conga                              : 0.9874
#     Weighted ECMP (Timeout)            : 1.0179
#     Weighted ECMP (No Timeout)         : 1.1598
#     Power-of-2 Random (Timeout)        : 0.9809
#     Power-of-2 Random (No Timeout)     : 0.9806
#
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/graph/normalised_vs_ecmp/private_enterprise_SMALL_relative_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/graph/normalised_vs_ecmp/private_enterprise_LARGE_relative_vs_load.png
#
# ================================================================================
# BENCHMARK: social_media_cloud
# ================================================================================
#
# Processing social_media_cloud | Load 0.1
# Small flows: 5,355
# Large flows: 8
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.005199s)
#     Conga                              : 1.0000
#     Weighted ECMP (Timeout)            : 1.0002
#     Weighted ECMP (No Timeout)         : 0.9996
#     Power-of-2 Random (Timeout)        : 1.0003
#     Power-of-2 Random (No Timeout)     : 1.0018
#   Large flows (ECMP avg = 0.127149s)
#     Conga                              : 1.0174
#     Weighted ECMP (Timeout)            : 0.9973
#     Weighted ECMP (No Timeout)         : 0.9997
#     Power-of-2 Random (Timeout)        : 1.0015
#     Power-of-2 Random (No Timeout)     : 0.9997
#
# Processing social_media_cloud | Load 0.2
# Small flows: 5,433
# Large flows: 3
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.006789s)
#     Conga                              : 0.9986
#     Weighted ECMP (Timeout)            : 0.9999
#     Weighted ECMP (No Timeout)         : 0.9974
#     Power-of-2 Random (Timeout)        : 1.0001
#     Power-of-2 Random (No Timeout)     : 0.9983
#   Large flows (ECMP avg = 0.153454s)
#     Conga                              : 1.0024
#     Weighted ECMP (Timeout)            : 1.0014
#     Weighted ECMP (No Timeout)         : 1.0019
#     Power-of-2 Random (Timeout)        : 1.0041
#     Power-of-2 Random (No Timeout)     : 1.0017
#
# Processing social_media_cloud | Load 0.3
# Small flows: 5,364
# Large flows: 8
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.010792s)
#     Conga                              : 1.0104
#     Weighted ECMP (Timeout)            : 1.0057
#     Weighted ECMP (No Timeout)         : 0.9990
#     Power-of-2 Random (Timeout)        : 1.0016
#     Power-of-2 Random (No Timeout)     : 1.0001
#   Large flows (ECMP avg = 0.140417s)
#     Conga                              : 0.9935
#     Weighted ECMP (Timeout)            : 1.0001
#     Weighted ECMP (No Timeout)         : 0.9984
#     Power-of-2 Random (Timeout)        : 0.9983
#     Power-of-2 Random (No Timeout)     : 1.0003
#
# Processing social_media_cloud | Load 0.4
# Small flows: 5,327
# Large flows: 3
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.016237s)
#     Conga                              : 0.9852
#     Weighted ECMP (Timeout)            : 0.9832
#     Weighted ECMP (No Timeout)         : 0.9825
#     Power-of-2 Random (Timeout)        : 0.9973
#     Power-of-2 Random (No Timeout)     : 0.9950
#   Large flows (ECMP avg = 0.169711s)
#     Conga                              : 1.0608
#     Weighted ECMP (Timeout)            : 1.0542
#     Weighted ECMP (No Timeout)         : 1.0362
#     Power-of-2 Random (Timeout)        : 1.0855
#     Power-of-2 Random (No Timeout)     : 1.0195
#
# Processing social_media_cloud | Load 0.5
# Small flows: 5,317
# Large flows: 8
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.019982s)
#     Conga                              : 0.9948
#     Weighted ECMP (Timeout)            : 0.9726
#     Weighted ECMP (No Timeout)         : 0.9812
#     Power-of-2 Random (Timeout)        : 1.0011
#     Power-of-2 Random (No Timeout)     : 1.0066
#   Large flows (ECMP avg = 0.189345s)
#     Conga                              : 1.0285
#     Weighted ECMP (Timeout)            : 1.0636
#     Weighted ECMP (No Timeout)         : 1.0183
#     Power-of-2 Random (Timeout)        : 1.0409
#     Power-of-2 Random (No Timeout)     : 1.0142
#
# Processing social_media_cloud | Load 0.6
# Small flows: 5,318
# Large flows: 6
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.021381s)
#     Conga                              : 1.0528
#     Weighted ECMP (Timeout)            : 1.0460
#     Weighted ECMP (No Timeout)         : 1.0295
#     Power-of-2 Random (Timeout)        : 1.0379
#     Power-of-2 Random (No Timeout)     : 1.0446
#   Large flows (ECMP avg = 0.279021s)
#     Conga                              : 0.9941
#     Weighted ECMP (Timeout)            : 0.9213
#     Weighted ECMP (No Timeout)         : 0.9772
#     Power-of-2 Random (Timeout)        : 1.0084
#     Power-of-2 Random (No Timeout)     : 1.0057
#
# Processing social_media_cloud | Load 0.7
# Small flows: 5,344
# Large flows: 4
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.029359s)
#     Conga                              : 0.9983
#     Weighted ECMP (Timeout)            : 1.0222
#     Weighted ECMP (No Timeout)         : 0.9947
#     Power-of-2 Random (Timeout)        : 1.0014
#     Power-of-2 Random (No Timeout)     : 0.9788
#   Large flows (ECMP avg = 0.268981s)
#     Conga                              : 1.0358
#     Weighted ECMP (Timeout)            : 1.0319
#     Weighted ECMP (No Timeout)         : 0.9864
#     Power-of-2 Random (Timeout)        : 1.0189
#     Power-of-2 Random (No Timeout)     : 1.1435
#
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/graph/normalised_vs_ecmp/social_media_cloud_SMALL_relative_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/graph/normalised_vs_ecmp/social_media_cloud_LARGE_relative_vs_load.png
#
# ================================================================================
# BENCHMARK: commercial_cloud
# ================================================================================
#
# Processing commercial_cloud | Load 0.1
# Small flows: 5,793
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.004767s)
#     Conga                              : 0.9972
#     Weighted ECMP (Timeout)            : 0.9986
#     Weighted ECMP (No Timeout)         : 0.9982
#     Power-of-2 Random (Timeout)        : 0.9979
#     Power-of-2 Random (No Timeout)     : 0.9995
#   Large flows (ECMP avg = 0.210760s)
#     Conga                              : 0.9994
#     Weighted ECMP (Timeout)            : 1.0000
#     Weighted ECMP (No Timeout)         : 0.9993
#     Power-of-2 Random (Timeout)        : 0.9994
#     Power-of-2 Random (No Timeout)     : 0.9998
#
# Processing commercial_cloud | Load 0.2
# Small flows: 5,785
# Large flows: 21
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.006635s)
#     Conga                              : 0.9921
#     Weighted ECMP (Timeout)            : 0.9951
#     Weighted ECMP (No Timeout)         : 0.9975
#     Power-of-2 Random (Timeout)        : 0.9972
#     Power-of-2 Random (No Timeout)     : 0.9963
#   Large flows (ECMP avg = 0.249592s)
#     Conga                              : 0.9999
#     Weighted ECMP (Timeout)            : 0.9994
#     Weighted ECMP (No Timeout)         : 0.9998
#     Power-of-2 Random (Timeout)        : 1.0000
#     Power-of-2 Random (No Timeout)     : 1.0000
#
# Processing commercial_cloud | Load 0.3
# Small flows: 5,781
# Large flows: 20
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.009912s)
#     Conga                              : 1.0006
#     Weighted ECMP (Timeout)            : 1.0010
#     Weighted ECMP (No Timeout)         : 1.0003
#     Power-of-2 Random (Timeout)        : 0.9993
#     Power-of-2 Random (No Timeout)     : 0.9934
#   Large flows (ECMP avg = 0.257786s)
#     Conga                              : 1.0000
#     Weighted ECMP (Timeout)            : 1.0018
#     Weighted ECMP (No Timeout)         : 1.0011
#     Power-of-2 Random (Timeout)        : 1.0011
#     Power-of-2 Random (No Timeout)     : 1.0003
#
# Processing commercial_cloud | Load 0.4
# Small flows: 5,778
# Large flows: 12
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.012234s)
#     Conga                              : 0.9839
#     Weighted ECMP (Timeout)            : 0.9941
#     Weighted ECMP (No Timeout)         : 0.9950
#     Power-of-2 Random (Timeout)        : 0.9983
#     Power-of-2 Random (No Timeout)     : 0.9906
#   Large flows (ECMP avg = 0.287671s)
#     Conga                              : 1.0730
#     Weighted ECMP (Timeout)            : 0.9982
#     Weighted ECMP (No Timeout)         : 0.9990
#     Power-of-2 Random (Timeout)        : 1.0009
#     Power-of-2 Random (No Timeout)     : 1.0018
#
# Processing commercial_cloud | Load 0.5
# Small flows: 5,811
# Large flows: 23
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.017936s)
#     Conga                              : 1.0116
#     Weighted ECMP (Timeout)            : 1.0130
#     Weighted ECMP (No Timeout)         : 1.0120
#     Power-of-2 Random (Timeout)        : 1.0033
#     Power-of-2 Random (No Timeout)     : 1.0057
#   Large flows (ECMP avg = 0.320922s)
#     Conga                              : 0.9988
#     Weighted ECMP (Timeout)            : 1.0006
#     Weighted ECMP (No Timeout)         : 1.0029
#     Power-of-2 Random (Timeout)        : 1.0053
#     Power-of-2 Random (No Timeout)     : 1.0034
#
# Processing commercial_cloud | Load 0.6
# Small flows: 5,787
# Large flows: 6
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.016071s)
#     Conga                              : 1.0697
#     Weighted ECMP (Timeout)            : 1.0488
#     Weighted ECMP (No Timeout)         : 1.0969
#     Power-of-2 Random (Timeout)        : 1.0005
#     Power-of-2 Random (No Timeout)     : 0.9934
#   Large flows (ECMP avg = 0.540578s)
#     Conga                              : 0.9868
#     Weighted ECMP (Timeout)            : 1.0367
#     Weighted ECMP (No Timeout)         : 1.0248
#     Power-of-2 Random (Timeout)        : 0.9977
#     Power-of-2 Random (No Timeout)     : 0.9894
#
# Processing commercial_cloud | Load 0.7
# Small flows: 5,785
# Large flows: 14
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.021698s)
#     Conga                              : 0.9791
#     Weighted ECMP (Timeout)            : 1.0531
#     Weighted ECMP (No Timeout)         : 1.0599
#     Power-of-2 Random (Timeout)        : 1.0466
#     Power-of-2 Random (No Timeout)     : 0.9861
#   Large flows (ECMP avg = 0.374115s)
#     Conga                              : 1.0139
#     Weighted ECMP (Timeout)            : 0.9992
#     Weighted ECMP (No Timeout)         : 1.0244
#     Power-of-2 Random (Timeout)        : 0.9903
#     Power-of-2 Random (No Timeout)     : 1.0007
#
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/graph/normalised_vs_ecmp/commercial_cloud_SMALL_relative_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/graph/normalised_vs_ecmp/commercial_cloud_LARGE_relative_vs_load.png
#
# ================================================================================
# BENCHMARK: university
# ================================================================================
#
# Processing university | Load 0.1
# Small flows: 5,768
# Large flows: 21
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.002831s)
#     Conga                              : 0.9843
#     Weighted ECMP (Timeout)            : 0.9894
#     Weighted ECMP (No Timeout)         : 0.9837
#     Power-of-2 Random (Timeout)        : 0.9924
#     Power-of-2 Random (No Timeout)     : 0.9783
#   Large flows (ECMP avg = 0.262504s)
#     Conga                              : 0.9997
#     Weighted ECMP (Timeout)            : 1.0008
#     Weighted ECMP (No Timeout)         : 1.0148
#     Power-of-2 Random (Timeout)        : 1.0001
#     Power-of-2 Random (No Timeout)     : 1.0098
#
# Processing university | Load 0.2
# Small flows: 5,801
# Large flows: 25
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.004592s)
#     Conga                              : 0.9500
#     Weighted ECMP (Timeout)            : 0.9642
#     Weighted ECMP (No Timeout)         : 0.8451
#     Power-of-2 Random (Timeout)        : 0.9332
#     Power-of-2 Random (No Timeout)     : 0.8914
#   Large flows (ECMP avg = 0.230145s)
#     Conga                              : 0.9876
#     Weighted ECMP (Timeout)            : 1.0163
#     Weighted ECMP (No Timeout)         : 1.0551
#     Power-of-2 Random (Timeout)        : 1.0110
#     Power-of-2 Random (No Timeout)     : 1.0371
#
# Processing university | Load 0.3
# Small flows: 5,803
# Large flows: 23
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.006810s)
#     Conga                              : 0.9560
#     Weighted ECMP (Timeout)            : 0.9679
#     Weighted ECMP (No Timeout)         : 0.8705
#     Power-of-2 Random (Timeout)        : 0.9678
#     Power-of-2 Random (No Timeout)     : 0.9140
#   Large flows (ECMP avg = 0.227740s)
#     Conga                              : 0.9889
#     Weighted ECMP (Timeout)            : 0.9989
#     Weighted ECMP (No Timeout)         : 1.0698
#     Power-of-2 Random (Timeout)        : 1.0147
#     Power-of-2 Random (No Timeout)     : 1.0763
#
# Processing university | Load 0.4
# Small flows: 5,786
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.011125s)
#     Conga                              : 0.9311
#     Weighted ECMP (Timeout)            : 0.8362
#     Weighted ECMP (No Timeout)         : 0.7455
#     Power-of-2 Random (Timeout)        : 0.8552
#     Power-of-2 Random (No Timeout)     : 0.7166
#   Large flows (ECMP avg = 0.319486s)
#     Conga                              : 1.0084
#     Weighted ECMP (Timeout)            : 1.0216
#     Weighted ECMP (No Timeout)         : 1.0654
#     Power-of-2 Random (Timeout)        : 0.9895
#     Power-of-2 Random (No Timeout)     : 1.0699
#
# Processing university | Load 0.5
# Small flows: 5,782
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.013125s)
#     Conga                              : 0.9876
#     Weighted ECMP (Timeout)            : 0.9086
#     Weighted ECMP (No Timeout)         : 0.8007
#     Power-of-2 Random (Timeout)        : 0.8894
#     Power-of-2 Random (No Timeout)     : 0.8013
#   Large flows (ECMP avg = 0.553983s)
#     Conga                              : 0.9550
#     Weighted ECMP (Timeout)            : 1.1453
#     Weighted ECMP (No Timeout)         : 1.2096
#     Power-of-2 Random (Timeout)        : 1.0961
#     Power-of-2 Random (No Timeout)     : 1.0603
#
# Processing university | Load 0.6
# Small flows: 5,779
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.018040s)
#     Conga                              : 1.1867
#     Weighted ECMP (Timeout)            : 0.8831
#     Weighted ECMP (No Timeout)         : 0.7162
#     Power-of-2 Random (Timeout)        : 1.2375
#     Power-of-2 Random (No Timeout)     : 0.7991
#   Large flows (ECMP avg = 0.604259s)
#     Conga                              : 1.0125
#     Weighted ECMP (Timeout)            : 1.1005
#     Weighted ECMP (No Timeout)         : 1.0797
#     Power-of-2 Random (Timeout)        : 1.1168
#     Power-of-2 Random (No Timeout)     : 1.0781
#
# Processing university | Load 0.7
# Small flows: 5,786
# Large flows: 19
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.023314s)
#     Conga                              : 0.7825
#     Weighted ECMP (Timeout)            : 0.7195
#     Weighted ECMP (No Timeout)         : 0.5516
#     Power-of-2 Random (Timeout)        : 0.7471
#     Power-of-2 Random (No Timeout)     : 0.5535
#   Large flows (ECMP avg = 0.344089s)
#     Conga                              : 0.9762
#     Weighted ECMP (Timeout)            : 1.1717
#     Weighted ECMP (No Timeout)         : 1.4089
#     Power-of-2 Random (Timeout)        : 1.0514
#     Power-of-2 Random (No Timeout)     : 1.4024
#
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/graph/normalised_vs_ecmp/university_SMALL_relative_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v2/analysis_results/graph/normalised_vs_ecmp/university_LARGE_relative_vs_load.png
#
# ================================================================================
# DONE: Normalized Average FCT graphs generated.
# ================================================================================
