# %%
import pandas as pd
from pathlib import Path
import numpy as np


# ============================================================
# CONFIG
# ============================================================

benchmarks = [
    "private_enterprise",
    "social_media_cloud",
    "commercial_cloud",
    "university"
]

# benchmarks = [
#     "private_enterprise",
#     "social_media_cloud"
# ]

loads = range(1, 10)

# Input TrafPy flow files
input_dir = "/home/hsd/workspace/trafpy/examples/comparison_generator/8_hosts_v2"

# CONGA / ECMP ns-3 outputs
conga_dir = "/home/hsd/workspace/ns3-load-balance/conga_sym_8_hosts_v2"

# RTT ns-3 outputs
rtt_dir = "/home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2"

# Output directory
save_dir = "/home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results"

Path(save_dir).mkdir(
    parents=True,
    exist_ok=True
)


# ============================================================
# MATCHING CONFIG
# ============================================================

PORT_START = 10000
PORT_END = 50000

ip_pattern = r'^\d+\.\d+\.\d+\.\d+$'


# ============================================================
# FUNCTIONS
# ============================================================

def clean(df):
    """
    Keep only rows that contain valid IP addresses.
    """

    required = [
        "Src",
        "Dest"
    ]

    for col in required:

        if col not in df.columns:

            raise ValueError(
                f"Required column '{col}' not found."
            )

    return df[
        df["Src"].astype(str).str.match(
            ip_pattern,
            na=False
        )
        &
        df["Dest"].astype(str).str.match(
            ip_pattern,
            na=False
        )
    ].copy()


# ============================================================

def ip_to_node(ip):
    """
    Convert ns-3 server IP to input trace node ID.

    Leaf 0:
        10.1.1.2 -> 0
        10.1.1.4 -> 1
        10.1.1.6 -> 2
        10.1.1.8 -> 3

    Leaf 1:
        10.1.2.2 -> 4
        10.1.2.4 -> 5
        10.1.2.6 -> 6
        10.1.2.8 -> 7
    """

    parts = ip.split(".")

    subnet = int(parts[-2])
    host = int(parts[-1])

    base = (host // 2) - 1

    if subnet == 1:

        return base

    elif subnet == 2:

        return base + 4

    else:

        raise ValueError(
            f"Unexpected IP address: {ip}"
        )


# ============================================================

def add_time(df):
    """
    Convert ns-3 TimeFirstTxPacket to seconds.
    """

    df = df.copy()

    df["start_time"] = (
        df["TimeFirstTxPacket"]
        .astype(str)
        .str.replace("+", "", regex=False)
        .str.replace("ns", "", regex=False)
        .astype(float)
        / 1e9
    )

    return df


# ============================================================

def expected_port(flow_index):
    """
    Reproduce the C++ destination-port calculation.

        port = PORT_START + flow.index

    with wrapping after PORT_END.
    """

    port = PORT_START + int(flow_index)

    if port > PORT_END:

        port = port - (
            PORT_END - PORT_START
        )

    return port


# ============================================================
# FLOW COLUMNS
# ============================================================

flow_columns = [
    "FlowID",
    "Src",
    "Dest",
    "TimeFirstRxPacket",
    "TimeFirstTxPacket",
    "TimeLastRxPacket",
    "TimeLastTxPacket",
    "FCT(s)",
    "TxPackets",
    "RxPackets",
    "LostPackets",
    "LossRate",
    "PDR",
    "LossPercent",
    "TxBytes",
    "RxBytes",
    "Throughput(Kbps)",
    "MeanDelay(ms)",
    "Jitter(ms)",
    "HopCount"
]


# ============================================================
# MATCHING FUNCTION
# ============================================================

def match_df(output_df, input_df, label):
    """
    Match input TrafPy flows to ns-3 flows.

    Matching is based on:

        1. source node
        2. destination node
        3. destination port

    If multiple ns-3 flows have the same tuple, the candidate
    with the closest start time to the input event time is used.

    Time is NOT a hard matching criterion.
    """

    matches = []

    # --------------------------------------------------------
    # Make copies
    # --------------------------------------------------------

    output_df = output_df.copy()
    input_df = input_df.copy()

    # --------------------------------------------------------
    # Numeric conversion
    # --------------------------------------------------------

    for col in [
        "SrcPort",
        "DestPort",
        "TxPackets",
        "RxPackets",
        "TxBytes",
        "RxBytes",
        "start_time",
        "sn",
        "dn"
    ]:

        if col in output_df.columns:

            output_df[col] = pd.to_numeric(
                output_df[col],
                errors="coerce"
            )

    for col in [
        "sn",
        "dn",
        "index",
        "flow_size",
        "event_time"
    ]:

        input_df[col] = pd.to_numeric(
            input_df[col],
            errors="coerce"
        )

    # --------------------------------------------------------
    # Remove invalid rows
    # --------------------------------------------------------

    output_df = output_df.dropna(
        subset=[
            "SrcPort",
            "DestPort",
            "TxPackets",
            "RxPackets",
            "TxBytes",
            "RxBytes",
            "start_time",
            "sn",
            "dn"
        ]
    ).copy()

    input_df = input_df.dropna(
        subset=[
            "sn",
            "dn",
            "index",
            "flow_size",
            "event_time"
        ]
    ).copy()

    # --------------------------------------------------------
    # Sort input by event time
    # --------------------------------------------------------

    input_df = input_df.sort_values(
        "event_time"
    ).reset_index(
        drop=True
    )

    # --------------------------------------------------------
    # Create lookup key
    #
    # (source node, destination node, destination port)
    # --------------------------------------------------------

    output_df["_match_key"] = list(
        zip(
            output_df["sn"].astype(int),
            output_df["dn"].astype(int),
            output_df["DestPort"].astype(int)
        )
    )

    # --------------------------------------------------------
    # Group ns-3 flows by matching key
    # --------------------------------------------------------

    grouped = {
        key: group
        for key, group in output_df.groupby(
            "_match_key",
            sort=False
        )
    }

    # --------------------------------------------------------
    # Process every input flow
    # --------------------------------------------------------

    for _, in_row in input_df.iterrows():

        input_flow_id = in_row["flow_id"]

        input_index = int(
            in_row["index"]
        )

        input_src = int(
            in_row["sn"]
        )

        input_dst = int(
            in_row["dn"]
        )

        input_time = float(
            in_row["event_time"]
        )

        input_size = float(
            in_row["flow_size"]
        )

        # ----------------------------------------------------
        # Expected destination port
        # ----------------------------------------------------

        expected_dst_port = expected_port(
            input_index
        )

        # ----------------------------------------------------
        # Lookup
        # ----------------------------------------------------

        key = (
            input_src,
            input_dst,
            expected_dst_port
        )

        candidates = grouped.get(
            key
        )

        # ----------------------------------------------------
        # No matching ns-3 flow
        # ----------------------------------------------------

        if candidates is None or len(candidates) == 0:

            continue

        # ----------------------------------------------------
        # Find closest start time
        # ----------------------------------------------------

        if len(candidates) == 1:

            best = candidates.iloc[0]

            time_diff = abs(
                best["start_time"]
                - input_time
            )

        else:

            time_diffs = (
                candidates["start_time"]
                - input_time
            ).abs()

            best_index = time_diffs.idxmin()

            best = candidates.loc[
                best_index
            ]

            time_diff = time_diffs.loc[
                best_index
            ]

        # ----------------------------------------------------
        # Size difference
        # ----------------------------------------------------

        if input_size > 0:

            size_diff = (
                abs(
                    best["TxBytes"]
                    - input_size
                )
                /
                max(
                    input_size,
                    best["TxBytes"],
                    1
                )
            )

        else:

            size_diff = np.nan

        # ----------------------------------------------------
        # Combined result
        # ----------------------------------------------------

        combined = {

            "flow_id":
                input_flow_id,

            "sn":
                input_src,

            "dn":
                input_dst,

            "input_time":
                input_time,

            "flow_size":
                input_size,

            #"expected_dest_port":
            #    expected_dst_port,

            f"time_diff_{label}":
                time_diff,

            f"size_diff_{label}":
                size_diff,

            f"TxPackets_{label}":
                best["TxPackets"],

            f"RxPackets_{label}":
                best["RxPackets"],

            f"TxBytes_calc_{label}":
                best["TxPackets"] * 1400,

            f"RxBytes_calc_{label}":
                best["RxPackets"] * 1400
        }

        # ----------------------------------------------------
        # Add all FlowMonitor columns
        # ----------------------------------------------------

        for col in flow_columns:

            combined[
                f"{col}_{label}"
            ] = best[col]

        matches.append(
            combined
        )

    return pd.DataFrame(
        matches
    )


# ============================================================
# MAIN
# ============================================================

for benchmark in benchmarks:

    for load in loads:

        print()
        print(
            "=" * 80
        )

        print(
            f"{benchmark} | Load 0.{load}"
        )

        print(
            "=" * 80
        )

        # ====================================================
        # INPUT TRACE
        # ====================================================

        input_path = (
            f"{input_dir}/"
            f"{benchmark}_load_{load}.csv"
        )

        try:

            input_df = pd.read_csv(
                input_path
            )

            print(
                f"Input flows: "
                f"{len(input_df):,}"
            )

        except Exception as e:

            print(
                f"Could not read input: {e}"
            )

            continue

        # ====================================================
        # ALGORITHMS
        #
        # COMMENT / UNCOMMENT ANYTHING YOU WANT
        # ====================================================

        try:

            algorithms = {

                # ------------------------------------------------
                # CONGA
                # ------------------------------------------------

                "conga": pd.read_csv(
                    f"{conga_dir}/"
                    f"{benchmark}_load_{load}_Conga.csv",
                    nrows=12000
                ),

                # ------------------------------------------------
                # CONGA variants
                # ------------------------------------------------

                # "conga_new": pd.read_csv(
                #     f"{conga_dir}/"
                #     f"{benchmark}_load_{load}_Conga_new.csv",
                #     nrows=12000
                # ),

                # "conga-ecmp": pd.read_csv(
                #     f"{conga_dir}/"
                #     f"{benchmark}_load_{load}_Conga-ECMP_new.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # ECMP
                # ------------------------------------------------

                "ecmp": pd.read_csv(
                    f"{conga_dir}/"
                    f"{benchmark}_load_{load}_ECMP.csv",
                    nrows=12000
                ),

                # ------------------------------------------------
                # ECMP variants
                # ------------------------------------------------

                # "ecmp_new": pd.read_csv(
                #     f"{conga_dir}/"
                #     f"{benchmark}_load_{load}_ECMP_new.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # Basic RTT
                # ------------------------------------------------

                # "rtt": pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_RTT.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # Weighted ECMP
                # ------------------------------------------------

                # "weighted": pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_WEIGHTED_ECMP_RTT.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # Power-of-2 Random
                # ------------------------------------------------

                # "random": pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_POWER_OF_2_RANDOM_RTT.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # Power-of-2 Top2
                # ------------------------------------------------

                # "top2": pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_POWER_OF_2_TOP2_RTT.csv",
                #     nrows=12000
                # ),
            }

            # ====================================================
            # TIMEOUT VARIANTS
            # ====================================================

            timeout_values = [
                "true",
                "false"
            ]

            for timeout in timeout_values:

                # ------------------------------------------------
                # Weighted ECMP + timeout
                # ------------------------------------------------

                algorithms[
                    f"weighted_{timeout}"
                    ] = pd.read_csv(
                    f"{rtt_dir}/"
                    f"{benchmark}_load_{load}_"
                    f"WEIGHTED_ECMP_timeout_{timeout}_RTT.csv",
                    nrows=12000
                )

                # ------------------------------------------------
                # Lowest RTT + timeout
                # ------------------------------------------------

                #algorithms[
                #    f"lrtt_{timeout}"
                #] = pd.read_csv(
                #    f"{rtt_dir}/"
                #    f"{benchmark}_load_{load}_"
                #    f"LOWEST_RTT_timeout_{timeout}_RTT.csv",
                #    nrows=12000
                #)

                # ------------------------------------------------
                # Power-of-2 Random + timeout
                # ------------------------------------------------

                algorithms[
                     f"random_{timeout}"
                     ] = pd.read_csv(
                     f"{rtt_dir}/"
                     f"{benchmark}_load_{load}_"
                     f"POWER_OF_2_RANDOM_timeout_{timeout}_RTT.csv",
                     nrows=12000
                 )

                # ------------------------------------------------
                # Power-of-2 Top2 + timeout
                # ------------------------------------------------

                # algorithms[
                #     f"top2_{timeout}"
                # ] = pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_"
                #     f"POWER_OF_2_TOP2_timeout_{timeout}_RTT.csv",
                #     nrows=12000
                # )

        except Exception as e:

            print(
                "Skipping:",
                e
            )

            continue

        # ====================================================
        # CLEAN + PREPARE
        # ====================================================

        for label, df in algorithms.items():

            try:

                df = clean(
                    df
                )

                df = add_time(
                    df
                )

                df["sn"] = df["Src"].apply(
                    ip_to_node
                )

                df["dn"] = df["Dest"].apply(
                    ip_to_node
                )

                algorithms[label] = df

                print(
                    f"{label}: "
                    f"{len(df):,} IP flows"
                )

            except Exception as e:

                print(
                    f"ERROR processing "
                    f"{label}: {e}"
                )

                algorithms[label] = (
                    pd.DataFrame()
                )

        # ====================================================
        # MATCH
        # ====================================================

        matched = {}

        for label, df in algorithms.items():

            if df.empty:

                print(
                    f"Skipping matching for "
                    f"{label}: empty dataframe"
                )

                continue

            print(
                f"Matching {label}..."
            )

            matched[label] = match_df(
                df,
                input_df,
                label
            )

            print(
                f"{label}: "
                f"{len(matched[label]):,} matches"
            )

        # ====================================================
        # REMOVE EMPTY ALGORITHMS
        # ====================================================

        matched = {
            label: df
            for label, df in matched.items()
            if not df.empty
        }

        if len(matched) == 0:

            print(
                "No matches."
            )

            continue

        # ====================================================
        # MERGE RESULTS
        # ====================================================

        merge_keys = [
            "flow_id",
            "sn",
            "dn",
            "input_time",
            "flow_size"
        ]

        algorithms_list = list(
            matched.keys()
        )

        final_df = matched[
            algorithms_list[0]
        ]

        for algo in algorithms_list[1:]:

            final_df = pd.merge(
                final_df,
                matched[algo],
                on=merge_keys,
                how="inner"
            )

        # ====================================================
        # CHECK RESULT
        # ====================================================

        if len(final_df) == 0:

            print(
                "No common matches across "
                "the selected algorithms."
            )

            continue

        print()
        print(
            f"Final matched flows: "
            f"{len(final_df):,}"
        )


        # ============================================================
        # MATCHING TIME-DIFFERENCE SANITY CHECK
        # ============================================================
        
        print("\n" + "=" * 80)
        print("MATCHING TIME-DIFFERENCE CHECK")
        print("=" * 80)
        
        for algo in algorithms:
        
            col = f"time_diff_{algo}"
        
            if col not in final_df.columns:
                continue
        
            max_diff = final_df[col].max()
            mean_diff = final_df[col].mean()
            p95_diff = final_df[col].quantile(0.95)
            p99_diff = final_df[col].quantile(0.99)
        
            max_idx = final_df[col].idxmax()
            worst = final_df.loc[max_idx]
        
            print(f"\n{algo}")
            print(f"  Maximum : {max_diff:.9f} s "
                  f"({max_diff * 1000:.6f} ms)")
            print(f"  Mean    : {mean_diff:.9f} s "
                  f"({mean_diff * 1000:.6f} ms)")
            print(f"  P95     : {p95_diff:.9f} s "
                  f"({p95_diff * 1000:.6f} ms)")
            print(f"  P99     : {p99_diff:.9f} s "
                  f"({p99_diff * 1000:.6f} ms)")
        
            print(f"  Worst matching flow:")
            print(f"    flow_id     : {worst['flow_id']}")
            print(f"    sn          : {worst['sn']}")
            print(f"    dn          : {worst['dn']}")
            print(f"    input_time  : {worst['input_time']:.9f} s")
            print(f"    time_diff   : {worst[col]:.9f} s")

        
        # ====================================================
        # DIFFERENCES
        # ====================================================

        reference = "ecmp"

        if reference in matched:

            for algo in algorithms:

                if algo == reference:
                    continue

                if (
                    f"FCT(s)_{reference}" in final_df.columns
                    and
                    f"FCT(s)_{algo}" in final_df.columns
                ):

                    final_df[
                        f"fct_diff_{reference}_{algo}"
                    ] = (
                        final_df[
                            f"FCT(s)_{reference}"
                        ]
                        -
                        final_df[
                            f"FCT(s)_{algo}"
                        ]
                    )

        # ====================================================
        # SAVE
        # ====================================================

        csv_path = (
            f"{save_dir}/"
            f"{benchmark}_load_{load}_full.csv"
        )

        final_df.to_csv(
            csv_path,
            index=False
        )

        print(
            f"Saved: {csv_path}"
        )

        # ====================================================
        # STATS
        # ====================================================

        print()
        print(
            "-" * 80
        )

        print(
            f"Statistics: "
            f"{benchmark} | Load 0.{load}"
        )

        print(
            "-" * 80
        )

        for algo in matched:

            column = (
                f"FCT(s)_{algo}"
            )

            if column not in final_df.columns:
                continue

            fct = final_df[
                column
            ]

            print(
                f"{algo:20s}"
                f"Avg: {fct.mean():.6f}  "
                f"P75: {fct.quantile(0.75):.6f}  "
                f"P90: {fct.quantile(0.90):.6f}  "
                f"P95: {fct.quantile(0.95):.6f}  "
                f"P99: {fct.quantile(0.99):.6f}"
            )


# ============================================================
# DONE
# ============================================================

print()
print(
    "=" * 80
)

print(
    "MATCHING COMPLETE"
)

print(
    "=" * 80
)
# Out:
# ================================================================================
# private_enterprise | Load 0.1
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3284
#     sn          : 4
#     dn          : 1
#     input_time  : 27.977796869 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3284
#     sn          : 4
#     dn          : 1
#     input_time  : 27.977796869 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3284
#     sn          : 4
#     dn          : 1
#     input_time  : 27.977796869 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3284
#     sn          : 4
#     dn          : 1
#     input_time  : 27.977796869 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3284
#     sn          : 4
#     dn          : 1
#     input_time  : 27.977796869 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3284
#     sn          : 4
#     dn          : 1
#     input_time  : 27.977796869 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/private_enterprise_load_1_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.1
# --------------------------------------------------------------------------------
# conga               Avg: 0.006423  P75: 0.003098  P90: 0.015435  P95: 0.027428  P99: 0.069237
# ecmp                Avg: 0.006434  P75: 0.003141  P90: 0.015333  P95: 0.027433  P99: 0.069239
# weighted_true       Avg: 0.006439  P75: 0.003120  P90: 0.015438  P95: 0.027415  P99: 0.069238
# random_true         Avg: 0.006436  P75: 0.003136  P90: 0.015382  P95: 0.027482  P99: 0.069238
# weighted_false      Avg: 0.006439  P75: 0.003123  P90: 0.015382  P95: 0.027488  P99: 0.069237
# random_false        Avg: 0.006435  P75: 0.003120  P90: 0.015446  P95: 0.027419  P99: 0.069238
#
# ================================================================================
# private_enterprise | Load 0.2
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4075
#     sn          : 3
#     dn          : 6
#     input_time  : 4.987554623 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4075
#     sn          : 3
#     dn          : 6
#     input_time  : 4.987554623 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4075
#     sn          : 3
#     dn          : 6
#     input_time  : 4.987554623 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4075
#     sn          : 3
#     dn          : 6
#     input_time  : 4.987554623 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4075
#     sn          : 3
#     dn          : 6
#     input_time  : 4.987554623 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4075
#     sn          : 3
#     dn          : 6
#     input_time  : 4.987554623 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/private_enterprise_load_2_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.2
# --------------------------------------------------------------------------------
# conga               Avg: 0.007859  P75: 0.006210  P90: 0.021549  P95: 0.033659  P99: 0.071095
# ecmp                Avg: 0.007784  P75: 0.006128  P90: 0.021695  P95: 0.033678  P99: 0.071217
# weighted_true       Avg: 0.007882  P75: 0.006227  P90: 0.021643  P95: 0.033660  P99: 0.072178
# random_true         Avg: 0.007804  P75: 0.006103  P90: 0.021557  P95: 0.033666  P99: 0.072152
# weighted_false      Avg: 0.007803  P75: 0.006116  P90: 0.021558  P95: 0.033685  P99: 0.071964
# random_false        Avg: 0.007808  P75: 0.006181  P90: 0.021595  P95: 0.033722  P99: 0.072079
#
# ================================================================================
# private_enterprise | Load 0.3
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2629
#     sn          : 4
#     dn          : 3
#     input_time  : 9.664454465 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2629
#     sn          : 4
#     dn          : 3
#     input_time  : 9.664454465 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2629
#     sn          : 4
#     dn          : 3
#     input_time  : 9.664454465 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2629
#     sn          : 4
#     dn          : 3
#     input_time  : 9.664454465 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2629
#     sn          : 4
#     dn          : 3
#     input_time  : 9.664454465 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2629
#     sn          : 4
#     dn          : 3
#     input_time  : 9.664454465 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/private_enterprise_load_3_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.3
# --------------------------------------------------------------------------------
# conga               Avg: 0.010353  P75: 0.010487  P90: 0.028276  P95: 0.041348  P99: 0.082163
# ecmp                Avg: 0.010377  P75: 0.010526  P90: 0.028355  P95: 0.041340  P99: 0.083108
# weighted_true       Avg: 0.010379  P75: 0.010505  P90: 0.028347  P95: 0.041401  P99: 0.083125
# random_true         Avg: 0.010353  P75: 0.010551  P90: 0.028349  P95: 0.041634  P99: 0.082047
# weighted_false      Avg: 0.010336  P75: 0.010545  P90: 0.028041  P95: 0.041190  P99: 0.082043
# random_false        Avg: 0.010351  P75: 0.010504  P90: 0.028282  P95: 0.041432  P99: 0.082911
#
# ================================================================================
# private_enterprise | Load 0.4
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4344
#     sn          : 5
#     dn          : 0
#     input_time  : 7.415190500 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4344
#     sn          : 5
#     dn          : 0
#     input_time  : 7.415190500 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4344
#     sn          : 5
#     dn          : 0
#     input_time  : 7.415190500 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4344
#     sn          : 5
#     dn          : 0
#     input_time  : 7.415190500 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4344
#     sn          : 5
#     dn          : 0
#     input_time  : 7.415190500 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4344
#     sn          : 5
#     dn          : 0
#     input_time  : 7.415190500 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/private_enterprise_load_4_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.4
# --------------------------------------------------------------------------------
# conga               Avg: 0.012006  P75: 0.014699  P90: 0.031732  P95: 0.045661  P99: 0.086048
# ecmp                Avg: 0.012215  P75: 0.014702  P90: 0.032118  P95: 0.047067  P99: 0.094798
# weighted_true       Avg: 0.012286  P75: 0.014879  P90: 0.032234  P95: 0.046970  P99: 0.095830
# random_true         Avg: 0.012299  P75: 0.014894  P90: 0.032312  P95: 0.047447  P99: 0.098542
# weighted_false      Avg: 0.012283  P75: 0.014873  P90: 0.032200  P95: 0.047078  P99: 0.091987
# random_false        Avg: 0.012295  P75: 0.014935  P90: 0.032336  P95: 0.047146  P99: 0.093365
#
# ================================================================================
# private_enterprise | Load 0.5
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2602
#     sn          : 0
#     dn          : 3
#     input_time  : 4.250564431 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2602
#     sn          : 0
#     dn          : 3
#     input_time  : 4.250564431 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2602
#     sn          : 0
#     dn          : 3
#     input_time  : 4.250564431 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2602
#     sn          : 0
#     dn          : 3
#     input_time  : 4.250564431 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2602
#     sn          : 0
#     dn          : 3
#     input_time  : 4.250564431 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2602
#     sn          : 0
#     dn          : 3
#     input_time  : 4.250564431 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/private_enterprise_load_5_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.5
# --------------------------------------------------------------------------------
# conga               Avg: 0.014988  P75: 0.017896  P90: 0.037186  P95: 0.058201  P99: 0.115457
# ecmp                Avg: 0.014846  P75: 0.017625  P90: 0.037189  P95: 0.058021  P99: 0.113998
# weighted_true       Avg: 0.015028  P75: 0.017432  P90: 0.038106  P95: 0.060325  P99: 0.112928
# random_true         Avg: 0.015036  P75: 0.017632  P90: 0.037779  P95: 0.058958  P99: 0.113968
# weighted_false      Avg: 0.014842  P75: 0.017546  P90: 0.037065  P95: 0.058898  P99: 0.112857
# random_false        Avg: 0.014286  P75: 0.016718  P90: 0.035112  P95: 0.053401  P99: 0.107895
#
# ================================================================================
# private_enterprise | Load 0.6
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1230
#     sn          : 3
#     dn          : 0
#     input_time  : 2.221919343 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1230
#     sn          : 3
#     dn          : 0
#     input_time  : 2.221919343 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1230
#     sn          : 3
#     dn          : 0
#     input_time  : 2.221919343 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1230
#     sn          : 3
#     dn          : 0
#     input_time  : 2.221919343 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1230
#     sn          : 3
#     dn          : 0
#     input_time  : 2.221919343 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1230
#     sn          : 3
#     dn          : 0
#     input_time  : 2.221919343 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/private_enterprise_load_6_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.6
# --------------------------------------------------------------------------------
# conga               Avg: 0.018979  P75: 0.023442  P90: 0.050546  P95: 0.071710  P99: 0.137930
# ecmp                Avg: 0.019379  P75: 0.024053  P90: 0.051470  P95: 0.071333  P99: 0.137100
# weighted_true       Avg: 0.019090  P75: 0.023422  P90: 0.051054  P95: 0.071083  P99: 0.138325
# random_true         Avg: 0.018838  P75: 0.022460  P90: 0.050956  P95: 0.070934  P99: 0.139890
# weighted_false      Avg: 0.019005  P75: 0.023351  P90: 0.049021  P95: 0.070604  P99: 0.134071
# random_false        Avg: 0.019022  P75: 0.023341  P90: 0.051148  P95: 0.070607  P99: 0.138823
#
# ================================================================================
# private_enterprise | Load 0.7
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3797
#     sn          : 1
#     dn          : 3
#     input_time  : 0.521445732 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3797
#     sn          : 1
#     dn          : 3
#     input_time  : 0.521445732 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3797
#     sn          : 1
#     dn          : 3
#     input_time  : 0.521445732 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3797
#     sn          : 1
#     dn          : 3
#     input_time  : 0.521445732 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3797
#     sn          : 1
#     dn          : 3
#     input_time  : 0.521445732 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3797
#     sn          : 1
#     dn          : 3
#     input_time  : 0.521445732 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/private_enterprise_load_7_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.7
# --------------------------------------------------------------------------------
# conga               Avg: 0.022681  P75: 0.031478  P90: 0.056039  P95: 0.074795  P99: 0.137699
# ecmp                Avg: 0.020672  P75: 0.027901  P90: 0.051153  P95: 0.070614  P99: 0.130058
# weighted_true       Avg: 0.021825  P75: 0.029505  P90: 0.054406  P95: 0.073271  P99: 0.135588
# random_true         Avg: 0.021002  P75: 0.029091  P90: 0.051721  P95: 0.068282  P99: 0.121509
# weighted_false      Avg: 0.020781  P75: 0.028027  P90: 0.052861  P95: 0.072315  P99: 0.138319
# random_false        Avg: 0.022096  P75: 0.029532  P90: 0.054955  P95: 0.073571  P99: 0.130712
#
# ================================================================================
# private_enterprise | Load 0.8
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1559
#     sn          : 0
#     dn          : 4
#     input_time  : 0.761235665 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1559
#     sn          : 0
#     dn          : 4
#     input_time  : 0.761235665 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1559
#     sn          : 0
#     dn          : 4
#     input_time  : 0.761235665 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1559
#     sn          : 0
#     dn          : 4
#     input_time  : 0.761235665 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1559
#     sn          : 0
#     dn          : 4
#     input_time  : 0.761235665 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1559
#     sn          : 0
#     dn          : 4
#     input_time  : 0.761235665 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/private_enterprise_load_8_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.8
# --------------------------------------------------------------------------------
# conga               Avg: 0.026246  P75: 0.032663  P90: 0.059739  P95: 0.082319  P99: 0.171648
# ecmp                Avg: 0.025741  P75: 0.033292  P90: 0.058738  P95: 0.081752  P99: 0.155505
# weighted_true       Avg: 0.021969  P75: 0.027076  P90: 0.049842  P95: 0.066362  P99: 0.127260
# random_true         Avg: 0.025045  P75: 0.033143  P90: 0.057778  P95: 0.077637  P99: 0.146009
# weighted_false      Avg: 0.024509  P75: 0.032942  P90: 0.055090  P95: 0.073801  P99: 0.140655
# random_false        Avg: 0.022827  P75: 0.029086  P90: 0.051878  P95: 0.068095  P99: 0.131624
#
# ================================================================================
# private_enterprise | Load 0.9
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_873
#     sn          : 4
#     dn          : 3
#     input_time  : 2.420250289 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_873
#     sn          : 4
#     dn          : 3
#     input_time  : 2.420250289 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_873
#     sn          : 4
#     dn          : 3
#     input_time  : 2.420250289 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_873
#     sn          : 4
#     dn          : 3
#     input_time  : 2.420250289 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_873
#     sn          : 4
#     dn          : 3
#     input_time  : 2.420250289 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_873
#     sn          : 4
#     dn          : 3
#     input_time  : 2.420250289 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/private_enterprise_load_9_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.9
# --------------------------------------------------------------------------------
# conga               Avg: 0.033481  P75: 0.047422  P90: 0.077012  P95: 0.100149  P99: 0.186700
# ecmp                Avg: 0.032432  P75: 0.044017  P90: 0.072608  P95: 0.098229  P99: 0.188688
# weighted_true       Avg: 0.033873  P75: 0.047956  P90: 0.076770  P95: 0.101247  P99: 0.187126
# random_true         Avg: 0.033080  P75: 0.046287  P90: 0.073459  P95: 0.097173  P99: 0.181358
# weighted_false      Avg: 0.030777  P75: 0.041724  P90: 0.067063  P95: 0.088040  P99: 0.167007
# random_false        Avg: 0.033098  P75: 0.045549  P90: 0.075245  P95: 0.098687  P99: 0.190732
#
# ================================================================================
# social_media_cloud | Load 0.1
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1106
#     sn          : 5
#     dn          : 6
#     input_time  : 30.678284129 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1106
#     sn          : 5
#     dn          : 6
#     input_time  : 30.678284129 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1106
#     sn          : 5
#     dn          : 6
#     input_time  : 30.678284129 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1106
#     sn          : 5
#     dn          : 6
#     input_time  : 30.678284129 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1106
#     sn          : 5
#     dn          : 6
#     input_time  : 30.678284129 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1106
#     sn          : 5
#     dn          : 6
#     input_time  : 30.678284129 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/social_media_cloud_load_1_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.1
# --------------------------------------------------------------------------------
# conga               Avg: 0.007594  P75: 0.008723  P90: 0.020162  P95: 0.031398  P99: 0.059827
# ecmp                Avg: 0.007597  P75: 0.008701  P90: 0.020260  P95: 0.031399  P99: 0.059889
# weighted_true       Avg: 0.007602  P75: 0.008721  P90: 0.020155  P95: 0.031400  P99: 0.059889
# random_true         Avg: 0.007596  P75: 0.008701  P90: 0.020156  P95: 0.031507  P99: 0.059827
# weighted_false      Avg: 0.007605  P75: 0.008682  P90: 0.020232  P95: 0.031400  P99: 0.059827
# random_false        Avg: 0.007598  P75: 0.008683  P90: 0.020260  P95: 0.031397  P99: 0.059826
#
# ================================================================================
# social_media_cloud | Load 0.2
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_950
#     sn          : 3
#     dn          : 2
#     input_time  : 8.438710180 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_950
#     sn          : 3
#     dn          : 2
#     input_time  : 8.438710180 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_950
#     sn          : 3
#     dn          : 2
#     input_time  : 8.438710180 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_950
#     sn          : 3
#     dn          : 2
#     input_time  : 8.438710180 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_950
#     sn          : 3
#     dn          : 2
#     input_time  : 8.438710180 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_950
#     sn          : 3
#     dn          : 2
#     input_time  : 8.438710180 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/social_media_cloud_load_2_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.2
# --------------------------------------------------------------------------------
# conga               Avg: 0.008993  P75: 0.010844  P90: 0.023837  P95: 0.034198  P99: 0.064629
# ecmp                Avg: 0.008991  P75: 0.010840  P90: 0.023848  P95: 0.034185  P99: 0.064596
# weighted_true       Avg: 0.008992  P75: 0.010834  P90: 0.023742  P95: 0.033993  P99: 0.064596
# random_true         Avg: 0.009009  P75: 0.010859  P90: 0.023824  P95: 0.034195  P99: 0.064579
# weighted_false      Avg: 0.008995  P75: 0.010823  P90: 0.023846  P95: 0.034193  P99: 0.064596
# random_false        Avg: 0.008997  P75: 0.010863  P90: 0.023902  P95: 0.034150  P99: 0.064596
#
# ================================================================================
# social_media_cloud | Load 0.3
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_547
#     sn          : 5
#     dn          : 6
#     input_time  : 5.000835369 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_547
#     sn          : 5
#     dn          : 6
#     input_time  : 5.000835369 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_547
#     sn          : 5
#     dn          : 6
#     input_time  : 5.000835369 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_547
#     sn          : 5
#     dn          : 6
#     input_time  : 5.000835369 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_547
#     sn          : 5
#     dn          : 6
#     input_time  : 5.000835369 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_547
#     sn          : 5
#     dn          : 6
#     input_time  : 5.000835369 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/social_media_cloud_load_3_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.3
# --------------------------------------------------------------------------------
# conga               Avg: 0.013854  P75: 0.019189  P90: 0.036323  P95: 0.049213  P99: 0.082473
# ecmp                Avg: 0.013794  P75: 0.018895  P90: 0.035895  P95: 0.048392  P99: 0.082652
# weighted_true       Avg: 0.013848  P75: 0.019165  P90: 0.036316  P95: 0.049307  P99: 0.082892
# random_true         Avg: 0.013778  P75: 0.019011  P90: 0.035784  P95: 0.048568  P99: 0.082529
# weighted_false      Avg: 0.013798  P75: 0.018878  P90: 0.035801  P95: 0.048992  P99: 0.082528
# random_false        Avg: 0.013791  P75: 0.018971  P90: 0.035895  P95: 0.048751  P99: 0.082529
#
# ================================================================================
# social_media_cloud | Load 0.4
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5724
#     sn          : 7
#     dn          : 5
#     input_time  : 12.675429750 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5724
#     sn          : 7
#     dn          : 5
#     input_time  : 12.675429750 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5724
#     sn          : 7
#     dn          : 5
#     input_time  : 12.675429750 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5724
#     sn          : 7
#     dn          : 5
#     input_time  : 12.675429750 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5724
#     sn          : 7
#     dn          : 5
#     input_time  : 12.675429750 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5724
#     sn          : 7
#     dn          : 5
#     input_time  : 12.675429750 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/social_media_cloud_load_4_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.4
# ...
#     sn          : 7
#     dn          : 6
#     input_time  : 2.392299764 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/university_load_5_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.5
# --------------------------------------------------------------------------------
# conga               Avg: 0.015630  P75: 0.019352  P90: 0.041752  P95: 0.059688  P99: 0.120006
# ecmp                Avg: 0.015660  P75: 0.019535  P90: 0.041577  P95: 0.060483  P99: 0.116099
# weighted_true       Avg: 0.015763  P75: 0.019473  P90: 0.042402  P95: 0.060698  P99: 0.120968
# random_true         Avg: 0.015722  P75: 0.019471  P90: 0.041900  P95: 0.060144  P99: 0.118530
# weighted_false      Avg: 0.015966  P75: 0.019907  P90: 0.043405  P95: 0.061319  P99: 0.124946
# random_false        Avg: 0.015624  P75: 0.019604  P90: 0.041945  P95: 0.059801  P99: 0.117027
#
# ================================================================================
# university | Load 0.6
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_612
#     sn          : 3
#     dn          : 6
#     input_time  : 0.121280322 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_612
#     sn          : 3
#     dn          : 6
#     input_time  : 0.121280322 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_612
#     sn          : 3
#     dn          : 6
#     input_time  : 0.121280322 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_612
#     sn          : 3
#     dn          : 6
#     input_time  : 0.121280322 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_612
#     sn          : 3
#     dn          : 6
#     input_time  : 0.121280322 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_612
#     sn          : 3
#     dn          : 6
#     input_time  : 0.121280322 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/university_load_6_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.6
# --------------------------------------------------------------------------------
# conga               Avg: 0.021726  P75: 0.025593  P90: 0.059179  P95: 0.084976  P99: 0.167895
# ecmp                Avg: 0.023826  P75: 0.025844  P90: 0.060559  P95: 0.088673  P99: 0.186493
# weighted_true       Avg: 0.025035  P75: 0.025264  P90: 0.057349  P95: 0.086494  P99: 0.187316
# random_true         Avg: 0.025353  P75: 0.025309  P90: 0.060408  P95: 0.088178  P99: 0.184411
# weighted_false      Avg: 0.021695  P75: 0.025617  P90: 0.059625  P95: 0.082317  P99: 0.165352
# random_false        Avg: 0.024924  P75: 0.025308  P90: 0.057905  P95: 0.087206  P99: 0.185510
#
# ================================================================================
# university | Load 0.7
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1686
#     sn          : 4
#     dn          : 1
#     input_time  : 2.806719533 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1686
#     sn          : 4
#     dn          : 1
#     input_time  : 2.806719533 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1686
#     sn          : 4
#     dn          : 1
#     input_time  : 2.806719533 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1686
#     sn          : 4
#     dn          : 1
#     input_time  : 2.806719533 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1686
#     sn          : 4
#     dn          : 1
#     input_time  : 2.806719533 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1686
#     sn          : 4
#     dn          : 1
#     input_time  : 2.806719533 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/university_load_7_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.7
# --------------------------------------------------------------------------------
# conga               Avg: 0.021511  P75: 0.030188  P90: 0.052370  P95: 0.071514  P99: 0.141331
# ecmp                Avg: 0.021474  P75: 0.029924  P90: 0.052429  P95: 0.071746  P99: 0.142962
# weighted_true       Avg: 0.021465  P75: 0.030017  P90: 0.052715  P95: 0.071346  P99: 0.140858
# random_true         Avg: 0.021238  P75: 0.029562  P90: 0.052100  P95: 0.070868  P99: 0.138631
# weighted_false      Avg: 0.021411  P75: 0.029764  P90: 0.052217  P95: 0.070798  P99: 0.138367
# random_false        Avg: 0.021625  P75: 0.030381  P90: 0.052889  P95: 0.071544  P99: 0.141586
#
# ================================================================================
# university | Load 0.8
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5790
#     sn          : 1
#     dn          : 6
#     input_time  : 0.027026184 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5790
#     sn          : 1
#     dn          : 6
#     input_time  : 0.027026184 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5790
#     sn          : 1
#     dn          : 6
#     input_time  : 0.027026184 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5790
#     sn          : 1
#     dn          : 6
#     input_time  : 0.027026184 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5790
#     sn          : 1
#     dn          : 6
#     input_time  : 0.027026184 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5790
#     sn          : 1
#     dn          : 6
#     input_time  : 0.027026184 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/university_load_8_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.8
# --------------------------------------------------------------------------------
# conga               Avg: 0.018020  P75: 0.023415  P90: 0.042629  P95: 0.058210  P99: 0.111962
# ecmp                Avg: 0.017560  P75: 0.022055  P90: 0.040684  P95: 0.055767  P99: 0.108017
# weighted_true       Avg: 0.019135  P75: 0.025861  P90: 0.045312  P95: 0.062722  P99: 0.121466
# random_true         Avg: 0.017966  P75: 0.023495  P90: 0.042095  P95: 0.055296  P99: 0.110169
# weighted_false      Avg: 0.017718  P75: 0.022614  P90: 0.041219  P95: 0.055975  P99: 0.109848
# random_false        Avg: 0.017586  P75: 0.022770  P90: 0.040909  P95: 0.054004  P99: 0.109445
#
# ================================================================================
# university | Load 0.9
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_715
#     sn          : 3
#     dn          : 7
#     input_time  : 0.104824366 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_715
#     sn          : 3
#     dn          : 7
#     input_time  : 0.104824366 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_715
#     sn          : 3
#     dn          : 7
#     input_time  : 0.104824366 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_715
#     sn          : 3
#     dn          : 7
#     input_time  : 0.104824366 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_715
#     sn          : 3
#     dn          : 7
#     input_time  : 0.104824366 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_715
#     sn          : 3
#     dn          : 7
#     input_time  : 0.104824366 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/university_load_9_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.9
# --------------------------------------------------------------------------------
# conga               Avg: 0.026285  P75: 0.034308  P90: 0.062618  P95: 0.085113  P99: 0.163926
# ecmp                Avg: 0.026562  P75: 0.034703  P90: 0.062124  P95: 0.086089  P99: 0.168882
# weighted_true       Avg: 0.026921  P75: 0.034659  P90: 0.062255  P95: 0.086213  P99: 0.166134
# random_true         Avg: 0.025826  P75: 0.033402  P90: 0.059822  P95: 0.081374  P99: 0.173056
# weighted_false      Avg: 0.025587  P75: 0.033212  P90: 0.060619  P95: 0.082302  P99: 0.166856
# random_false        Avg: 0.025828  P75: 0.033361  P90: 0.061300  P95: 0.082563  P99: 0.170131
#
# ================================================================================
# MATCHING COMPLETE
# ================================================================================

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

# ------------------ CONFIG ------------------

save_dir = Path(
    "/home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results"
)

graph_dir = save_dir / "graph"
graph_dir.mkdir(parents=True, exist_ok=True)

benchmarks = [
    "private_enterprise",
    "social_media_cloud",
    "commercial_cloud",
    "university"
]

loads = range(1, 10)

SMALL = 100 * 1024        # 100 KB
LARGE = 1 * 1024 * 1024   # 1 MB

algorithms = [
    "conga",
    #"conga_new",
    #"conga-ecmp",
    "ecmp",
    #"ecmp_new",
    
    #"lrtt_true",
    #"lrtt_false",
    
    #"weighted",
    #"random",
    #"top2"
    
    "weighted_true",
    "weighted_false",

    "random_true",
    "random_false",

    #"top2_true",
    #"top2_false"
]

label_map = {
    "conga": "Conga",
    #"conga_new": "Conga_New",
    #"conga-ecmp": "Conga-ECMP",
    "ecmp": "ECMP",
    #"ecmp_new": "ECMP_New",
    #"rtt": "RTT",

    "lrtt_true": "Lowest RTT (Timeout)",
    "lrtt_false": "Lowest RTT (No Timeout)",
    
    "weighted": "Weighted ECMP",
    "random": "Power-of-2 Random",
    "top2": "Power-of-2 Top2",
    
    "weighted_true": "Weighted ECMP (Timeout)",
    "weighted_false": "Weighted ECMP (No Timeout)",

    "random_true": "Power-of-2 Random (Timeout)",
    "random_false": "Power-of-2 Random (No Timeout)",

    "top2_true": "Power-of-2 Top2 (Timeout)",
    "top2_false": "Power-of-2 Top2 (No Timeout)"
}

color_map = {
    "conga": "tab:blue",
    #"conga_new": "tab:orange",
    #"conga-ecmp": "tab:green",
    "ecmp": "tab:red",
    #"ecmp_new": "tab:purple",
    #"rtt": "tab:brown",

    "lrtt_true": "tab:cyan",
    "lrtt_false": "tab:cyan",
    
    "weighted": "tab:pink",
    "random": "tab:gray",
    "top2": "tab:olive",
    
    "weighted_true": "tab:brown",
    "weighted_false": "tab:brown",

    "random_true": "tab:orange",
    "random_false": "tab:orange",

    "top2_true": "tab:gray",
    "top2_false": "tab:gray",
}

marker_map = {
    "conga": "o",
    #"conga_new": "x",
    #"conga-ecmp": "X",
    "ecmp": "s",
    #"ecmp_new": "*",
    #"rtt": "^",

    "lrtt_true": "1",
    "lrtt_false": "2",
    
    "weighted": "D",
    "random": "v",
    "top2": "P",
    
    "weighted_true": "D",
    "weighted_false": "d",

    "random_true": "^",
    "random_false": "v",

    "top2_true": "P",
    "top2_false": "X"
}

# ------------------ GLOBAL Y-LIMITS ------------------

small_global = []
large_global = []

for benchmark in benchmarks:
    for load in loads:

        csv_path = save_dir / f"{benchmark}_load_{load}_full.csv"

        if not csv_path.exists():
            continue

        df = pd.read_csv(csv_path)

        if df.empty:
            continue

        small_df = df[df["flow_size"] < SMALL]
        large_df = df[df["flow_size"] > LARGE]

        for algo in algorithms:
            col = f"FCT(s)_{algo}"

            if not small_df.empty:
                small_global.append(small_df[col].mean())

            if not large_df.empty:
                large_global.append(large_df[col].mean())

small_min = min(small_global)
small_max = max(small_global)

large_min = min(large_global)
large_max = max(large_global)

small_margin = 0.05 * (small_max - small_min)
large_margin = 0.05 * (large_max - large_min)

small_ylim = (small_min - small_margin, small_max + small_margin)
large_ylim = (large_min - large_margin, large_max + large_margin)

# ------------------ ANALYSIS ------------------

for benchmark in benchmarks:

    print(f"\n===== {benchmark} =====")

    load_vals = []

    small_results = {algo: [] for algo in algorithms}
    large_results = {algo: [] for algo in algorithms}

    for load in loads:

        csv_path = save_dir / f"{benchmark}_load_{load}_full.csv"

        if not csv_path.exists():
            print(f"Missing: {csv_path}")
            continue

        df = pd.read_csv(csv_path)

        if df.empty:
            continue

        small_df = df[df["flow_size"] < SMALL]
        large_df = df[df["flow_size"] > LARGE]

        # ---------- Small Flows ----------

        for algo in algorithms:

            col = f"FCT(s)_{algo}"

            if not small_df.empty:
                small_results[algo].append(
                    small_df[col].mean()
                )
            else:
                small_results[algo].append(np.nan)

        # ---------- Large Flows ----------

        for algo in algorithms:

            col = f"FCT(s)_{algo}"

            if not large_df.empty:
                large_results[algo].append(
                    large_df[col].mean()
                )
            else:
                large_results[algo].append(np.nan)

        load_vals.append(load / 10)

    # ==================================================
    # SMALL FLOWS
    # ==================================================

    plt.figure(figsize=(8, 5))

    for algo in algorithms:

        plt.plot(
            load_vals,
            small_results[algo],
            marker=marker_map[algo],
            color=color_map[algo],
            linestyle="--" if algo.endswith("_false") else "-",
            linewidth=2,
            label=label_map[algo]
        )

    plt.xlabel("Network Load")
    plt.ylabel("Average FCT (s)")
    plt.title(f"{benchmark}: Small Flows (<100 KB)")
    #plt.ylim(small_ylim)
    plt.grid(True)
    plt.legend()

    out_path = graph_dir / f"{benchmark}_SMALL_vs_load.png"

    plt.tight_layout()
    plt.savefig(out_path, dpi=300)
    plt.close()

    print(f"Saved: {out_path}")

    # ==================================================
    # LARGE FLOWS
    # ==================================================

    plt.figure(figsize=(8, 5))

    for algo in algorithms:

        plt.plot(
            load_vals,
            large_results[algo],
            marker=marker_map[algo],
            color=color_map[algo],
            linestyle="--" if algo.endswith("_false") else "-",
            linewidth=2,
            label=label_map[algo]
        )

    plt.xlabel("Network Load")
    plt.ylabel("Average FCT (s)")
    plt.title(f"{benchmark}: Large Flows (>1 MB)")
    #plt.ylim(large_ylim)
    plt.grid(True)
    plt.legend()

    out_path = graph_dir / f"{benchmark}_LARGE_vs_load.png"

    plt.tight_layout()
    plt.savefig(out_path, dpi=300)
    plt.close()

    print(f"Saved: {out_path}")

print("\nDone: Small vs Large flow comparison for all algorithms.")
# Out:
# ===== private_enterprise =====
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/graph/private_enterprise_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/graph/private_enterprise_LARGE_vs_load.png
#
# ===== social_media_cloud =====
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/graph/social_media_cloud_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/graph/social_media_cloud_LARGE_vs_load.png
#
# ===== commercial_cloud =====
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/graph/commercial_cloud_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/graph/commercial_cloud_LARGE_vs_load.png
#
# ===== university =====
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/graph/university_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/graph/university_LARGE_vs_load.png
#
# Done: Small vs Large flow comparison for all algorithms.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

# ============================================================
# CONFIG
# ============================================================

save_dir = Path(
    "/home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results"
)

baseline = "ecmp"

graph_dir = save_dir / "graph" / f"normalised_vs_{baseline}"
graph_dir.mkdir(parents=True, exist_ok=True)

benchmarks = [
    "private_enterprise",
    "social_media_cloud",
    "commercial_cloud",
    "university"
]

# ------------------------------------------------------------
# Loads
# ------------------------------------------------------------

loads = range(1, 10)

# ------------------------------------------------------------
# Flow size thresholds
# ------------------------------------------------------------

SMALL = 100 * 1024          # 100 KB
LARGE = 1 * 1024 * 1024     # 1 MB


# ============================================================
# ALGORITHMS
#
# Comment/uncomment algorithms here as required.
# ECMP is the baseline and therefore does NOT need to be here.
# ============================================================

algorithms = [

    "conga",

    # "lrtt_true",
    # "lrtt_false",

    "weighted_true",
    "weighted_false",

    "random_true",
    "random_false",

    # "top2_true",
    # "top2_false",

    # "weighted",
    # "random",
    # "top2",
]


# ============================================================
# LABELS
# ============================================================

label_map = {

    "conga":
        "Conga",

    "lrtt_true":
        "Lowest RTT (Timeout)",

    "lrtt_false":
        "Lowest RTT (No Timeout)",

    "weighted":
        "Weighted ECMP",

    "random":
        "Power-of-2 Random",

    "top2":
        "Power-of-2 Top2",

    "weighted_true":
        "Weighted ECMP (Timeout)",

    "weighted_false":
        "Weighted ECMP (No Timeout)",

    "random_true":
        "Power-of-2 Random (Timeout)",

    "random_false":
        "Power-of-2 Random (No Timeout)",

    "top2_true":
        "Power-of-2 Top2 (Timeout)",

    "top2_false":
        "Power-of-2 Top2 (No Timeout)",
}


# ============================================================
# COLORS
# ============================================================

color_map = {

    "conga":
        "tab:blue",

    "lrtt_true":
        "tab:cyan",

    "lrtt_false":
        "tab:cyan",

    "weighted":
        "tab:purple",

    "random":
        "tab:gray",

    "top2":
        "tab:olive",

    "weighted_true":
        "tab:brown",

    "weighted_false":
        "tab:brown",

    "random_true":
        "tab:orange",

    "random_false":
        "tab:orange",

    "top2_true":
        "tab:gray",

    "top2_false":
        "tab:gray",
}


# ============================================================
# MARKERS
# ============================================================

marker_map = {

    "conga":
        "o",

    "lrtt_true":
        "1",

    "lrtt_false":
        "2",

    "weighted":
        "^",

    "random":
        "D",

    "top2":
        "P",

    "weighted_true":
        "D",

    "weighted_false":
        "d",

    "random_true":
        "^",

    "random_false":
        "v",

    "top2_true":
        "P",

    "top2_false":
        "X",
}


# ============================================================
# RESULT STORAGE
# ============================================================

summary_results = {}


# ============================================================
# MAIN ANALYSIS
# ============================================================

for benchmark in benchmarks:

    print()
    print("=" * 80)
    print(f"BENCHMARK: {benchmark}")
    print("=" * 80)

    # --------------------------------------------------------
    # Store load values
    # --------------------------------------------------------

    load_vals = []

    # --------------------------------------------------------
    # Results for each algorithm
    #
    # Each entry will contain one value per network load.
    # --------------------------------------------------------

    small_results = {
        algo: []
        for algo in algorithms
    }

    large_results = {
        algo: []
        for algo in algorithms
    }

    # ========================================================
    # PROCESS EACH LOAD
    # ========================================================

    for load in loads:

        print()
        print(
            f"Processing {benchmark} | Load 0.{load}"
        )

        csv_path = (
            save_dir /
            f"{benchmark}_load_{load}_full.csv"
        )

        # ----------------------------------------------------
        # Check file
        # ----------------------------------------------------

        if not csv_path.exists():

            print(
                f"Missing: {csv_path}"
            )

            continue

        # ----------------------------------------------------
        # Read CSV
        # ----------------------------------------------------

        df = pd.read_csv(
            csv_path
        )

        if df.empty:

            print(
                "Empty dataframe."
            )

            continue

        # ====================================================
        # CHECK REQUIRED COLUMNS
        # ====================================================

        baseline_col = (
            f"FCT(s)_{baseline}"
        )

        if baseline_col not in df.columns:

            print(
                f"ERROR: Missing baseline column "
                f"{baseline_col}"
            )

            continue

        missing_algorithms = []

        for algo in algorithms:

            col = f"FCT(s)_{algo}"

            if col not in df.columns:

                missing_algorithms.append(
                    col
                )

        if missing_algorithms:

            print(
                "ERROR: Missing algorithm columns:"
            )

            for col in missing_algorithms:

                print(
                    f"    {col}"
                )

            continue

        # ====================================================
        # REMOVE INVALID BASELINE FCT VALUES
        # ====================================================

        df = df[
            df[baseline_col] > 0
        ].copy()

        if df.empty:

            print(
                "No valid flows after removing "
                "zero/negative ECMP FCT."
            )

            continue

        # ====================================================
        # FLOW SIZE SPLIT
        # ====================================================

        small_df = df[
            df["flow_size"] < SMALL
        ].copy()

        large_df = df[
            df["flow_size"] > LARGE
        ].copy()

        print(
            f"Small flows: {len(small_df):,}"
        )

        print(
            f"Large flows: {len(large_df):,}"
        )

        # ====================================================
        # BASELINE AVERAGES
        #
        # IMPORTANT:
        #
        # We calculate:
        #
        #     mean(FCT_algorithm)
        #     --------------------
        #     mean(FCT_ECMP)
        #
        # NOT:
        #
        #     mean(FCT_algorithm / FCT_ECMP)
        #
        # This makes the normalized graph consistent with
        # the Average FCT graph.
        # ====================================================

        # ----------------------------------------------------
        # SMALL FLOWS
        # ----------------------------------------------------

        if not small_df.empty:

            baseline_small_avg = (
                small_df[baseline_col].mean()
            )

        else:

            baseline_small_avg = np.nan

        # ----------------------------------------------------
        # LARGE FLOWS
        # ----------------------------------------------------

        if not large_df.empty:

            baseline_large_avg = (
                large_df[baseline_col].mean()
            )

        else:

            baseline_large_avg = np.nan

        # ====================================================
        # NORMALIZED RESULTS
        # ====================================================

        for algo in algorithms:

            algo_col = (
                f"FCT(s)_{algo}"
            )

            # ------------------------------------------------
            # SMALL FLOWS
            # ------------------------------------------------

            if (
                not small_df.empty
                and baseline_small_avg > 0
            ):

                algo_small_avg = (
                    small_df[algo_col].mean()
                )

                normalized_small = (
                    algo_small_avg /
                    baseline_small_avg
                )

                small_results[algo].append(
                    normalized_small
                )

            else:

                small_results[algo].append(
                    np.nan
                )

            # ------------------------------------------------
            # LARGE FLOWS
            # ------------------------------------------------

            if (
                not large_df.empty
                and baseline_large_avg > 0
            ):

                algo_large_avg = (
                    large_df[algo_col].mean()
                )

                normalized_large = (
                    algo_large_avg /
                    baseline_large_avg
                )

                large_results[algo].append(
                    normalized_large
                )

            else:

                large_results[algo].append(
                    np.nan
                )

        # ----------------------------------------------------
        # Store load
        # ----------------------------------------------------

        load_vals.append(
            load / 10
        )

        # ====================================================
        # PRINT NORMALIZED VALUES
        # ====================================================

        print()
        print(
            "Normalized Average FCT:"
        )

        if not small_df.empty:

            print(
                f"  Small flows "
                f"(ECMP avg = "
                f"{baseline_small_avg:.6f}s)"
            )

            for algo in algorithms:

                value = (
                    small_results[algo][-1]
                )

                print(
                    f"    {label_map[algo]:35s}: "
                    f"{value:.4f}"
                )

        if not large_df.empty:

            print(
                f"  Large flows "
                f"(ECMP avg = "
                f"{baseline_large_avg:.6f}s)"
            )

            for algo in algorithms:

                value = (
                    large_results[algo][-1]
                )

                print(
                    f"    {label_map[algo]:35s}: "
                    f"{value:.4f}"
                )


    # ========================================================
    # STORE RESULTS
    # ========================================================

    summary_results[benchmark] = {

        "loads":
            load_vals,

        "small":
            small_results,

        "large":
            large_results
    }


    # ========================================================
    # SMALL FLOWS PLOT
    # ========================================================

    plt.figure(
        figsize=(10, 7),
        dpi=120
    )

    for algo in algorithms:

        plt.plot(

            load_vals,

            small_results[algo],

            marker=marker_map[algo],

            color=color_map[algo],

            linestyle=(
                "--"
                if algo.endswith("_false")
                else "-"
            ),

            linewidth=2,

            markersize=7,

            label=(
                f"{label_map[algo]} / ECMP"
            )
        )

    # --------------------------------------------------------
    # ECMP baseline
    # --------------------------------------------------------

    plt.axhline(
        y=1,
        linestyle="--",
        color="black",
        linewidth=1.5,
        label="ECMP baseline"
    )

    # --------------------------------------------------------
    # Labels
    # --------------------------------------------------------

    plt.xlabel(
        "Network Load"
    )

    plt.ylabel(
        "Normalized Average FCT"
    )

    plt.title(
        f"{benchmark}: "
        f"Small Flows (<100 KB)"
    )

    # --------------------------------------------------------
    # Y-axis
    # --------------------------------------------------------

    plt.ylim(
        0,
        1.8
    )

    plt.yticks(
        np.arange(
            0,
            1.81,
            0.2
        )
    )

    # --------------------------------------------------------
    # Grid
    # --------------------------------------------------------

    plt.grid(
        True,
        alpha=0.3
    )

    plt.legend()

    plt.tight_layout()

    out_path = (
        graph_dir /
        f"{benchmark}_SMALL_relative_vs_load.png"
    )

    plt.savefig(
        out_path,
        dpi=300,
        bbox_inches="tight"
    )

    plt.close()

    print()
    print(
        f"Saved: {out_path}"
    )


    # ========================================================
    # LARGE FLOWS PLOT
    # ========================================================

    plt.figure(
        figsize=(10, 7),
        dpi=120
    )

    for algo in algorithms:

        plt.plot(

            load_vals,

            large_results[algo],

            marker=marker_map[algo],

            color=color_map[algo],

            linestyle=(
                "--"
                if algo.endswith("_false")
                else "-"
            ),

            linewidth=2,

            markersize=7,

            label=(
                f"{label_map[algo]} / ECMP"
            )
        )

    # --------------------------------------------------------
    # ECMP baseline
    # --------------------------------------------------------

    plt.axhline(
        y=1,
        linestyle="--",
        color="black",
        linewidth=1.5,
        label="ECMP baseline"
    )

    # --------------------------------------------------------
    # Labels
    # --------------------------------------------------------

    plt.xlabel(
        "Network Load"
    )

    plt.ylabel(
        "Normalized Average FCT"
    )

    plt.title(
        f"{benchmark}: "
        f"Large Flows (>1 MB)"
    )

    # --------------------------------------------------------
    # Y-axis
    # --------------------------------------------------------

    plt.ylim(
        0,
        1.4
    )

    plt.yticks(
        np.arange(
            0,
            1.41,
            0.2
        )
    )

    # --------------------------------------------------------
    # Grid
    # --------------------------------------------------------

    plt.grid(
        True,
        alpha=0.3
    )

    plt.legend()

    plt.tight_layout()

    out_path = (
        graph_dir /
        f"{benchmark}_LARGE_relative_vs_load.png"
    )

    plt.savefig(
        out_path,
        dpi=300,
        bbox_inches="tight"
    )

    plt.close()

    print(
        f"Saved: {out_path}"
    )


# ============================================================
# DONE
# ============================================================

print()
print("=" * 80)
print(
    "DONE: Normalized Average FCT graphs generated."
)
print("=" * 80)
# Out:
# ================================================================================
# BENCHMARK: private_enterprise
# ================================================================================
#
# Processing private_enterprise | Load 0.1
# Small flows: 5,787
# Large flows: 24
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.004024s)
#     Conga                              : 0.9975
#     Weighted ECMP (Timeout)            : 1.0014
#     Weighted ECMP (No Timeout)         : 1.0015
#     Power-of-2 Random (Timeout)        : 1.0007
#     Power-of-2 Random (No Timeout)     : 1.0003
#   Large flows (ECMP avg = 0.383445s)
#     Conga                              : 1.0000
#     Weighted ECMP (Timeout)            : 1.0000
#     Weighted ECMP (No Timeout)         : 1.0000
#     Power-of-2 Random (Timeout)        : 1.0001
#     Power-of-2 Random (No Timeout)     : 1.0001
#
# Processing private_enterprise | Load 0.2
# Small flows: 5,791
# Large flows: 16
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.005641s)
#     Conga                              : 0.9984
#     Weighted ECMP (Timeout)            : 1.0027
#     Weighted ECMP (No Timeout)         : 1.0035
#     Power-of-2 Random (Timeout)        : 1.0039
#     Power-of-2 Random (No Timeout)     : 1.0047
#   Large flows (ECMP avg = 0.375833s)
#     Conga                              : 1.0784
#     Weighted ECMP (Timeout)            : 1.0796
#     Weighted ECMP (No Timeout)         : 1.0015
#     Power-of-2 Random (Timeout)        : 1.0014
#     Power-of-2 Random (No Timeout)     : 1.0018
#
# Processing private_enterprise | Load 0.3
# Small flows: 5,830
# Large flows: 16
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.008202s)
#     Conga                              : 0.9974
#     Weighted ECMP (Timeout)            : 1.0002
#     Weighted ECMP (No Timeout)         : 0.9955
#     Power-of-2 Random (Timeout)        : 0.9978
#     Power-of-2 Random (No Timeout)     : 0.9968
#   Large flows (ECMP avg = 0.491197s)
#     Conga                              : 1.0011
#     Weighted ECMP (Timeout)            : 1.0001
#     Weighted ECMP (No Timeout)         : 1.0013
#     Power-of-2 Random (Timeout)        : 1.0015
#     Power-of-2 Random (No Timeout)     : 1.0003
#
# Processing private_enterprise | Load 0.4
# Small flows: 5,786
# Large flows: 16
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.009849s)
#     Conga                              : 0.9761
#     Weighted ECMP (Timeout)            : 1.0058
#     Weighted ECMP (No Timeout)         : 1.0048
#     Power-of-2 Random (Timeout)        : 1.0072
#     Power-of-2 Random (No Timeout)     : 1.0064
#   Large flows (ECMP avg = 0.445119s)
#     Conga                              : 1.0004
#     Weighted ECMP (Timeout)            : 1.0104
#     Weighted ECMP (No Timeout)         : 1.0160
#     Power-of-2 Random (Timeout)        : 1.0085
#     Power-of-2 Random (No Timeout)     : 1.0155
#
# Processing private_enterprise | Load 0.5
# Small flows: 5,784
# Large flows: 20
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.011833s)
#     Conga                              : 1.0112
#     Weighted ECMP (Timeout)            : 1.0184
#     Weighted ECMP (No Timeout)         : 1.0020
#     Power-of-2 Random (Timeout)        : 1.0222
#     Power-of-2 Random (No Timeout)     : 0.9627
#   Large flows (ECMP avg = 0.488878s)
#     Conga                              : 1.0019
#     Weighted ECMP (Timeout)            : 0.9623
#     Weighted ECMP (No Timeout)         : 1.0048
#     Power-of-2 Random (Timeout)        : 0.9640
#     Power-of-2 Random (No Timeout)     : 1.0048
#
# Processing private_enterprise | Load 0.6
# Small flows: 5,801
# Large flows: 21
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.016335s)
#     Conga                              : 0.9809
#     Weighted ECMP (Timeout)            : 0.9868
#     Weighted ECMP (No Timeout)         : 0.9770
#     Power-of-2 Random (Timeout)        : 0.9666
#     Power-of-2 Random (No Timeout)     : 0.9817
#   Large flows (ECMP avg = 0.437818s)
#     Conga                              : 0.9803
#     Weighted ECMP (Timeout)            : 0.9987
#     Weighted ECMP (No Timeout)         : 0.9908
#     Power-of-2 Random (Timeout)        : 0.9894
#     Power-of-2 Random (No Timeout)     : 1.0004
#
# Processing private_enterprise | Load 0.7
# Small flows: 5,802
# Large flows: 14
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.017865s)
#     Conga                              : 1.0931
#     Weighted ECMP (Timeout)            : 1.0474
#     Weighted ECMP (No Timeout)         : 1.0071
#     Power-of-2 Random (Timeout)        : 1.0075
#     Power-of-2 Random (No Timeout)     : 1.0586
#   Large flows (ECMP avg = 0.461039s)
#     Conga                              : 1.1728
#     Weighted ECMP (Timeout)            : 1.2330
#     Weighted ECMP (No Timeout)         : 0.9821
#     Power-of-2 Random (Timeout)        : 1.2253
#     Power-of-2 Random (No Timeout)     : 1.2449
#
# Processing private_enterprise | Load 0.8
# Small flows: 5,785
# Large flows: 22
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.020307s)
#     Conga                              : 1.0185
#     Weighted ECMP (Timeout)            : 0.8320
#     Weighted ECMP (No Timeout)         : 0.9608
#     Power-of-2 Random (Timeout)        : 0.9720
#     Power-of-2 Random (No Timeout)     : 0.8773
#   Large flows (ECMP avg = 0.922629s)
#     Conga                              : 1.0257
#     Weighted ECMP (Timeout)            : 0.9869
#     Weighted ECMP (No Timeout)         : 0.9129
#     Power-of-2 Random (Timeout)        : 0.9654
#     Power-of-2 Random (No Timeout)     : 0.9386
#
# Processing private_enterprise | Load 0.9
# Small flows: 5,778
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.028072s)
#     Conga                              : 1.0457
#     Weighted ECMP (Timeout)            : 1.0492
#     Weighted ECMP (No Timeout)         : 0.9453
#     Power-of-2 Random (Timeout)        : 1.0182
#     Power-of-2 Random (No Timeout)     : 1.0210
#   Large flows (ECMP avg = 0.591845s)
#     Conga                              : 1.0162
#     Weighted ECMP (Timeout)            : 1.1246
#     Weighted ECMP (No Timeout)         : 1.1212
#     Power-of-2 Random (Timeout)        : 1.1049
#     Power-of-2 Random (No Timeout)     : 1.1137
#
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/graph/normalised_vs_ecmp/private_enterprise_SMALL_relative_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/graph/normalised_vs_ecmp/private_enterprise_LARGE_relative_vs_load.png
#
# ================================================================================
# BENCHMARK: social_media_cloud
# ================================================================================
#
# Processing social_media_cloud | Load 0.1
# Small flows: 5,355
# Large flows: 8
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.005139s)
#     Conga                              : 0.9994
#     Weighted ECMP (Timeout)            : 1.0011
#     Weighted ECMP (No Timeout)         : 1.0018
#     Power-of-2 Random (Timeout)        : 1.0002
#     Power-of-2 Random (No Timeout)     : 1.0010
#   Large flows (ECMP avg = 0.127070s)
#     Conga                              : 1.0003
#     Weighted ECMP (Timeout)            : 1.0000
#     Weighted ECMP (No Timeout)         : 1.0000
#     Power-of-2 Random (Timeout)        : 1.0002
#     Power-of-2 Random (No Timeout)     : 1.0023
#
# Processing social_media_cloud | Load 0.2
# Small flows: 5,433
# Large flows: 3
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.006761s)
#     Conga                              : 1.0006
#     Weighted ECMP (Timeout)            : 0.9994
#     Weighted ECMP (No Timeout)         : 0.9999
#     Power-of-2 Random (Timeout)        : 1.0017
#     Power-of-2 Random (No Timeout)     : 1.0008
#   Large flows (ECMP avg = 0.153552s)
#     Conga                              : 1.0000
#     Weighted ECMP (Timeout)            : 1.0000
#     Weighted ECMP (No Timeout)         : 1.0000
#     Power-of-2 Random (Timeout)        : 1.0000
#     Power-of-2 Random (No Timeout)     : 1.0000
#
# Processing social_media_cloud | Load 0.3
# Small flows: 5,364
# Large flows: 8
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.010749s)
#     Conga                              : 1.0051
#     Weighted ECMP (Timeout)            : 1.0051
#     Weighted ECMP (No Timeout)         : 1.0005
#     Power-of-2 Random (Timeout)        : 0.9993
#     Power-of-2 Random (No Timeout)     : 1.0011
#   Large flows (ECMP avg = 0.140367s)
#     Conga                              : 1.0011
#     Weighted ECMP (Timeout)            : 1.0002
#     Weighted ECMP (No Timeout)         : 1.0012
#     Power-of-2 Random (Timeout)        : 1.0013
#     Power-of-2 Random (No Timeout)     : 1.0011
#
# Processing social_media_cloud | Load 0.4
# Small flows: 5,327
# Large flows: 3
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.016249s)
#     Conga                              : 0.9864
#     Weighted ECMP (Timeout)            : 0.9887
#     Weighted ECMP (No Timeout)         : 0.9973
#     Power-of-2 Random (Timeout)        : 0.9924
#     Power-of-2 Random (No Timeout)     : 0.9809
#   Large flows (ECMP avg = 0.177328s)
#     Conga                              : 0.9552
#     Weighted ECMP (Timeout)            : 0.9709
#     Weighted ECMP (No Timeout)         : 0.9567
#     Power-of-2 Random (Timeout)        : 0.9669
#     Power-of-2 Random (No Timeout)     : 0.9769
#
# Processing social_media_cloud | Load 0.5
# Small flows: 5,317
# Large flows: 8
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.019928s)
#     Conga                              : 0.9800
#     Weighted ECMP (Timeout)            : 0.9878
#     Weighted ECMP (No Timeout)         : 1.0135
#     Power-of-2 Random (Timeout)        : 0.9960
#     Power-of-2 Random (No Timeout)     : 1.0047
#   Large flows (ECMP avg = 0.191218s)
#     Conga                              : 1.0272
#     Weighted ECMP (Timeout)            : 1.0173
#     Weighted ECMP (No Timeout)         : 1.0108
#     Power-of-2 Random (Timeout)        : 1.0228
#     Power-of-2 Random (No Timeout)     : 1.0085
#
# Processing social_media_cloud | Load 0.6
# Small flows: 5,318
# Large flows: 6
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.022993s)
#     Conga                              : 0.9746
#     Weighted ECMP (Timeout)            : 0.9334
#     Weighted ECMP (No Timeout)         : 0.9790
#     Power-of-2 Random (Timeout)        : 0.9592
#     Power-of-2 Random (No Timeout)     : 0.9407
#   Large flows (ECMP avg = 0.277413s)
#     Conga                              : 0.9547
#     Weighted ECMP (Timeout)            : 0.9970
#     Weighted ECMP (No Timeout)         : 1.0105
#     Power-of-2 Random (Timeout)        : 1.0105
#     Power-of-2 Random (No Timeout)     : 0.9566
#
# Processing social_media_cloud | Load 0.7
# Small flows: 5,344
# Large flows: 4
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.029017s)
#     Conga                              : 1.0235
#     Weighted ECMP (Timeout)            : 1.0130
#     Weighted ECMP (No Timeout)         : 0.9894
#     Power-of-2 Random (Timeout)        : 0.9821
#     Power-of-2 Random (No Timeout)     : 0.9968
#   Large flows (ECMP avg = 0.264273s)
#     Conga                              : 1.0952
#     Weighted ECMP (Timeout)            : 1.0273
#     Weighted ECMP (No Timeout)         : 1.3398
#     Power-of-2 Random (Timeout)        : 1.2573
#     Power-of-2 Random (No Timeout)     : 0.9789
#
# Processing social_media_cloud | Load 0.8
# Small flows: 5,339
# Large flows: 9
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.041518s)
#     Conga                              : 0.9807
#     Weighted ECMP (Timeout)            : 0.9146
#     Weighted ECMP (No Timeout)         : 0.8590
#     Power-of-2 Random (Timeout)        : 0.9827
#     Power-of-2 Random (No Timeout)     : 0.8874
#   Large flows (ECMP avg = 0.425449s)
#     Conga                              : 0.7246
#     Weighted ECMP (Timeout)            : 0.7855
#     Weighted ECMP (No Timeout)         : 0.7181
#     Power-of-2 Random (Timeout)        : 0.6919
#     Power-of-2 Random (No Timeout)     : 0.6760
#
# Processing social_media_cloud | Load 0.9
# Small flows: 5,321
# Large flows: 9
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.034187s)
#     Conga                              : 0.9806
#     Weighted ECMP (Timeout)            : 0.9323
#     Weighted ECMP (No Timeout)         : 0.9680
#     Power-of-2 Random (Timeout)        : 0.9747
#     Power-of-2 Random (No Timeout)     : 0.9638
#   Large flows (ECMP avg = 0.466655s)
#     Conga                              : 0.8735
#     Weighted ECMP (Timeout)            : 0.6379
#     Weighted ECMP (No Timeout)         : 0.7272
#     Power-of-2 Random (Timeout)        : 0.9108
#     Power-of-2 Random (No Timeout)     : 0.8181
#
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/graph/normalised_vs_ecmp/social_media_cloud_SMALL_relative_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/graph/normalised_vs_ecmp/social_media_cloud_LARGE_relative_vs_load.png
#
# ================================================================================
# BENCHMARK: commercial_cloud
# ================================================================================
#
# Processing commercial_cloud | Load 0.1
# Small flows: 5,793
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.004733s)
#     Conga                              : 0.9993
#     Weighted ECMP (Timeout)            : 0.9998
#     Weighted ECMP (No Timeout)         : 1.0001
#     Power-of-2 Random (Timeout)        : 1.0001
#     Power-of-2 Random (No Timeout)     : 1.0001
#   Large flows (ECMP avg = 0.210801s)
#     Conga                              : 1.0000
#     Weighted ECMP (Timeout)            : 1.0000
#     Weighted ECMP (No Timeout)         : 1.0000
#     Power-of-2 Random (Timeout)        : 1.0000
#     Power-of-2 Random (No Timeout)     : 1.0000
#
# Processing commercial_cloud | Load 0.2
# Small flows: 5,785
# Large flows: 21
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.006590s)
#     Conga                              : 0.9943
#     Weighted ECMP (Timeout)            : 0.9952
#     Weighted ECMP (No Timeout)         : 1.0015
#     Power-of-2 Random (Timeout)        : 0.9985
#     Power-of-2 Random (No Timeout)     : 0.9993
#   Large flows (ECMP avg = 0.249711s)
#     Conga                              : 0.9993
#     Weighted ECMP (Timeout)            : 0.9993
#     Weighted ECMP (No Timeout)         : 1.0001
#     Power-of-2 Random (Timeout)        : 0.9994
#     Power-of-2 Random (No Timeout)     : 0.9994
#
# Processing commercial_cloud | Load 0.3
# Small flows: 5,781
# Large flows: 20
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.009845s)
#     Conga                              : 0.9996
#     Weighted ECMP (Timeout)            : 1.0002
#     Weighted ECMP (No Timeout)         : 1.0014
#     Power-of-2 Random (Timeout)        : 0.9937
#     Power-of-2 Random (No Timeout)     : 1.0018
#   Large flows (ECMP avg = 0.257737s)
#     Conga                              : 1.0018
#     Weighted ECMP (Timeout)            : 1.0018
#     Weighted ECMP (No Timeout)         : 0.9999
#     Power-of-2 Random (Timeout)        : 0.9977
#     Power-of-2 Random (No Timeout)     : 1.0019
#
# Processing commercial_cloud | Load 0.4
# Small flows: 5,778
# Large flows: 12
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.012149s)
#     Conga                              : 0.9988
#     Weighted ECMP (Timeout)            : 1.0000
#     Weighted ECMP (No Timeout)         : 0.9975
#     Power-of-2 Random (Timeout)        : 1.0000
#     Power-of-2 Random (No Timeout)     : 1.0013
#   Large flows (ECMP avg = 0.287805s)
#     Conga                              : 0.9982
#     Weighted ECMP (Timeout)            : 0.9971
#     Weighted ECMP (No Timeout)         : 1.0001
#     Power-of-2 Random (Timeout)        : 1.0000
#     Power-of-2 Random (No Timeout)     : 1.0019
#
# Processing commercial_cloud | Load 0.5
# Small flows: 5,811
# Large flows: 23
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.018138s)
#     Conga                              : 0.9850
#     Weighted ECMP (Timeout)            : 0.9984
#     Weighted ECMP (No Timeout)         : 0.9959
#     Power-of-2 Random (Timeout)        : 0.9965
#     Power-of-2 Random (No Timeout)     : 1.0034
#   Large flows (ECMP avg = 0.323843s)
#     Conga                              : 1.0397
#     Weighted ECMP (Timeout)            : 0.9958
#     Weighted ECMP (No Timeout)         : 0.9989
#     Power-of-2 Random (Timeout)        : 0.9941
#     Power-of-2 Random (No Timeout)     : 0.9959
#
# Processing commercial_cloud | Load 0.6
# Small flows: 5,787
# Large flows: 6
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.016691s)
#     Conga                              : 0.9912
#     Weighted ECMP (Timeout)            : 1.0382
#     Weighted ECMP (No Timeout)         : 0.9953
#     Power-of-2 Random (Timeout)        : 1.0181
#     Power-of-2 Random (No Timeout)     : 0.9896
#   Large flows (ECMP avg = 0.553253s)
#     Conga                              : 0.9866
#     Weighted ECMP (Timeout)            : 0.9838
#     Weighted ECMP (No Timeout)         : 0.9935
#     Power-of-2 Random (Timeout)        : 0.9783
#     Power-of-2 Random (No Timeout)     : 1.0034
#
# Processing commercial_cloud | Load 0.7
# Small flows: 5,785
# Large flows: 14
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.022759s)
#     Conga                              : 0.9533
#     Weighted ECMP (Timeout)            : 0.9491
#     Weighted ECMP (No Timeout)         : 0.8437
#     Power-of-2 Random (Timeout)        : 0.9637
#     Power-of-2 Random (No Timeout)     : 1.0376
#   Large flows (ECMP avg = 0.400219s)
#     Conga                              : 0.9294
#     Weighted ECMP (Timeout)            : 0.9283
#     Weighted ECMP (No Timeout)         : 0.9224
#     Power-of-2 Random (Timeout)        : 1.0964
#     Power-of-2 Random (No Timeout)     : 1.0350
#
# Processing commercial_cloud | Load 0.8
# Small flows: 5,803
# Large flows: 20
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.028422s)
#     Conga                              : 0.9771
#     Weighted ECMP (Timeout)            : 0.9216
#     Weighted ECMP (No Timeout)         : 0.9524
#     Power-of-2 Random (Timeout)        : 1.0944
#     Power-of-2 Random (No Timeout)     : 1.0769
#   Large flows (ECMP avg = 0.341486s)
#     Conga                              : 1.0441
#     Weighted ECMP (Timeout)            : 1.1925
#     Weighted ECMP (No Timeout)         : 0.9613
#     Power-of-2 Random (Timeout)        : 0.9710
#     Power-of-2 Random (No Timeout)     : 0.9711
#
# Processing commercial_cloud | Load 0.9
# Small flows: 5,754
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.046037s)
#     Conga                              : 1.1144
#     Weighted ECMP (Timeout)            : 0.9198
#     Weighted ECMP (No Timeout)         : 1.0936
#     Power-of-2 Random (Timeout)        : 0.9794
#     Power-of-2 Random (No Timeout)     : 0.8086
#   Large flows (ECMP avg = 0.600543s)
#     Conga                              : 0.9870
#     Weighted ECMP (Timeout)            : 0.9629
#     Weighted ECMP (No Timeout)         : 0.9796
#     Power-of-2 Random (Timeout)        : 0.9868
#     Power-of-2 Random (No Timeout)     : 1.0089
#
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/graph/normalised_vs_ecmp/commercial_cloud_SMALL_relative_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/graph/normalised_vs_ecmp/commercial_cloud_LARGE_relative_vs_load.png
#
# ================================================================================
# BENCHMARK: university
# ================================================================================
#
# Processing university | Load 0.1
# Small flows: 5,768
# Large flows: 21
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.002780s)
#     Conga                              : 0.9955
#     Weighted ECMP (Timeout)            : 1.0007
#     Weighted ECMP (No Timeout)         : 1.0009
#     Power-of-2 Random (Timeout)        : 1.0004
#     Power-of-2 Random (No Timeout)     : 1.0006
#   Large flows (ECMP avg = 0.262305s)
#     Conga                              : 1.0012
#     Weighted ECMP (Timeout)            : 1.0004
#     Weighted ECMP (No Timeout)         : 1.0002
#     Power-of-2 Random (Timeout)        : 1.0005
#     Power-of-2 Random (No Timeout)     : 1.0001
#
# Processing university | Load 0.2
# Small flows: 5,801
# Large flows: 25
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.004422s)
#     Conga                              : 0.9943
#     Weighted ECMP (Timeout)            : 0.9995
#     Weighted ECMP (No Timeout)         : 0.9995
#     Power-of-2 Random (Timeout)        : 0.9996
#     Power-of-2 Random (No Timeout)     : 0.9999
#   Large flows (ECMP avg = 0.227076s)
#     Conga                              : 0.9997
#     Weighted ECMP (Timeout)            : 1.0002
#     Weighted ECMP (No Timeout)         : 1.0002
#     Power-of-2 Random (Timeout)        : 1.0001
#     Power-of-2 Random (No Timeout)     : 1.0001
#
# Processing university | Load 0.3
# Small flows: 5,803
# Large flows: 23
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.006519s)
#     Conga                              : 0.9985
#     Weighted ECMP (Timeout)            : 1.0014
#     Weighted ECMP (No Timeout)         : 1.0003
#     Power-of-2 Random (Timeout)        : 1.0002
#     Power-of-2 Random (No Timeout)     : 1.0012
#   Large flows (ECMP avg = 0.224826s)
#     Conga                              : 1.0011
#     Weighted ECMP (Timeout)            : 1.0008
#     Weighted ECMP (No Timeout)         : 1.0010
#     Power-of-2 Random (Timeout)        : 1.0012
#     Power-of-2 Random (No Timeout)     : 1.0004
#
# Processing university | Load 0.4
# Small flows: 5,786
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.010571s)
#     Conga                              : 0.9961
#     Weighted ECMP (Timeout)            : 0.9997
#     Weighted ECMP (No Timeout)         : 0.9886
#     Power-of-2 Random (Timeout)        : 0.9983
#     Power-of-2 Random (No Timeout)     : 0.9910
#   Large flows (ECMP avg = 0.311565s)
#     Conga                              : 1.0005
#     Weighted ECMP (Timeout)            : 1.0021
#     Weighted ECMP (No Timeout)         : 0.9994
#     Power-of-2 Random (Timeout)        : 1.0045
#     Power-of-2 Random (No Timeout)     : 1.0020
#
# Processing university | Load 0.5
# Small flows: 5,782
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.012403s)
#     Conga                              : 0.9966
#     Weighted ECMP (Timeout)            : 1.0047
#     Weighted ECMP (No Timeout)         : 1.0221
#     Power-of-2 Random (Timeout)        : 1.0035
#     Power-of-2 Random (No Timeout)     : 0.9959
#   Large flows (ECMP avg = 0.524892s)
#     Conga                              : 0.9987
#     Weighted ECMP (Timeout)            : 1.0011
#     Weighted ECMP (No Timeout)         : 0.9945
#     Power-of-2 Random (Timeout)        : 1.0005
#     Power-of-2 Random (No Timeout)     : 1.0024
#
# Processing university | Load 0.6
# Small flows: 5,779
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.019592s)
#     Conga                              : 0.8960
#     Weighted ECMP (Timeout)            : 1.0655
#     Weighted ECMP (No Timeout)         : 0.8861
#     Power-of-2 Random (Timeout)        : 1.0812
#     Power-of-2 Random (No Timeout)     : 1.0590
#   Large flows (ECMP avg = 0.570578s)
#     Conga                              : 0.9974
#     Weighted ECMP (Timeout)            : 1.0022
#     Weighted ECMP (No Timeout)         : 0.9944
#     Power-of-2 Random (Timeout)        : 1.0036
#     Power-of-2 Random (No Timeout)     : 1.0026
#
# Processing university | Load 0.7
# Small flows: 5,786
# Large flows: 19
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.018836s)
#     Conga                              : 1.0033
#     Weighted ECMP (Timeout)            : 0.9996
#     Weighted ECMP (No Timeout)         : 0.9978
#     Power-of-2 Random (Timeout)        : 0.9910
#     Power-of-2 Random (No Timeout)     : 1.0075
#   Large flows (ECMP avg = 0.309624s)
#     Conga                              : 0.9934
#     Weighted ECMP (Timeout)            : 1.0018
#     Weighted ECMP (No Timeout)         : 0.9716
#     Power-of-2 Random (Timeout)        : 0.9871
#     Power-of-2 Random (No Timeout)     : 0.9935
#
# Processing university | Load 0.8
# Small flows: 5,791
# Large flows: 15
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.014308s)
#     Conga                              : 1.0331
#     Weighted ECMP (Timeout)            : 1.1312
#     Weighted ECMP (No Timeout)         : 1.0088
#     Power-of-2 Random (Timeout)        : 1.0222
#     Power-of-2 Random (No Timeout)     : 0.9999
#   Large flows (ECMP avg = 0.550271s)
#     Conga                              : 0.9882
#     Weighted ECMP (Timeout)            : 0.9312
#     Weighted ECMP (No Timeout)         : 1.0205
#     Power-of-2 Random (Timeout)        : 1.0228
#     Power-of-2 Random (No Timeout)     : 1.0038
#
# Processing university | Load 0.9
# Small flows: 5,789
# Large flows: 25
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.022148s)
#     Conga                              : 0.9900
#     Weighted ECMP (Timeout)            : 1.0093
#     Weighted ECMP (No Timeout)         : 0.9577
#     Power-of-2 Random (Timeout)        : 0.9555
#     Power-of-2 Random (No Timeout)     : 0.9593
#   Large flows (ECMP avg = 0.469337s)
#     Conga                              : 0.9749
#     Weighted ECMP (Timeout)            : 1.0987
#     Weighted ECMP (No Timeout)         : 0.9713
#     Power-of-2 Random (Timeout)        : 1.0429
#     Power-of-2 Random (No Timeout)     : 1.0416
#
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/graph/normalised_vs_ecmp/university_SMALL_relative_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v2/analysis_results/graph/normalised_vs_ecmp/university_LARGE_relative_vs_load.png
#
# ================================================================================
# DONE: Normalized Average FCT graphs generated.
# ================================================================================
