# %%
import trafpy.generator as tpg
from trafpy.benchmarker import BenchmarkImporter

from pathlib import Path
import time

# ------------------ NETWORK SETUP ------------------
num_eps = 8
'''
num_racks = 2

racks_dict = {}
eps_per_rack = int(num_eps / num_racks)

for rack in range(num_racks):
    racks_dict[rack] = [
        ep for ep in range(rack * eps_per_rack,
                           (rack * eps_per_rack) + eps_per_rack)
    ]

print("racks_dict:", racks_dict)
'''

# 100 Mbps → Bytes/sec
ep_capacity = 100000000 / 8

net = tpg.gen_arbitrary_network(
    num_eps=num_eps,
    ep_capacity=ep_capacity)
    #racks_dict=racks_dict
#)

# ------------------ NETWORK INFO ------------------
print("\n--- NETWORK INFO ---")
print("topology_type:", net.graph['topology_type'])
print("max_nw_capacity:", net.graph['max_nw_capacity'])
print("endpoints:", net.graph['endpoints'])

# ------------------ BENCHMARK SETUP ------------------
importer = BenchmarkImporter(
    benchmark_version='v001',
    load_prev_dists=False
)

# Add/remove benchmarks here
benchmark_names = [
    'private_enterprise',
    'social_media_cloud',
    'commercial_cloud',
    'university'    
]

# ------------------ OUTPUT DIR ------------------
path_to_data = "8_hosts_v5(no_rack)/"
Path(path_to_data).mkdir(exist_ok=True, parents=True)

# ------------------ PARAMETERS ------------------
jsd_threshold = 0.9
loads = [i / 10 for i in range(1, 10)]  # 0.1 → 0.9

# ------------------ MAIN LOOP ------------------
for benchmark_name in benchmark_names:
    print(f"\n==============================")
    print(f"Benchmark: {benchmark_name}")
    print(f"==============================")

    # Load distributions for this benchmark
    dists = importer.get_benchmark_dists(
        benchmark_name=benchmark_name,
        eps=net.graph['endpoints'],
        racks_dict=net.graph['rack_to_ep_dict']
    )

    print("Loaded distributions:", list(dists.keys()))

    # Loop over loads
    for load in loads:
        print(f"\n--- Load {load} ---")
        start_time = time.time()

        network_load_config = {
            'network_rate_capacity': net.graph['max_nw_capacity'],
            'ep_link_capacity': net.graph['ep_link_capacity'],
            'target_load_fraction': load
        }

        demand_data = tpg.create_demand_data(
            eps=net.graph['endpoints'],
            node_dist=dists['node_dist'],
            flow_size_dist=dists['flow_size_dist'],
            interarrival_time_dist=dists['interarrival_time_dist'],
            #min_num_demands=40000,
            network_load_config=network_load_config,
            jensen_shannon_distance_threshold=jsd_threshold
        )

        # ------------------ SAVE ------------------
        filename = f"{path_to_data}{benchmark_name}_load_{int(load*10)}.csv"

        tpg.save_data_as_csv(
            data=demand_data,
            path_to_save=filename,
            overwrite=True
        )

        print(f"Saved: {filename}")
        print(f"Time: {time.time() - start_time:.2f}s")

print("\n All datasets generated!")
# Out:
# /home/hsd/anaconda3/envs/trafpy-env/lib/python3.13/site-packages/nxviz/__init__.py:18: UserWarning:
# nxviz has a new API! Version 0.7.3 onwards, the old class-based API is being
# deprecated in favour of a new API focused on advancing a grammar of network
# graphics. If your plotting code depends on the old API, please consider
# pinning nxviz at version 0.7.3, as the new API will break your old code.
#
# To check out the new API, please head over to the docs at
# https://ericmjl.github.io/nxviz/ to learn more. We hope you enjoy using it!
#
# (This deprecation message will go away in version 1.0.)
#
#   warnings.warn(
# --- NETWORK INFO ---
# topology_type: arbitrary_endpoints_8_chancap_12500000.0_channels_1
# max_nw_capacity: 50000000.0
# endpoints: ['0', '1', '2', '3', '4', '5', '6', '7']
# load_prev_dist=False. Will re-generate dists with given network params and override any previously saved distributions.
#
# ==============================
# Benchmark: private_enterprise
# ==============================
# Set to save benchmark private_enterprise distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/private_enterprise/
# Saved node_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/private_enterprise/
# Saved flow_size_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/private_enterprise/
# Saved interarrival_time_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/private_enterprise/
# Loaded distributions: ['node_dist', 'flow_size_dist', 'interarrival_time_dist', 'num_ops_dist']
#
# --- Load 0.1 ---
# Packed 6000 flows in 0.241 s | Node distribution Jensen Shannon distance from target achieved: 0.06005844484366115
# Time to save data to 8_hosts_v5(no_rack)/private_enterprise_load_1.csv: 0.015317678451538086 s
# Saved: 8_hosts_v5(no_rack)/private_enterprise_load_1.csv
# Time: 0.28s
#
# --- Load 0.2 ---
# Packed 6000 flows in 0.242 s | Node distribution Jensen Shannon distance from target achieved: 0.11956969515241479
# Time to save data to 8_hosts_v5(no_rack)/private_enterprise_load_2.csv: 0.014646768569946289 s
# Saved: 8_hosts_v5(no_rack)/private_enterprise_load_2.csv
# Time: 0.28s
#
# --- Load 0.3 ---
# Packed 6000 flows in 0.240 s | Node distribution Jensen Shannon distance from target achieved: 0.052447346934192805
# Time to save data to 8_hosts_v5(no_rack)/private_enterprise_load_3.csv: 0.014144182205200195 s
# Saved: 8_hosts_v5(no_rack)/private_enterprise_load_3.csv
# Time: 0.28s
#
# --- Load 0.4 ---
# Packed 6000 flows in 0.240 s | Node distribution Jensen Shannon distance from target achieved: 0.04911706853039897
# Time to save data to 8_hosts_v5(no_rack)/private_enterprise_load_4.csv: 0.014204740524291992 s
# Saved: 8_hosts_v5(no_rack)/private_enterprise_load_4.csv
# Time: 0.28s
#
# --- Load 0.5 ---
# Packed 6000 flows in 0.241 s | Node distribution Jensen Shannon distance from target achieved: 0.10388158371172641
# Time to save data to 8_hosts_v5(no_rack)/private_enterprise_load_5.csv: 0.014073848724365234 s
# Saved: 8_hosts_v5(no_rack)/private_enterprise_load_5.csv
# Time: 0.28s
#
# --- Load 0.6 ---
# Packed 6000 flows in 0.245 s | Node distribution Jensen Shannon distance from target achieved: 0.01641027161450657
# Time to save data to 8_hosts_v5(no_rack)/private_enterprise_load_6.csv: 0.014513969421386719 s
# Saved: 8_hosts_v5(no_rack)/private_enterprise_load_6.csv
# Time: 0.28s
#
# --- Load 0.7 ---
# Packed 6000 flows in 0.249 s | Node distribution Jensen Shannon distance from target achieved: 0.01635069825684576
# Time to save data to 8_hosts_v5(no_rack)/private_enterprise_load_7.csv: 0.014502286911010742 s
# Saved: 8_hosts_v5(no_rack)/private_enterprise_load_7.csv
# Time: 0.29s
#
# --- Load 0.8 ---
# Packed 6000 flows in 0.242 s | Node distribution Jensen Shannon distance from target achieved: 0.11420396711062052
# Time to save data to 8_hosts_v5(no_rack)/private_enterprise_load_8.csv: 0.014467716217041016 s
# Saved: 8_hosts_v5(no_rack)/private_enterprise_load_8.csv
# Time: 0.28s
#
# --- Load 0.9 ---
# Packed 6000 flows in 0.264 s | Node distribution Jensen Shannon distance from target achieved: 0.3455454294970572
# Time to save data to 8_hosts_v5(no_rack)/private_enterprise_load_9.csv: 0.016060352325439453 s
# Saved: 8_hosts_v5(no_rack)/private_enterprise_load_9.csv
# Time: 0.30s
#
# ==============================
# Benchmark: social_media_cloud
# ==============================
# Set to save benchmark social_media_cloud distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/social_media_cloud/
# Saved node_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/social_media_cloud/
# Saved flow_size_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/social_media_cloud/
# Saved interarrival_time_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/social_media_cloud/
# Loaded distributions: ['node_dist', 'flow_size_dist', 'interarrival_time_dist', 'num_ops_dist']
#
# --- Load 0.1 ---
# Packed 6000 flows in 0.434 s | Node distribution Jensen Shannon distance from target achieved: 4.3182779878625905e-07
# Time to save data to 8_hosts_v5(no_rack)/social_media_cloud_load_1.csv: 0.025594234466552734 s
# Saved: 8_hosts_v5(no_rack)/social_media_cloud_load_1.csv
# Time: 0.51s
#
# --- Load 0.2 ---
# Packed 6000 flows in 0.529 s | Node distribution Jensen Shannon distance from target achieved: 6.524949695794537e-07
# Time to save data to 8_hosts_v5(no_rack)/social_media_cloud_load_2.csv: 0.027012348175048828 s
# Saved: 8_hosts_v5(no_rack)/social_media_cloud_load_2.csv
# Time: 0.60s
#
# --- Load 0.3 ---
# Packed 6000 flows in 0.406 s | Node distribution Jensen Shannon distance from target achieved: 4.082332543101092e-07
# Time to save data to 8_hosts_v5(no_rack)/social_media_cloud_load_3.csv: 0.028084516525268555 s
# Saved: 8_hosts_v5(no_rack)/social_media_cloud_load_3.csv
# Time: 0.48s
#
# --- Load 0.4 ---
# Packed 6000 flows in 0.398 s | Node distribution Jensen Shannon distance from target achieved: 6.098632963955142e-07
# Time to save data to 8_hosts_v5(no_rack)/social_media_cloud_load_4.csv: 0.0246889591217041 s
# Saved: 8_hosts_v5(no_rack)/social_media_cloud_load_4.csv
# Time: 0.47s
#
# --- Load 0.5 ---
# Packed 6000 flows in 0.417 s | Node distribution Jensen Shannon distance from target achieved: 5.856231934249686e-07
# Time to save data to 8_hosts_v5(no_rack)/social_media_cloud_load_5.csv: 0.02475738525390625 s
# Saved: 8_hosts_v5(no_rack)/social_media_cloud_load_5.csv
# Time: 0.49s
#
# --- Load 0.6 ---
# Packed 6000 flows in 0.407 s | Node distribution Jensen Shannon distance from target achieved: 6.051655664726192e-07
# Time to save data to 8_hosts_v5(no_rack)/social_media_cloud_load_6.csv: 0.023333072662353516 s
# Saved: 8_hosts_v5(no_rack)/social_media_cloud_load_6.csv
# Time: 0.48s
#
# --- Load 0.7 ---
# Packed 6000 flows in 0.412 s | Node distribution Jensen Shannon distance from target achieved: 5.113578988185161e-07
# Time to save data to 8_hosts_v5(no_rack)/social_media_cloud_load_7.csv: 0.024535655975341797 s
# Saved: 8_hosts_v5(no_rack)/social_media_cloud_load_7.csv
# Time: 0.48s
#
# --- Load 0.8 ---
# Packed 6000 flows in 0.439 s | Node distribution Jensen Shannon distance from target achieved: 0.002361151236732348
# Time to save data to 8_hosts_v5(no_rack)/social_media_cloud_load_8.csv: 0.026849985122680664 s
# Saved: 8_hosts_v5(no_rack)/social_media_cloud_load_8.csv
# Time: 0.51s
#
# --- Load 0.9 ---
# Packed 6000 flows in 0.413 s | Node distribution Jensen Shannon distance from target achieved: 0.048439777888574335
# Time to save data to 8_hosts_v5(no_rack)/social_media_cloud_load_9.csv: 0.025191307067871094 s
# Saved: 8_hosts_v5(no_rack)/social_media_cloud_load_9.csv
# Time: 0.49s
#
# ==============================
# Benchmark: commercial_cloud
# ==============================
# Set to save benchmark commercial_cloud distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/commercial_cloud/
# Saved node_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/commercial_cloud/
# Saved flow_size_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/commercial_cloud/
# Saved interarrival_time_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/commercial_cloud/
# Loaded distributions: ['node_dist', 'flow_size_dist', 'interarrival_time_dist', 'num_ops_dist']
#
# --- Load 0.1 ---
# Packed 6000 flows in 0.409 s | Node distribution Jensen Shannon distance from target achieved: 0.05758155456711846
# Time to save data to 8_hosts_v5(no_rack)/commercial_cloud_load_1.csv: 0.024677276611328125 s
# Saved: 8_hosts_v5(no_rack)/commercial_cloud_load_1.csv
# Time: 0.47s
#
# --- Load 0.2 ---
# Packed 6000 flows in 0.412 s | Node distribution Jensen Shannon distance from target achieved: 0.019264689748986895
# Time to save data to 8_hosts_v5(no_rack)/commercial_cloud_load_2.csv: 0.02833390235900879 s
# Saved: 8_hosts_v5(no_rack)/commercial_cloud_load_2.csv
# Time: 0.48s
#
# --- Load 0.3 ---
# Packed 6000 flows in 0.391 s | Node distribution Jensen Shannon distance from target achieved: 0.02643022847633332
# Time to save data to 8_hosts_v5(no_rack)/commercial_cloud_load_3.csv: 0.0269620418548584 s
# Saved: 8_hosts_v5(no_rack)/commercial_cloud_load_3.csv
# Time: 0.45s
#
# --- Load 0.4 ---
# Packed 6000 flows in 0.398 s | Node distribution Jensen Shannon distance from target achieved: 0.05515847412512592
# Time to save data to 8_hosts_v5(no_rack)/commercial_cloud_load_4.csv: 0.023932456970214844 s
# Saved: 8_hosts_v5(no_rack)/commercial_cloud_load_4.csv
# Time: 0.46s
#
# --- Load 0.5 ---
# Packed 6000 flows in 0.420 s | Node distribution Jensen Shannon distance from target achieved: 0.06640260519495686
# Time to save data to 8_hosts_v5(no_rack)/commercial_cloud_load_5.csv: 0.024161338806152344 s
# Saved: 8_hosts_v5(no_rack)/commercial_cloud_load_5.csv
# Time: 0.48s
#
# --- Load 0.6 ---
# Packed 6000 flows in 0.393 s | Node distribution Jensen Shannon distance from target achieved: 0.05731954801127044
# Time to save data to 8_hosts_v5(no_rack)/commercial_cloud_load_6.csv: 0.02504134178161621 s
# Saved: 8_hosts_v5(no_rack)/commercial_cloud_load_6.csv
# Time: 0.45s
#
# --- Load 0.7 ---
# Packed 6000 flows in 0.408 s | Node distribution Jensen Shannon distance from target achieved: 0.21621040173154973
# Time to save data to 8_hosts_v5(no_rack)/commercial_cloud_load_7.csv: 0.02445673942565918 s
# Saved: 8_hosts_v5(no_rack)/commercial_cloud_load_7.csv
# Time: 0.47s
#
# --- Load 0.8 ---
# Packed 6000 flows in 0.413 s | Node distribution Jensen Shannon distance from target achieved: 0.18910764969341007
# Time to save data to 8_hosts_v5(no_rack)/commercial_cloud_load_8.csv: 0.02350783348083496 s
# Saved: 8_hosts_v5(no_rack)/commercial_cloud_load_8.csv
# Time: 0.47s
#
# --- Load 0.9 ---
# Packed 6000 flows in 0.424 s | Node distribution Jensen Shannon distance from target achieved: 0.16226167677573358
# Time to save data to 8_hosts_v5(no_rack)/commercial_cloud_load_9.csv: 0.02441096305847168 s
# Saved: 8_hosts_v5(no_rack)/commercial_cloud_load_9.csv
# Time: 0.48s
#
# ==============================
# Benchmark: university
# ==============================
# Set to save benchmark university distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/university/
# Saved node_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/university/
# Saved flow_size_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/university/
# Saved interarrival_time_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/university/
# Loaded distributions: ['node_dist', 'flow_size_dist', 'interarrival_time_dist', 'num_ops_dist']
#
# --- Load 0.1 ---
# Packed 6000 flows in 0.417 s | Node distribution Jensen Shannon distance from target achieved: 0.09709210329974699
# Time to save data to 8_hosts_v5(no_rack)/university_load_1.csv: 0.02635049819946289 s
# Saved: 8_hosts_v5(no_rack)/university_load_1.csv
# Time: 0.48s
#
# --- Load 0.2 ---
# Packed 6000 flows in 0.430 s | Node distribution Jensen Shannon distance from target achieved: 0.04808601447626599
# Time to save data to 8_hosts_v5(no_rack)/university_load_2.csv: 0.024266719818115234 s
# Saved: 8_hosts_v5(no_rack)/university_load_2.csv
# Time: 0.49s
#
# --- Load 0.3 ---
# Packed 6000 flows in 0.436 s | Node distribution Jensen Shannon distance from target achieved: 0.17613138162377898
# Time to save data to 8_hosts_v5(no_rack)/university_load_3.csv: 0.023607492446899414 s
# Saved: 8_hosts_v5(no_rack)/university_load_3.csv
# Time: 0.50s
#
# --- Load 0.4 ---
# Packed 6000 flows in 0.421 s | Node distribution Jensen Shannon distance from target achieved: 0.04713272809969105
# Time to save data to 8_hosts_v5(no_rack)/university_load_4.csv: 0.024287700653076172 s
# Saved: 8_hosts_v5(no_rack)/university_load_4.csv
# Time: 0.48s
#
# --- Load 0.5 ---
# Packed 6000 flows in 0.422 s | Node distribution Jensen Shannon distance from target achieved: 0.08957523551878721
# Time to save data to 8_hosts_v5(no_rack)/university_load_5.csv: 0.024956941604614258 s
# Saved: 8_hosts_v5(no_rack)/university_load_5.csv
# Time: 0.49s
#
# --- Load 0.6 ---
# Packed 6000 flows in 0.422 s | Node distribution Jensen Shannon distance from target achieved: 0.12679776621764835
# Time to save data to 8_hosts_v5(no_rack)/university_load_6.csv: 0.024332046508789062 s
# Saved: 8_hosts_v5(no_rack)/university_load_6.csv
# Time: 0.49s
#
# --- Load 0.7 ---
# Packed 6000 flows in 0.410 s | Node distribution Jensen Shannon distance from target achieved: 0.043098892699367966
# Time to save data to 8_hosts_v5(no_rack)/university_load_7.csv: 0.026428937911987305 s
# Saved: 8_hosts_v5(no_rack)/university_load_7.csv
# Time: 0.48s
#
# --- Load 0.8 ---
# Packed 6000 flows in 0.417 s | Node distribution Jensen Shannon distance from target achieved: 0.016007653007964365
# Time to save data to 8_hosts_v5(no_rack)/university_load_8.csv: 0.0245668888092041 s
# Saved: 8_hosts_v5(no_rack)/university_load_8.csv
# Time: 0.48s
#
# --- Load 0.9 ---
# Packed 6000 flows in 0.420 s | Node distribution Jensen Shannon distance from target achieved: 0.10973510725689327
# Time to save data to 8_hosts_v5(no_rack)/university_load_9.csv: 0.0282742977142334 s
# Saved: 8_hosts_v5(no_rack)/university_load_9.csv
# Time: 0.49s
#
#  All datasets generated!
