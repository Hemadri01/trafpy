# %%
import pandas as pd
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt


# ============================================================
# CONFIG
# ============================================================

benchmarks = [
    "private_enterprise",
    "social_media_cloud",
    "commercial_cloud",
    "university"
]

# benchmarks = [
#     "private_enterprise",
#     "social_media_cloud"
# ]

loads = range(1, 8)

# Input TrafPy flow files
input_dir = "/home/hsd/workspace/trafpy/examples/comparison_generator/8_hosts_v9(prob1)"

# CONGA / ECMP ns-3 outputs
conga_dir = "/home/hsd/workspace/ns-3.45/conga_asym_8_hosts_v9(prob1)"

# RTT ns-3 outputs
rtt_dir = "/home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)"

# Output directory
save_dir = "/home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results"

Path(save_dir).mkdir(
    parents=True,
    exist_ok=True
)


# ============================================================
# MATCHING CONFIG
# ============================================================

PORT_START = 10000
PORT_END = 50000

ip_pattern = r'^\d+\.\d+\.\d+\.\d+$'


# ============================================================
# FUNCTIONS
# ============================================================

def clean(df):
    """
    Keep only rows that contain valid IP addresses.
    """

    required = [
        "Src",
        "Dest"
    ]

    for col in required:

        if col not in df.columns:

            raise ValueError(
                f"Required column '{col}' not found."
            )

    return df[
        df["Src"].astype(str).str.match(
            ip_pattern,
            na=False
        )
        &
        df["Dest"].astype(str).str.match(
            ip_pattern,
            na=False
        )
    ].copy()


# ============================================================

def ip_to_node(ip):
    """
    Convert ns-3 server IP to input trace node ID.

    Leaf 0:
        10.1.1.2 -> 0
        10.1.1.4 -> 1
        10.1.1.6 -> 2
        10.1.1.8 -> 3

    Leaf 1:
        10.1.2.2 -> 4
        10.1.2.4 -> 5
        10.1.2.6 -> 6
        10.1.2.8 -> 7
    """

    parts = ip.split(".")

    subnet = int(parts[-2])
    host = int(parts[-1])

    base = (host // 2) - 1

    if subnet == 1:

        return base

    elif subnet == 2:

        return base + 4

    else:

        raise ValueError(
            f"Unexpected IP address: {ip}"
        )


# ============================================================

def add_time(df):
    """
    Convert ns-3 TimeFirstTxPacket to seconds.
    """

    df = df.copy()

    df["start_time"] = (
        df["TimeFirstTxPacket"]
        .astype(str)
        .str.replace("+", "", regex=False)
        .str.replace("ns", "", regex=False)
        .astype(float)
        / 1e9
    )

    return df


# ============================================================

def expected_port(flow_index):
    """
    Reproduce the C++ destination-port calculation.

        port = PORT_START + flow.index

    with wrapping after PORT_END.
    """

    port = PORT_START + int(flow_index)

    if port > PORT_END:

        port = port - (
            PORT_END - PORT_START
        )

    return port


# ============================================================
# FLOW COLUMNS
# ============================================================

flow_columns = [
    "FlowID",
    "Src",
    "Dest",
    "TimeFirstRxPacket",
    "TimeFirstTxPacket",
    "TimeLastRxPacket",
    "TimeLastTxPacket",
    "FCT(s)",
    "TxPackets",
    "RxPackets",
    "LostPackets",
    "LossRate",
    "PDR",
    "LossPercent",
    "TxBytes",
    "RxBytes",
    "Throughput(Kbps)",
    "MeanDelay(ms)",
    "Jitter(ms)",
    "HopCount"
]


# ============================================================
# MATCHING FUNCTION
# ============================================================

def match_df(output_df, input_df, label):
    """
    Match input TrafPy flows to ns-3 flows.

    Matching is based on:

        1. source node
        2. destination node
        3. destination port

    If multiple ns-3 flows have the same tuple, the candidate
    with the closest start time to the input event time is used.

    Time is NOT a hard matching criterion.
    """

    matches = []

    # --------------------------------------------------------
    # Make copies
    # --------------------------------------------------------

    output_df = output_df.copy()
    input_df = input_df.copy()

    # --------------------------------------------------------
    # Numeric conversion
    # --------------------------------------------------------

    for col in [
        "SrcPort",
        "DestPort",
        "TxPackets",
        "RxPackets",
        "TxBytes",
        "RxBytes",
        "start_time",
        "sn",
        "dn"
    ]:

        if col in output_df.columns:

            output_df[col] = pd.to_numeric(
                output_df[col],
                errors="coerce"
            )

    for col in [
        "sn",
        "dn",
        "index",
        "flow_size",
        "event_time"
    ]:

        input_df[col] = pd.to_numeric(
            input_df[col],
            errors="coerce"
        )

    # --------------------------------------------------------
    # Remove invalid rows
    # --------------------------------------------------------

    output_df = output_df.dropna(
        subset=[
            "SrcPort",
            "DestPort",
            "TxPackets",
            "RxPackets",
            "TxBytes",
            "RxBytes",
            "start_time",
            "sn",
            "dn"
        ]
    ).copy()

    input_df = input_df.dropna(
        subset=[
            "sn",
            "dn",
            "index",
            "flow_size",
            "event_time"
        ]
    ).copy()

    # --------------------------------------------------------
    # Sort input by event time
    # --------------------------------------------------------

    input_df = input_df.sort_values(
        "event_time"
    ).reset_index(
        drop=True
    )

    # --------------------------------------------------------
    # Create lookup key
    #
    # (source node, destination node, destination port)
    # --------------------------------------------------------

    output_df["_match_key"] = list(
        zip(
            output_df["sn"].astype(int),
            output_df["dn"].astype(int),
            output_df["DestPort"].astype(int)
        )
    )

    # --------------------------------------------------------
    # Group ns-3 flows by matching key
    # --------------------------------------------------------

    grouped = {
        key: group
        for key, group in output_df.groupby(
            "_match_key",
            sort=False
        )
    }

    # --------------------------------------------------------
    # Process every input flow
    # --------------------------------------------------------

    for _, in_row in input_df.iterrows():

        input_flow_id = in_row["flow_id"]

        input_index = int(
            in_row["index"]
        )

        input_src = int(
            in_row["sn"]
        )

        input_dst = int(
            in_row["dn"]
        )

        input_time = float(
            in_row["event_time"]
        )

        input_size = float(
            in_row["flow_size"]
        )

        # ----------------------------------------------------
        # Expected destination port
        # ----------------------------------------------------

        expected_dst_port = expected_port(
            input_index
        )

        # ----------------------------------------------------
        # Lookup
        # ----------------------------------------------------

        key = (
            input_src,
            input_dst,
            expected_dst_port
        )

        candidates = grouped.get(
            key
        )

        # ----------------------------------------------------
        # No matching ns-3 flow
        # ----------------------------------------------------

        if candidates is None or len(candidates) == 0:

            continue

        # ----------------------------------------------------
        # Find closest start time
        # ----------------------------------------------------

        if len(candidates) == 1:

            best = candidates.iloc[0]

            time_diff = abs(
                best["start_time"]
                - input_time
            )

        else:

            time_diffs = (
                candidates["start_time"]
                - input_time
            ).abs()

            best_index = time_diffs.idxmin()

            best = candidates.loc[
                best_index
            ]

            time_diff = time_diffs.loc[
                best_index
            ]

        # ----------------------------------------------------
        # Size difference
        # ----------------------------------------------------

        if input_size > 0:

            size_diff = (
                abs(
                    best["TxBytes"]
                    - input_size
                )
                /
                max(
                    input_size,
                    best["TxBytes"],
                    1
                )
            )

        else:

            size_diff = np.nan

        # ----------------------------------------------------
        # Combined result
        # ----------------------------------------------------

        combined = {

            "flow_id":
                input_flow_id,

            "sn":
                input_src,

            "dn":
                input_dst,

            "input_time":
                input_time,

            "flow_size":
                input_size,

            #"expected_dest_port":
            #    expected_dst_port,

            f"time_diff_{label}":
                time_diff,

            f"size_diff_{label}":
                size_diff,

            f"TxPackets_{label}":
                best["TxPackets"],

            f"RxPackets_{label}":
                best["RxPackets"],

            f"TxBytes_calc_{label}":
                best["TxPackets"] * 1400,

            f"RxBytes_calc_{label}":
                best["RxPackets"] * 1400
        }

        # ----------------------------------------------------
        # Add all FlowMonitor columns
        # ----------------------------------------------------

        for col in flow_columns:

            combined[
                f"{col}_{label}"
            ] = best[col]

        matches.append(
            combined
        )

    return pd.DataFrame(
        matches
    )


# ============================================================
# AVERAGE FCT RESULTS FOR PLOTTING
# ============================================================

avg_fct_results = {
    benchmark: {}
    for benchmark in benchmarks
}



# ============================================================
# MAIN
# ============================================================



for benchmark in benchmarks:

    for load in loads:

        print()
        print(
            "=" * 80
        )

        print(
            f"{benchmark} | Load 0.{load}"
        )

        print(
            "=" * 80
        )

        # ====================================================
        # INPUT TRACE
        # ====================================================

        input_path = (
            f"{input_dir}/"
            f"{benchmark}_load_{load}.csv"
        )

        try:

            input_df = pd.read_csv(
                input_path
            )

            print(
                f"Input flows: "
                f"{len(input_df):,}"
            )

        except Exception as e:

            print(
                f"Could not read input: {e}"
            )

            continue

        # ====================================================
        # ALGORITHMS
        #
        # COMMENT / UNCOMMENT ANYTHING YOU WANT
        # ====================================================

        try:

            algorithms = {

                # ------------------------------------------------
                # CONGA
                # ------------------------------------------------

                "conga": pd.read_csv(
                    f"{conga_dir}/"
                    f"{benchmark}_load_{load}_Conga.csv",
                    nrows=12000
                ),

                # ------------------------------------------------
                # CONGA variants
                # ------------------------------------------------

                # "conga_new": pd.read_csv(
                #     f"{conga_dir}/"
                #     f"{benchmark}_load_{load}_Conga_new.csv",
                #     nrows=12000
                # ),

                # "conga-ecmp": pd.read_csv(
                #     f"{conga_dir}/"
                #     f"{benchmark}_load_{load}_Conga-ECMP_new.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # ECMP
                # ------------------------------------------------

                "ecmp": pd.read_csv(
                    f"{conga_dir}/"
                    f"{benchmark}_load_{load}_ECMP.csv",
                    nrows=12000
                ),

                # ------------------------------------------------
                # ECMP variants
                # ------------------------------------------------

                # "ecmp_new": pd.read_csv(
                #     f"{conga_dir}/"
                #     f"{benchmark}_load_{load}_ECMP_new.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # Basic RTT
                # ------------------------------------------------

                # "rtt": pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_RTT.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # Weighted ECMP
                # ------------------------------------------------

                # "weighted": pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_WEIGHTED_ECMP_RTT.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # Power-of-2 Random
                # ------------------------------------------------

                # "random": pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_POWER_OF_2_RANDOM_RTT.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # Power-of-2 Top2
                # ------------------------------------------------

                # "top2": pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_POWER_OF_2_TOP2_RTT.csv",
                #     nrows=12000
                # ),
            }

            # ====================================================
            # TIMEOUT VARIANTS
            # ====================================================

            timeout_values = [
                "true",
                "false"
            ]

            for timeout in timeout_values:

                # ------------------------------------------------
                # Weighted ECMP + timeout
                # ------------------------------------------------

                algorithms[
                    f"weighted_{timeout}"
                    ] = pd.read_csv(
                    f"{rtt_dir}/"
                    f"{benchmark}_load_{load}_"
                    f"WEIGHTED_ECMP_timeout_{timeout}_RTT.csv",
                    nrows=12000
                )

                # ------------------------------------------------
                # Lowest RTT + timeout
                # ------------------------------------------------

                #algorithms[
                #    f"lrtt_{timeout}"
                #] = pd.read_csv(
                #    f"{rtt_dir}/"
                #    f"{benchmark}_load_{load}_"
                #    f"LOWEST_RTT_timeout_{timeout}_RTT.csv",
                #    nrows=12000
                #)

                # ------------------------------------------------
                # Power-of-2 Random + timeout
                # ------------------------------------------------

                algorithms[
                     f"random_{timeout}"
                     ] = pd.read_csv(
                     f"{rtt_dir}/"
                     f"{benchmark}_load_{load}_"
                     f"POWER_OF_2_RANDOM_timeout_{timeout}_RTT.csv",
                     nrows=12000
                 )

                # ------------------------------------------------
                # Power-of-2 Top2 + timeout
                # ------------------------------------------------

                # algorithms[
                #     f"top2_{timeout}"
                # ] = pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_"
                #     f"POWER_OF_2_TOP2_timeout_{timeout}_RTT.csv",
                #     nrows=12000
                # )

        except Exception as e:

            print(
                "Skipping:",
                e
            )

            continue

        # ====================================================
        # CLEAN + PREPARE
        # ====================================================

        for label, df in algorithms.items():

            try:

                df = clean(
                    df
                )

                df = add_time(
                    df
                )

                df["sn"] = df["Src"].apply(
                    ip_to_node
                )

                df["dn"] = df["Dest"].apply(
                    ip_to_node
                )

                algorithms[label] = df

                print(
                    f"{label}: "
                    f"{len(df):,} IP flows"
                )

            except Exception as e:

                print(
                    f"ERROR processing "
                    f"{label}: {e}"
                )

                algorithms[label] = (
                    pd.DataFrame()
                )

        # ====================================================
        # MATCH
        # ====================================================

        matched = {}

        for label, df in algorithms.items():

            if df.empty:

                print(
                    f"Skipping matching for "
                    f"{label}: empty dataframe"
                )

                continue

            print(
                f"Matching {label}..."
            )

            matched[label] = match_df(
                df,
                input_df,
                label
            )

            print(
                f"{label}: "
                f"{len(matched[label]):,} matches"
            )

        # ====================================================
        # REMOVE EMPTY ALGORITHMS
        # ====================================================

        matched = {
            label: df
            for label, df in matched.items()
            if not df.empty
        }

        if len(matched) == 0:

            print(
                "No matches."
            )

            continue

        # ====================================================
        # MERGE RESULTS
        # ====================================================

        merge_keys = [
            "flow_id",
            "sn",
            "dn",
            "input_time",
            "flow_size"
        ]

        algorithms_list = list(
            matched.keys()
        )

        final_df = matched[
            algorithms_list[0]
        ]

        for algo in algorithms_list[1:]:

            final_df = pd.merge(
                final_df,
                matched[algo],
                on=merge_keys,
                how="inner"
            )

        # ====================================================
        # CHECK RESULT
        # ====================================================

        if len(final_df) == 0:

            print(
                "No common matches across "
                "the selected algorithms."
            )

            continue

        print()
        print(
            f"Final matched flows: "
            f"{len(final_df):,}"
        )


        # ============================================================
        # MATCHING TIME-DIFFERENCE SANITY CHECK
        # ============================================================
        
        print("\n" + "=" * 80)
        print("MATCHING TIME-DIFFERENCE CHECK")
        print("=" * 80)
        
        for algo in algorithms:
        
            col = f"time_diff_{algo}"
        
            if col not in final_df.columns:
                continue
        
            max_diff = final_df[col].max()
            mean_diff = final_df[col].mean()
            p95_diff = final_df[col].quantile(0.95)
            p99_diff = final_df[col].quantile(0.99)
        
            max_idx = final_df[col].idxmax()
            worst = final_df.loc[max_idx]
        
            print(f"\n{algo}")
            print(f"  Maximum : {max_diff:.9f} s "
                  f"({max_diff * 1000:.6f} ms)")
            print(f"  Mean    : {mean_diff:.9f} s "
                  f"({mean_diff * 1000:.6f} ms)")
            print(f"  P95     : {p95_diff:.9f} s "
                  f"({p95_diff * 1000:.6f} ms)")
            print(f"  P99     : {p99_diff:.9f} s "
                  f"({p99_diff * 1000:.6f} ms)")
        
            print(f"  Worst matching flow:")
            print(f"    flow_id     : {worst['flow_id']}")
            print(f"    sn          : {worst['sn']}")
            print(f"    dn          : {worst['dn']}")
            print(f"    input_time  : {worst['input_time']:.9f} s")
            print(f"    time_diff   : {worst[col]:.9f} s")

        
        # ====================================================
        # DIFFERENCES
        # ====================================================

        reference = "ecmp"

        if reference in matched:

            for algo in algorithms:

                if algo == reference:
                    continue

                if (
                    f"FCT(s)_{reference}" in final_df.columns
                    and
                    f"FCT(s)_{algo}" in final_df.columns
                ):

                    final_df[
                        f"fct_diff_{reference}_{algo}"
                    ] = (
                        final_df[
                            f"FCT(s)_{reference}"
                        ]
                        -
                        final_df[
                            f"FCT(s)_{algo}"
                        ]
                    )

        # ====================================================
        # SAVE
        # ====================================================

        csv_path = (
            f"{save_dir}/"
            f"{benchmark}_load_{load}_full.csv"
        )

        final_df.to_csv(
            csv_path,
            index=False
        )

        print(
            f"Saved: {csv_path}"
        )

        # ====================================================
        # STATS
        # ====================================================

        print()
        print(
            "-" * 80
        )

        print(
            f"Statistics: "
            f"{benchmark} | Load 0.{load}"
        )

        print(
            "-" * 80
        )

        for algo in matched:

            column = (
                f"FCT(s)_{algo}"
            )

            if column not in final_df.columns:
                continue

            fct = final_df[column]

            avg_fct = fct.mean()

            # --------------------------------------------------------
            # Store average FCT for later plotting
            # --------------------------------------------------------
        
            avg_fct_results[benchmark].setdefault(algo,{})
        
            avg_fct_results[benchmark][algo][load] = avg_fct



            print(
                f"{algo:20s}"
                f"Avg: {fct.mean():.6f}  "
                f"P75: {fct.quantile(0.75):.6f}  "
                f"P90: {fct.quantile(0.90):.6f}  "
                f"P95: {fct.quantile(0.95):.6f}  "
                f"P99: {fct.quantile(0.99):.6f}"
            )


# ============================================================
# DONE
# ============================================================

# ============================================================
# AVERAGE FCT COMPARISON GRAPHS
# ============================================================

print()
print("=" * 80)
print("GENERATING AVERAGE FCT COMPARISON GRAPHS")
print("=" * 80)


for benchmark in benchmarks:

    benchmark_results = avg_fct_results.get(
        benchmark,
        {}
    )

    if not benchmark_results:

        print(
            f"No FCT results available for "
            f"{benchmark}"
        )

        continue

    # --------------------------------------------------------
    # Create figure
    # --------------------------------------------------------

    plt.figure(
        figsize=(10, 6)
    )

    # --------------------------------------------------------
    # Plot each algorithm
    # --------------------------------------------------------

    for algo, load_results in benchmark_results.items():

        if not load_results:
            continue

        x = sorted(
            load_results.keys()
        )

        y = [
            load_results[load]
            for load in x
        ]

        # Convert load 1..9 to 0.1..0.9
        x_values = [
            load / 10
            for load in x
        ]

        plt.plot(
            x_values,
            y,
            marker="o",
            linewidth=2,
            markersize=6,
            label=algo
        )

    # --------------------------------------------------------
    # Labels
    # --------------------------------------------------------

    plt.xlabel(
        "Load",
        fontsize=12
    )

    plt.ylabel(
        "Average FCT (s)",
        fontsize=12
    )

    plt.title(
        f"Average Flow Completion Time - {benchmark}",
        fontsize=14
    )

    # --------------------------------------------------------
    # X-axis
    # --------------------------------------------------------

    plt.xticks(
        np.arange(
            0.1,
            0.8,
            0.1
        )
    )

    # --------------------------------------------------------
    # Grid
    # --------------------------------------------------------

    plt.grid(
        True,
        linestyle="--",
        alpha=0.5
    )

    # --------------------------------------------------------
    # Legend
    # --------------------------------------------------------

    plt.legend(
        fontsize=10
    )

    # --------------------------------------------------------
    # Layout
    # --------------------------------------------------------

    plt.tight_layout()

    # --------------------------------------------------------
    # Save
    # --------------------------------------------------------

    # ============================================================
    # GRAPH OUTPUT DIRECTORIES
    # ============================================================
    
    graph_dir = Path(save_dir) / "graph"
    avg_graph_dir = graph_dir / "avg"
    
    avg_graph_dir.mkdir(
        parents=True,
        exist_ok=True
    )

    graph_path = (
        avg_graph_dir /
        f"{benchmark}_average_fct_comparison.png"
    )

    plt.savefig(
        graph_path,
        dpi=300,
        bbox_inches="tight"
    )

    plt.close()

    print(
        f"Saved graph: {graph_path}"
    )

print(
    "MATCHING COMPLETE"
)

print(
    "=" * 80
)
# Out:
# ================================================================================
# private_enterprise | Load 0.1
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 9.294129165 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 9.294129165 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 9.294129165 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 9.294129165 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 9.294129165 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 9.294129165 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/private_enterprise_load_1_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.1
# --------------------------------------------------------------------------------
# conga               Avg: 0.008951  P75: 0.006460  P90: 0.021535  P95: 0.037790  P99: 0.106120
# ecmp                Avg: 0.013687  P75: 0.008652  P90: 0.039757  P95: 0.067572  P99: 0.155553
# weighted_true       Avg: 0.008616  P75: 0.007144  P90: 0.021905  P95: 0.033518  P99: 0.080435
# random_true         Avg: 0.008783  P75: 0.007445  P90: 0.022032  P95: 0.033788  P99: 0.088275
# weighted_false      Avg: 0.006509  P75: 0.004725  P90: 0.011390  P95: 0.019907  P99: 0.066527
# random_false        Avg: 0.006553  P75: 0.004749  P90: 0.011271  P95: 0.020481  P99: 0.069577
#
# ================================================================================
# private_enterprise | Load 0.2
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 15.557174508 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 15.557174508 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 15.557174508 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 15.557174508 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 15.557174508 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 15.557174508 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/private_enterprise_load_2_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.2
# --------------------------------------------------------------------------------
# conga               Avg: 0.015280  P75: 0.015947  P90: 0.040708  P95: 0.059243  P99: 0.142226
# ecmp                Avg: 0.041866  P75: 0.021559  P90: 0.064727  P95: 0.105019  P99: 0.241167
# weighted_true       Avg: 0.012121  P75: 0.012898  P90: 0.028400  P95: 0.041762  P99: 0.107096
# random_true         Avg: 0.012234  P75: 0.013246  P90: 0.028243  P95: 0.043517  P99: 0.111009
# weighted_false      Avg: 0.009353  P75: 0.006997  P90: 0.014351  P95: 0.024892  P99: 0.102455
# random_false        Avg: 0.009789  P75: 0.007376  P90: 0.015378  P95: 0.026660  P99: 0.103882
#
# ================================================================================
# private_enterprise | Load 0.3
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 3.098043055 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 3.098043055 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 3.098043055 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 3.098043055 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 3.098043055 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 3.098043055 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/private_enterprise_load_3_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.3
# --------------------------------------------------------------------------------
# conga               Avg: 0.039419  P75: 0.033377  P90: 0.073864  P95: 0.106962  P99: 0.306641
# ecmp                Avg: 0.150554  P75: 0.045380  P90: 0.107406  P95: 0.162458  P99: 8.933271
# weighted_true       Avg: 0.018824  P75: 0.020444  P90: 0.038401  P95: 0.057528  P99: 0.165540
# random_true         Avg: 0.018156  P75: 0.018698  P90: 0.036736  P95: 0.053913  P99: 0.167678
# weighted_false      Avg: 0.018179  P75: 0.012006  P90: 0.025141  P95: 0.043886  P99: 0.200708
# random_false        Avg: 0.017903  P75: 0.012210  P90: 0.025010  P95: 0.044739  P99: 0.198503
#
# ================================================================================
# private_enterprise | Load 0.4
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 7.778587254 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 7.778587254 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 7.778587254 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 7.778587254 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 7.778587254 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 7.778587254 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/private_enterprise_load_4_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.4
# --------------------------------------------------------------------------------
# conga               Avg: 0.121527  P75: 0.066621  P90: 0.127530  P95: 0.216443  P99: 1.579577
# ecmp                Avg: 0.295246  P75: 0.079954  P90: 0.155351  P95: 0.257290  P99: 10.450931
# weighted_true       Avg: 0.027776  P75: 0.024383  P90: 0.047017  P95: 0.073806  P99: 0.274987
# random_true         Avg: 0.029318  P75: 0.026907  P90: 0.048891  P95: 0.078025  P99: 0.269147
# weighted_false      Avg: 0.045406  P75: 0.030031  P90: 0.061188  P95: 0.112989  P99: 0.583240
# random_false        Avg: 0.042351  P75: 0.027216  P90: 0.057765  P95: 0.107947  P99: 0.549962
#
# ================================================================================
# private_enterprise | Load 0.5
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 1.858825833 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 1.858825833 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 1.858825833 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 1.858825833 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 1.858825833 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 1.858825833 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/private_enterprise_load_5_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.5
# --------------------------------------------------------------------------------
# conga               Avg: 0.359540  P75: 0.122512  P90: 0.320908  P95: 1.315046  P99: 7.332498
# ecmp                Avg: 0.299811  P75: 0.101099  P90: 0.179926  P95: 0.313185  P99: 7.145984
# weighted_true       Avg: 0.124096  P75: 0.094547  P90: 0.185159  P95: 0.342534  P99: 1.924699
# random_true         Avg: 0.120997  P75: 0.085069  P90: 0.167004  P95: 0.313442  P99: 2.000493
# weighted_false      Avg: 0.191163  P75: 0.197482  P90: 0.331181  P95: 0.581530  P99: 2.980047
# random_false        Avg: 0.173507  P75: 0.178852  P90: 0.302867  P95: 0.553388  P99: 2.567514
#
# ================================================================================
# private_enterprise | Load 0.6
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_271
#     sn          : 2
#     dn          : 7
#     input_time  : 1.235577460 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_271
#     sn          : 2
#     dn          : 7
#     input_time  : 1.235577460 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_271
#     sn          : 2
#     dn          : 7
#     input_time  : 1.235577460 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_271
#     sn          : 2
#     dn          : 7
#     input_time  : 1.235577460 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_271
#     sn          : 2
#     dn          : 7
#     input_time  : 1.235577460 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_271
#     sn          : 2
#     dn          : 7
#     input_time  : 1.235577460 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/private_enterprise_load_6_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.6
# --------------------------------------------------------------------------------
# conga               Avg: 0.476403  P75: 0.152067  P90: 0.854932  P95: 3.634555  P99: 7.144038
# ecmp                Avg: 0.447834  P75: 0.127120  P90: 0.282108  P95: 4.370446  P99: 7.426165
# weighted_true       Avg: 0.175553  P75: 0.153153  P90: 0.275323  P95: 0.553239  P99: 3.036171
# random_true         Avg: 0.205310  P75: 0.205788  P90: 0.364233  P95: 0.717728  P99: 3.317822
# weighted_false      Avg: 0.221244  P75: 0.224098  P90: 0.417986  P95: 0.812959  P99: 3.350806
# random_false        Avg: 0.222232  P75: 0.249538  P90: 0.463752  P95: 0.950750  P99: 2.852596
#
# ================================================================================
# private_enterprise | Load 0.7
# ================================================================================
# Input flows: 6,000
# conga: 11,999 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3622
#     sn          : 0
#     dn          : 6
#     input_time  : 4.185044248 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3622
#     sn          : 0
#     dn          : 6
#     input_time  : 4.185044248 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3622
#     sn          : 0
#     dn          : 6
#     input_time  : 4.185044248 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3622
#     sn          : 0
#     dn          : 6
#     input_time  : 4.185044248 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3622
#     sn          : 0
#     dn          : 6
#     input_time  : 4.185044248 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3622
#     sn          : 0
#     dn          : 6
#     input_time  : 4.185044248 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/private_enterprise_load_7_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.7
# --------------------------------------------------------------------------------
# conga               Avg: 0.511306  P75: 0.200956  P90: 1.331305  P95: 4.002197  P99: 5.757138
# ecmp                Avg: 0.402000  P75: 0.138290  P90: 0.302163  P95: 3.682718  P99: 6.298302
# weighted_true       Avg: 0.231411  P75: 0.235925  P90: 0.460983  P95: 0.952422  P99: 3.444002
# random_true         Avg: 0.200783  P75: 0.226984  P90: 0.394419  P95: 0.741383  P99: 2.595470
# weighted_false      Avg: 0.229560  P75: 0.236135  P90: 0.451006  P95: 0.949445  P99: 3.383783
# random_false        Avg: 0.229487  P75: 0.242047  P90: 0.464081  P95: 0.938053  P99: 3.384722
#
# ================================================================================
# social_media_cloud | Load 0.1
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 15.230570656 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 15.230570656 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 15.230570656 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 15.230570656 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 15.230570656 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 15.230570656 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/social_media_cloud_load_1_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.1
# --------------------------------------------------------------------------------
# conga               Avg: 0.014257  P75: 0.018533  P90: 0.037245  P95: 0.053128  P99: 0.100910
# ecmp                Avg: 0.016110  P75: 0.019768  P90: 0.044489  P95: 0.064538  P99: 0.115740
# weighted_true       Avg: 0.012360  P75: 0.015588  P90: 0.031529  P95: 0.045914  P99: 0.087643
# random_true         Avg: 0.012565  P75: 0.016194  P90: 0.032768  P95: 0.047100  P99: 0.086298
# weighted_false      Avg: 0.011912  P75: 0.013437  P90: 0.029380  P95: 0.046898  P99: 0.097724
# random_false        Avg: 0.011945  P75: 0.013043  P90: 0.029695  P95: 0.047365  P99: 0.099243
#
# ================================================================================
# social_media_cloud | Load 0.2
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 7.615285328 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 7.615285328 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 7.615285328 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 7.615285328 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 7.615285328 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 7.615285328 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/social_media_cloud_load_2_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.2
# --------------------------------------------------------------------------------
# conga               Avg: 0.029824  P75: 0.036498  P90: 0.070805  P95: 0.109079  P99: 0.238408
# ecmp                Avg: 0.044602  P75: 0.037393  P90: 0.075159  P95: 0.112534  P99: 0.221727
# weighted_true       Avg: 0.022512  P75: 0.027647  P90: 0.053763  P95: 0.079762  P99: 0.171455
# random_true         Avg: 0.022299  P75: 0.028254  P90: 0.055077  P95: 0.078273  P99: 0.152574
# weighted_false      Avg: 0.024170  P75: 0.024103  P90: 0.058327  P95: 0.094696  P99: 0.249203
# random_false        Avg: 0.023203  P75: 0.023595  P90: 0.057700  P95: 0.089095  P99: 0.214845
#
# ================================================================================
# social_media_cloud | Load 0.3
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 11,999 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1255
#     sn          : 5
#     dn          : 1
#     input_time  : 3.461752383 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1255
#     sn          : 5
#     dn          : 1
#     input_time  : 3.461752383 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1255
#     sn          : 5
#     dn          : 1
#     input_time  : 3.461752383 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1255
#     sn          : 5
#     dn          : 1
#     input_time  : 3.461752383 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1255
#     sn          : 5
#     dn          : 1
#     input_time  : 3.461752383 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1255
#     sn          : 5
#     dn          : 1
#     input_time  : 3.461752383 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/social_media_cloud_load_3_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.3
# --------------------------------------------------------------------------------
# conga               Avg: 0.566282  P75: 0.194067  P90: 0.580861  P95: 1.261087  P99: 15.390660
# ecmp                Avg: 0.134441  P75: 0.065920  P90: 0.132039  P95: 0.191208  P99: 0.626338
# weighted_true       Avg: 0.046038  P75: 0.051441  P90: 0.108662  P95: 0.172399  P99: 0.402098
# random_true         Avg: 0.047982  P75: 0.051634  P90: 0.110697  P95: 0.183299  P99: 0.439366
# weighted_false      Avg: 0.448020  P75: 0.485587  P90: 1.145616  P95: 1.781307  P99: 3.660115
# random_false        Avg: 0.437937  P75: 0.486220  P90: 1.152196  P95: 1.806063  P99: 3.640260
#
# ================================================================================
# social_media_cloud | Load 0.4
# ================================================================================
# Input flows: 6,000
# conga: 11,998 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 3.807642664 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 3.807642664 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 3.807642664 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 3.807642664 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 3.807642664 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 3.807642664 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/social_media_cloud_load_4_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.4
# --------------------------------------------------------------------------------
# conga               Avg: 1.016630  P75: 0.629791  P90: 2.066896  P95: 6.399302  P99: 14.008017
# ecmp                Avg: 0.617442  P75: 0.139547  P90: 0.291934  P95: 0.614406  P99: 14.820490
# weighted_true       Avg: 0.579534  P75: 0.600204  P90: 1.499496  P95: 2.422720  P99: 5.236099
# random_true         Avg: 0.796815  P75: 0.783131  P90: 2.155274  P95: 3.385898  P99: 7.645604
# weighted_false      Avg: 0.513891  P75: 0.584598  P90: 1.330156  P95: 1.962926  P99: 4.153994
# random_false        Avg: 0.525259  P75: 0.598195  P90: 1.348762  P95: 2.026458  P99: 4.269081
#
# ================================================================================
# social_media_cloud | Load 0.5
# ================================================================================
# Input flows: 6,000
# conga: 11,996 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 11,999 IP flows
# weighted_false: 11,999 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_458
#     sn          : 0
#     dn          : 7
#     input_time  : 9.094720591 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_458
#     sn          : 0
#     dn          : 7
#     input_time  : 9.094720591 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_458
#     sn          : 0
#     dn          : 7
#     input_time  : 9.094720591 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_458
#     sn          : 0
#     dn          : 7
#     input_time  : 9.094720591 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_458
#     sn          : 0
#     dn          : 7
#     input_time  : 9.094720591 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_458
#     sn          : 0
#     dn          : 7
#     input_time  : 9.094720591 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/social_media_cloud_load_5_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.5
# --------------------------------------------------------------------------------
# conga               Avg: 0.909609  P75: 0.663704  P90: 1.982545  P95: 4.180309  P99: 13.090964
# ecmp                Avg: 1.426682  P75: 0.285344  P90: 7.801940  P95: 10.830286  P99: 14.821116
# weighted_true       Avg: 0.883403  P75: 1.055956  P90: 2.518934  P95: 3.601976  P99: 7.814607
# random_true         Avg: 0.697319  P75: 0.792304  P90: 1.941812  P95: 2.873165  P99: 5.916621
# weighted_false      Avg: 0.764784  P75: 0.863775  P90: 2.090421  P95: 3.118054  P99: 7.307426
# random_false        Avg: 0.635465  P75: 0.735016  P90: 1.723998  P95: 2.514741  P99: 5.158560
#
# ================================================================================
# social_media_cloud | Load 0.6
# ================================================================================
# Input flows: 6,000
# conga: 11,998 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 11,998 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1450
#     sn          : 3
#     dn          : 7
#     input_time  : 7.089681822 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1450
#     sn          : 3
#     dn          : 7
#     input_time  : 7.089681822 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1450
#     sn          : 3
#     dn          : 7
#     input_time  : 7.089681822 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1450
#     sn          : 3
#     dn          : 7
#     input_time  : 7.089681822 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1450
#     sn          : 3
#     dn          : 7
#     input_time  : 7.089681822 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1450
#     sn          : 3
#     dn          : 7
#     input_time  : 7.089681822 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/social_media_cloud_load_6_full.csv
#
# --------------------------------------------------------------------------------
# ...
# weighted_false      Avg: 0.012146  P75: 0.008892  P90: 0.016983  P95: 0.027936  P99: 0.140348
# random_false        Avg: 0.011720  P75: 0.008656  P90: 0.016297  P95: 0.027298  P99: 0.134473
#
# ================================================================================
# university | Load 0.4
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 6.538410550 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 6.538410550 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 6.538410550 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 6.538410550 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 6.538410550 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 6.538410550 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/university_load_4_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.4
# --------------------------------------------------------------------------------
# conga               Avg: 0.043964  P75: 0.044559  P90: 0.076690  P95: 0.109864  P99: 0.374717
# ecmp                Avg: 0.285692  P75: 0.100024  P90: 0.174124  P95: 0.302623  P99: 7.790675
# weighted_true       Avg: 0.028598  P75: 0.028112  P90: 0.047483  P95: 0.068842  P99: 0.249103
# random_true         Avg: 0.032329  P75: 0.030336  P90: 0.052312  P95: 0.079572  P99: 0.305929
# weighted_false      Avg: 0.090073  P75: 0.073947  P90: 0.152068  P95: 0.238085  P99: 1.133356
# random_false        Avg: 0.054869  P75: 0.040383  P90: 0.076579  P95: 0.141607  P99: 0.679958
#
# ================================================================================
# university | Load 0.5
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 5.230728440 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 5.230728440 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 5.230728440 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 5.230728440 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 5.230728440 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 5.230728440 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/university_load_5_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.5
# --------------------------------------------------------------------------------
# conga               Avg: 0.278345  P75: 0.107142  P90: 0.256657  P95: 0.908900  P99: 6.392207
# ecmp                Avg: 0.295209  P75: 0.102318  P90: 0.185950  P95: 0.358843  P99: 7.049726
# weighted_true       Avg: 0.194859  P75: 0.201111  P90: 0.330393  P95: 0.634423  P99: 3.122827
# random_true         Avg: 0.173482  P75: 0.163345  P90: 0.274758  P95: 0.480708  P99: 2.981441
# weighted_false      Avg: 0.172786  P75: 0.191243  P90: 0.305407  P95: 0.541057  P99: 2.539106
# random_false        Avg: 0.192237  P75: 0.213300  P90: 0.337569  P95: 0.638165  P99: 2.850899
#
# ================================================================================
# university | Load 0.6
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3189
#     sn          : 6
#     dn          : 3
#     input_time  : 1.283891153 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3189
#     sn          : 6
#     dn          : 3
#     input_time  : 1.283891153 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3189
#     sn          : 6
#     dn          : 3
#     input_time  : 1.283891153 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3189
#     sn          : 6
#     dn          : 3
#     input_time  : 1.283891153 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3189
#     sn          : 6
#     dn          : 3
#     input_time  : 1.283891153 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3189
#     sn          : 6
#     dn          : 3
#     input_time  : 1.283891153 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/university_load_6_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.6
# --------------------------------------------------------------------------------
# conga               Avg: 0.424285  P75: 0.161475  P90: 0.867400  P95: 3.358584  P99: 5.623894
# ecmp                Avg: 0.433594  P75: 0.140756  P90: 0.363223  P95: 3.910033  P99: 5.735932
# weighted_true       Avg: 0.233548  P75: 0.224532  P90: 0.420240  P95: 0.855724  P99: 3.042308
# random_true         Avg: 0.249037  P75: 0.243389  P90: 0.458146  P95: 0.988679  P99: 3.339540
# weighted_false      Avg: 0.245872  P75: 0.226841  P90: 0.416567  P95: 0.968200  P99: 3.778932
# random_false        Avg: 0.231591  P75: 0.227667  P90: 0.413412  P95: 0.902242  P99: 3.240802
#
# ================================================================================
# university | Load 0.7
# ================================================================================
# Input flows: 6,000
# conga: 11,993 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 11,999 IP flows
# weighted_false: 11,999 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 3.736234600 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 3.736234600 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 3.736234600 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 3.736234600 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 3.736234600 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 3.736234600 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/university_load_7_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.7
# --------------------------------------------------------------------------------
# conga               Avg: 0.446643  P75: 0.187193  P90: 1.200198  P95: 3.589904  P99: 4.795045
# ecmp                Avg: 0.398937  P75: 0.154459  P90: 0.394161  P95: 3.449916  P99: 5.170576
# weighted_true       Avg: 0.272633  P75: 0.255681  P90: 0.540142  P95: 1.159781  P99: 3.411545
# random_true         Avg: 0.294453  P75: 0.254959  P90: 0.590766  P95: 1.356306  P99: 3.788718
# weighted_false      Avg: 0.276911  P75: 0.252635  P90: 0.526624  P95: 1.142508  P99: 3.574549
# random_false        Avg: 0.287390  P75: 0.255609  P90: 0.558682  P95: 1.140590  P99: 3.727021
#
# ================================================================================
# GENERATING AVERAGE FCT COMPARISON GRAPHS
# ================================================================================
# Saved graph: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/avg/private_enterprise_average_fct_comparison.png
# Saved graph: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/avg/social_media_cloud_average_fct_comparison.png
# Saved graph: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/avg/commercial_cloud_average_fct_comparison.png
# Saved graph: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/avg/university_average_fct_comparison.png
# MATCHING COMPLETE
# ================================================================================

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

# ------------------ CONFIG ------------------

save_dir = Path(
    "/home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results"
)

graph_dir = save_dir / "graph"
graph_dir.mkdir(parents=True, exist_ok=True)

benchmarks = [
    "private_enterprise",
    "social_media_cloud",
    "commercial_cloud",
    "university"
]

loads = range(1, 8)

SMALL = 100 * 1024        # 100 KB
LARGE = 1 * 1024 * 1024   # 1 MB

algorithms = [
    "conga",
    #"conga_new",
    #"conga-ecmp",
    "ecmp",
    #"ecmp_new",
    
    #"lrtt_true",
    #"lrtt_false",
    
    #"weighted",
    #"random",
    #"top2"
    
    "weighted_true",
    "weighted_false",

    "random_true",
    "random_false",

    #"top2_true",
    #"top2_false"
]

label_map = {
    "conga": "Conga",
    #"conga_new": "Conga_New",
    #"conga-ecmp": "Conga-ECMP",
    "ecmp": "ECMP",
    #"ecmp_new": "ECMP_New",
    #"rtt": "RTT",

    "lrtt_true": "Lowest RTT (Timeout)",
    "lrtt_false": "Lowest RTT (No Timeout)",
    
    "weighted": "Weighted ECMP",
    "random": "Power-of-2 Random",
    "top2": "Power-of-2 Top2",
    
    "weighted_true": "Weighted ECMP (Timeout)",
    "weighted_false": "Weighted ECMP (No Timeout)",

    "random_true": "Power-of-2 Random (Timeout)",
    "random_false": "Power-of-2 Random (No Timeout)",

    "top2_true": "Power-of-2 Top2 (Timeout)",
    "top2_false": "Power-of-2 Top2 (No Timeout)"
}

color_map = {
    "conga": "tab:blue",
    #"conga_new": "tab:orange",
    #"conga-ecmp": "tab:green",
    "ecmp": "tab:red",
    #"ecmp_new": "tab:purple",
    #"rtt": "tab:brown",

    "lrtt_true": "tab:cyan",
    "lrtt_false": "tab:cyan",
    
    "weighted": "tab:pink",
    "random": "tab:gray",
    "top2": "tab:olive",
    
    "weighted_true": "tab:brown",
    "weighted_false": "tab:brown",

    "random_true": "tab:orange",
    "random_false": "tab:orange",

    "top2_true": "tab:gray",
    "top2_false": "tab:gray",
}

marker_map = {
    "conga": "o",
    #"conga_new": "x",
    #"conga-ecmp": "X",
    "ecmp": "s",
    #"ecmp_new": "*",
    #"rtt": "^",

    "lrtt_true": "1",
    "lrtt_false": "2",
    
    "weighted": "D",
    "random": "v",
    "top2": "P",
    
    "weighted_true": "D",
    "weighted_false": "d",

    "random_true": "^",
    "random_false": "v",

    "top2_true": "P",
    "top2_false": "X"
}

# ------------------ GLOBAL Y-LIMITS ------------------

small_global = []
large_global = []

for benchmark in benchmarks:
    for load in loads:

        csv_path = save_dir / f"{benchmark}_load_{load}_full.csv"

        if not csv_path.exists():
            continue

        df = pd.read_csv(csv_path)

        if df.empty:
            continue

        small_df = df[df["flow_size"] < SMALL]
        large_df = df[df["flow_size"] > LARGE]

        for algo in algorithms:
            col = f"FCT(s)_{algo}"

            if not small_df.empty:
                small_global.append(small_df[col].mean())

            if not large_df.empty:
                large_global.append(large_df[col].mean())

small_min = min(small_global)
small_max = max(small_global)

large_min = min(large_global)
large_max = max(large_global)

small_margin = 0.05 * (small_max - small_min)
large_margin = 0.05 * (large_max - large_min)

small_ylim = (small_min - small_margin, small_max + small_margin)
large_ylim = (large_min - large_margin, large_max + large_margin)

# ------------------ ANALYSIS ------------------

for benchmark in benchmarks:

    print(f"\n===== {benchmark} =====")

    load_vals = []

    small_results = {algo: [] for algo in algorithms}
    large_results = {algo: [] for algo in algorithms}

    for load in loads:

        csv_path = save_dir / f"{benchmark}_load_{load}_full.csv"

        if not csv_path.exists():
            print(f"Missing: {csv_path}")
            continue

        df = pd.read_csv(csv_path)

        if df.empty:
            continue

        small_df = df[df["flow_size"] < SMALL]
        large_df = df[df["flow_size"] > LARGE]

        # ---------- Small Flows ----------

        for algo in algorithms:

            col = f"FCT(s)_{algo}"

            if not small_df.empty:
                small_results[algo].append(
                    small_df[col].mean()
                )
            else:
                small_results[algo].append(np.nan)

        # ---------- Large Flows ----------

        for algo in algorithms:

            col = f"FCT(s)_{algo}"

            if not large_df.empty:
                large_results[algo].append(
                    large_df[col].mean()
                )
            else:
                large_results[algo].append(np.nan)

        load_vals.append(load / 10)

    # ==================================================
    # SMALL FLOWS
    # ==================================================

    plt.figure(figsize=(8, 5))

    for algo in algorithms:

        plt.plot(
            load_vals,
            small_results[algo],
            marker=marker_map[algo],
            color=color_map[algo],
            linestyle="--" if algo.endswith("_false") else "-",
            linewidth=2,
            label=label_map[algo]
        )

    plt.xlabel("Network Load")
    plt.ylabel("Average FCT (s)")
    plt.title(f"{benchmark}: Small Flows (<100 KB)")
    #plt.ylim(small_ylim)
    plt.grid(True)
    plt.legend()

    out_path = graph_dir / f"{benchmark}_SMALL_vs_load.png"

    plt.tight_layout()
    plt.savefig(out_path, dpi=300)
    plt.close()

    print(f"Saved: {out_path}")

    # ==================================================
    # LARGE FLOWS
    # ==================================================

    plt.figure(figsize=(8, 5))

    for algo in algorithms:

        plt.plot(
            load_vals,
            large_results[algo],
            marker=marker_map[algo],
            color=color_map[algo],
            linestyle="--" if algo.endswith("_false") else "-",
            linewidth=2,
            label=label_map[algo]
        )

    plt.xlabel("Network Load")
    plt.ylabel("Average FCT (s)")
    plt.title(f"{benchmark}: Large Flows (>1 MB)")
    #plt.ylim(large_ylim)
    plt.grid(True)
    plt.legend()

    out_path = graph_dir / f"{benchmark}_LARGE_vs_load.png"

    plt.tight_layout()
    plt.savefig(out_path, dpi=300)
    plt.close()

    print(f"Saved: {out_path}")

print("\nDone: Small vs Large flow comparison for all algorithms.")
# Out:
# ===== private_enterprise =====
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/private_enterprise_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/private_enterprise_LARGE_vs_load.png
#
# ===== social_media_cloud =====
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/social_media_cloud_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/social_media_cloud_LARGE_vs_load.png
#
# ===== commercial_cloud =====
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/commercial_cloud_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/commercial_cloud_LARGE_vs_load.png
#
# ===== university =====
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/university_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/university_LARGE_vs_load.png
#
# Done: Small vs Large flow comparison for all algorithms.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

# ============================================================
# CONFIG
# ============================================================

save_dir = Path(
    "/home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results"
)

baseline = "ecmp"

graph_dir = save_dir / "graph" / f"normalised_vs_{baseline}"
graph_dir.mkdir(parents=True, exist_ok=True)

benchmarks = [
    "private_enterprise",
    "social_media_cloud",
    "commercial_cloud",
    "university"
]

# ------------------------------------------------------------
# Loads
# ------------------------------------------------------------

loads = range(1, 8)

# ------------------------------------------------------------
# Flow size thresholds
# ------------------------------------------------------------

SMALL = 100 * 1024          # 100 KB
LARGE = 1 * 1024 * 1024     # 1 MB


# ============================================================
# ALGORITHMS
#
# Comment/uncomment algorithms here as required.
# ECMP is the baseline and therefore does NOT need to be here.
# ============================================================

algorithms = [

    "conga",

    # "lrtt_true",
    # "lrtt_false",

    "weighted_true",
    "weighted_false",

    "random_true",
    "random_false",

    # "top2_true",
    # "top2_false",

    # "weighted",
    # "random",
    # "top2",
]


# ============================================================
# LABELS
# ============================================================

label_map = {

    "conga":
        "Conga",

    "lrtt_true":
        "Lowest RTT (Timeout)",

    "lrtt_false":
        "Lowest RTT (No Timeout)",

    "weighted":
        "Weighted ECMP",

    "random":
        "Power-of-2 Random",

    "top2":
        "Power-of-2 Top2",

    "weighted_true":
        "Weighted ECMP (Timeout)",

    "weighted_false":
        "Weighted ECMP (No Timeout)",

    "random_true":
        "Power-of-2 Random (Timeout)",

    "random_false":
        "Power-of-2 Random (No Timeout)",

    "top2_true":
        "Power-of-2 Top2 (Timeout)",

    "top2_false":
        "Power-of-2 Top2 (No Timeout)",
}


# ============================================================
# COLORS
# ============================================================

color_map = {

    "conga":
        "tab:blue",

    "lrtt_true":
        "tab:cyan",

    "lrtt_false":
        "tab:cyan",

    "weighted":
        "tab:purple",

    "random":
        "tab:gray",

    "top2":
        "tab:olive",

    "weighted_true":
        "tab:brown",

    "weighted_false":
        "tab:brown",

    "random_true":
        "tab:orange",

    "random_false":
        "tab:orange",

    "top2_true":
        "tab:gray",

    "top2_false":
        "tab:gray",
}


# ============================================================
# MARKERS
# ============================================================

marker_map = {

    "conga":
        "o",

    "lrtt_true":
        "1",

    "lrtt_false":
        "2",

    "weighted":
        "^",

    "random":
        "D",

    "top2":
        "P",

    "weighted_true":
        "D",

    "weighted_false":
        "d",

    "random_true":
        "^",

    "random_false":
        "v",

    "top2_true":
        "P",

    "top2_false":
        "X",
}


# ============================================================
# RESULT STORAGE
# ============================================================

summary_results = {}


# ============================================================
# MAIN ANALYSIS
# ============================================================

for benchmark in benchmarks:

    print()
    print("=" * 80)
    print(f"BENCHMARK: {benchmark}")
    print("=" * 80)

    # --------------------------------------------------------
    # Store load values
    # --------------------------------------------------------

    load_vals = []

    # --------------------------------------------------------
    # Results for each algorithm
    #
    # Each entry will contain one value per network load.
    # --------------------------------------------------------

    small_results = {
        algo: []
        for algo in algorithms
    }

    large_results = {
        algo: []
        for algo in algorithms
    }

    # ========================================================
    # PROCESS EACH LOAD
    # ========================================================

    for load in loads:

        print()
        print(
            f"Processing {benchmark} | Load 0.{load}"
        )

        csv_path = (
            save_dir /
            f"{benchmark}_load_{load}_full.csv"
        )

        # ----------------------------------------------------
        # Check file
        # ----------------------------------------------------

        if not csv_path.exists():

            print(
                f"Missing: {csv_path}"
            )

            continue

        # ----------------------------------------------------
        # Read CSV
        # ----------------------------------------------------

        df = pd.read_csv(
            csv_path
        )

        if df.empty:

            print(
                "Empty dataframe."
            )

            continue

        # ====================================================
        # CHECK REQUIRED COLUMNS
        # ====================================================

        baseline_col = (
            f"FCT(s)_{baseline}"
        )

        if baseline_col not in df.columns:

            print(
                f"ERROR: Missing baseline column "
                f"{baseline_col}"
            )

            continue

        missing_algorithms = []

        for algo in algorithms:

            col = f"FCT(s)_{algo}"

            if col not in df.columns:

                missing_algorithms.append(
                    col
                )

        if missing_algorithms:

            print(
                "ERROR: Missing algorithm columns:"
            )

            for col in missing_algorithms:

                print(
                    f"    {col}"
                )

            continue

        # ====================================================
        # REMOVE INVALID BASELINE FCT VALUES
        # ====================================================

        df = df[
            df[baseline_col] > 0
        ].copy()

        if df.empty:

            print(
                "No valid flows after removing "
                "zero/negative ECMP FCT."
            )

            continue

        # ====================================================
        # FLOW SIZE SPLIT
        # ====================================================

        small_df = df[
            df["flow_size"] < SMALL
        ].copy()

        large_df = df[
            df["flow_size"] > LARGE
        ].copy()

        print(
            f"Small flows: {len(small_df):,}"
        )

        print(
            f"Large flows: {len(large_df):,}"
        )

        # ====================================================
        # BASELINE AVERAGES
        #
        # IMPORTANT:
        #
        # We calculate:
        #
        #     mean(FCT_algorithm)
        #     --------------------
        #     mean(FCT_ECMP)
        #
        # NOT:
        #
        #     mean(FCT_algorithm / FCT_ECMP)
        #
        # This makes the normalized graph consistent with
        # the Average FCT graph.
        # ====================================================

        # ----------------------------------------------------
        # SMALL FLOWS
        # ----------------------------------------------------

        if not small_df.empty:

            baseline_small_avg = (
                small_df[baseline_col].mean()
            )

        else:

            baseline_small_avg = np.nan

        # ----------------------------------------------------
        # LARGE FLOWS
        # ----------------------------------------------------

        if not large_df.empty:

            baseline_large_avg = (
                large_df[baseline_col].mean()
            )

        else:

            baseline_large_avg = np.nan

        # ====================================================
        # NORMALIZED RESULTS
        # ====================================================

        for algo in algorithms:

            algo_col = (
                f"FCT(s)_{algo}"
            )

            # ------------------------------------------------
            # SMALL FLOWS
            # ------------------------------------------------

            if (
                not small_df.empty
                and baseline_small_avg > 0
            ):

                algo_small_avg = (
                    small_df[algo_col].mean()
                )

                normalized_small = (
                    algo_small_avg /
                    baseline_small_avg
                )

                small_results[algo].append(
                    normalized_small
                )

            else:

                small_results[algo].append(
                    np.nan
                )

            # ------------------------------------------------
            # LARGE FLOWS
            # ------------------------------------------------

            if (
                not large_df.empty
                and baseline_large_avg > 0
            ):

                algo_large_avg = (
                    large_df[algo_col].mean()
                )

                normalized_large = (
                    algo_large_avg /
                    baseline_large_avg
                )

                large_results[algo].append(
                    normalized_large
                )

            else:

                large_results[algo].append(
                    np.nan
                )

        # ----------------------------------------------------
        # Store load
        # ----------------------------------------------------

        load_vals.append(
            load / 10
        )

        # ====================================================
        # PRINT NORMALIZED VALUES
        # ====================================================

        print()
        print(
            "Normalized Average FCT:"
        )

        if not small_df.empty:

            print(
                f"  Small flows "
                f"(ECMP avg = "
                f"{baseline_small_avg:.6f}s)"
            )

            for algo in algorithms:

                value = (
                    small_results[algo][-1]
                )

                print(
                    f"    {label_map[algo]:35s}: "
                    f"{value:.4f}"
                )

        if not large_df.empty:

            print(
                f"  Large flows "
                f"(ECMP avg = "
                f"{baseline_large_avg:.6f}s)"
            )

            for algo in algorithms:

                value = (
                    large_results[algo][-1]
                )

                print(
                    f"    {label_map[algo]:35s}: "
                    f"{value:.4f}"
                )


    # ========================================================
    # STORE RESULTS
    # ========================================================

    summary_results[benchmark] = {

        "loads":
            load_vals,

        "small":
            small_results,

        "large":
            large_results
    }


    # ========================================================
    # SMALL FLOWS PLOT
    # ========================================================

    plt.figure(
        figsize=(10, 7),
        dpi=120
    )

    for algo in algorithms:

        plt.plot(

            load_vals,

            small_results[algo],

            marker=marker_map[algo],

            color=color_map[algo],

            linestyle=(
                "--"
                if algo.endswith("_false")
                else "-"
            ),

            linewidth=2,

            markersize=7,

            label=(
                f"{label_map[algo]} / ECMP"
            )
        )

    # --------------------------------------------------------
    # ECMP baseline
    # --------------------------------------------------------

    plt.axhline(
        y=1,
        linestyle="--",
        color="black",
        linewidth=1.5,
        label="ECMP baseline"
    )

    # --------------------------------------------------------
    # Labels
    # --------------------------------------------------------

    plt.xlabel(
        "Network Load"
    )

    plt.ylabel(
        "Normalized Average FCT"
    )

    plt.title(
        f"{benchmark}: "
        f"Small Flows (<100 KB)"
    )

    # --------------------------------------------------------
    # Y-axis
    # --------------------------------------------------------

    plt.ylim(
        0,
        1.8
    )

    plt.yticks(
        np.arange(
            0,
            1.81,
            0.2
        )
    )

    # --------------------------------------------------------
    # Grid
    # --------------------------------------------------------

    plt.grid(
        True,
        alpha=0.3
    )

    plt.legend()

    plt.tight_layout()

    out_path = (
        graph_dir /
        f"{benchmark}_SMALL_relative_vs_load.png"
    )

    plt.savefig(
        out_path,
        dpi=300,
        bbox_inches="tight"
    )

    plt.close()

    print()
    print(
        f"Saved: {out_path}"
    )


    # ========================================================
    # LARGE FLOWS PLOT
    # ========================================================

    plt.figure(
        figsize=(10, 7),
        dpi=120
    )

    for algo in algorithms:

        plt.plot(

            load_vals,

            large_results[algo],

            marker=marker_map[algo],

            color=color_map[algo],

            linestyle=(
                "--"
                if algo.endswith("_false")
                else "-"
            ),

            linewidth=2,

            markersize=7,

            label=(
                f"{label_map[algo]} / ECMP"
            )
        )

    # --------------------------------------------------------
    # ECMP baseline
    # --------------------------------------------------------

    plt.axhline(
        y=1,
        linestyle="--",
        color="black",
        linewidth=1.5,
        label="ECMP baseline"
    )

    # --------------------------------------------------------
    # Labels
    # --------------------------------------------------------

    plt.xlabel(
        "Network Load"
    )

    plt.ylabel(
        "Normalized Average FCT"
    )

    plt.title(
        f"{benchmark}: "
        f"Large Flows (>1 MB)"
    )

    # --------------------------------------------------------
    # Y-axis
    # --------------------------------------------------------

    plt.ylim(
        0,
        1.4
    )

    plt.yticks(
        np.arange(
            0,
            1.41,
            0.2
        )
    )

    # --------------------------------------------------------
    # Grid
    # --------------------------------------------------------

    plt.grid(
        True,
        alpha=0.3
    )

    plt.legend()

    plt.tight_layout()

    out_path = (
        graph_dir /
        f"{benchmark}_LARGE_relative_vs_load.png"
    )

    plt.savefig(
        out_path,
        dpi=300,
        bbox_inches="tight"
    )

    plt.close()

    print(
        f"Saved: {out_path}"
    )


# ============================================================
# DONE
# ============================================================

print()
print("=" * 80)
print(
    "DONE: Normalized Average FCT graphs generated."
)
print("=" * 80)
# Out:
# ================================================================================
# BENCHMARK: private_enterprise
# ================================================================================
#
# Processing private_enterprise | Load 0.1
# Small flows: 5,790
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.010127s)
#     Conga                              : 0.6269
#     Weighted ECMP (Timeout)            : 0.5857
#     Weighted ECMP (No Timeout)         : 0.3534
#     Power-of-2 Random (Timeout)        : 0.5963
#     Power-of-2 Random (No Timeout)     : 0.3567
#   Large flows (ECMP avg = 0.418300s)
#     Conga                              : 0.7627
#     Weighted ECMP (Timeout)            : 0.8318
#     Weighted ECMP (No Timeout)         : 0.8785
#     Power-of-2 Random (Timeout)        : 0.8394
#     Power-of-2 Random (No Timeout)     : 0.8826
#
# Processing private_enterprise | Load 0.2
# Small flows: 5,790
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.038254s)
#     Conga                              : 0.3060
#     Weighted ECMP (Timeout)            : 0.2273
#     Weighted ECMP (No Timeout)         : 0.1285
#     Power-of-2 Random (Timeout)        : 0.2301
#     Power-of-2 Random (No Timeout)     : 0.1354
#   Large flows (ECMP avg = 0.489177s)
#     Conga                              : 0.7748
#     Weighted ECMP (Timeout)            : 0.8510
#     Weighted ECMP (No Timeout)         : 1.1542
#     Power-of-2 Random (Timeout)        : 0.8015
#     Power-of-2 Random (No Timeout)     : 1.2124
#
# Processing private_enterprise | Load 0.3
# Small flows: 5,790
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.143464s)
#     Conga                              : 0.2142
#     Weighted ECMP (Timeout)            : 0.0908
#     Weighted ECMP (No Timeout)         : 0.0598
#     Power-of-2 Random (Timeout)        : 0.0853
#     Power-of-2 Random (No Timeout)     : 0.0599
#   Large flows (ECMP avg = 0.672624s)
#     Conga                              : 1.4063
#     Weighted ECMP (Timeout)            : 1.1055
#     Weighted ECMP (No Timeout)         : 1.8958
#     Power-of-2 Random (Timeout)        : 1.1054
#     Power-of-2 Random (No Timeout)     : 1.8605
#
# Processing private_enterprise | Load 0.4
# Small flows: 5,790
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.288604s)
#     Conga                              : 0.3395
#     Weighted ECMP (Timeout)            : 0.0581
#     Weighted ECMP (No Timeout)         : 0.0745
#     Power-of-2 Random (Timeout)        : 0.0624
#     Power-of-2 Random (No Timeout)     : 0.0686
#   Large flows (ECMP avg = 1.447075s)
#     Conga                              : 1.6115
#     Weighted ECMP (Timeout)            : 0.9630
#     Weighted ECMP (No Timeout)         : 2.0066
#     Power-of-2 Random (Timeout)        : 1.0445
#     Power-of-2 Random (No Timeout)     : 1.9096
#
# Processing private_enterprise | Load 0.5
# Small flows: 5,790
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.286180s)
#     Conga                              : 1.1290
#     Weighted ECMP (Timeout)            : 0.3053
#     Weighted ECMP (No Timeout)         : 0.4349
#     Power-of-2 Random (Timeout)        : 0.2953
#     Power-of-2 Random (No Timeout)     : 0.3867
#   Large flows (ECMP avg = 1.573810s)
#     Conga                              : 2.0944
#     Weighted ECMP (Timeout)            : 2.4442
#     Weighted ECMP (No Timeout)         : 3.5307
#     Power-of-2 Random (Timeout)        : 2.5004
#     Power-of-2 Random (No Timeout)     : 3.4232
#
# Processing private_enterprise | Load 0.6
# Small flows: 5,790
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.426827s)
#     Conga                              : 1.0078
#     Weighted ECMP (Timeout)            : 0.2978
#     Weighted ECMP (No Timeout)         : 0.3536
#     Power-of-2 Random (Timeout)        : 0.3601
#     Power-of-2 Random (No Timeout)     : 0.3860
#   Large flows (ECMP avg = 1.855705s)
#     Conga                              : 2.0246
#     Weighted ECMP (Timeout)            : 2.3717
#     Weighted ECMP (No Timeout)         : 2.7337
#     Power-of-2 Random (Timeout)        : 1.9915
#     Power-of-2 Random (No Timeout)     : 2.4387
#
# Processing private_enterprise | Load 0.7
# Small flows: 5,790
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.379934s)
#     Conga                              : 1.2117
#     Weighted ECMP (Timeout)            : 0.4532
#     Weighted ECMP (No Timeout)         : 0.4174
#     Power-of-2 Random (Timeout)        : 0.3920
#     Power-of-2 Random (No Timeout)     : 0.4377
#   Large flows (ECMP avg = 2.133847s)
#     Conga                              : 1.5585
#     Weighted ECMP (Timeout)            : 2.0199
#     Weighted ECMP (No Timeout)         : 2.2009
#     Power-of-2 Random (Timeout)        : 1.9154
#     Power-of-2 Random (No Timeout)     : 2.1720
#
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/normalised_vs_ecmp/private_enterprise_SMALL_relative_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/normalised_vs_ecmp/private_enterprise_LARGE_relative_vs_load.png
#
# ================================================================================
# BENCHMARK: social_media_cloud
# ================================================================================
#
# Processing social_media_cloud | Load 0.1
# Small flows: 5,369
# Large flows: 2
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.011979s)
#     Conga                              : 0.8773
#     Weighted ECMP (Timeout)            : 0.7424
#     Weighted ECMP (No Timeout)         : 0.6065
#     Power-of-2 Random (Timeout)        : 0.7590
#     Power-of-2 Random (No Timeout)     : 0.6095
#   Large flows (ECMP avg = 0.291776s)
#     Conga                              : 0.6590
#     Weighted ECMP (Timeout)            : 0.6671
#     Weighted ECMP (No Timeout)         : 0.9501
#     Power-of-2 Random (Timeout)        : 0.6960
#     Power-of-2 Random (No Timeout)     : 1.0492
#
# Processing social_media_cloud | Load 0.2
# Small flows: 5,369
# Large flows: 2
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.038963s)
#     Conga                              : 0.5821
#     Weighted ECMP (Timeout)            : 0.4253
#     Weighted ECMP (No Timeout)         : 0.3706
#     Power-of-2 Random (Timeout)        : 0.4281
#     Power-of-2 Random (No Timeout)     : 0.3598
#   Large flows (ECMP avg = 0.382341s)
#     Conga                              : 0.5140
#     Weighted ECMP (Timeout)            : 0.9520
#     Weighted ECMP (No Timeout)         : 1.5520
#     Power-of-2 Random (Timeout)        : 1.0210
#     Power-of-2 Random (No Timeout)     : 1.5100
#
# Processing social_media_cloud | Load 0.3
# Small flows: 5,369
# Large flows: 2
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.125003s)
#     Conga                              : 4.1075
#     Weighted ECMP (Timeout)            : 0.2616
#     Weighted ECMP (No Timeout)         : 2.4590
#     Power-of-2 Random (Timeout)        : 0.2706
#     Power-of-2 Random (No Timeout)     : 2.3633
#   Large flows (ECMP avg = 0.469413s)
#     Conga                              : 4.8983
#     Weighted ECMP (Timeout)            : 1.3949
#     Weighted ECMP (No Timeout)         : 34.1858
#     Power-of-2 Random (Timeout)        : 3.4895
#     Power-of-2 Random (No Timeout)     : 21.2841
#
# Processing social_media_cloud | Load 0.4
# Small flows: 5,369
# Large flows: 2
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.592556s)
#     Conga                              : 1.5449
#     Weighted ECMP (Timeout)            : 0.7470
#     Weighted ECMP (No Timeout)         : 0.6116
#     Power-of-2 Random (Timeout)        : 0.9917
#     Power-of-2 Random (No Timeout)     : 0.6304
#   Large flows (ECMP avg = 1.707185s)
#     Conga                              : 1.7367
#     Weighted ECMP (Timeout)            : 2.7478
#     Weighted ECMP (No Timeout)         : 3.9633
#     Power-of-2 Random (Timeout)        : 1.5278
#     Power-of-2 Random (No Timeout)     : 3.8045
#
# Processing social_media_cloud | Load 0.5
# Small flows: 5,369
# Large flows: 2
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 1.377846s)
#     Conga                              : 0.5678
#     Weighted ECMP (Timeout)            : 0.4886
#     Weighted ECMP (No Timeout)         : 0.3773
#     Power-of-2 Random (Timeout)        : 0.3791
#     Power-of-2 Random (No Timeout)     : 0.3210
#   Large flows (ECMP avg = 4.352626s)
#     Conga                              : 1.3667
#     Weighted ECMP (Timeout)            : 1.3921
#     Weighted ECMP (No Timeout)         : 1.6043
#     Power-of-2 Random (Timeout)        : 1.2925
#     Power-of-2 Random (No Timeout)     : 1.6905
#
# Processing social_media_cloud | Load 0.6
# Small flows: 5,369
# Large flows: 2
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 1.722525s)
#     Conga                              : 0.3608
#     Weighted ECMP (Timeout)            : 0.4516
#     Weighted ECMP (No Timeout)         : 0.5714
#     Power-of-2 Random (Timeout)        : 0.4391
#     Power-of-2 Random (No Timeout)     : 0.3632
#   Large flows (ECMP avg = 3.709877s)
#     Conga                              : 1.4235
#     Weighted ECMP (Timeout)            : 1.2834
#     Weighted ECMP (No Timeout)         : 1.9501
#     Power-of-2 Random (Timeout)        : 1.4652
#     Power-of-2 Random (No Timeout)     : 1.6329
#
# Processing social_media_cloud | Load 0.7
# Small flows: 5,369
# Large flows: 2
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 1.758028s)
#     Conga                              : 0.3857
#     Weighted ECMP (Timeout)            : 0.7599
#     Weighted ECMP (No Timeout)         : 0.6695
#     Power-of-2 Random (Timeout)        : 0.6305
#     Power-of-2 Random (No Timeout)     : 0.6995
#   Large flows (ECMP avg = 4.470551s)
#     Conga                              : 0.2372
#     Weighted ECMP (Timeout)            : 2.1299
#     Weighted ECMP (No Timeout)         : 1.4094
#     Power-of-2 Random (Timeout)        : 1.5346
#     Power-of-2 Random (No Timeout)     : 1.4748
#
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/normalised_vs_ecmp/social_media_cloud_SMALL_relative_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/normalised_vs_ecmp/social_media_cloud_LARGE_relative_vs_load.png
#
# ================================================================================
# BENCHMARK: commercial_cloud
# ================================================================================
#
# Processing commercial_cloud | Load 0.1
# Small flows: 5,798
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.025289s)
#     Conga                              : 0.2599
#     Weighted ECMP (Timeout)            : 0.2346
#     Weighted ECMP (No Timeout)         : 0.1277
#     Power-of-2 Random (Timeout)        : 0.2507
#     Power-of-2 Random (No Timeout)     : 0.1290
#   Large flows (ECMP avg = 0.571318s)
#     Conga                              : 0.7812
#     Weighted ECMP (Timeout)            : 0.7290
#     Weighted ECMP (No Timeout)         : 0.8342
#     Power-of-2 Random (Timeout)        : 0.8429
#     Power-of-2 Random (No Timeout)     : 0.8453
#
# Processing commercial_cloud | Load 0.2
# Small flows: 5,798
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.063458s)
#     Conga                              : 0.1805
#     Weighted ECMP (Timeout)            : 0.1511
#     Weighted ECMP (No Timeout)         : 0.0781
#     Power-of-2 Random (Timeout)        : 0.1719
#     Power-of-2 Random (No Timeout)     : 0.0756
#   Large flows (ECMP avg = 0.752302s)
#     Conga                              : 0.6335
#     Weighted ECMP (Timeout)            : 0.6765
#     Weighted ECMP (No Timeout)         : 0.8304
#     Power-of-2 Random (Timeout)        : 0.7183
#     Power-of-2 Random (No Timeout)     : 0.8313
#
# Processing commercial_cloud | Load 0.3
# Small flows: 5,798
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.191799s)
#     Conga                              : 0.0942
#     Weighted ECMP (Timeout)            : 0.0770
#     Weighted ECMP (No Timeout)         : 0.0425
#     Power-of-2 Random (Timeout)        : 0.0839
#     Power-of-2 Random (No Timeout)     : 0.0399
#   Large flows (ECMP avg = 0.785634s)
#     Conga                              : 0.9759
#     Weighted ECMP (Timeout)            : 1.0547
#     Weighted ECMP (No Timeout)         : 1.3680
#     Power-of-2 Random (Timeout)        : 1.0514
#     Power-of-2 Random (No Timeout)     : 1.3424
#
# Processing commercial_cloud | Load 0.4
# Small flows: 5,798
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.328033s)
#     Conga                              : 0.1752
#     Weighted ECMP (Timeout)            : 0.0670
#     Weighted ECMP (No Timeout)         : 0.0854
#     Power-of-2 Random (Timeout)        : 0.0639
#     Power-of-2 Random (No Timeout)     : 0.0672
#   Large flows (ECMP avg = 1.516184s)
#     Conga                              : 1.0771
#     Weighted ECMP (Timeout)            : 0.9971
#     Weighted ECMP (No Timeout)         : 1.6789
#     Power-of-2 Random (Timeout)        : 0.8415
#     Power-of-2 Random (No Timeout)     : 1.6288
#
# Processing commercial_cloud | Load 0.5
# Small flows: 5,798
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.252696s)
#     Conga                              : 0.7024
#     Weighted ECMP (Timeout)            : 0.1974
#     Weighted ECMP (No Timeout)         : 0.5549
#     Power-of-2 Random (Timeout)        : 0.2638
#     Power-of-2 Random (No Timeout)     : 0.5515
#   Large flows (ECMP avg = 1.490876s)
#     Conga                              : 1.7460
#     Weighted ECMP (Timeout)            : 2.0363
#     Weighted ECMP (No Timeout)         : 3.0896
#     Power-of-2 Random (Timeout)        : 2.0735
#     Power-of-2 Random (No Timeout)     : 3.0646
#
# Processing commercial_cloud | Load 0.6
# Small flows: 5,798
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.296820s)
#     Conga                              : 0.9743
#     Weighted ECMP (Timeout)            : 0.3950
#     Weighted ECMP (No Timeout)         : 0.5239
#     Power-of-2 Random (Timeout)        : 0.4251
#     Power-of-2 Random (No Timeout)     : 0.5028
#   Large flows (ECMP avg = 1.573084s)
#     Conga                              : 1.7643
#     Weighted ECMP (Timeout)            : 2.1051
#     Weighted ECMP (No Timeout)         : 2.6209
#     Power-of-2 Random (Timeout)        : 2.1186
#     Power-of-2 Random (No Timeout)     : 2.3124
#
# Processing commercial_cloud | Load 0.7
# Small flows: 5,798
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.464186s)
#     Conga                              : 0.6986
#     Weighted ECMP (Timeout)            : 0.4568
#     Weighted ECMP (No Timeout)         : 0.3658
#     Power-of-2 Random (Timeout)        : 0.3966
#     Power-of-2 Random (No Timeout)     : 0.3677
#   Large flows (ECMP avg = 2.597665s)
#     Conga                              : 1.0555
#     Weighted ECMP (Timeout)            : 1.2231
#     Weighted ECMP (No Timeout)         : 1.6549
#     Power-of-2 Random (Timeout)        : 1.1690
#     Power-of-2 Random (No Timeout)     : 1.6330
#
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/normalised_vs_ecmp/commercial_cloud_SMALL_relative_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/normalised_vs_ecmp/commercial_cloud_LARGE_relative_vs_load.png
#
# ================================================================================
# BENCHMARK: university
# ================================================================================
#
# Processing university | Load 0.1
# Small flows: 5,786
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.008702s)
#     Conga                              : 0.4872
#     Weighted ECMP (Timeout)            : 0.4836
#     Weighted ECMP (No Timeout)         : 0.3153
#     Power-of-2 Random (Timeout)        : 0.4767
#     Power-of-2 Random (No Timeout)     : 0.2990
#   Large flows (ECMP avg = 0.366662s)
#     Conga                              : 0.7030
#     Weighted ECMP (Timeout)            : 0.7420
#     Weighted ECMP (No Timeout)         : 0.8288
#     Power-of-2 Random (Timeout)        : 0.7250
#     Power-of-2 Random (No Timeout)     : 0.8263
#
# Processing university | Load 0.2
# Small flows: 5,786
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.023542s)
#     Conga                              : 0.3653
#     Weighted ECMP (Timeout)            : 0.3056
#     Weighted ECMP (No Timeout)         : 0.1652
#     Power-of-2 Random (Timeout)        : 0.3071
#     Power-of-2 Random (No Timeout)     : 0.1649
#   Large flows (ECMP avg = 0.460020s)
#     Conga                              : 0.6314
#     Weighted ECMP (Timeout)            : 0.7187
#     Weighted ECMP (No Timeout)         : 0.9216
#     Power-of-2 Random (Timeout)        : 0.6747
#     Power-of-2 Random (No Timeout)     : 0.9254
#
# Processing university | Load 0.3
# Small flows: 5,786
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.158506s)
#     Conga                              : 0.3926
#     Weighted ECMP (Timeout)            : 0.0687
#     Weighted ECMP (No Timeout)         : 0.0401
#     Power-of-2 Random (Timeout)        : 0.0698
#     Power-of-2 Random (No Timeout)     : 0.0391
#   Large flows (ECMP avg = 0.603587s)
#     Conga                              : 0.7318
#     Weighted ECMP (Timeout)            : 0.8000
#     Weighted ECMP (No Timeout)         : 1.4854
#     Power-of-2 Random (Timeout)        : 0.9035
#     Power-of-2 Random (No Timeout)     : 1.4088
#
# Processing university | Load 0.4
# Small flows: 5,786
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.277542s)
#     Conga                              : 0.1143
#     Weighted ECMP (Timeout)            : 0.0696
#     Weighted ECMP (No Timeout)         : 0.2081
#     Power-of-2 Random (Timeout)        : 0.0770
#     Power-of-2 Random (No Timeout)     : 0.1118
#   Large flows (ECMP avg = 0.950517s)
#     Conga                              : 1.6823
#     Weighted ECMP (Timeout)            : 1.5972
#     Weighted ECMP (No Timeout)         : 4.6963
#     Power-of-2 Random (Timeout)        : 1.7842
#     Power-of-2 Random (No Timeout)     : 3.5937
#
# Processing university | Load 0.5
# Small flows: 5,786
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.282601s)
#     Conga                              : 0.8963
#     Weighted ECMP (Timeout)            : 0.5494
#     Weighted ECMP (No Timeout)         : 0.4260
#     Power-of-2 Random (Timeout)        : 0.4911
#     Power-of-2 Random (No Timeout)     : 0.4964
#   Large flows (ECMP avg = 1.297323s)
#     Conga                              : 2.1295
#     Weighted ECMP (Timeout)            : 2.8413
#     Weighted ECMP (No Timeout)         : 3.7373
#     Power-of-2 Random (Timeout)        : 3.0465
#     Power-of-2 Random (No Timeout)     : 3.4876
#
# Processing university | Load 0.6
# Small flows: 5,786
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.408611s)
#     Conga                              : 0.9405
#     Weighted ECMP (Timeout)            : 0.4556
#     Weighted ECMP (No Timeout)         : 0.4406
#     Power-of-2 Random (Timeout)        : 0.4980
#     Power-of-2 Random (No Timeout)     : 0.4213
#   Large flows (ECMP avg = 2.091095s)
#     Conga                              : 1.2636
#     Weighted ECMP (Timeout)            : 1.7621
#     Weighted ECMP (No Timeout)         : 2.1893
#     Power-of-2 Random (Timeout)        : 1.4187
#     Power-of-2 Random (No Timeout)     : 2.0278
#
# Processing university | Load 0.7
# Small flows: 5,786
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.379336s)
#     Conga                              : 1.0936
#     Weighted ECMP (Timeout)            : 0.5922
#     Weighted ECMP (No Timeout)         : 0.5580
#     Power-of-2 Random (Timeout)        : 0.6294
#     Power-of-2 Random (No Timeout)     : 0.5864
#   Large flows (ECMP avg = 2.390639s)
#     Conga                              : 0.9951
#     Weighted ECMP (Timeout)            : 1.2881
#     Weighted ECMP (No Timeout)         : 1.5425
#     Power-of-2 Random (Timeout)        : 1.4518
#     Power-of-2 Random (No Timeout)     : 1.9245
#
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/normalised_vs_ecmp/university_SMALL_relative_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/normalised_vs_ecmp/university_LARGE_relative_vs_load.png
#
# ================================================================================
# DONE: Normalized Average FCT graphs generated.
# ================================================================================
