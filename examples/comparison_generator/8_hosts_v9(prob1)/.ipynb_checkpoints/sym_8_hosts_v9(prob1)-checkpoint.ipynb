# %%
import pandas as pd
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt


# ============================================================
# CONFIG
# ============================================================

benchmarks = [
    "private_enterprise",
    "social_media_cloud",
    "commercial_cloud",
    "university"
]

# benchmarks = [
#     "private_enterprise",
#     "social_media_cloud"
# ]

loads = range(1, 10)

# Input TrafPy flow files
input_dir = "/home/hsd/workspace/trafpy/examples/comparison_generator/8_hosts_v9(prob1)"

# CONGA / ECMP ns-3 outputs
conga_dir = "/home/hsd/workspace/ns-3.45/conga_sym_8_hosts_v9(prob1)"

# RTT ns-3 outputs
rtt_dir = "/home/hsd/workspace/ns-3.45/rtt_sym_8_hosts_v9(prob1)"

# Output directory
save_dir = "/home/hsd/workspace/ns-3.45/rtt_sym_8_hosts_v9(prob1)/analysis_results"

Path(save_dir).mkdir(
    parents=True,
    exist_ok=True
)


# ============================================================
# MATCHING CONFIG
# ============================================================

PORT_START = 10000
PORT_END = 50000

ip_pattern = r'^\d+\.\d+\.\d+\.\d+$'


# ============================================================
# FUNCTIONS
# ============================================================

def clean(df):
    """
    Keep only rows that contain valid IP addresses.
    """

    required = [
        "Src",
        "Dest"
    ]

    for col in required:

        if col not in df.columns:

            raise ValueError(
                f"Required column '{col}' not found."
            )

    return df[
        df["Src"].astype(str).str.match(
            ip_pattern,
            na=False
        )
        &
        df["Dest"].astype(str).str.match(
            ip_pattern,
            na=False
        )
    ].copy()


# ============================================================

def ip_to_node(ip):
    """
    Convert ns-3 server IP to input trace node ID.

    Leaf 0:
        10.1.1.2 -> 0
        10.1.1.4 -> 1
        10.1.1.6 -> 2
        10.1.1.8 -> 3

    Leaf 1:
        10.1.2.2 -> 4
        10.1.2.4 -> 5
        10.1.2.6 -> 6
        10.1.2.8 -> 7
    """

    parts = ip.split(".")

    subnet = int(parts[-2])
    host = int(parts[-1])

    base = (host // 2) - 1

    if subnet == 1:

        return base

    elif subnet == 2:

        return base + 4

    else:

        raise ValueError(
            f"Unexpected IP address: {ip}"
        )


# ============================================================

def add_time(df):
    """
    Convert ns-3 TimeFirstTxPacket to seconds.
    """

    df = df.copy()

    df["start_time"] = (
        df["TimeFirstTxPacket"]
        .astype(str)
        .str.replace("+", "", regex=False)
        .str.replace("ns", "", regex=False)
        .astype(float)
        / 1e9
    )

    return df


# ============================================================

def expected_port(flow_index):
    """
    Reproduce the C++ destination-port calculation.

        port = PORT_START + flow.index

    with wrapping after PORT_END.
    """

    port = PORT_START + int(flow_index)

    if port > PORT_END:

        port = port - (
            PORT_END - PORT_START
        )

    return port


# ============================================================
# FLOW COLUMNS
# ============================================================

flow_columns = [
    "FlowID",
    "Src",
    "Dest",
    "TimeFirstRxPacket",
    "TimeFirstTxPacket",
    "TimeLastRxPacket",
    "TimeLastTxPacket",
    "FCT(s)",
    "TxPackets",
    "RxPackets",
    "LostPackets",
    "LossRate",
    "PDR",
    "LossPercent",
    "TxBytes",
    "RxBytes",
    "Throughput(Kbps)",
    "MeanDelay(ms)",
    "Jitter(ms)",
    "HopCount"
]


# ============================================================
# MATCHING FUNCTION
# ============================================================

def match_df(output_df, input_df, label):
    """
    Match input TrafPy flows to ns-3 flows.

    Matching is based on:

        1. source node
        2. destination node
        3. destination port

    If multiple ns-3 flows have the same tuple, the candidate
    with the closest start time to the input event time is used.

    Time is NOT a hard matching criterion.
    """

    matches = []

    # --------------------------------------------------------
    # Make copies
    # --------------------------------------------------------

    output_df = output_df.copy()
    input_df = input_df.copy()

    # --------------------------------------------------------
    # Numeric conversion
    # --------------------------------------------------------

    for col in [
        "SrcPort",
        "DestPort",
        "TxPackets",
        "RxPackets",
        "TxBytes",
        "RxBytes",
        "start_time",
        "sn",
        "dn"
    ]:

        if col in output_df.columns:

            output_df[col] = pd.to_numeric(
                output_df[col],
                errors="coerce"
            )

    for col in [
        "sn",
        "dn",
        "index",
        "flow_size",
        "event_time"
    ]:

        input_df[col] = pd.to_numeric(
            input_df[col],
            errors="coerce"
        )

    # --------------------------------------------------------
    # Remove invalid rows
    # --------------------------------------------------------

    output_df = output_df.dropna(
        subset=[
            "SrcPort",
            "DestPort",
            "TxPackets",
            "RxPackets",
            "TxBytes",
            "RxBytes",
            "start_time",
            "sn",
            "dn"
        ]
    ).copy()

    input_df = input_df.dropna(
        subset=[
            "sn",
            "dn",
            "index",
            "flow_size",
            "event_time"
        ]
    ).copy()

    # --------------------------------------------------------
    # Sort input by event time
    # --------------------------------------------------------

    input_df = input_df.sort_values(
        "event_time"
    ).reset_index(
        drop=True
    )

    # --------------------------------------------------------
    # Create lookup key
    #
    # (source node, destination node, destination port)
    # --------------------------------------------------------

    output_df["_match_key"] = list(
        zip(
            output_df["sn"].astype(int),
            output_df["dn"].astype(int),
            output_df["DestPort"].astype(int)
        )
    )

    # --------------------------------------------------------
    # Group ns-3 flows by matching key
    # --------------------------------------------------------

    grouped = {
        key: group
        for key, group in output_df.groupby(
            "_match_key",
            sort=False
        )
    }

    # --------------------------------------------------------
    # Process every input flow
    # --------------------------------------------------------

    for _, in_row in input_df.iterrows():

        input_flow_id = in_row["flow_id"]

        input_index = int(
            in_row["index"]
        )

        input_src = int(
            in_row["sn"]
        )

        input_dst = int(
            in_row["dn"]
        )

        input_time = float(
            in_row["event_time"]
        )

        input_size = float(
            in_row["flow_size"]
        )

        # ----------------------------------------------------
        # Expected destination port
        # ----------------------------------------------------

        expected_dst_port = expected_port(
            input_index
        )

        # ----------------------------------------------------
        # Lookup
        # ----------------------------------------------------

        key = (
            input_src,
            input_dst,
            expected_dst_port
        )

        candidates = grouped.get(
            key
        )

        # ----------------------------------------------------
        # No matching ns-3 flow
        # ----------------------------------------------------

        if candidates is None or len(candidates) == 0:

            continue

        # ----------------------------------------------------
        # Find closest start time
        # ----------------------------------------------------

        if len(candidates) == 1:

            best = candidates.iloc[0]

            time_diff = abs(
                best["start_time"]
                - input_time
            )

        else:

            time_diffs = (
                candidates["start_time"]
                - input_time
            ).abs()

            best_index = time_diffs.idxmin()

            best = candidates.loc[
                best_index
            ]

            time_diff = time_diffs.loc[
                best_index
            ]

        # ----------------------------------------------------
        # Size difference
        # ----------------------------------------------------

        if input_size > 0:

            size_diff = (
                abs(
                    best["TxBytes"]
                    - input_size
                )
                /
                max(
                    input_size,
                    best["TxBytes"],
                    1
                )
            )

        else:

            size_diff = np.nan

        # ----------------------------------------------------
        # Combined result
        # ----------------------------------------------------

        combined = {

            "flow_id":
                input_flow_id,

            "sn":
                input_src,

            "dn":
                input_dst,

            "input_time":
                input_time,

            "flow_size":
                input_size,

            #"expected_dest_port":
            #    expected_dst_port,

            f"time_diff_{label}":
                time_diff,

            f"size_diff_{label}":
                size_diff,

            f"TxPackets_{label}":
                best["TxPackets"],

            f"RxPackets_{label}":
                best["RxPackets"],

            f"TxBytes_calc_{label}":
                best["TxPackets"] * 1400,

            f"RxBytes_calc_{label}":
                best["RxPackets"] * 1400
        }

        # ----------------------------------------------------
        # Add all FlowMonitor columns
        # ----------------------------------------------------

        for col in flow_columns:

            combined[
                f"{col}_{label}"
            ] = best[col]

        matches.append(
            combined
        )

    return pd.DataFrame(
        matches
    )


# ============================================================
# AVERAGE FCT RESULTS FOR PLOTTING
# ============================================================

avg_fct_results = {
    benchmark: {}
    for benchmark in benchmarks
}



# ============================================================
# MAIN
# ============================================================



for benchmark in benchmarks:

    for load in loads:

        print()
        print(
            "=" * 80
        )

        print(
            f"{benchmark} | Load 0.{load}"
        )

        print(
            "=" * 80
        )

        # ====================================================
        # INPUT TRACE
        # ====================================================

        input_path = (
            f"{input_dir}/"
            f"{benchmark}_load_{load}.csv"
        )

        try:

            input_df = pd.read_csv(
                input_path
            )

            print(
                f"Input flows: "
                f"{len(input_df):,}"
            )

        except Exception as e:

            print(
                f"Could not read input: {e}"
            )

            continue

        # ====================================================
        # ALGORITHMS
        #
        # COMMENT / UNCOMMENT ANYTHING YOU WANT
        # ====================================================

        try:

            algorithms = {

                # ------------------------------------------------
                # CONGA
                # ------------------------------------------------

                "conga": pd.read_csv(
                    f"{conga_dir}/"
                    f"{benchmark}_load_{load}_Conga.csv",
                    nrows=12000
                ),

                # ------------------------------------------------
                # CONGA variants
                # ------------------------------------------------

                # "conga_new": pd.read_csv(
                #     f"{conga_dir}/"
                #     f"{benchmark}_load_{load}_Conga_new.csv",
                #     nrows=12000
                # ),

                # "conga-ecmp": pd.read_csv(
                #     f"{conga_dir}/"
                #     f"{benchmark}_load_{load}_Conga-ECMP_new.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # ECMP
                # ------------------------------------------------

                "ecmp": pd.read_csv(
                    f"{conga_dir}/"
                    f"{benchmark}_load_{load}_ECMP.csv",
                    nrows=12000
                ),

                # ------------------------------------------------
                # ECMP variants
                # ------------------------------------------------

                # "ecmp_new": pd.read_csv(
                #     f"{conga_dir}/"
                #     f"{benchmark}_load_{load}_ECMP_new.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # Basic RTT
                # ------------------------------------------------

                # "rtt": pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_RTT.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # Weighted ECMP
                # ------------------------------------------------

                # "weighted": pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_WEIGHTED_ECMP_RTT.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # Power-of-2 Random
                # ------------------------------------------------

                # "random": pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_POWER_OF_2_RANDOM_RTT.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # Power-of-2 Top2
                # ------------------------------------------------

                # "top2": pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_POWER_OF_2_TOP2_RTT.csv",
                #     nrows=12000
                # ),
            }

            # ====================================================
            # TIMEOUT VARIANTS
            # ====================================================

            timeout_values = [
                "true",
                "false"
            ]

            for timeout in timeout_values:

                # ------------------------------------------------
                # Weighted ECMP + timeout
                # ------------------------------------------------

                algorithms[
                    f"weighted_{timeout}"
                    ] = pd.read_csv(
                    f"{rtt_dir}/"
                    f"{benchmark}_load_{load}_"
                    f"WEIGHTED_ECMP_timeout_{timeout}_RTT.csv",
                    nrows=12000
                )

                # ------------------------------------------------
                # Lowest RTT + timeout
                # ------------------------------------------------

                #algorithms[
                #    f"lrtt_{timeout}"
                #] = pd.read_csv(
                #    f"{rtt_dir}/"
                #    f"{benchmark}_load_{load}_"
                #    f"LOWEST_RTT_timeout_{timeout}_RTT.csv",
                #    nrows=12000
                #)

                # ------------------------------------------------
                # Power-of-2 Random + timeout
                # ------------------------------------------------

                algorithms[
                     f"random_{timeout}"
                     ] = pd.read_csv(
                     f"{rtt_dir}/"
                     f"{benchmark}_load_{load}_"
                     f"POWER_OF_2_RANDOM_timeout_{timeout}_RTT.csv",
                     nrows=12000
                 )

                # ------------------------------------------------
                # Power-of-2 Top2 + timeout
                # ------------------------------------------------

                # algorithms[
                #     f"top2_{timeout}"
                # ] = pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_"
                #     f"POWER_OF_2_TOP2_timeout_{timeout}_RTT.csv",
                #     nrows=12000
                # )

        except Exception as e:

            print(
                "Skipping:",
                e
            )

            continue

        # ====================================================
        # CLEAN + PREPARE
        # ====================================================

        for label, df in algorithms.items():

            try:

                df = clean(
                    df
                )

                df = add_time(
                    df
                )

                df["sn"] = df["Src"].apply(
                    ip_to_node
                )

                df["dn"] = df["Dest"].apply(
                    ip_to_node
                )

                algorithms[label] = df

                print(
                    f"{label}: "
                    f"{len(df):,} IP flows"
                )

            except Exception as e:

                print(
                    f"ERROR processing "
                    f"{label}: {e}"
                )

                algorithms[label] = (
                    pd.DataFrame()
                )

        # ====================================================
        # MATCH
        # ====================================================

        matched = {}

        for label, df in algorithms.items():

            if df.empty:

                print(
                    f"Skipping matching for "
                    f"{label}: empty dataframe"
                )

                continue

            print(
                f"Matching {label}..."
            )

            matched[label] = match_df(
                df,
                input_df,
                label
            )

            print(
                f"{label}: "
                f"{len(matched[label]):,} matches"
            )

        # ====================================================
        # REMOVE EMPTY ALGORITHMS
        # ====================================================

        matched = {
            label: df
            for label, df in matched.items()
            if not df.empty
        }

        if len(matched) == 0:

            print(
                "No matches."
            )

            continue

        # ====================================================
        # MERGE RESULTS
        # ====================================================

        merge_keys = [
            "flow_id",
            "sn",
            "dn",
            "input_time",
            "flow_size"
        ]

        algorithms_list = list(
            matched.keys()
        )

        final_df = matched[
            algorithms_list[0]
        ]

        for algo in algorithms_list[1:]:

            final_df = pd.merge(
                final_df,
                matched[algo],
                on=merge_keys,
                how="inner"
            )

        # ====================================================
        # CHECK RESULT
        # ====================================================

        if len(final_df) == 0:

            print(
                "No common matches across "
                "the selected algorithms."
            )

            continue

        print()
        print(
            f"Final matched flows: "
            f"{len(final_df):,}"
        )


        # ============================================================
        # MATCHING TIME-DIFFERENCE SANITY CHECK
        # ============================================================
        
        print("\n" + "=" * 80)
        print("MATCHING TIME-DIFFERENCE CHECK")
        print("=" * 80)
        
        for algo in algorithms:
        
            col = f"time_diff_{algo}"
        
            if col not in final_df.columns:
                continue
        
            max_diff = final_df[col].max()
            mean_diff = final_df[col].mean()
            p95_diff = final_df[col].quantile(0.95)
            p99_diff = final_df[col].quantile(0.99)
        
            max_idx = final_df[col].idxmax()
            worst = final_df.loc[max_idx]
        
            print(f"\n{algo}")
            print(f"  Maximum : {max_diff:.9f} s "
                  f"({max_diff * 1000:.6f} ms)")
            print(f"  Mean    : {mean_diff:.9f} s "
                  f"({mean_diff * 1000:.6f} ms)")
            print(f"  P95     : {p95_diff:.9f} s "
                  f"({p95_diff * 1000:.6f} ms)")
            print(f"  P99     : {p99_diff:.9f} s "
                  f"({p99_diff * 1000:.6f} ms)")
        
            print(f"  Worst matching flow:")
            print(f"    flow_id     : {worst['flow_id']}")
            print(f"    sn          : {worst['sn']}")
            print(f"    dn          : {worst['dn']}")
            print(f"    input_time  : {worst['input_time']:.9f} s")
            print(f"    time_diff   : {worst[col]:.9f} s")

        
        # ====================================================
        # DIFFERENCES
        # ====================================================

        reference = "ecmp"

        if reference in matched:

            for algo in algorithms:

                if algo == reference:
                    continue

                if (
                    f"FCT(s)_{reference}" in final_df.columns
                    and
                    f"FCT(s)_{algo}" in final_df.columns
                ):

                    final_df[
                        f"fct_diff_{reference}_{algo}"
                    ] = (
                        final_df[
                            f"FCT(s)_{reference}"
                        ]
                        -
                        final_df[
                            f"FCT(s)_{algo}"
                        ]
                    )

        # ====================================================
        # SAVE
        # ====================================================

        csv_path = (
            f"{save_dir}/"
            f"{benchmark}_load_{load}_full.csv"
        )

        final_df.to_csv(
            csv_path,
            index=False
        )

        print(
            f"Saved: {csv_path}"
        )

        # ====================================================
        # STATS
        # ====================================================

        print()
        print(
            "-" * 80
        )

        print(
            f"Statistics: "
            f"{benchmark} | Load 0.{load}"
        )

        print(
            "-" * 80
        )

        for algo in matched:

            column = (
                f"FCT(s)_{algo}"
            )

            if column not in final_df.columns:
                continue

            fct = final_df[column]

            avg_fct = fct.mean()

            # --------------------------------------------------------
            # Store average FCT for later plotting
            # --------------------------------------------------------
        
            avg_fct_results[benchmark].setdefault(algo,{})
        
            avg_fct_results[benchmark][algo][load] = avg_fct



            print(
                f"{algo:20s}"
                f"Avg: {fct.mean():.6f}  "
                f"P75: {fct.quantile(0.75):.6f}  "
                f"P90: {fct.quantile(0.90):.6f}  "
                f"P95: {fct.quantile(0.95):.6f}  "
                f"P99: {fct.quantile(0.99):.6f}"
            )


# ============================================================
# DONE
# ============================================================

# ============================================================
# AVERAGE FCT COMPARISON GRAPHS
# ============================================================

print()
print("=" * 80)
print("GENERATING AVERAGE FCT COMPARISON GRAPHS")
print("=" * 80)


for benchmark in benchmarks:

    benchmark_results = avg_fct_results.get(
        benchmark,
        {}
    )

    if not benchmark_results:

        print(
            f"No FCT results available for "
            f"{benchmark}"
        )

        continue

    # --------------------------------------------------------
    # Create figure
    # --------------------------------------------------------

    plt.figure(
        figsize=(10, 6)
    )

    # --------------------------------------------------------
    # Plot each algorithm
    # --------------------------------------------------------

    for algo, load_results in benchmark_results.items():

        if not load_results:
            continue

        x = sorted(
            load_results.keys()
        )

        y = [
            load_results[load]
            for load in x
        ]

        # Convert load 1..9 to 0.1..0.9
        x_values = [
            load / 10
            for load in x
        ]

        plt.plot(
            x_values,
            y,
            marker="o",
            linewidth=2,
            markersize=6,
            label=algo
        )

    # --------------------------------------------------------
    # Labels
    # --------------------------------------------------------

    plt.xlabel(
        "Load",
        fontsize=12
    )

    plt.ylabel(
        "Average FCT (s)",
        fontsize=12
    )

    plt.title(
        f"Average Flow Completion Time - {benchmark}",
        fontsize=14
    )

    # --------------------------------------------------------
    # X-axis
    # --------------------------------------------------------

    plt.xticks(
        np.arange(
            0.1,
            1.0,
            0.1
        )
    )

    # --------------------------------------------------------
    # Grid
    # --------------------------------------------------------

    plt.grid(
        True,
        linestyle="--",
        alpha=0.5
    )

    # --------------------------------------------------------
    # Legend
    # --------------------------------------------------------

    plt.legend(
        fontsize=10
    )

    # --------------------------------------------------------
    # Layout
    # --------------------------------------------------------

    plt.tight_layout()

    # --------------------------------------------------------
    # Save
    # --------------------------------------------------------

    # ============================================================
    # GRAPH OUTPUT DIRECTORIES
    # ============================================================
    
    graph_dir = Path(save_dir) / "graph"
    avg_graph_dir = graph_dir / "avg"
    
    avg_graph_dir.mkdir(
        parents=True,
        exist_ok=True
    )

    graph_path = (
        avg_graph_dir /
        f"{benchmark}_average_fct_comparison.png"
    )

    plt.savefig(
        graph_path,
        dpi=300,
        bbox_inches="tight"
    )

    plt.close()

    print(
        f"Saved graph: {graph_path}"
    )

print(
    "MATCHING COMPLETE"
)

print(
    "=" * 80
)
# Out:
# ================================================================================
# private_enterprise | Load 0.1
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 9.294129165 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 9.294129165 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 9.294129165 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 9.294129165 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 9.294129165 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 9.294129165 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/private_enterprise_load_1_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.1
# --------------------------------------------------------------------------------
# conga               Avg: 0.006323  P75: 0.003784  P90: 0.016141  P95: 0.028644  P99: 0.067838
# ecmp                Avg: 0.007816  P75: 0.004775  P90: 0.020412  P95: 0.035074  P99: 0.084438
# weighted_true       Avg: 0.006558  P75: 0.004512  P90: 0.016040  P95: 0.026923  P99: 0.065135
# random_true         Avg: 0.006911  P75: 0.004615  P90: 0.017495  P95: 0.029355  P99: 0.073103
# weighted_false      Avg: 0.006194  P75: 0.004033  P90: 0.013896  P95: 0.025393  P99: 0.068423
# random_false        Avg: 0.005968  P75: 0.003939  P90: 0.012808  P95: 0.023555  P99: 0.065367
#
# ================================================================================
# private_enterprise | Load 0.2
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 15.557174508 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 15.557174508 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 15.557174508 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 15.557174508 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 15.557174508 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 15.557174508 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/private_enterprise_load_2_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.2
# --------------------------------------------------------------------------------
# conga               Avg: 0.008554  P75: 0.007432  P90: 0.022780  P95: 0.035367  P99: 0.075383
# ecmp                Avg: 0.011515  P75: 0.009775  P90: 0.032504  P95: 0.051899  P99: 0.109948
# weighted_true       Avg: 0.009241  P75: 0.008868  P90: 0.023522  P95: 0.035222  P99: 0.085483
# random_true         Avg: 0.008988  P75: 0.008370  P90: 0.022750  P95: 0.034929  P99: 0.079877
# weighted_false      Avg: 0.007104  P75: 0.005741  P90: 0.015851  P95: 0.026971  P99: 0.067655
# random_false        Avg: 0.007526  P75: 0.006247  P90: 0.017496  P95: 0.028295  P99: 0.069880
#
# ================================================================================
# private_enterprise | Load 0.3
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 3.098043055 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 3.098043055 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 3.098043055 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 3.098043055 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 3.098043055 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 3.098043055 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/private_enterprise_load_3_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.3
# --------------------------------------------------------------------------------
# conga               Avg: 0.010987  P75: 0.012684  P90: 0.028503  P95: 0.039879  P99: 0.086859
# ecmp                Avg: 0.018109  P75: 0.020564  P90: 0.054111  P95: 0.074099  P99: 0.144444
# weighted_true       Avg: 0.011502  P75: 0.012676  P90: 0.028181  P95: 0.040050  P99: 0.094735
# random_true         Avg: 0.011625  P75: 0.013138  P90: 0.028395  P95: 0.041317  P99: 0.089151
# weighted_false      Avg: 0.008783  P75: 0.008231  P90: 0.019179  P95: 0.031996  P99: 0.079395
# random_false        Avg: 0.008646  P75: 0.008024  P90: 0.018595  P95: 0.030264  P99: 0.075053
#
# ================================================================================
# private_enterprise | Load 0.4
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 7.778587254 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 7.778587254 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 7.778587254 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 7.778587254 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 7.778587254 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 7.778587254 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/private_enterprise_load_4_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.4
# --------------------------------------------------------------------------------
# conga               Avg: 0.014515  P75: 0.018191  P90: 0.035047  P95: 0.049322  P99: 0.099995
# ecmp                Avg: 0.032696  P75: 0.036638  P90: 0.084541  P95: 0.120393  P99: 0.228861
# weighted_true       Avg: 0.014714  P75: 0.016694  P90: 0.031195  P95: 0.044613  P99: 0.109667
# random_true         Avg: 0.015597  P75: 0.017105  P90: 0.033526  P95: 0.049644  P99: 0.129065
# weighted_false      Avg: 0.010143  P75: 0.009400  P90: 0.019900  P95: 0.030711  P99: 0.081475
# random_false        Avg: 0.010539  P75: 0.009862  P90: 0.020987  P95: 0.032596  P99: 0.084960
#
# ================================================================================
# private_enterprise | Load 0.5
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 1.858825833 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 1.858825833 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 1.858825833 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 1.858825833 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 1.858825833 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 1.858825833 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/private_enterprise_load_5_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.5
# --------------------------------------------------------------------------------
# conga               Avg: 0.018191  P75: 0.022560  P90: 0.039096  P95: 0.055522  P99: 0.119072
# ecmp                Avg: 0.059418  P75: 0.049845  P90: 0.101413  P95: 0.144694  P99: 0.310328
# weighted_true       Avg: 0.017620  P75: 0.019220  P90: 0.034176  P95: 0.049956  P99: 0.136990
# random_true         Avg: 0.017934  P75: 0.018703  P90: 0.035368  P95: 0.051757  P99: 0.149681
# weighted_false      Avg: 0.012116  P75: 0.011328  P90: 0.022422  P95: 0.034000  P99: 0.097845
# random_false        Avg: 0.012506  P75: 0.011899  P90: 0.023451  P95: 0.035214  P99: 0.095093
#
# ================================================================================
# private_enterprise | Load 0.6
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_271
#     sn          : 2
#     dn          : 7
#     input_time  : 1.235577460 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_271
#     sn          : 2
#     dn          : 7
#     input_time  : 1.235577460 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_271
#     sn          : 2
#     dn          : 7
#     input_time  : 1.235577460 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_271
#     sn          : 2
#     dn          : 7
#     input_time  : 1.235577460 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_271
#     sn          : 2
#     dn          : 7
#     input_time  : 1.235577460 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_271
#     sn          : 2
#     dn          : 7
#     input_time  : 1.235577460 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/private_enterprise_load_6_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.6
# --------------------------------------------------------------------------------
# conga               Avg: 0.021554  P75: 0.025449  P90: 0.044591  P95: 0.062049  P99: 0.142650
# ecmp                Avg: 0.063785  P75: 0.065418  P90: 0.111829  P95: 0.149348  P99: 0.320376
# weighted_true       Avg: 0.020247  P75: 0.020396  P90: 0.035091  P95: 0.049987  P99: 0.164541
# random_true         Avg: 0.021409  P75: 0.021931  P90: 0.037847  P95: 0.054235  P99: 0.173818
# weighted_false      Avg: 0.013873  P75: 0.012629  P90: 0.023287  P95: 0.036100  P99: 0.126514
# random_false        Avg: 0.014674  P75: 0.013815  P90: 0.025752  P95: 0.038954  P99: 0.121615
#
# ================================================================================
# private_enterprise | Load 0.7
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3622
#     sn          : 0
#     dn          : 6
#     input_time  : 4.185044248 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3622
#     sn          : 0
#     dn          : 6
#     input_time  : 4.185044248 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3622
#     sn          : 0
#     dn          : 6
#     input_time  : 4.185044248 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3622
#     sn          : 0
#     dn          : 6
#     input_time  : 4.185044248 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3622
#     sn          : 0
#     dn          : 6
#     input_time  : 4.185044248 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3622
#     sn          : 0
#     dn          : 6
#     input_time  : 4.185044248 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/private_enterprise_load_7_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.7
# --------------------------------------------------------------------------------
# conga               Avg: 0.031409  P75: 0.036738  P90: 0.059827  P95: 0.082717  P99: 0.200327
# ecmp                Avg: 0.075044  P75: 0.078456  P90: 0.125461  P95: 0.168336  P99: 0.355299
# weighted_true       Avg: 0.025646  P75: 0.025145  P90: 0.043570  P95: 0.063555  P99: 0.210097
# random_true         Avg: 0.027129  P75: 0.026370  P90: 0.046101  P95: 0.067140  P99: 0.214902
# weighted_false      Avg: 0.016993  P75: 0.014861  P90: 0.027483  P95: 0.042657  P99: 0.157185
# random_false        Avg: 0.017487  P75: 0.015963  P90: 0.028259  P95: 0.043976  P99: 0.152055
#
# ================================================================================
# private_enterprise | Load 0.8
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 3.889293627 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 3.889293627 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 3.889293627 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 3.889293627 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 3.889293627 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_58
#     sn          : 0
#     dn          : 4
#     input_time  : 3.889293627 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/private_enterprise_load_8_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.8
# --------------------------------------------------------------------------------
# conga               Avg: 0.043615  P75: 0.050601  P90: 0.078708  P95: 0.107152  P99: 0.249646
# ecmp                Avg: 0.088335  P75: 0.089772  P90: 0.136525  P95: 0.192321  P99: 0.537440
# weighted_true       Avg: 0.035954  P75: 0.033692  P90: 0.056189  P95: 0.081468  P99: 0.301164
# random_true         Avg: 0.036977  P75: 0.034164  P90: 0.057048  P95: 0.082912  P99: 0.287997
# weighted_false      Avg: 0.023175  P75: 0.020110  P90: 0.034881  P95: 0.053661  P99: 0.197059
# random_false        Avg: 0.022437  P75: 0.019231  P90: 0.033023  P95: 0.051991  P99: 0.199066
#
# ================================================================================
# private_enterprise | Load 0.9
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_624
#     sn          : 2
#     dn          : 6
#     input_time  : 1.958403521 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_624
#     sn          : 2
#     dn          : 6
#     input_time  : 1.958403521 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_624
#     sn          : 2
#     dn          : 6
#     input_time  : 1.958403521 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_624
#     sn          : 2
#     dn          : 6
#     input_time  : 1.958403521 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_624
#     sn          : 2
#     dn          : 6
#     input_time  : 1.958403521 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_624
#     sn          : 2
#     dn          : 6
#     input_time  : 1.958403521 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/private_enterprise_load_9_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.9
# --------------------------------------------------------------------------------
# conga               Avg: 0.049358  P75: 0.052029  P90: 0.085819  P95: 0.119569  P99: 0.352729
# ecmp                Avg: 0.090385  P75: 0.092541  P90: 0.149273  P95: 0.199545  P99: 0.605225
# weighted_true       Avg: 0.039568  P75: 0.037036  P90: 0.062913  P95: 0.090508  P99: 0.361919
# random_true         Avg: 0.039859  P75: 0.036236  P90: 0.062937  P95: 0.095319  P99: 0.425530
# weighted_false      Avg: 0.025410  P75: 0.023630  P90: 0.042809  P95: 0.066893  P99: 0.240146
# random_false        Avg: 0.027635  P75: 0.025048  P90: 0.045036  P95: 0.069452  P99: 0.262450
#
# ================================================================================
# social_media_cloud | Load 0.1
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 15.230570656 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 15.230570656 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 15.230570656 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 15.230570656 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 15.230570656 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 15.230570656 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/social_media_cloud_load_1_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.1
# --------------------------------------------------------------------------------
# conga               Avg: 0.007714  P75: 0.009266  P90: 0.020344  P95: 0.029802  P99: 0.054072
# ecmp                Avg: 0.009166  P75: 0.011419  P90: 0.024209  P95: 0.035543  P99: 0.060165
# weighted_true       Avg: 0.008429  P75: 0.010241  P90: 0.022254  P95: 0.031875  P99: 0.058474
# random_true         Avg: 0.008565  P75: 0.010487  P90: 0.022256  P95: 0.032558  P99: 0.058621
# weighted_false      Avg: 0.007875  P75: 0.009299  P90: 0.020112  P95: 0.029883  P99: 0.053494
# random_false        Avg: 0.007846  P75: 0.009294  P90: 0.020123  P95: 0.029945  P99: 0.053716
#
# ================================================================================
# social_media_cloud | Load 0.2
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 7.615285328 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 7.615285328 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 7.615285328 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 7.615285328 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 7.615285328 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 7.615285328 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/social_media_cloud_load_2_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.2
# --------------------------------------------------------------------------------
# conga               Avg: 0.011081  P75: 0.014178  P90: 0.028255  P95: 0.039712  P99: 0.071413
# ecmp                Avg: 0.013514  P75: 0.018232  P90: 0.034699  P95: 0.048963  P99: 0.081669
# weighted_true       Avg: 0.012458  P75: 0.015957  P90: 0.030573  P95: 0.042239  P99: 0.080273
# random_true         Avg: 0.012781  P75: 0.016634  P90: 0.031581  P95: 0.044306  P99: 0.082422
# weighted_false      Avg: 0.010826  P75: 0.013525  P90: 0.026638  P95: 0.038847  P99: 0.071021
# random_false        Avg: 0.010941  P75: 0.013792  P90: 0.026859  P95: 0.039252  P99: 0.071737
#
# ================================================================================
# social_media_cloud | Load 0.3
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1255
#     sn          : 5
#     dn          : 1
#     input_time  : 3.461752383 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1255
#     sn          : 5
#     dn          : 1
#     input_time  : 3.461752383 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1255
#     sn          : 5
#     dn          : 1
#     input_time  : 3.461752383 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1255
#     sn          : 5
#     dn          : 1
#     input_time  : 3.461752383 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1255
#     sn          : 5
#     dn          : 1
#     input_time  : 3.461752383 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1255
#     sn          : 5
#     dn          : 1
#     input_time  : 3.461752383 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/social_media_cloud_load_3_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.3
# --------------------------------------------------------------------------------
# conga               Avg: 0.015487  P75: 0.020504  P90: 0.038023  P95: 0.052997  P99: 0.093652
# ecmp                Avg: 0.018523  P75: 0.025675  P90: 0.047396  P95: 0.062293  P99: 0.102552
# weighted_true       Avg: 0.017619  P75: 0.022983  P90: 0.041200  P95: 0.058390  P99: 0.107727
# random_true         Avg: 0.018167  P75: 0.023487  P90: 0.041743  P95: 0.060116  P99: 0.115645
# weighted_false      Avg: 0.014003  P75: 0.017458  P90: 0.033475  P95: 0.047166  P99: 0.091684
# random_false        Avg: 0.014182  P75: 0.017424  P90: 0.033302  P95: 0.048334  P99: 0.090517
#
# ================================================================================
# social_media_cloud | Load 0.4
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 3.807642664 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 3.807642664 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 3.807642664 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 3.807642664 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 3.807642664 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5259
#     sn          : 1
#     dn          : 4
#     input_time  : 3.807642664 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/social_media_cloud_load_4_full.csv
#
# --------------------------------------------------------------------------------
# ...
# weighted_false      Avg: 0.010035  P75: 0.010408  P90: 0.019834  P95: 0.029277  P99: 0.085844
# random_false        Avg: 0.011063  P75: 0.011953  P90: 0.023649  P95: 0.033091  P99: 0.079348
#
# ================================================================================
# university | Load 0.6
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3189
#     sn          : 6
#     dn          : 3
#     input_time  : 1.283891153 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3189
#     sn          : 6
#     dn          : 3
#     input_time  : 1.283891153 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3189
#     sn          : 6
#     dn          : 3
#     input_time  : 1.283891153 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3189
#     sn          : 6
#     dn          : 3
#     input_time  : 1.283891153 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3189
#     sn          : 6
#     dn          : 3
#     input_time  : 1.283891153 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3189
#     sn          : 6
#     dn          : 3
#     input_time  : 1.283891153 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/university_load_6_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.6
# --------------------------------------------------------------------------------
# conga               Avg: 0.018563  P75: 0.023892  P90: 0.038125  P95: 0.051210  P99: 0.105399
# ecmp                Avg: 0.040750  P75: 0.052127  P90: 0.084397  P95: 0.114653  P99: 0.206377
# weighted_true       Avg: 0.020986  P75: 0.022456  P90: 0.037650  P95: 0.053031  P99: 0.140111
# random_true         Avg: 0.021231  P75: 0.023206  P90: 0.038479  P95: 0.052302  P99: 0.139791
# weighted_false      Avg: 0.013586  P75: 0.013812  P90: 0.024690  P95: 0.035335  P99: 0.106625
# random_false        Avg: 0.013301  P75: 0.013553  P90: 0.023915  P95: 0.034678  P99: 0.105569
#
# ================================================================================
# university | Load 0.7
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 3.736234600 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 3.736234600 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 3.736234600 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 3.736234600 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 3.736234600 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 3.736234600 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/university_load_7_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.7
# --------------------------------------------------------------------------------
# conga               Avg: 0.030220  P75: 0.037454  P90: 0.057422  P95: 0.079107  P99: 0.156801
# ecmp                Avg: 0.068188  P75: 0.076274  P90: 0.119561  P95: 0.161178  P99: 0.336768
# weighted_true       Avg: 0.026783  P75: 0.026448  P90: 0.041991  P95: 0.059459  P99: 0.214626
# random_true         Avg: 0.028173  P75: 0.028866  P90: 0.046232  P95: 0.064808  P99: 0.194413
# weighted_false      Avg: 0.016580  P75: 0.015938  P90: 0.027495  P95: 0.039656  P99: 0.141986
# random_false        Avg: 0.016516  P75: 0.015724  P90: 0.026859  P95: 0.040011  P99: 0.135529
#
# ================================================================================
# university | Load 0.8
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 3.269205275 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 3.269205275 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 3.269205275 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 3.269205275 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 3.269205275 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5238
#     sn          : 2
#     dn          : 7
#     input_time  : 3.269205275 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/university_load_8_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.8
# --------------------------------------------------------------------------------
# conga               Avg: 0.037320  P75: 0.041688  P90: 0.061783  P95: 0.082053  P99: 0.180729
# ecmp                Avg: 0.080068  P75: 0.082882  P90: 0.128643  P95: 0.177407  P99: 0.471998
# weighted_true       Avg: 0.042588  P75: 0.040845  P90: 0.064476  P95: 0.093617  P99: 0.349030
# random_true         Avg: 0.041397  P75: 0.039500  P90: 0.063451  P95: 0.088255  P99: 0.345266
# weighted_false      Avg: 0.020531  P75: 0.018208  P90: 0.030717  P95: 0.049005  P99: 0.176629
# random_false        Avg: 0.022850  P75: 0.021629  P90: 0.035112  P95: 0.052356  P99: 0.194476
#
# ================================================================================
# university | Load 0.9
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5653
#     sn          : 1
#     dn          : 6
#     input_time  : 1.967836341 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5653
#     sn          : 1
#     dn          : 6
#     input_time  : 1.967836341 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5653
#     sn          : 1
#     dn          : 6
#     input_time  : 1.967836341 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5653
#     sn          : 1
#     dn          : 6
#     input_time  : 1.967836341 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5653
#     sn          : 1
#     dn          : 6
#     input_time  : 1.967836341 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5653
#     sn          : 1
#     dn          : 6
#     input_time  : 1.967836341 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/university_load_9_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.9
# --------------------------------------------------------------------------------
# conga               Avg: 0.066634  P75: 0.072322  P90: 0.108571  P95: 0.142381  P99: 0.363140
# ecmp                Avg: 0.099839  P75: 0.093774  P90: 0.143987  P95: 0.195484  P99: 1.334316
# weighted_true       Avg: 0.059364  P75: 0.057388  P90: 0.092330  P95: 0.137731  P99: 0.562058
# random_true         Avg: 0.049684  P75: 0.050019  P90: 0.075986  P95: 0.106311  P99: 0.449550
# weighted_false      Avg: 0.031678  P75: 0.029336  P90: 0.046709  P95: 0.072542  P99: 0.269404
# random_false        Avg: 0.032748  P75: 0.029593  P90: 0.047327  P95: 0.073917  P99: 0.289502
#
# ================================================================================
# GENERATING AVERAGE FCT COMPARISON GRAPHS
# ================================================================================
# Saved graph: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/graph/avg/private_enterprise_average_fct_comparison.png
# Saved graph: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/graph/avg/social_media_cloud_average_fct_comparison.png
# Saved graph: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/graph/avg/commercial_cloud_average_fct_comparison.png
# Saved graph: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/graph/avg/university_average_fct_comparison.png
# MATCHING COMPLETE
# ================================================================================

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

# ------------------ CONFIG ------------------

save_dir = Path(
    "/home/hsd/workspace/ns-3.45/rtt_sym_8_hosts_v9(prob1)/analysis_results"
)

graph_dir = save_dir / "graph"
graph_dir.mkdir(parents=True, exist_ok=True)

benchmarks = [
    "private_enterprise",
    "social_media_cloud",
    "commercial_cloud",
    "university"
]

loads = range(1, 10)

SMALL = 100 * 1024        # 100 KB
LARGE = 1 * 1024 * 1024   # 1 MB

algorithms = [
    "conga",
    #"conga_new",
    #"conga-ecmp",
    "ecmp",
    #"ecmp_new",
    
    #"lrtt_true",
    #"lrtt_false",
    
    #"weighted",
    #"random",
    #"top2"
    
    "weighted_true",
    "weighted_false",

    "random_true",
    "random_false",

    #"top2_true",
    #"top2_false"
]

label_map = {
    "conga": "Conga",
    #"conga_new": "Conga_New",
    #"conga-ecmp": "Conga-ECMP",
    "ecmp": "ECMP",
    #"ecmp_new": "ECMP_New",
    #"rtt": "RTT",

    "lrtt_true": "Lowest RTT (Timeout)",
    "lrtt_false": "Lowest RTT (No Timeout)",
    
    "weighted": "Weighted ECMP",
    "random": "Power-of-2 Random",
    "top2": "Power-of-2 Top2",
    
    "weighted_true": "Weighted ECMP (Timeout)",
    "weighted_false": "Weighted ECMP (No Timeout)",

    "random_true": "Power-of-2 Random (Timeout)",
    "random_false": "Power-of-2 Random (No Timeout)",

    "top2_true": "Power-of-2 Top2 (Timeout)",
    "top2_false": "Power-of-2 Top2 (No Timeout)"
}

color_map = {
    "conga": "tab:blue",
    #"conga_new": "tab:orange",
    #"conga-ecmp": "tab:green",
    "ecmp": "tab:red",
    #"ecmp_new": "tab:purple",
    #"rtt": "tab:brown",

    "lrtt_true": "tab:cyan",
    "lrtt_false": "tab:cyan",
    
    "weighted": "tab:pink",
    "random": "tab:gray",
    "top2": "tab:olive",
    
    "weighted_true": "tab:brown",
    "weighted_false": "tab:brown",

    "random_true": "tab:orange",
    "random_false": "tab:orange",

    "top2_true": "tab:gray",
    "top2_false": "tab:gray",
}

marker_map = {
    "conga": "o",
    #"conga_new": "x",
    #"conga-ecmp": "X",
    "ecmp": "s",
    #"ecmp_new": "*",
    #"rtt": "^",

    "lrtt_true": "1",
    "lrtt_false": "2",
    
    "weighted": "D",
    "random": "v",
    "top2": "P",
    
    "weighted_true": "D",
    "weighted_false": "d",

    "random_true": "^",
    "random_false": "v",

    "top2_true": "P",
    "top2_false": "X"
}

# ------------------ GLOBAL Y-LIMITS ------------------

small_global = []
large_global = []

for benchmark in benchmarks:
    for load in loads:

        csv_path = save_dir / f"{benchmark}_load_{load}_full.csv"

        if not csv_path.exists():
            continue

        df = pd.read_csv(csv_path)

        if df.empty:
            continue

        small_df = df[df["flow_size"] < SMALL]
        large_df = df[df["flow_size"] > LARGE]

        for algo in algorithms:
            col = f"FCT(s)_{algo}"

            if not small_df.empty:
                small_global.append(small_df[col].mean())

            if not large_df.empty:
                large_global.append(large_df[col].mean())

small_min = min(small_global)
small_max = max(small_global)

large_min = min(large_global)
large_max = max(large_global)

small_margin = 0.05 * (small_max - small_min)
large_margin = 0.05 * (large_max - large_min)

small_ylim = (small_min - small_margin, small_max + small_margin)
large_ylim = (large_min - large_margin, large_max + large_margin)

# ------------------ ANALYSIS ------------------

for benchmark in benchmarks:

    print(f"\n===== {benchmark} =====")

    load_vals = []

    small_results = {algo: [] for algo in algorithms}
    large_results = {algo: [] for algo in algorithms}

    for load in loads:

        csv_path = save_dir / f"{benchmark}_load_{load}_full.csv"

        if not csv_path.exists():
            print(f"Missing: {csv_path}")
            continue

        df = pd.read_csv(csv_path)

        if df.empty:
            continue

        small_df = df[df["flow_size"] < SMALL]
        large_df = df[df["flow_size"] > LARGE]

        # ---------- Small Flows ----------

        for algo in algorithms:

            col = f"FCT(s)_{algo}"

            if not small_df.empty:
                small_results[algo].append(
                    small_df[col].mean()
                )
            else:
                small_results[algo].append(np.nan)

        # ---------- Large Flows ----------

        for algo in algorithms:

            col = f"FCT(s)_{algo}"

            if not large_df.empty:
                large_results[algo].append(
                    large_df[col].mean()
                )
            else:
                large_results[algo].append(np.nan)

        load_vals.append(load / 10)

    # ==================================================
    # SMALL FLOWS
    # ==================================================

    plt.figure(figsize=(8, 5))

    for algo in algorithms:

        plt.plot(
            load_vals,
            small_results[algo],
            marker=marker_map[algo],
            color=color_map[algo],
            linestyle="--" if algo.endswith("_false") else "-",
            linewidth=2,
            label=label_map[algo]
        )

    plt.xlabel("Network Load")
    plt.ylabel("Average FCT (s)")
    plt.title(f"{benchmark}: Small Flows (<100 KB)")
    #plt.ylim(small_ylim)
    plt.grid(True)
    plt.legend()

    out_path = graph_dir / f"{benchmark}_SMALL_vs_load.png"

    plt.tight_layout()
    plt.savefig(out_path, dpi=300)
    plt.close()

    print(f"Saved: {out_path}")

    # ==================================================
    # LARGE FLOWS
    # ==================================================

    plt.figure(figsize=(8, 5))

    for algo in algorithms:

        plt.plot(
            load_vals,
            large_results[algo],
            marker=marker_map[algo],
            color=color_map[algo],
            linestyle="--" if algo.endswith("_false") else "-",
            linewidth=2,
            label=label_map[algo]
        )

    plt.xlabel("Network Load")
    plt.ylabel("Average FCT (s)")
    plt.title(f"{benchmark}: Large Flows (>1 MB)")
    #plt.ylim(large_ylim)
    plt.grid(True)
    plt.legend()

    out_path = graph_dir / f"{benchmark}_LARGE_vs_load.png"

    plt.tight_layout()
    plt.savefig(out_path, dpi=300)
    plt.close()

    print(f"Saved: {out_path}")

print("\nDone: Small vs Large flow comparison for all algorithms.")
# Out:
# ===== private_enterprise =====
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/graph/private_enterprise_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/graph/private_enterprise_LARGE_vs_load.png
#
# ===== social_media_cloud =====
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/graph/social_media_cloud_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/graph/social_media_cloud_LARGE_vs_load.png
#
# ===== commercial_cloud =====
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/graph/commercial_cloud_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/graph/commercial_cloud_LARGE_vs_load.png
#
# ===== university =====
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/graph/university_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/graph/university_LARGE_vs_load.png
#
# Done: Small vs Large flow comparison for all algorithms.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

# ============================================================
# CONFIG
# ============================================================

save_dir = Path(
    "/home/hsd/workspace/ns-3.45/rtt_sym_8_hosts_v9(prob1)/analysis_results"
)

baseline = "ecmp"

graph_dir = save_dir / "graph" / f"normalised_vs_{baseline}"
graph_dir.mkdir(parents=True, exist_ok=True)

benchmarks = [
    "private_enterprise",
    "social_media_cloud",
    "commercial_cloud",
    "university"
]

# ------------------------------------------------------------
# Loads
# ------------------------------------------------------------

loads = range(1, 10)

# ------------------------------------------------------------
# Flow size thresholds
# ------------------------------------------------------------

SMALL = 100 * 1024          # 100 KB
LARGE = 1 * 1024 * 1024     # 1 MB


# ============================================================
# ALGORITHMS
#
# Comment/uncomment algorithms here as required.
# ECMP is the baseline and therefore does NOT need to be here.
# ============================================================

algorithms = [

    "conga",

    # "lrtt_true",
    # "lrtt_false",

    "weighted_true",
    "weighted_false",

    "random_true",
    "random_false",

    # "top2_true",
    # "top2_false",

    # "weighted",
    # "random",
    # "top2",
]


# ============================================================
# LABELS
# ============================================================

label_map = {

    "conga":
        "Conga",

    "lrtt_true":
        "Lowest RTT (Timeout)",

    "lrtt_false":
        "Lowest RTT (No Timeout)",

    "weighted":
        "Weighted ECMP",

    "random":
        "Power-of-2 Random",

    "top2":
        "Power-of-2 Top2",

    "weighted_true":
        "Weighted ECMP (Timeout)",

    "weighted_false":
        "Weighted ECMP (No Timeout)",

    "random_true":
        "Power-of-2 Random (Timeout)",

    "random_false":
        "Power-of-2 Random (No Timeout)",

    "top2_true":
        "Power-of-2 Top2 (Timeout)",

    "top2_false":
        "Power-of-2 Top2 (No Timeout)",
}


# ============================================================
# COLORS
# ============================================================

color_map = {

    "conga":
        "tab:blue",

    "lrtt_true":
        "tab:cyan",

    "lrtt_false":
        "tab:cyan",

    "weighted":
        "tab:purple",

    "random":
        "tab:gray",

    "top2":
        "tab:olive",

    "weighted_true":
        "tab:brown",

    "weighted_false":
        "tab:brown",

    "random_true":
        "tab:orange",

    "random_false":
        "tab:orange",

    "top2_true":
        "tab:gray",

    "top2_false":
        "tab:gray",
}


# ============================================================
# MARKERS
# ============================================================

marker_map = {

    "conga":
        "o",

    "lrtt_true":
        "1",

    "lrtt_false":
        "2",

    "weighted":
        "^",

    "random":
        "D",

    "top2":
        "P",

    "weighted_true":
        "D",

    "weighted_false":
        "d",

    "random_true":
        "^",

    "random_false":
        "v",

    "top2_true":
        "P",

    "top2_false":
        "X",
}


# ============================================================
# RESULT STORAGE
# ============================================================

summary_results = {}


# ============================================================
# MAIN ANALYSIS
# ============================================================

for benchmark in benchmarks:

    print()
    print("=" * 80)
    print(f"BENCHMARK: {benchmark}")
    print("=" * 80)

    # --------------------------------------------------------
    # Store load values
    # --------------------------------------------------------

    load_vals = []

    # --------------------------------------------------------
    # Results for each algorithm
    #
    # Each entry will contain one value per network load.
    # --------------------------------------------------------

    small_results = {
        algo: []
        for algo in algorithms
    }

    large_results = {
        algo: []
        for algo in algorithms
    }

    # ========================================================
    # PROCESS EACH LOAD
    # ========================================================

    for load in loads:

        print()
        print(
            f"Processing {benchmark} | Load 0.{load}"
        )

        csv_path = (
            save_dir /
            f"{benchmark}_load_{load}_full.csv"
        )

        # ----------------------------------------------------
        # Check file
        # ----------------------------------------------------

        if not csv_path.exists():

            print(
                f"Missing: {csv_path}"
            )

            continue

        # ----------------------------------------------------
        # Read CSV
        # ----------------------------------------------------

        df = pd.read_csv(
            csv_path
        )

        if df.empty:

            print(
                "Empty dataframe."
            )

            continue

        # ====================================================
        # CHECK REQUIRED COLUMNS
        # ====================================================

        baseline_col = (
            f"FCT(s)_{baseline}"
        )

        if baseline_col not in df.columns:

            print(
                f"ERROR: Missing baseline column "
                f"{baseline_col}"
            )

            continue

        missing_algorithms = []

        for algo in algorithms:

            col = f"FCT(s)_{algo}"

            if col not in df.columns:

                missing_algorithms.append(
                    col
                )

        if missing_algorithms:

            print(
                "ERROR: Missing algorithm columns:"
            )

            for col in missing_algorithms:

                print(
                    f"    {col}"
                )

            continue

        # ====================================================
        # REMOVE INVALID BASELINE FCT VALUES
        # ====================================================

        df = df[
            df[baseline_col] > 0
        ].copy()

        if df.empty:

            print(
                "No valid flows after removing "
                "zero/negative ECMP FCT."
            )

            continue

        # ====================================================
        # FLOW SIZE SPLIT
        # ====================================================

        small_df = df[
            df["flow_size"] < SMALL
        ].copy()

        large_df = df[
            df["flow_size"] > LARGE
        ].copy()

        print(
            f"Small flows: {len(small_df):,}"
        )

        print(
            f"Large flows: {len(large_df):,}"
        )

        # ====================================================
        # BASELINE AVERAGES
        #
        # IMPORTANT:
        #
        # We calculate:
        #
        #     mean(FCT_algorithm)
        #     --------------------
        #     mean(FCT_ECMP)
        #
        # NOT:
        #
        #     mean(FCT_algorithm / FCT_ECMP)
        #
        # This makes the normalized graph consistent with
        # the Average FCT graph.
        # ====================================================

        # ----------------------------------------------------
        # SMALL FLOWS
        # ----------------------------------------------------

        if not small_df.empty:

            baseline_small_avg = (
                small_df[baseline_col].mean()
            )

        else:

            baseline_small_avg = np.nan

        # ----------------------------------------------------
        # LARGE FLOWS
        # ----------------------------------------------------

        if not large_df.empty:

            baseline_large_avg = (
                large_df[baseline_col].mean()
            )

        else:

            baseline_large_avg = np.nan

        # ====================================================
        # NORMALIZED RESULTS
        # ====================================================

        for algo in algorithms:

            algo_col = (
                f"FCT(s)_{algo}"
            )

            # ------------------------------------------------
            # SMALL FLOWS
            # ------------------------------------------------

            if (
                not small_df.empty
                and baseline_small_avg > 0
            ):

                algo_small_avg = (
                    small_df[algo_col].mean()
                )

                normalized_small = (
                    algo_small_avg /
                    baseline_small_avg
                )

                small_results[algo].append(
                    normalized_small
                )

            else:

                small_results[algo].append(
                    np.nan
                )

            # ------------------------------------------------
            # LARGE FLOWS
            # ------------------------------------------------

            if (
                not large_df.empty
                and baseline_large_avg > 0
            ):

                algo_large_avg = (
                    large_df[algo_col].mean()
                )

                normalized_large = (
                    algo_large_avg /
                    baseline_large_avg
                )

                large_results[algo].append(
                    normalized_large
                )

            else:

                large_results[algo].append(
                    np.nan
                )

        # ----------------------------------------------------
        # Store load
        # ----------------------------------------------------

        load_vals.append(
            load / 10
        )

        # ====================================================
        # PRINT NORMALIZED VALUES
        # ====================================================

        print()
        print(
            "Normalized Average FCT:"
        )

        if not small_df.empty:

            print(
                f"  Small flows "
                f"(ECMP avg = "
                f"{baseline_small_avg:.6f}s)"
            )

            for algo in algorithms:

                value = (
                    small_results[algo][-1]
                )

                print(
                    f"    {label_map[algo]:35s}: "
                    f"{value:.4f}"
                )

        if not large_df.empty:

            print(
                f"  Large flows "
                f"(ECMP avg = "
                f"{baseline_large_avg:.6f}s)"
            )

            for algo in algorithms:

                value = (
                    large_results[algo][-1]
                )

                print(
                    f"    {label_map[algo]:35s}: "
                    f"{value:.4f}"
                )


    # ========================================================
    # STORE RESULTS
    # ========================================================

    summary_results[benchmark] = {

        "loads":
            load_vals,

        "small":
            small_results,

        "large":
            large_results
    }


    # ========================================================
    # SMALL FLOWS PLOT
    # ========================================================

    plt.figure(
        figsize=(10, 7),
        dpi=120
    )

    for algo in algorithms:

        plt.plot(

            load_vals,

            small_results[algo],

            marker=marker_map[algo],

            color=color_map[algo],

            linestyle=(
                "--"
                if algo.endswith("_false")
                else "-"
            ),

            linewidth=2,

            markersize=7,

            label=(
                f"{label_map[algo]} / ECMP"
            )
        )

    # --------------------------------------------------------
    # ECMP baseline
    # --------------------------------------------------------

    plt.axhline(
        y=1,
        linestyle="--",
        color="black",
        linewidth=1.5,
        label="ECMP baseline"
    )

    # --------------------------------------------------------
    # Labels
    # --------------------------------------------------------

    plt.xlabel(
        "Network Load"
    )

    plt.ylabel(
        "Normalized Average FCT"
    )

    plt.title(
        f"{benchmark}: "
        f"Small Flows (<100 KB)"
    )

    # --------------------------------------------------------
    # Y-axis
    # --------------------------------------------------------

    plt.ylim(
        0,
        1.8
    )

    plt.yticks(
        np.arange(
            0,
            1.81,
            0.2
        )
    )

    # --------------------------------------------------------
    # Grid
    # --------------------------------------------------------

    plt.grid(
        True,
        alpha=0.3
    )

    plt.legend()

    plt.tight_layout()

    out_path = (
        graph_dir /
        f"{benchmark}_SMALL_relative_vs_load.png"
    )

    plt.savefig(
        out_path,
        dpi=300,
        bbox_inches="tight"
    )

    plt.close()

    print()
    print(
        f"Saved: {out_path}"
    )


    # ========================================================
    # LARGE FLOWS PLOT
    # ========================================================

    plt.figure(
        figsize=(10, 7),
        dpi=120
    )

    for algo in algorithms:

        plt.plot(

            load_vals,

            large_results[algo],

            marker=marker_map[algo],

            color=color_map[algo],

            linestyle=(
                "--"
                if algo.endswith("_false")
                else "-"
            ),

            linewidth=2,

            markersize=7,

            label=(
                f"{label_map[algo]} / ECMP"
            )
        )

    # --------------------------------------------------------
    # ECMP baseline
    # --------------------------------------------------------

    plt.axhline(
        y=1,
        linestyle="--",
        color="black",
        linewidth=1.5,
        label="ECMP baseline"
    )

    # --------------------------------------------------------
    # Labels
    # --------------------------------------------------------

    plt.xlabel(
        "Network Load"
    )

    plt.ylabel(
        "Normalized Average FCT"
    )

    plt.title(
        f"{benchmark}: "
        f"Large Flows (>1 MB)"
    )

    # --------------------------------------------------------
    # Y-axis
    # --------------------------------------------------------

    plt.ylim(
        0,
        1.4
    )

    plt.yticks(
        np.arange(
            0,
            1.41,
            0.2
        )
    )

    # --------------------------------------------------------
    # Grid
    # --------------------------------------------------------

    plt.grid(
        True,
        alpha=0.3
    )

    plt.legend()

    plt.tight_layout()

    out_path = (
        graph_dir /
        f"{benchmark}_LARGE_relative_vs_load.png"
    )

    plt.savefig(
        out_path,
        dpi=300,
        bbox_inches="tight"
    )

    plt.close()

    print(
        f"Saved: {out_path}"
    )


# ============================================================
# DONE
# ============================================================

print()
print("=" * 80)
print(
    "DONE: Normalized Average FCT graphs generated."
)
print("=" * 80)
# Out:
# ================================================================================
# BENCHMARK: private_enterprise
# ================================================================================
#
# Processing private_enterprise | Load 0.1
# Small flows: 5,790
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.005472s)
#     Conga                              : 0.7874
#     Weighted ECMP (Timeout)            : 0.8116
#     Weighted ECMP (No Timeout)         : 0.7450
#     Power-of-2 Random (Timeout)        : 0.8561
#     Power-of-2 Random (No Timeout)     : 0.7060
#   Large flows (ECMP avg = 0.289691s)
#     Conga                              : 0.9180
#     Weighted ECMP (Timeout)            : 0.9383
#     Weighted ECMP (No Timeout)         : 0.9551
#     Power-of-2 Random (Timeout)        : 0.9702
#     Power-of-2 Random (No Timeout)     : 0.9554
#
# Processing private_enterprise | Load 0.2
# Small flows: 5,790
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.008773s)
#     Conga                              : 0.7259
#     Weighted ECMP (Timeout)            : 0.7671
#     Weighted ECMP (No Timeout)         : 0.5531
#     Power-of-2 Random (Timeout)        : 0.7560
#     Power-of-2 Random (No Timeout)     : 0.5961
#   Large flows (ECMP avg = 0.324376s)
#     Conga                              : 0.8413
#     Weighted ECMP (Timeout)            : 0.8991
#     Weighted ECMP (No Timeout)         : 0.8946
#     Power-of-2 Random (Timeout)        : 0.8764
#     Power-of-2 Random (No Timeout)     : 0.8928
#
# Processing private_enterprise | Load 0.3
# Small flows: 5,790
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.014674s)
#     Conga                              : 0.5801
#     Weighted ECMP (Timeout)            : 0.5866
#     Weighted ECMP (No Timeout)         : 0.4171
#     Power-of-2 Random (Timeout)        : 0.6021
#     Power-of-2 Random (No Timeout)     : 0.4075
#   Large flows (ECMP avg = 0.391737s)
#     Conga                              : 0.7733
#     Weighted ECMP (Timeout)            : 0.8790
#     Weighted ECMP (No Timeout)         : 0.8775
#     Power-of-2 Random (Timeout)        : 0.8590
#     Power-of-2 Random (No Timeout)     : 0.8861
#
# Processing private_enterprise | Load 0.4
# Small flows: 5,790
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.028018s)
#     Conga                              : 0.4005
#     Weighted ECMP (Timeout)            : 0.3763
#     Weighted ECMP (No Timeout)         : 0.2402
#     Power-of-2 Random (Timeout)        : 0.4038
#     Power-of-2 Random (No Timeout)     : 0.2517
#   Large flows (ECMP avg = 0.553583s)
#     Conga                              : 0.7196
#     Weighted ECMP (Timeout)            : 1.0086
#     Weighted ECMP (No Timeout)         : 0.8360
#     Power-of-2 Random (Timeout)        : 0.9660
#     Power-of-2 Random (No Timeout)     : 0.8566
#
# Processing private_enterprise | Load 0.5
# Small flows: 5,790
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.054398s)
#     Conga                              : 0.2536
#     Weighted ECMP (Timeout)            : 0.2272
#     Weighted ECMP (No Timeout)         : 0.1447
#     Power-of-2 Random (Timeout)        : 0.2287
#     Power-of-2 Random (No Timeout)     : 0.1516
#   Large flows (ECMP avg = 0.644232s)
#     Conga                              : 0.8974
#     Weighted ECMP (Timeout)            : 1.0893
#     Weighted ECMP (No Timeout)         : 0.9131
#     Power-of-2 Random (Timeout)        : 1.1224
#     Power-of-2 Random (No Timeout)     : 0.9158
#
# Processing private_enterprise | Load 0.6
# Small flows: 5,790
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.057207s)
#     Conga                              : 0.2832
#     Weighted ECMP (Timeout)            : 0.2367
#     Weighted ECMP (No Timeout)         : 0.1515
#     Power-of-2 Random (Timeout)        : 0.2548
#     Power-of-2 Random (No Timeout)     : 0.1652
#   Large flows (ECMP avg = 0.737025s)
#     Conga                              : 0.9949
#     Weighted ECMP (Timeout)            : 1.1912
#     Weighted ECMP (No Timeout)         : 0.9642
#     Power-of-2 Random (Timeout)        : 1.2222
#     Power-of-2 Random (No Timeout)     : 0.9770
#
# Processing private_enterprise | Load 0.7
# Small flows: 5,790
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.065824s)
#     Conga                              : 0.3613
#     Weighted ECMP (Timeout)            : 0.2619
#     Weighted ECMP (No Timeout)         : 0.1591
#     Power-of-2 Random (Timeout)        : 0.2756
#     Power-of-2 Random (No Timeout)     : 0.1670
#   Large flows (ECMP avg = 0.965000s)
#     Conga                              : 0.9946
#     Weighted ECMP (Timeout)            : 1.1776
#     Weighted ECMP (No Timeout)         : 0.8822
#     Power-of-2 Random (Timeout)        : 1.2768
#     Power-of-2 Random (No Timeout)     : 0.8857
#
# Processing private_enterprise | Load 0.8
# Small flows: 5,790
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.077125s)
#     Conga                              : 0.4319
#     Weighted ECMP (Timeout)            : 0.3031
#     Weighted ECMP (No Timeout)         : 0.1857
#     Power-of-2 Random (Timeout)        : 0.3158
#     Power-of-2 Random (No Timeout)     : 0.1771
#   Large flows (ECMP avg = 1.480459s)
#     Conga                              : 0.9132
#     Weighted ECMP (Timeout)            : 1.1072
#     Weighted ECMP (No Timeout)         : 0.7757
#     Power-of-2 Random (Timeout)        : 1.1798
#     Power-of-2 Random (No Timeout)     : 0.7572
#
# Processing private_enterprise | Load 0.9
# Small flows: 5,790
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.073537s)
#     Conga                              : 0.4732
#     Weighted ECMP (Timeout)            : 0.3344
#     Weighted ECMP (No Timeout)         : 0.2106
#     Power-of-2 Random (Timeout)        : 0.3334
#     Power-of-2 Random (No Timeout)     : 0.2262
#   Large flows (ECMP avg = 1.541697s)
#     Conga                              : 1.1749
#     Weighted ECMP (Timeout)            : 1.2781
#     Weighted ECMP (No Timeout)         : 0.8352
#     Power-of-2 Random (Timeout)        : 1.2455
#     Power-of-2 Random (No Timeout)     : 0.8887
#
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/graph/normalised_vs_ecmp/private_enterprise_SMALL_relative_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/graph/normalised_vs_ecmp/private_enterprise_LARGE_relative_vs_load.png
#
# ================================================================================
# BENCHMARK: social_media_cloud
# ================================================================================
#
# Processing social_media_cloud | Load 0.1
# Small flows: 5,369
# Large flows: 2
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.006522s)
#     Conga                              : 0.8220
#     Weighted ECMP (Timeout)            : 0.9072
#     Weighted ECMP (No Timeout)         : 0.8249
#     Power-of-2 Random (Timeout)        : 0.9281
#     Power-of-2 Random (No Timeout)     : 0.8269
#   Large flows (ECMP avg = 0.179887s)
#     Conga                              : 0.8472
#     Weighted ECMP (Timeout)            : 0.9719
#     Weighted ECMP (No Timeout)         : 0.9285
#     Power-of-2 Random (Timeout)        : 0.8554
#     Power-of-2 Random (No Timeout)     : 0.8726
#
# Processing social_media_cloud | Load 0.2
# Small flows: 5,369
# Large flows: 2
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.010429s)
#     Conga                              : 0.7948
#     Weighted ECMP (Timeout)            : 0.8922
#     Weighted ECMP (No Timeout)         : 0.7479
#     Power-of-2 Random (Timeout)        : 0.9271
#     Power-of-2 Random (No Timeout)     : 0.7580
#   Large flows (ECMP avg = 0.208489s)
#     Conga                              : 1.1289
#     Weighted ECMP (Timeout)            : 1.2494
#     Weighted ECMP (No Timeout)         : 1.1707
#     Power-of-2 Random (Timeout)        : 1.1905
#     Power-of-2 Random (No Timeout)     : 1.1729
#
# Processing social_media_cloud | Load 0.3
# Small flows: 5,369
# Large flows: 2
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.014788s)
#     Conga                              : 0.8138
#     Weighted ECMP (Timeout)            : 0.9063
#     Weighted ECMP (No Timeout)         : 0.6762
#     Power-of-2 Random (Timeout)        : 0.9318
#     Power-of-2 Random (No Timeout)     : 0.6872
#   Large flows (ECMP avg = 0.281220s)
#     Conga                              : 0.9174
#     Weighted ECMP (Timeout)            : 1.0820
#     Weighted ECMP (No Timeout)         : 0.9820
#     Power-of-2 Random (Timeout)        : 1.0233
#     Power-of-2 Random (No Timeout)     : 0.9800
#
# Processing social_media_cloud | Load 0.4
# Small flows: 5,369
# Large flows: 2
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.021368s)
#     Conga                              : 0.7869
#     Weighted ECMP (Timeout)            : 0.9054
#     Weighted ECMP (No Timeout)         : 0.6319
#     Power-of-2 Random (Timeout)        : 0.9199
#     Power-of-2 Random (No Timeout)     : 0.6196
#   Large flows (ECMP avg = 0.275008s)
#     Conga                              : 1.0102
#     Weighted ECMP (Timeout)            : 1.2910
#     Weighted ECMP (No Timeout)         : 1.0892
#     Power-of-2 Random (Timeout)        : 1.3492
#     Power-of-2 Random (No Timeout)     : 1.1176
#
# Processing social_media_cloud | Load 0.5
# Small flows: 5,369
# Large flows: 2
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.029366s)
#     Conga                              : 0.8037
#     Weighted ECMP (Timeout)            : 0.9049
#     Weighted ECMP (No Timeout)         : 0.5686
#     Power-of-2 Random (Timeout)        : 0.8903
#     Power-of-2 Random (No Timeout)     : 0.5700
#   Large flows (ECMP avg = 0.365830s)
#     Conga                              : 1.2421
#     Weighted ECMP (Timeout)            : 2.0516
#     Weighted ECMP (No Timeout)         : 0.9855
#     Power-of-2 Random (Timeout)        : 1.7945
#     Power-of-2 Random (No Timeout)     : 0.9824
#
# Processing social_media_cloud | Load 0.6
# Small flows: 5,369
# Large flows: 2
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.085078s)
#     Conga                              : 0.4462
#     Weighted ECMP (Timeout)            : 0.5123
#     Weighted ECMP (No Timeout)         : 0.2625
#     Power-of-2 Random (Timeout)        : 0.4964
#     Power-of-2 Random (No Timeout)     : 0.2723
#   Large flows (ECMP avg = 0.517690s)
#     Conga                              : 1.6737
#     Weighted ECMP (Timeout)            : 2.6491
#     Weighted ECMP (No Timeout)         : 1.4860
#     Power-of-2 Random (Timeout)        : 2.1636
#     Power-of-2 Random (No Timeout)     : 1.3682
#
# Processing social_media_cloud | Load 0.7
# Small flows: 5,369
# Large flows: 2
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.129807s)
#     Conga                              : 0.6050
#     Weighted ECMP (Timeout)            : 1.1765
#     Weighted ECMP (No Timeout)         : 0.4752
#     Power-of-2 Random (Timeout)        : 1.1147
#     Power-of-2 Random (No Timeout)     : 0.3371
#   Large flows (ECMP avg = 0.484286s)
#     Conga                              : 3.5818
#     Weighted ECMP (Timeout)            : 7.6487
#     Weighted ECMP (No Timeout)         : 2.0674
#     Power-of-2 Random (Timeout)        : 8.1006
#     Power-of-2 Random (No Timeout)     : 2.3185
#
# Processing social_media_cloud | Load 0.8
# Small flows: 5,369
# Large flows: 2
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.351830s)
#     Conga                              : 0.7878
#     Weighted ECMP (Timeout)            : 1.4264
#     Weighted ECMP (No Timeout)         : 0.3202
#     Power-of-2 Random (Timeout)        : 1.5764
#     Power-of-2 Random (No Timeout)     : 0.3247
#   Large flows (ECMP avg = 1.646168s)
#     Conga                              : 2.7497
#     Weighted ECMP (Timeout)            : 3.1043
#     Weighted ECMP (No Timeout)         : 2.3365
#     Power-of-2 Random (Timeout)        : 3.1481
#     Power-of-2 Random (No Timeout)     : 1.5377
#
# Processing social_media_cloud | Load 0.9
# Small flows: 5,369
# Large flows: 2
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.530711s)
#     Conga                              : 0.7856
#     Weighted ECMP (Timeout)            : 1.4924
#     Weighted ECMP (No Timeout)         : 0.5530
#     Power-of-2 Random (Timeout)        : 1.6369
#     Power-of-2 Random (No Timeout)     : 0.5114
#   Large flows (ECMP avg = 9.113905s)
#     Conga                              : 0.5295
#     Weighted ECMP (Timeout)            : 0.5414
#     Weighted ECMP (No Timeout)         : 0.5304
#     Power-of-2 Random (Timeout)        : 0.5423
#     Power-of-2 Random (No Timeout)     : 0.5374
#
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/graph/normalised_vs_ecmp/social_media_cloud_SMALL_relative_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/graph/normalised_vs_ecmp/social_media_cloud_LARGE_relative_vs_load.png
#
# ================================================================================
# BENCHMARK: commercial_cloud
# ================================================================================
#
# Processing commercial_cloud | Load 0.1
# Small flows: 5,798
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.005588s)
#     Conga                              : 0.6935
#     Weighted ECMP (Timeout)            : 0.8016
#     Weighted ECMP (No Timeout)         : 0.6612
#     Power-of-2 Random (Timeout)        : 0.7856
#     Power-of-2 Random (No Timeout)     : 0.6412
#   Large flows (ECMP avg = 0.376213s)
#     Conga                              : 0.9485
#     Weighted ECMP (Timeout)            : 0.9765
#     Weighted ECMP (No Timeout)         : 0.9898
#     Power-of-2 Random (Timeout)        : 0.9849
#     Power-of-2 Random (No Timeout)     : 0.9906
#
# Processing commercial_cloud | Load 0.2
# Small flows: 5,798
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.010034s)
#     Conga                              : 0.6131
#     Weighted ECMP (Timeout)            : 0.7251
#     Weighted ECMP (No Timeout)         : 0.5283
#     Power-of-2 Random (Timeout)        : 0.7091
#     Power-of-2 Random (No Timeout)     : 0.5415
#   Large flows (ECMP avg = 0.398990s)
#     Conga                              : 0.9453
#     Weighted ECMP (Timeout)            : 1.0079
#     Weighted ECMP (No Timeout)         : 0.9993
#     Power-of-2 Random (Timeout)        : 1.0586
#     Power-of-2 Random (No Timeout)     : 1.0056
#
# Processing commercial_cloud | Load 0.3
# Small flows: 5,798
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.015918s)
#     Conga                              : 0.5567
#     Weighted ECMP (Timeout)            : 0.6191
#     Weighted ECMP (No Timeout)         : 0.4210
#     Power-of-2 Random (Timeout)        : 0.5808
#     Power-of-2 Random (No Timeout)     : 0.4425
#   Large flows (ECMP avg = 0.477677s)
#     Conga                              : 0.9565
#     Weighted ECMP (Timeout)            : 0.9893
#     Weighted ECMP (No Timeout)         : 1.0194
#     Power-of-2 Random (Timeout)        : 0.9616
#     Power-of-2 Random (No Timeout)     : 1.0454
#
# Processing commercial_cloud | Load 0.4
# Small flows: 5,798
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.020954s)
#     Conga                              : 0.5232
#     Weighted ECMP (Timeout)            : 0.5560
#     Weighted ECMP (No Timeout)         : 0.3681
#     Power-of-2 Random (Timeout)        : 0.6002
#     Power-of-2 Random (No Timeout)     : 0.3707
#   Large flows (ECMP avg = 0.561449s)
#     Conga                              : 0.9045
#     Weighted ECMP (Timeout)            : 1.1541
#     Weighted ECMP (No Timeout)         : 1.0223
#     Power-of-2 Random (Timeout)        : 1.2484
#     Power-of-2 Random (No Timeout)     : 1.0365
#
# Processing commercial_cloud | Load 0.5
# Small flows: 5,798
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.029684s)
#     Conga                              : 0.5188
#     Weighted ECMP (Timeout)            : 0.4845
#     Weighted ECMP (No Timeout)         : 0.3109
#     Power-of-2 Random (Timeout)        : 0.5020
#     Power-of-2 Random (No Timeout)     : 0.2909
#   Large flows (ECMP avg = 0.688864s)
#     Conga                              : 0.8876
#     Weighted ECMP (Timeout)            : 1.2365
#     Weighted ECMP (No Timeout)         : 1.1280
#     Power-of-2 Random (Timeout)        : 1.1740
#     Power-of-2 Random (No Timeout)     : 1.0905
#
# Processing commercial_cloud | Load 0.6
# Small flows: 5,798
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.037502s)
#     Conga                              : 0.4871
#     Weighted ECMP (Timeout)            : 0.5161
#     Weighted ECMP (No Timeout)         : 0.2604
#     Power-of-2 Random (Timeout)        : 0.4611
#     Power-of-2 Random (No Timeout)     : 0.2860
#   Large flows (ECMP avg = 0.784705s)
#     Conga                              : 1.1069
#     Weighted ECMP (Timeout)            : 1.4557
#     Weighted ECMP (No Timeout)         : 1.0828
#     Power-of-2 Random (Timeout)        : 1.3081
#     Power-of-2 Random (No Timeout)     : 1.1010
#
# Processing commercial_cloud | Load 0.7
# Small flows: 5,798
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.064071s)
#     Conga                              : 0.3958
#     Weighted ECMP (Timeout)            : 0.3545
#     Weighted ECMP (No Timeout)         : 0.2037
#     Power-of-2 Random (Timeout)        : 0.3165
#     Power-of-2 Random (No Timeout)     : 0.2196
#   Large flows (ECMP avg = 0.959084s)
#     Conga                              : 0.9312
#     Weighted ECMP (Timeout)            : 1.3209
#     Weighted ECMP (No Timeout)         : 1.0375
#     Power-of-2 Random (Timeout)        : 1.2904
#     Power-of-2 Random (No Timeout)     : 1.0112
#
# Processing commercial_cloud | Load 0.8
# Small flows: 5,798
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.060728s)
#     Conga                              : 0.5320
#     Weighted ECMP (Timeout)            : 0.4106
#     Weighted ECMP (No Timeout)         : 0.2785
#     Power-of-2 Random (Timeout)        : 0.4116
#     Power-of-2 Random (No Timeout)     : 0.2779
#   Large flows (ECMP avg = 1.483585s)
#     Conga                              : 1.0623
#     Weighted ECMP (Timeout)            : 1.2070
#     Weighted ECMP (No Timeout)         : 0.9017
#     Power-of-2 Random (Timeout)        : 1.2202
#     Power-of-2 Random (No Timeout)     : 0.9099
#
# Processing commercial_cloud | Load 0.9
# Small flows: 5,798
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.066273s)
#     Conga                              : 0.5174
#     Weighted ECMP (Timeout)            : 0.4100
#     Weighted ECMP (No Timeout)         : 0.2973
#     Power-of-2 Random (Timeout)        : 0.4402
#     Power-of-2 Random (No Timeout)     : 0.2860
#   Large flows (ECMP avg = 1.289221s)
#     Conga                              : 1.2402
#     Weighted ECMP (Timeout)            : 1.4871
#     Weighted ECMP (No Timeout)         : 1.1582
#     Power-of-2 Random (Timeout)        : 1.5691
#     Power-of-2 Random (No Timeout)     : 1.2226
#
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/graph/normalised_vs_ecmp/commercial_cloud_SMALL_relative_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/graph/normalised_vs_ecmp/commercial_cloud_LARGE_relative_vs_load.png
#
# ================================================================================
# BENCHMARK: university
# ================================================================================
#
# Processing university | Load 0.1
# Small flows: 5,786
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.003875s)
#     Conga                              : 0.7329
#     Weighted ECMP (Timeout)            : 0.7793
#     Weighted ECMP (No Timeout)         : 0.7005
#     Power-of-2 Random (Timeout)        : 0.7765
#     Power-of-2 Random (No Timeout)     : 0.7110
#   Large flows (ECMP avg = 0.248838s)
#     Conga                              : 0.8884
#     Weighted ECMP (Timeout)            : 0.8936
#     Weighted ECMP (No Timeout)         : 0.9189
#     Power-of-2 Random (Timeout)        : 0.8999
#     Power-of-2 Random (No Timeout)     : 0.9183
#
# Processing university | Load 0.2
# Small flows: 5,786
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.007485s)
#     Conga                              : 0.6511
#     Weighted ECMP (Timeout)            : 0.7080
#     Weighted ECMP (No Timeout)         : 0.5756
#     Power-of-2 Random (Timeout)        : 0.7082
#     Power-of-2 Random (No Timeout)     : 0.5882
#   Large flows (ECMP avg = 0.274630s)
#     Conga                              : 0.8435
#     Weighted ECMP (Timeout)            : 0.8713
#     Weighted ECMP (No Timeout)         : 0.9291
#     Power-of-2 Random (Timeout)        : 0.8799
#     Power-of-2 Random (No Timeout)     : 0.9167
#
# Processing university | Load 0.3
# Small flows: 5,786
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.011896s)
#     Conga                              : 0.5835
#     Weighted ECMP (Timeout)            : 0.6339
#     Weighted ECMP (No Timeout)         : 0.4816
#     Power-of-2 Random (Timeout)        : 0.6270
#     Power-of-2 Random (No Timeout)     : 0.4894
#   Large flows (ECMP avg = 0.333294s)
#     Conga                              : 0.7934
#     Weighted ECMP (Timeout)            : 0.8750
#     Weighted ECMP (No Timeout)         : 0.9204
#     Power-of-2 Random (Timeout)        : 0.8403
#     Power-of-2 Random (No Timeout)     : 0.8917
#
# Processing university | Load 0.4
# Small flows: 5,786
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.018238s)
#     Conga                              : 0.5429
#     Weighted ECMP (Timeout)            : 0.5522
#     Weighted ECMP (No Timeout)         : 0.3802
#     Power-of-2 Random (Timeout)        : 0.5201
#     Power-of-2 Random (No Timeout)     : 0.3763
#   Large flows (ECMP avg = 0.469689s)
#     Conga                              : 0.6896
#     Weighted ECMP (Timeout)            : 0.8255
#     Weighted ECMP (No Timeout)         : 0.7910
#     Power-of-2 Random (Timeout)        : 0.8166
#     Power-of-2 Random (No Timeout)     : 0.7683
#
# Processing university | Load 0.5
# Small flows: 5,786
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.028858s)
#     Conga                              : 0.4324
#     Weighted ECMP (Timeout)            : 0.4384
#     Weighted ECMP (No Timeout)         : 0.2481
#     Power-of-2 Random (Timeout)        : 0.4241
#     Power-of-2 Random (No Timeout)     : 0.2814
#   Large flows (ECMP avg = 0.638558s)
#     Conga                              : 0.6482
#     Weighted ECMP (Timeout)            : 1.0158
#     Weighted ECMP (No Timeout)         : 0.7333
#     Power-of-2 Random (Timeout)        : 0.9496
#     Power-of-2 Random (No Timeout)     : 0.7666
#
# Processing university | Load 0.6
# Small flows: 5,786
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.035606s)
#     Conga                              : 0.4185
#     Weighted ECMP (Timeout)            : 0.4355
#     Weighted ECMP (No Timeout)         : 0.2671
#     Power-of-2 Random (Timeout)        : 0.4502
#     Power-of-2 Random (No Timeout)     : 0.2610
#   Large flows (ECMP avg = 0.656339s)
#     Conga                              : 0.9484
#     Weighted ECMP (Timeout)            : 1.3918
#     Weighted ECMP (No Timeout)         : 1.0261
#     Power-of-2 Random (Timeout)        : 1.2576
#     Power-of-2 Random (No Timeout)     : 0.9926
#
# Processing university | Load 0.7
# Small flows: 5,786
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.061605s)
#     Conga                              : 0.4018
#     Weighted ECMP (Timeout)            : 0.3078
#     Weighted ECMP (No Timeout)         : 0.1826
#     Power-of-2 Random (Timeout)        : 0.3346
#     Power-of-2 Random (No Timeout)     : 0.1827
#   Large flows (ECMP avg = 0.853482s)
#     Conga                              : 0.9710
#     Weighted ECMP (Timeout)            : 1.4901
#     Weighted ECMP (No Timeout)         : 0.9270
#     Power-of-2 Random (Timeout)        : 1.4211
#     Power-of-2 Random (No Timeout)     : 0.9703
#
# Processing university | Load 0.8
# Small flows: 5,786
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.068651s)
#     Conga                              : 0.4337
#     Weighted ECMP (Timeout)            : 0.4373
#     Weighted ECMP (No Timeout)         : 0.1997
#     Power-of-2 Random (Timeout)        : 0.4250
#     Power-of-2 Random (No Timeout)     : 0.2299
#   Large flows (ECMP avg = 1.240322s)
#     Conga                              : 1.0769
#     Weighted ECMP (Timeout)            : 1.5671
#     Weighted ECMP (No Timeout)         : 0.8345
#     Power-of-2 Random (Timeout)        : 1.4010
#     Power-of-2 Random (No Timeout)     : 0.8411
#
# Processing university | Load 0.9
# Small flows: 5,786
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.086516s)
#     Conga                              : 0.6168
#     Weighted ECMP (Timeout)            : 0.4875
#     Weighted ECMP (No Timeout)         : 0.2494
#     Power-of-2 Random (Timeout)        : 0.4119
#     Power-of-2 Random (No Timeout)     : 0.2586
#   Large flows (ECMP avg = 1.314835s)
#     Conga                              : 1.3637
#     Weighted ECMP (Timeout)            : 1.5443
#     Weighted ECMP (No Timeout)         : 1.0852
#     Power-of-2 Random (Timeout)        : 1.4474
#     Power-of-2 Random (No Timeout)     : 1.0983
#
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/graph/normalised_vs_ecmp/university_SMALL_relative_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_sym_8_hosts_v9(prob1)/analysis_results/graph/normalised_vs_ecmp/university_LARGE_relative_vs_load.png
#
# ================================================================================
# DONE: Normalized Average FCT graphs generated.
# ================================================================================
