# %%
import pandas as pd
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt


# ============================================================
# CONFIG
# ============================================================

benchmarks = [
    "private_enterprise",
    "social_media_cloud",
    "commercial_cloud",
    "university"
]

# benchmarks = [
#     "private_enterprise",
#     "social_media_cloud"
# ]

loads = range(1, 8)

# Input TrafPy flow files
input_dir = "/home/hsd/workspace/trafpy/examples/comparison_generator/8_hosts_v9(prob1)"

# CONGA / ECMP ns-3 outputs
conga_dir = "/home/hsd/workspace/ns-3.45/conga_asym_8_hosts_v9(prob1)"

# RTT ns-3 outputs
rtt_dir = "/home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)"

# Output directory
save_dir = "/home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results"

Path(save_dir).mkdir(
    parents=True,
    exist_ok=True
)


# ============================================================
# MATCHING CONFIG
# ============================================================

PORT_START = 10000
PORT_END = 50000

ip_pattern = r'^\d+\.\d+\.\d+\.\d+$'


# ============================================================
# FUNCTIONS
# ============================================================

def clean(df):
    """
    Keep only rows that contain valid IP addresses.
    """

    required = [
        "Src",
        "Dest"
    ]

    for col in required:

        if col not in df.columns:

            raise ValueError(
                f"Required column '{col}' not found."
            )

    return df[
        df["Src"].astype(str).str.match(
            ip_pattern,
            na=False
        )
        &
        df["Dest"].astype(str).str.match(
            ip_pattern,
            na=False
        )
    ].copy()


# ============================================================

def ip_to_node(ip):
    """
    Convert ns-3 server IP to input trace node ID.

    Leaf 0:
        10.1.1.2 -> 0
        10.1.1.4 -> 1
        10.1.1.6 -> 2
        10.1.1.8 -> 3

    Leaf 1:
        10.1.2.2 -> 4
        10.1.2.4 -> 5
        10.1.2.6 -> 6
        10.1.2.8 -> 7
    """

    parts = ip.split(".")

    subnet = int(parts[-2])
    host = int(parts[-1])

    base = (host // 2) - 1

    if subnet == 1:

        return base

    elif subnet == 2:

        return base + 4

    else:

        raise ValueError(
            f"Unexpected IP address: {ip}"
        )


# ============================================================

def add_time(df):
    """
    Convert ns-3 TimeFirstTxPacket to seconds.
    """

    df = df.copy()

    df["start_time"] = (
        df["TimeFirstTxPacket"]
        .astype(str)
        .str.replace("+", "", regex=False)
        .str.replace("ns", "", regex=False)
        .astype(float)
        / 1e9
    )

    return df


# ============================================================

def expected_port(flow_index):
    """
    Reproduce the C++ destination-port calculation.

        port = PORT_START + flow.index

    with wrapping after PORT_END.
    """

    port = PORT_START + int(flow_index)

    if port > PORT_END:

        port = port - (
            PORT_END - PORT_START
        )

    return port


# ============================================================
# FLOW COLUMNS
# ============================================================

flow_columns = [
    "FlowID",
    "Src",
    "Dest",
    "TimeFirstRxPacket",
    "TimeFirstTxPacket",
    "TimeLastRxPacket",
    "TimeLastTxPacket",
    "FCT(s)",
    "TxPackets",
    "RxPackets",
    "LostPackets",
    "LossRate",
    "PDR",
    "LossPercent",
    "TxBytes",
    "RxBytes",
    "Throughput(Kbps)",
    "MeanDelay(ms)",
    "Jitter(ms)",
    "HopCount"
]


# ============================================================
# MATCHING FUNCTION
# ============================================================

def match_df(output_df, input_df, label):
    """
    Match input TrafPy flows to ns-3 flows.

    Matching is based on:

        1. source node
        2. destination node
        3. destination port

    If multiple ns-3 flows have the same tuple, the candidate
    with the closest start time to the input event time is used.

    Time is NOT a hard matching criterion.
    """

    matches = []

    # --------------------------------------------------------
    # Make copies
    # --------------------------------------------------------

    output_df = output_df.copy()
    input_df = input_df.copy()

    # --------------------------------------------------------
    # Numeric conversion
    # --------------------------------------------------------

    for col in [
        "SrcPort",
        "DestPort",
        "TxPackets",
        "RxPackets",
        "TxBytes",
        "RxBytes",
        "start_time",
        "sn",
        "dn"
    ]:

        if col in output_df.columns:

            output_df[col] = pd.to_numeric(
                output_df[col],
                errors="coerce"
            )

    for col in [
        "sn",
        "dn",
        "index",
        "flow_size",
        "event_time"
    ]:

        input_df[col] = pd.to_numeric(
            input_df[col],
            errors="coerce"
        )

    # --------------------------------------------------------
    # Remove invalid rows
    # --------------------------------------------------------

    output_df = output_df.dropna(
        subset=[
            "SrcPort",
            "DestPort",
            "TxPackets",
            "RxPackets",
            "TxBytes",
            "RxBytes",
            "start_time",
            "sn",
            "dn"
        ]
    ).copy()

    input_df = input_df.dropna(
        subset=[
            "sn",
            "dn",
            "index",
            "flow_size",
            "event_time"
        ]
    ).copy()

    # --------------------------------------------------------
    # Sort input by event time
    # --------------------------------------------------------

    input_df = input_df.sort_values(
        "event_time"
    ).reset_index(
        drop=True
    )

    # --------------------------------------------------------
    # Create lookup key
    #
    # (source node, destination node, destination port)
    # --------------------------------------------------------

    output_df["_match_key"] = list(
        zip(
            output_df["sn"].astype(int),
            output_df["dn"].astype(int),
            output_df["DestPort"].astype(int)
        )
    )

    # --------------------------------------------------------
    # Group ns-3 flows by matching key
    # --------------------------------------------------------

    grouped = {
        key: group
        for key, group in output_df.groupby(
            "_match_key",
            sort=False
        )
    }

    # --------------------------------------------------------
    # Process every input flow
    # --------------------------------------------------------

    for _, in_row in input_df.iterrows():

        input_flow_id = in_row["flow_id"]

        input_index = int(
            in_row["index"]
        )

        input_src = int(
            in_row["sn"]
        )

        input_dst = int(
            in_row["dn"]
        )

        input_time = float(
            in_row["event_time"]
        )

        input_size = float(
            in_row["flow_size"]
        )

        # ----------------------------------------------------
        # Expected destination port
        # ----------------------------------------------------

        expected_dst_port = expected_port(
            input_index
        )

        # ----------------------------------------------------
        # Lookup
        # ----------------------------------------------------

        key = (
            input_src,
            input_dst,
            expected_dst_port
        )

        candidates = grouped.get(
            key
        )

        # ----------------------------------------------------
        # No matching ns-3 flow
        # ----------------------------------------------------

        if candidates is None or len(candidates) == 0:

            continue

        # ----------------------------------------------------
        # Find closest start time
        # ----------------------------------------------------

        if len(candidates) == 1:

            best = candidates.iloc[0]

            time_diff = abs(
                best["start_time"]
                - input_time
            )

        else:

            time_diffs = (
                candidates["start_time"]
                - input_time
            ).abs()

            best_index = time_diffs.idxmin()

            best = candidates.loc[
                best_index
            ]

            time_diff = time_diffs.loc[
                best_index
            ]

        # ----------------------------------------------------
        # Size difference
        # ----------------------------------------------------

        if input_size > 0:

            size_diff = (
                abs(
                    best["TxBytes"]
                    - input_size
                )
                /
                max(
                    input_size,
                    best["TxBytes"],
                    1
                )
            )

        else:

            size_diff = np.nan

        # ----------------------------------------------------
        # Combined result
        # ----------------------------------------------------

        combined = {

            "flow_id":
                input_flow_id,

            "sn":
                input_src,

            "dn":
                input_dst,

            "input_time":
                input_time,

            "flow_size":
                input_size,

            #"expected_dest_port":
            #    expected_dst_port,

            f"time_diff_{label}":
                time_diff,

            f"size_diff_{label}":
                size_diff,

            f"TxPackets_{label}":
                best["TxPackets"],

            f"RxPackets_{label}":
                best["RxPackets"],

            f"TxBytes_calc_{label}":
                best["TxPackets"] * 1400,

            f"RxBytes_calc_{label}":
                best["RxPackets"] * 1400
        }

        # ----------------------------------------------------
        # Add all FlowMonitor columns
        # ----------------------------------------------------

        for col in flow_columns:

            combined[
                f"{col}_{label}"
            ] = best[col]

        matches.append(
            combined
        )

    return pd.DataFrame(
        matches
    )


# ============================================================
# AVERAGE FCT RESULTS FOR PLOTTING
# ============================================================

avg_fct_results = {
    benchmark: {}
    for benchmark in benchmarks
}



# ============================================================
# MAIN
# ============================================================



for benchmark in benchmarks:

    for load in loads:

        print()
        print(
            "=" * 80
        )

        print(
            f"{benchmark} | Load 0.{load}"
        )

        print(
            "=" * 80
        )

        # ====================================================
        # INPUT TRACE
        # ====================================================

        input_path = (
            f"{input_dir}/"
            f"{benchmark}_load_{load}.csv"
        )

        try:

            input_df = pd.read_csv(
                input_path
            )

            print(
                f"Input flows: "
                f"{len(input_df):,}"
            )

        except Exception as e:

            print(
                f"Could not read input: {e}"
            )

            continue

        # ====================================================
        # ALGORITHMS
        #
        # COMMENT / UNCOMMENT ANYTHING YOU WANT
        # ====================================================

        try:

            algorithms = {

                # ------------------------------------------------
                # CONGA
                # ------------------------------------------------

                "conga": pd.read_csv(
                    f"{conga_dir}/"
                    f"{benchmark}_load_{load}_Conga.csv",
                    nrows=12000
                ),

                # ------------------------------------------------
                # CONGA variants
                # ------------------------------------------------

                # "conga_new": pd.read_csv(
                #     f"{conga_dir}/"
                #     f"{benchmark}_load_{load}_Conga_new.csv",
                #     nrows=12000
                # ),

                # "conga-ecmp": pd.read_csv(
                #     f"{conga_dir}/"
                #     f"{benchmark}_load_{load}_Conga-ECMP_new.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # ECMP
                # ------------------------------------------------

                "ecmp": pd.read_csv(
                    f"{conga_dir}/"
                    f"{benchmark}_load_{load}_ECMP.csv",
                    nrows=12000
                ),

                # ------------------------------------------------
                # ECMP variants
                # ------------------------------------------------

                # "ecmp_new": pd.read_csv(
                #     f"{conga_dir}/"
                #     f"{benchmark}_load_{load}_ECMP_new.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # Basic RTT
                # ------------------------------------------------

                # "rtt": pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_RTT.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # Weighted ECMP
                # ------------------------------------------------

                # "weighted": pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_WEIGHTED_ECMP_RTT.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # Power-of-2 Random
                # ------------------------------------------------

                # "random": pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_POWER_OF_2_RANDOM_RTT.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # Power-of-2 Top2
                # ------------------------------------------------

                # "top2": pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_POWER_OF_2_TOP2_RTT.csv",
                #     nrows=12000
                # ),
            }

            # ====================================================
            # TIMEOUT VARIANTS
            # ====================================================

            timeout_values = [
                "true",
                "false"
            ]

            for timeout in timeout_values:

                # ------------------------------------------------
                # Weighted ECMP + timeout
                # ------------------------------------------------

                algorithms[
                    f"weighted_{timeout}"
                    ] = pd.read_csv(
                    f"{rtt_dir}/"
                    f"{benchmark}_load_{load}_"
                    f"WEIGHTED_ECMP_timeout_{timeout}_RTT.csv",
                    nrows=12000
                )

                # ------------------------------------------------
                # Lowest RTT + timeout
                # ------------------------------------------------

                #algorithms[
                #    f"lrtt_{timeout}"
                #] = pd.read_csv(
                #    f"{rtt_dir}/"
                #    f"{benchmark}_load_{load}_"
                #    f"LOWEST_RTT_timeout_{timeout}_RTT.csv",
                #    nrows=12000
                #)

                # ------------------------------------------------
                # Power-of-2 Random + timeout
                # ------------------------------------------------

                algorithms[
                     f"random_{timeout}"
                     ] = pd.read_csv(
                     f"{rtt_dir}/"
                     f"{benchmark}_load_{load}_"
                     f"POWER_OF_2_RANDOM_timeout_{timeout}_RTT.csv",
                     nrows=12000
                 )

                # ------------------------------------------------
                # Power-of-2 Top2 + timeout
                # ------------------------------------------------

                # algorithms[
                #     f"top2_{timeout}"
                # ] = pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_"
                #     f"POWER_OF_2_TOP2_timeout_{timeout}_RTT.csv",
                #     nrows=12000
                # )

        except Exception as e:

            print(
                "Skipping:",
                e
            )

            continue

        # ====================================================
        # CLEAN + PREPARE
        # ====================================================

        for label, df in algorithms.items():

            try:

                df = clean(
                    df
                )

                df = add_time(
                    df
                )

                df["sn"] = df["Src"].apply(
                    ip_to_node
                )

                df["dn"] = df["Dest"].apply(
                    ip_to_node
                )

                algorithms[label] = df

                print(
                    f"{label}: "
                    f"{len(df):,} IP flows"
                )

            except Exception as e:

                print(
                    f"ERROR processing "
                    f"{label}: {e}"
                )

                algorithms[label] = (
                    pd.DataFrame()
                )

        # ====================================================
        # MATCH
        # ====================================================

        matched = {}

        for label, df in algorithms.items():

            if df.empty:

                print(
                    f"Skipping matching for "
                    f"{label}: empty dataframe"
                )

                continue

            print(
                f"Matching {label}..."
            )

            matched[label] = match_df(
                df,
                input_df,
                label
            )

            print(
                f"{label}: "
                f"{len(matched[label]):,} matches"
            )

        # ====================================================
        # REMOVE EMPTY ALGORITHMS
        # ====================================================

        matched = {
            label: df
            for label, df in matched.items()
            if not df.empty
        }

        if len(matched) == 0:

            print(
                "No matches."
            )

            continue

        # ====================================================
        # MERGE RESULTS
        # ====================================================

        merge_keys = [
            "flow_id",
            "sn",
            "dn",
            "input_time",
            "flow_size"
        ]

        algorithms_list = list(
            matched.keys()
        )

        final_df = matched[
            algorithms_list[0]
        ]

        for algo in algorithms_list[1:]:

            final_df = pd.merge(
                final_df,
                matched[algo],
                on=merge_keys,
                how="inner"
            )

        # ====================================================
        # CHECK RESULT
        # ====================================================

        if len(final_df) == 0:

            print(
                "No common matches across "
                "the selected algorithms."
            )

            continue

        print()
        print(
            f"Final matched flows: "
            f"{len(final_df):,}"
        )


        # ============================================================
        # MATCHING TIME-DIFFERENCE SANITY CHECK
        # ============================================================
        
        print("\n" + "=" * 80)
        print("MATCHING TIME-DIFFERENCE CHECK")
        print("=" * 80)
        
        for algo in algorithms:
        
            col = f"time_diff_{algo}"
        
            if col not in final_df.columns:
                continue
        
            max_diff = final_df[col].max()
            mean_diff = final_df[col].mean()
            p95_diff = final_df[col].quantile(0.95)
            p99_diff = final_df[col].quantile(0.99)
        
            max_idx = final_df[col].idxmax()
            worst = final_df.loc[max_idx]
        
            print(f"\n{algo}")
            print(f"  Maximum : {max_diff:.9f} s "
                  f"({max_diff * 1000:.6f} ms)")
            print(f"  Mean    : {mean_diff:.9f} s "
                  f"({mean_diff * 1000:.6f} ms)")
            print(f"  P95     : {p95_diff:.9f} s "
                  f"({p95_diff * 1000:.6f} ms)")
            print(f"  P99     : {p99_diff:.9f} s "
                  f"({p99_diff * 1000:.6f} ms)")
        
            print(f"  Worst matching flow:")
            print(f"    flow_id     : {worst['flow_id']}")
            print(f"    sn          : {worst['sn']}")
            print(f"    dn          : {worst['dn']}")
            print(f"    input_time  : {worst['input_time']:.9f} s")
            print(f"    time_diff   : {worst[col]:.9f} s")

        
        # ====================================================
        # DIFFERENCES
        # ====================================================

        reference = "ecmp"

        if reference in matched:

            for algo in algorithms:

                if algo == reference:
                    continue

                if (
                    f"FCT(s)_{reference}" in final_df.columns
                    and
                    f"FCT(s)_{algo}" in final_df.columns
                ):

                    final_df[
                        f"fct_diff_{reference}_{algo}"
                    ] = (
                        final_df[
                            f"FCT(s)_{reference}"
                        ]
                        -
                        final_df[
                            f"FCT(s)_{algo}"
                        ]
                    )

        # ====================================================
        # SAVE
        # ====================================================

        csv_path = (
            f"{save_dir}/"
            f"{benchmark}_load_{load}_full.csv"
        )

        final_df.to_csv(
            csv_path,
            index=False
        )

        print(
            f"Saved: {csv_path}"
        )

        # ====================================================
        # STATS
        # ====================================================

        print()
        print(
            "-" * 80
        )

        print(
            f"Statistics: "
            f"{benchmark} | Load 0.{load}"
        )

        print(
            "-" * 80
        )

        for algo in matched:

            column = (
                f"FCT(s)_{algo}"
            )

            if column not in final_df.columns:
                continue

            fct = final_df[column]

            avg_fct = fct.mean()

            # --------------------------------------------------------
            # Store average FCT for later plotting
            # --------------------------------------------------------
        
            avg_fct_results[benchmark].setdefault(algo,{})
        
            avg_fct_results[benchmark][algo][load] = avg_fct



            print(
                f"{algo:20s}"
                f"Avg: {fct.mean():.6f}  "
                f"P75: {fct.quantile(0.75):.6f}  "
                f"P90: {fct.quantile(0.90):.6f}  "
                f"P95: {fct.quantile(0.95):.6f}  "
                f"P99: {fct.quantile(0.99):.6f}"
            )


# ============================================================
# DONE
# ============================================================

# ============================================================
# AVERAGE FCT COMPARISON GRAPHS
# ============================================================

print()
print("=" * 80)
print("GENERATING AVERAGE FCT COMPARISON GRAPHS")
print("=" * 80)


for benchmark in benchmarks:

    benchmark_results = avg_fct_results.get(
        benchmark,
        {}
    )

    if not benchmark_results:

        print(
            f"No FCT results available for "
            f"{benchmark}"
        )

        continue

    # --------------------------------------------------------
    # Create figure
    # --------------------------------------------------------

    plt.figure(
        figsize=(10, 6)
    )

    # --------------------------------------------------------
    # Plot each algorithm
    # --------------------------------------------------------

    for algo, load_results in benchmark_results.items():

        if not load_results:
            continue

        x = sorted(
            load_results.keys()
        )

        y = [
            load_results[load]
            for load in x
        ]

        # Convert load 1..9 to 0.1..0.9
        x_values = [
            load / 10
            for load in x
        ]

        plt.plot(
            x_values,
            y,
            marker="o",
            linewidth=2,
            markersize=6,
            label=algo
        )

    # --------------------------------------------------------
    # Labels
    # --------------------------------------------------------

    plt.xlabel(
        "Load",
        fontsize=12
    )

    plt.ylabel(
        "Average FCT (s)",
        fontsize=12
    )

    plt.title(
        f"Average Flow Completion Time - {benchmark}",
        fontsize=14
    )

    # --------------------------------------------------------
    # X-axis
    # --------------------------------------------------------

    plt.xticks(
        np.arange(
            0.1,
            0.8,
            0.1
        )
    )

    # --------------------------------------------------------
    # Grid
    # --------------------------------------------------------

    plt.grid(
        True,
        linestyle="--",
        alpha=0.5
    )

    # --------------------------------------------------------
    # Legend
    # --------------------------------------------------------

    plt.legend(
        fontsize=10
    )

    # --------------------------------------------------------
    # Layout
    # --------------------------------------------------------

    plt.tight_layout()

    # --------------------------------------------------------
    # Save
    # --------------------------------------------------------

    # ============================================================
    # GRAPH OUTPUT DIRECTORIES
    # ============================================================
    
    graph_dir = Path(save_dir) / "graph"
    avg_graph_dir = graph_dir / "avg"
    
    avg_graph_dir.mkdir(
        parents=True,
        exist_ok=True
    )

    graph_path = (
        avg_graph_dir /
        f"{benchmark}_average_fct_comparison.png"
    )

    plt.savefig(
        graph_path,
        dpi=300,
        bbox_inches="tight"
    )

    plt.close()

    print(
        f"Saved graph: {graph_path}"
    )

print(
    "MATCHING COMPLETE"
)

print(
    "=" * 80
)
# Out:
# ================================================================================
# private_enterprise | Load 0.1
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_123
#     sn          : 6
#     dn          : 1
#     input_time  : 1.972790288 s
#     time_diff   : 0.000000000 s
#
# ecmp
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_123
#     sn          : 6
#     dn          : 1
#     input_time  : 1.972790288 s
#     time_diff   : 0.000000000 s
#
# weighted_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_123
#     sn          : 6
#     dn          : 1
#     input_time  : 1.972790288 s
#     time_diff   : 0.000000000 s
#
# random_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_123
#     sn          : 6
#     dn          : 1
#     input_time  : 1.972790288 s
#     time_diff   : 0.000000000 s
#
# weighted_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_123
#     sn          : 6
#     dn          : 1
#     input_time  : 1.972790288 s
#     time_diff   : 0.000000000 s
#
# random_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_123
#     sn          : 6
#     dn          : 1
#     input_time  : 1.972790288 s
#     time_diff   : 0.000000000 s
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/private_enterprise_load_1_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.1
# --------------------------------------------------------------------------------
# conga               Avg: 0.011250  P75: 0.009895  P90: 0.021710  P95: 0.033596  P99: 0.094053
# ecmp                Avg: 0.010851  P75: 0.008104  P90: 0.026810  P95: 0.046837  P99: 0.111305
# weighted_true       Avg: 0.010663  P75: 0.010094  P90: 0.018851  P95: 0.027535  P99: 0.095862
# random_true         Avg: 0.010946  P75: 0.008387  P90: 0.023565  P95: 0.036634  P99: 0.106451
# weighted_false      Avg: 0.013629  P75: 0.012231  P90: 0.037950  P95: 0.053004  P99: 0.119312
# random_false        Avg: 0.009720  P75: 0.008439  P90: 0.023701  P95: 0.039282  P99: 0.081881
#
# ================================================================================
# private_enterprise | Load 0.2
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 4.647064582 s
#     time_diff   : 0.000000000 s
#
# ecmp
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 4.647064582 s
#     time_diff   : 0.000000000 s
#
# weighted_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 4.647064582 s
#     time_diff   : 0.000000000 s
#
# random_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 4.647064582 s
#     time_diff   : 0.000000000 s
#
# weighted_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 4.647064582 s
#     time_diff   : 0.000000000 s
#
# random_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 4.647064582 s
#     time_diff   : 0.000000000 s
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/private_enterprise_load_2_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.2
# --------------------------------------------------------------------------------
# conga               Avg: 0.023815  P75: 0.019171  P90: 0.040848  P95: 0.062727  P99: 0.193358
# ecmp                Avg: 0.021761  P75: 0.018360  P90: 0.050316  P95: 0.076759  P99: 0.162444
# weighted_true       Avg: 0.022066  P75: 0.023075  P90: 0.039122  P95: 0.052647  P99: 0.148233
# random_true         Avg: 0.047002  P75: 0.037259  P90: 0.082452  P95: 0.116465  P99: 0.570829
# weighted_false      Avg: 0.031784  P75: 0.044316  P90: 0.070745  P95: 0.093151  P99: 0.172357
# random_false        Avg: 0.019900  P75: 0.024761  P90: 0.047676  P95: 0.066558  P99: 0.179789
#
# ================================================================================
# private_enterprise | Load 0.3
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_5196
#     sn          : 5
#     dn          : 7
#     input_time  : 10.031136835 s
#     time_diff   : 0.000000000 s
#
# ecmp
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_5196
#     sn          : 5
#     dn          : 7
#     input_time  : 10.031136835 s
#     time_diff   : 0.000000000 s
#
# weighted_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_5196
#     sn          : 5
#     dn          : 7
#     input_time  : 10.031136835 s
#     time_diff   : 0.000000000 s
#
# random_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_5196
#     sn          : 5
#     dn          : 7
#     input_time  : 10.031136835 s
#     time_diff   : 0.000000000 s
#
# weighted_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_5196
#     sn          : 5
#     dn          : 7
#     input_time  : 10.031136835 s
#     time_diff   : 0.000000000 s
#
# random_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_5196
#     sn          : 5
#     dn          : 7
#     input_time  : 10.031136835 s
#     time_diff   : 0.000000000 s
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/private_enterprise_load_3_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.3
# --------------------------------------------------------------------------------
# conga               Avg: 0.051556  P75: 0.045159  P90: 0.076839  P95: 0.100400  P99: 0.476852
# ecmp                Avg: 0.050695  P75: 0.038173  P90: 0.083053  P95: 0.111815  P99: 0.234295
# weighted_true       Avg: 0.037690  P75: 0.040184  P90: 0.064268  P95: 0.085778  P99: 0.223010
# random_true         Avg: 0.113337  P75: 0.066239  P90: 0.131657  P95: 0.266089  P99: 1.858361
# weighted_false      Avg: 0.101820  P75: 0.073933  P90: 0.104763  P95: 0.129140  P99: 0.667746
# random_false        Avg: 0.027217  P75: 0.039869  P90: 0.057698  P95: 0.074637  P99: 0.165515
#
# ================================================================================
# private_enterprise | Load 0.4
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3878
#     sn          : 0
#     dn          : 7
#     input_time  : 5.739248049 s
#     time_diff   : 0.000000000 s
#
# ecmp
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3878
#     sn          : 0
#     dn          : 7
#     input_time  : 5.739248049 s
#     time_diff   : 0.000000000 s
#
# weighted_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3878
#     sn          : 0
#     dn          : 7
#     input_time  : 5.739248049 s
#     time_diff   : 0.000000000 s
#
# random_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3878
#     sn          : 0
#     dn          : 7
#     input_time  : 5.739248049 s
#     time_diff   : 0.000000000 s
#
# weighted_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3878
#     sn          : 0
#     dn          : 7
#     input_time  : 5.739248049 s
#     time_diff   : 0.000000000 s
#
# random_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3878
#     sn          : 0
#     dn          : 7
#     input_time  : 5.739248049 s
#     time_diff   : 0.000000000 s
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/private_enterprise_load_4_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.4
# --------------------------------------------------------------------------------
# conga               Avg: 0.094555  P75: 0.058528  P90: 0.097626  P95: 0.164274  P99: 1.292296
# ecmp                Avg: 0.079767  P75: 0.069961  P90: 0.115575  P95: 0.148131  P99: 0.412997
# weighted_true       Avg: 0.113996  P75: 0.070804  P90: 0.098121  P95: 0.130769  P99: 1.009223
# random_true         Avg: 0.486561  P75: 0.131859  P90: 0.525410  P95: 3.040549  P99: 8.379051
# weighted_false      Avg: 0.261672  P75: 0.097604  P90: 0.137175  P95: 0.205300  P99: 8.171023
# random_false        Avg: 0.051502  P75: 0.067991  P90: 0.097561  P95: 0.114851  P99: 0.282800
#
# ================================================================================
# private_enterprise | Load 0.5
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3187
#     sn          : 7
#     dn          : 0
#     input_time  : 2.189944338 s
#     time_diff   : 0.000000000 s
#
# ecmp
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3187
#     sn          : 7
#     dn          : 0
#     input_time  : 2.189944338 s
#     time_diff   : 0.000000000 s
#
# weighted_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3187
#     sn          : 7
#     dn          : 0
#     input_time  : 2.189944338 s
#     time_diff   : 0.000000000 s
#
# random_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3187
#     sn          : 7
#     dn          : 0
#     input_time  : 2.189944338 s
#     time_diff   : 0.000000000 s
#
# weighted_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3187
#     sn          : 7
#     dn          : 0
#     input_time  : 2.189944338 s
#     time_diff   : 0.000000000 s
#
# random_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3187
#     sn          : 7
#     dn          : 0
#     input_time  : 2.189944338 s
#     time_diff   : 0.000000000 s
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/private_enterprise_load_5_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.5
# --------------------------------------------------------------------------------
# conga               Avg: 0.140834  P75: 0.073474  P90: 0.131033  P95: 0.312754  P99: 3.847314
# ecmp                Avg: 0.110725  P75: 0.083808  P90: 0.123048  P95: 0.161820  P99: 1.207314
# weighted_true       Avg: 0.225610  P75: 0.097895  P90: 0.146995  P95: 0.232664  P99: 6.653730
# random_true         Avg: 0.557749  P75: 0.132491  P90: 0.552126  P95: 4.569068  P99: 8.170628
# weighted_false      Avg: 0.208880  P75: 0.099975  P90: 0.143174  P95: 0.205922  P99: 7.220454
# random_false        Avg: 0.116720  P75: 0.078067  P90: 0.117547  P95: 0.148598  P99: 1.784556
#
# ================================================================================
# private_enterprise | Load 0.6
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 1.549021527 s
#     time_diff   : 0.000000000 s
#
# ecmp
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 1.549021527 s
#     time_diff   : 0.000000000 s
#
# weighted_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 1.549021527 s
#     time_diff   : 0.000000000 s
#
# random_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 1.549021527 s
#     time_diff   : 0.000000000 s
#
# weighted_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 1.549021527 s
#     time_diff   : 0.000000000 s
#
# random_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_2570
#     sn          : 1
#     dn          : 2
#     input_time  : 1.549021527 s
#     time_diff   : 0.000000000 s
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/private_enterprise_load_6_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.6
# --------------------------------------------------------------------------------
# conga               Avg: 0.176196  P75: 0.079601  P90: 0.187514  P95: 0.474466  P99: 4.803575
# ecmp                Avg: 0.174321  P75: 0.096909  P90: 0.147450  P95: 0.215925  P99: 4.983437
# weighted_true       Avg: 0.401521  P75: 0.137426  P90: 0.259331  P95: 3.634506  P99: 7.221056
# random_true         Avg: 0.511274  P75: 0.149590  P90: 0.928164  P95: 3.892352  P99: 7.162185
# weighted_false      Avg: 0.182022  P75: 0.107867  P90: 0.150452  P95: 0.218757  P99: 4.795369
# random_false        Avg: 0.100870  P75: 0.093561  P90: 0.119429  P95: 0.153241  P99: 0.736137
#
# ================================================================================
# private_enterprise | Load 0.7
# ================================================================================
# Input flows: 6,000
# Skipping: [Errno 2] No such file or directory: '/home/hsd/workspace/ns-3.45/conga_asym_8_hosts_v9(prob1)/private_enterprise_load_7_Conga.csv'
#
# ================================================================================
# social_media_cloud | Load 0.1
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_5687
#     sn          : 4
#     dn          : 3
#     input_time  : 27.332219054 s
#     time_diff   : 0.000000000 s
#
# ecmp
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_5687
#     sn          : 4
#     dn          : 3
#     input_time  : 27.332219054 s
#     time_diff   : 0.000000000 s
#
# weighted_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_5687
#     sn          : 4
#     dn          : 3
#     input_time  : 27.332219054 s
#     time_diff   : 0.000000000 s
#
# random_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_5687
#     sn          : 4
#     dn          : 3
#     input_time  : 27.332219054 s
#     time_diff   : 0.000000000 s
#
# weighted_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_5687
#     sn          : 4
#     dn          : 3
#     input_time  : 27.332219054 s
#     time_diff   : 0.000000000 s
#
# random_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_5687
#     sn          : 4
#     dn          : 3
#     input_time  : 27.332219054 s
#     time_diff   : 0.000000000 s
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/social_media_cloud_load_1_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.1
# --------------------------------------------------------------------------------
# conga               Avg: 0.017961  P75: 0.019635  P90: 0.044279  P95: 0.069822  P99: 0.149523
# ecmp                Avg: 0.014835  P75: 0.017458  P90: 0.039013  P95: 0.058074  P99: 0.115035
# weighted_true       Avg: 0.017117  P75: 0.020823  P90: 0.040025  P95: 0.058176  P99: 0.128498
# random_true         Avg: 0.018763  P75: 0.019049  P90: 0.045935  P95: 0.073857  P99: 0.179273
# weighted_false      Avg: 0.021026  P75: 0.026731  P90: 0.050114  P95: 0.070304  P99: 0.129478
# random_false        Avg: 0.014130  P75: 0.016943  P90: 0.035341  P95: 0.054130  P99: 0.106587
#
# ================================================================================
# social_media_cloud | Load 0.2
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3625
#     sn          : 6
#     dn          : 3
#     input_time  : 20.745795996 s
#     time_diff   : 0.000000000 s
#
# ecmp
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3625
#     sn          : 6
#     dn          : 3
#     input_time  : 20.745795996 s
#     time_diff   : 0.000000000 s
#
# weighted_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3625
#     sn          : 6
#     dn          : 3
#     input_time  : 20.745795996 s
#     time_diff   : 0.000000000 s
#
# random_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3625
#     sn          : 6
#     dn          : 3
#     input_time  : 20.745795996 s
#     time_diff   : 0.000000000 s
#
# weighted_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3625
#     sn          : 6
#     dn          : 3
#     input_time  : 20.745795996 s
#     time_diff   : 0.000000000 s
#
# random_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3625
#     sn          : 6
#     dn          : 3
#     input_time  : 20.745795996 s
#     time_diff   : 0.000000000 s
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/social_media_cloud_load_2_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.2
# --------------------------------------------------------------------------------
# conga               Avg: 0.046770  P75: 0.050859  P90: 0.101308  P95: 0.166126  P99: 0.467906
# ecmp                Avg: 0.034258  P75: 0.034063  P90: 0.071684  P95: 0.105198  P99: 0.198064
# weighted_true       Avg: 0.055283  P75: 0.048774  P90: 0.084079  P95: 0.117791  P99: 0.272820
# random_true         Avg: 0.382018  P75: 0.165730  P90: 0.543044  P95: 1.244272  P99: 9.120259
# weighted_false      Avg: 0.037914  P75: 0.050235  P90: 0.083488  P95: 0.115315  P99: 0.215995
# random_false        Avg: 0.032007  P75: 0.041193  P90: 0.078041  P95: 0.112349  P99: 0.226845
#
# ================================================================================
# social_media_cloud | Load 0.3
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3157
#     sn          : 0
#     dn          : 2
#     input_time  : 9.066886322 s
#     time_diff   : 0.000000000 s
#
# ecmp
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3157
#     sn          : 0
#     dn          : 2
#     input_time  : 9.066886322 s
#     time_diff   : 0.000000000 s
#
# weighted_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3157
#     sn          : 0
#     dn          : 2
#     input_time  : 9.066886322 s
#     time_diff   : 0.000000000 s
#
# random_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3157
#     sn          : 0
#     dn          : 2
#     input_time  : 9.066886322 s
#     time_diff   : 0.000000000 s
#
# weighted_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3157
#     sn          : 0
#     dn          : 2
#     input_time  : 9.066886322 s
#     time_diff   : 0.000000000 s
#
# random_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3157
#     sn          : 0
#     dn          : 2
#     input_time  : 9.066886322 s
#     time_diff   : 0.000000000 s
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/social_media_cloud_load_3_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.3
# --------------------------------------------------------------------------------
# conga               Avg: 0.350439  P75: 0.199961  P90: 0.710079  P95: 1.405194  P99: 6.859635
# ecmp                Avg: 0.106823  P75: 0.079830  P90: 0.139704  P95: 0.199309  P99: 0.649932
# weighted_true       Avg: 0.200532  P75: 0.098905  P90: 0.169159  P95: 0.257960  P99: 7.261391
# random_true         Avg: 1.776458  P75: 0.990305  P90: 7.615668  P95: 9.556816  P99: 16.543657
# weighted_false      Avg: 0.221544  P75: 0.096503  P90: 0.167330  P95: 0.240604  P99: 8.399651
# random_false        Avg: 0.065087  P75: 0.080195  P90: 0.131327  P95: 0.190156  P99: 0.424548
#
# ================================================================================
# social_media_cloud | Load 0.4
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 11,998 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_563
#     sn          : 3
#     dn          : 4
#     input_time  : 10.733189546 s
#     time_diff   : 0.000000000 s
#
# ecmp
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_563
#     sn          : 3
#     dn          : 4
#     input_time  : 10.733189546 s
#     time_diff   : 0.000000000 s
#
# weighted_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_563
#     sn          : 3
#     dn          : 4
#     input_time  : 10.733189546 s
#     time_diff   : 0.000000000 s
#
# random_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_563
#     sn          : 3
#     dn          : 4
#     input_time  : 10.733189546 s
#     time_diff   : 0.000000000 s
#
# weighted_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_563
#     sn          : 3
#     dn          : 4
#     input_time  : 10.733189546 s
#     time_diff   : 0.000000000 s
#
# random_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_563
#     sn          : 3
#     dn          : 4
#     input_time  : 10.733189546 s
#     time_diff   : 0.000000000 s
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/social_media_cloud_load_4_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.4
# --------------------------------------------------------------------------------
# conga               Avg: 0.737122  P75: 0.597656  P90: 1.890275  P95: 3.891161  P99: 9.499641
# ecmp                Avg: 0.459466  P75: 0.143168  P90: 0.362870  P95: 1.388643  P99: 10.830506
# weighted_true       Avg: 0.939159  P75: 0.267779  P90: 1.013154  P95: 8.928880  P99: 12.784405
# random_true         Avg: 2.249045  P75: 2.416723  P90: 8.227138  P95: 10.489362  P99: 14.060774
# weighted_false      Avg: 0.818935  P75: 0.169985  P90: 0.853081  P95: 7.814616  P99: 12.540129
# random_false        Avg: 0.120356  P75: 0.103952  P90: 0.159911  P95: 0.223495  P99: 0.597674
#
# ================================================================================
# social_media_cloud | Load 0.5
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 11,998 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_4091
#     sn          : 7
#     dn          : 0
#     input_time  : 3.137795818 s
#     time_diff   : 0.000000000 s
#
# ecmp
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_4091
#     sn          : 7
#     dn          : 0
#     input_time  : 3.137795818 s
#     time_diff   : 0.000000000 s
#
# weighted_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_4091
#     sn          : 7
#     dn          : 0
#     input_time  : 3.137795818 s
#     time_diff   : 0.000000000 s
#
# random_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_4091
#     sn          : 7
#     dn          : 0
#     input_time  : 3.137795818 s
#     time_diff   : 0.000000000 s
#
# weighted_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_4091
#     sn          : 7
#     dn          : 0
#     input_time  : 3.137795818 s
#     time_diff   : 0.000000000 s
#
# random_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_4091
#     sn          : 7
#     dn          : 0
#     input_time  : 3.137795818 s
#     time_diff   : 0.000000000 s
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/social_media_cloud_load_5_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.5
# --------------------------------------------------------------------------------
# conga               Avg: 0.985918  P75: 0.865424  P90: 2.921422  P95: 6.036589  P99: 9.346247
# ecmp                Avg: 1.129498  P75: 0.237244  P90: 5.053815  P95: 9.306045  P99: 11.780345
# weighted_true       Avg: 1.860494  P75: 0.670835  P90: 9.119236  P95: 10.449380  P99: 12.540656
# random_true         Avg: 3.658253  P75: 8.170436  P90: 10.442190  P95: 11.400348  P99: 13.249478
# weighted_false      Avg: 1.231698  P75: 0.222405  P90: 6.956513  P95: 9.880885  P99: 13.303058
# random_false        Avg: 0.401963  P75: 0.153372  P90: 0.286413  P95: 0.560992  P99: 10.640971
#
# ================================================================================
# social_media_cloud | Load 0.6
# ================================================================================
# Input flows: 6,000
# conga: 11,998 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 11,997 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_1723
#     sn          : 7
#     dn          : 1
#     input_time  : 3.237292805 s
#     time_diff   : 0.000000000 s
#
# ecmp
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_1723
#     sn          : 7
#     dn          : 1
#     input_time  : 3.237292805 s
#     time_diff   : 0.000000000 s
#
# weighted_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_1723
#     sn          : 7
#     dn          : 1
#     input_time  : 3.237292805 s
#     time_diff   : 0.000000000 s
#
# random_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_1723
#     sn          : 7
#     dn          : 1
#     input_time  : 3.237292805 s
#     time_diff   : 0.000000000 s
#
# weighted_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_1723
#     sn          : 7
#     dn          : 1
#     input_time  : 3.237292805 s
#     time_diff   : 0.000000000 s
#
# random_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_1723
#     sn          : 7
#     dn          : 1
#     input_time  : 3.237292805 s
#     time_diff   : 0.000000000 s
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/social_media_cloud_load_6_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.6
# --------------------------------------------------------------------------------
# conga               Avg: 1.166638  P75: 1.151788  P90: 4.119855  P95: 6.475596  P99: 9.192198
# ecmp                Avg: 1.510512  P75: 0.435192  P90: 7.411239  P95: 9.120490  P99: 11.020762
# weighted_true       Avg: 2.261018  P75: 2.702978  P90: 8.741690  P95: 10.070883  P99: 11.781166
# random_true         Avg: 2.266369  P75: 3.772435  P90: 7.469237  P95: 9.306864  P99: 11.589866
# weighted_false      Avg: 1.704362  P75: 0.520640  P90: 8.170119  P95: 9.500847  P99: 11.400816
# random_false        Avg: 0.936153  P75: 0.287933  P90: 1.492769  P95: 7.790873  P99: 11.020212
#
# ================================================================================
# social_media_cloud | Load 0.7
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 11,997 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3157
#     sn          : 0
#     dn          : 2
#     input_time  : 3.885808424 s
#     time_diff   : 0.000000000 s
#
# ecmp
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3157
#     sn          : 0
#     dn          : 2
#     input_time  : 3.885808424 s
#     time_diff   : 0.000000000 s
#
# weighted_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3157
#     sn          : 0
#     dn          : 2
#     input_time  : 3.885808424 s
#     time_diff   : 0.000000000 s
#
# random_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3157
#     sn          : 0
#     dn          : 2
#     input_time  : 3.885808424 s
#     time_diff   : 0.000000000 s
#
# weighted_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3157
#     sn          : 0
#     dn          : 2
#     input_time  : 3.885808424 s
#     time_diff   : 0.000000000 s
#
# random_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_3157
#     sn          : 0
# ...
# random_true         Avg: 0.123048  P75: 0.104085  P90: 0.130942  P95: 0.216977  P99: 1.548107
# weighted_false      Avg: 0.025763  P75: 0.034956  P90: 0.058478  P95: 0.074446  P99: 0.138345
# random_false        Avg: 0.026051  P75: 0.040171  P90: 0.057713  P95: 0.070157  P99: 0.133560
#
# ================================================================================
# university | Load 0.4
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_2467
#     sn          : 3
#     dn          : 4
#     input_time  : 4.532149631 s
#     time_diff   : 0.000000000 s
#
# ecmp
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_2467
#     sn          : 3
#     dn          : 4
#     input_time  : 4.532149631 s
#     time_diff   : 0.000000000 s
#
# weighted_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_2467
#     sn          : 3
#     dn          : 4
#     input_time  : 4.532149631 s
#     time_diff   : 0.000000000 s
#
# random_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_2467
#     sn          : 3
#     dn          : 4
#     input_time  : 4.532149631 s
#     time_diff   : 0.000000000 s
#
# weighted_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_2467
#     sn          : 3
#     dn          : 4
#     input_time  : 4.532149631 s
#     time_diff   : 0.000000000 s
#
# random_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_2467
#     sn          : 3
#     dn          : 4
#     input_time  : 4.532149631 s
#     time_diff   : 0.000000000 s
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/university_load_4_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.4
# --------------------------------------------------------------------------------
# conga               Avg: 0.083088  P75: 0.058423  P90: 0.090004  P95: 0.141925  P99: 1.149120
# ecmp                Avg: 0.099944  P75: 0.065772  P90: 0.102038  P95: 0.138254  P99: 0.556583
# weighted_true       Avg: 0.089414  P75: 0.071386  P90: 0.097520  P95: 0.118121  P99: 0.511165
# random_true         Avg: 0.594872  P75: 0.128559  P90: 0.595811  P95: 5.554252  P99: 8.360582
# weighted_false      Avg: 0.072672  P75: 0.073081  P90: 0.095659  P95: 0.114378  P99: 0.237943
# random_false        Avg: 0.055336  P75: 0.065247  P90: 0.089209  P95: 0.106535  P99: 0.378987
#
# ================================================================================
# university | Load 0.5
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_5123
#     sn          : 2
#     dn          : 7
#     input_time  : 1.035251575 s
#     time_diff   : 0.000000000 s
#
# ecmp
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_5123
#     sn          : 2
#     dn          : 7
#     input_time  : 1.035251575 s
#     time_diff   : 0.000000000 s
#
# weighted_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_5123
#     sn          : 2
#     dn          : 7
#     input_time  : 1.035251575 s
#     time_diff   : 0.000000000 s
#
# random_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_5123
#     sn          : 2
#     dn          : 7
#     input_time  : 1.035251575 s
#     time_diff   : 0.000000000 s
#
# weighted_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_5123
#     sn          : 2
#     dn          : 7
#     input_time  : 1.035251575 s
#     time_diff   : 0.000000000 s
#
# random_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_5123
#     sn          : 2
#     dn          : 7
#     input_time  : 1.035251575 s
#     time_diff   : 0.000000000 s
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/university_load_5_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.5
# --------------------------------------------------------------------------------
# conga               Avg: 0.145430  P75: 0.080435  P90: 0.146371  P95: 0.323223  P99: 3.385461
# ecmp                Avg: 0.153954  P75: 0.091402  P90: 0.132410  P95: 0.178668  P99: 4.904010
# weighted_true       Avg: 0.163739  P75: 0.101274  P90: 0.141118  P95: 0.195970  P99: 4.098051
# random_true         Avg: 0.487112  P75: 0.139574  P90: 0.718477  P95: 4.061244  P99: 6.839327
# weighted_false      Avg: 0.153038  P75: 0.098491  P90: 0.131702  P95: 0.166919  P99: 4.418779
# random_false        Avg: 0.069727  P75: 0.074638  P90: 0.096565  P95: 0.118525  P99: 0.268561
#
# ================================================================================
# university | Load 0.6
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_5653
#     sn          : 1
#     dn          : 6
#     input_time  : 2.951754511 s
#     time_diff   : 0.000000000 s
#
# ecmp
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_5653
#     sn          : 1
#     dn          : 6
#     input_time  : 2.951754511 s
#     time_diff   : 0.000000000 s
#
# weighted_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_5653
#     sn          : 1
#     dn          : 6
#     input_time  : 2.951754511 s
#     time_diff   : 0.000000000 s
#
# random_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_5653
#     sn          : 1
#     dn          : 6
#     input_time  : 2.951754511 s
#     time_diff   : 0.000000000 s
#
# weighted_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_5653
#     sn          : 1
#     dn          : 6
#     input_time  : 2.951754511 s
#     time_diff   : 0.000000000 s
#
# random_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_5653
#     sn          : 1
#     dn          : 6
#     input_time  : 2.951754511 s
#     time_diff   : 0.000000000 s
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/university_load_6_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.6
# --------------------------------------------------------------------------------
# conga               Avg: 0.207433  P75: 0.094686  P90: 0.281201  P95: 0.714819  P99: 4.043640
# ecmp                Avg: 0.241323  P75: 0.115149  P90: 0.167904  P95: 0.457011  P99: 4.887696
# weighted_true       Avg: 0.282813  P75: 0.126042  P90: 0.213550  P95: 0.902581  P99: 4.740064
# random_true         Avg: 0.305067  P75: 0.133285  P90: 0.441267  P95: 1.328032  P99: 5.263537
# weighted_false      Avg: 0.193846  P75: 0.104704  P90: 0.137522  P95: 0.207916  P99: 4.512029
# random_false        Avg: 0.132832  P75: 0.089451  P90: 0.118811  P95: 0.162162  P99: 3.855162
#
# ================================================================================
# university | Load 0.7
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 11,998 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_775
#     sn          : 0
#     dn          : 5
#     input_time  : 1.261172620 s
#     time_diff   : 0.000000000 s
#
# ecmp
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_775
#     sn          : 0
#     dn          : 5
#     input_time  : 1.261172620 s
#     time_diff   : 0.000000000 s
#
# weighted_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_775
#     sn          : 0
#     dn          : 5
#     input_time  : 1.261172620 s
#     time_diff   : 0.000000000 s
#
# random_true
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_775
#     sn          : 0
#     dn          : 5
#     input_time  : 1.261172620 s
#     time_diff   : 0.000000000 s
#
# weighted_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_775
#     sn          : 0
#     dn          : 5
#     input_time  : 1.261172620 s
#     time_diff   : 0.000000000 s
#
# random_false
#   Maximum : 0.000000000 s (0.000000 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000000 s (0.000000 ms)
#   P99     : 0.000000000 s (0.000000 ms)
#   Worst matching flow:
#     flow_id     : flow_775
#     sn          : 0
#     dn          : 5
#     input_time  : 1.261172620 s
#     time_diff   : 0.000000000 s
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/university_load_7_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.7
# --------------------------------------------------------------------------------
# conga               Avg: 0.236147  P75: 0.100209  P90: 0.384156  P95: 0.986343  P99: 3.987026
# ecmp                Avg: 0.236214  P75: 0.118253  P90: 0.173898  P95: 0.521200  P99: 4.512509
# weighted_true       Avg: 0.352341  P75: 0.139627  P90: 0.348603  P95: 2.910900  P99: 4.605893
# random_true         Avg: 0.960119  P75: 0.893191  P90: 3.722647  P95: 4.230168  P99: 5.275508
# weighted_false      Avg: 0.331146  P75: 0.137937  P90: 0.212812  P95: 3.290858  P99: 4.668191
# random_false        Avg: 0.218011  P75: 0.118609  P90: 0.162423  P95: 0.339521  P99: 4.325147
#
# ================================================================================
# GENERATING AVERAGE FCT COMPARISON GRAPHS
# ================================================================================
# Saved graph: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/avg/private_enterprise_average_fct_comparison.png
# Saved graph: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/avg/social_media_cloud_average_fct_comparison.png
# Saved graph: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/avg/commercial_cloud_average_fct_comparison.png
# Saved graph: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/avg/university_average_fct_comparison.png
# MATCHING COMPLETE
# ================================================================================

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

# ------------------ CONFIG ------------------

save_dir = Path(
    "/home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results"
)

graph_dir = save_dir / "graph"
graph_dir.mkdir(parents=True, exist_ok=True)

benchmarks = [
    "private_enterprise",
    "social_media_cloud",
    "commercial_cloud",
    "university"
]

loads = range(1, 8)

SMALL = 100 * 1024        # 100 KB
LARGE = 1 * 1024 * 1024   # 1 MB

algorithms = [
    "conga",
    #"conga_new",
    #"conga-ecmp",
    "ecmp",
    #"ecmp_new",
    
    #"lrtt_true",
    #"lrtt_false",
    
    #"weighted",
    #"random",
    #"top2"
    
    "weighted_true",
    "weighted_false",

    "random_true",
    "random_false",

    #"top2_true",
    #"top2_false"
]

label_map = {
    "conga": "Conga",
    #"conga_new": "Conga_New",
    #"conga-ecmp": "Conga-ECMP",
    "ecmp": "ECMP",
    #"ecmp_new": "ECMP_New",
    #"rtt": "RTT",

    "lrtt_true": "Lowest RTT (Timeout)",
    "lrtt_false": "Lowest RTT (No Timeout)",
    
    "weighted": "Weighted ECMP",
    "random": "Power-of-2 Random",
    "top2": "Power-of-2 Top2",
    
    "weighted_true": "Weighted ECMP (Timeout)",
    "weighted_false": "Weighted ECMP (No Timeout)",

    "random_true": "Power-of-2 Random (Timeout)",
    "random_false": "Power-of-2 Random (No Timeout)",

    "top2_true": "Power-of-2 Top2 (Timeout)",
    "top2_false": "Power-of-2 Top2 (No Timeout)"
}

color_map = {
    "conga": "tab:blue",
    #"conga_new": "tab:orange",
    #"conga-ecmp": "tab:green",
    "ecmp": "tab:red",
    #"ecmp_new": "tab:purple",
    #"rtt": "tab:brown",

    "lrtt_true": "tab:cyan",
    "lrtt_false": "tab:cyan",
    
    "weighted": "tab:pink",
    "random": "tab:gray",
    "top2": "tab:olive",
    
    "weighted_true": "tab:brown",
    "weighted_false": "tab:brown",

    "random_true": "tab:orange",
    "random_false": "tab:orange",

    "top2_true": "tab:gray",
    "top2_false": "tab:gray",
}

marker_map = {
    "conga": "o",
    #"conga_new": "x",
    #"conga-ecmp": "X",
    "ecmp": "s",
    #"ecmp_new": "*",
    #"rtt": "^",

    "lrtt_true": "1",
    "lrtt_false": "2",
    
    "weighted": "D",
    "random": "v",
    "top2": "P",
    
    "weighted_true": "D",
    "weighted_false": "d",

    "random_true": "^",
    "random_false": "v",

    "top2_true": "P",
    "top2_false": "X"
}

# ------------------ GLOBAL Y-LIMITS ------------------

small_global = []
large_global = []

for benchmark in benchmarks:
    for load in loads:

        csv_path = save_dir / f"{benchmark}_load_{load}_full.csv"

        if not csv_path.exists():
            continue

        df = pd.read_csv(csv_path)

        if df.empty:
            continue

        small_df = df[df["flow_size"] < SMALL]
        large_df = df[df["flow_size"] > LARGE]

        for algo in algorithms:
            col = f"FCT(s)_{algo}"

            if not small_df.empty:
                small_global.append(small_df[col].mean())

            if not large_df.empty:
                large_global.append(large_df[col].mean())

small_min = min(small_global)
small_max = max(small_global)

large_min = min(large_global)
large_max = max(large_global)

small_margin = 0.05 * (small_max - small_min)
large_margin = 0.05 * (large_max - large_min)

small_ylim = (small_min - small_margin, small_max + small_margin)
large_ylim = (large_min - large_margin, large_max + large_margin)

# ------------------ ANALYSIS ------------------

for benchmark in benchmarks:

    print(f"\n===== {benchmark} =====")

    load_vals = []

    small_results = {algo: [] for algo in algorithms}
    large_results = {algo: [] for algo in algorithms}

    for load in loads:

        csv_path = save_dir / f"{benchmark}_load_{load}_full.csv"

        if not csv_path.exists():
            print(f"Missing: {csv_path}")
            continue

        df = pd.read_csv(csv_path)

        if df.empty:
            continue

        small_df = df[df["flow_size"] < SMALL]
        large_df = df[df["flow_size"] > LARGE]

        # ---------- Small Flows ----------

        for algo in algorithms:

            col = f"FCT(s)_{algo}"

            if not small_df.empty:
                small_results[algo].append(
                    small_df[col].mean()
                )
            else:
                small_results[algo].append(np.nan)

        # ---------- Large Flows ----------

        for algo in algorithms:

            col = f"FCT(s)_{algo}"

            if not large_df.empty:
                large_results[algo].append(
                    large_df[col].mean()
                )
            else:
                large_results[algo].append(np.nan)

        load_vals.append(load / 10)

    # ==================================================
    # SMALL FLOWS
    # ==================================================

    plt.figure(figsize=(8, 5))

    for algo in algorithms:

        plt.plot(
            load_vals,
            small_results[algo],
            marker=marker_map[algo],
            color=color_map[algo],
            linestyle="--" if algo.endswith("_false") else "-",
            linewidth=2,
            label=label_map[algo]
        )

    plt.xlabel("Network Load")
    plt.ylabel("Average FCT (s)")
    plt.title(f"{benchmark}: Small Flows (<100 KB)")
    #plt.ylim(small_ylim)
    plt.grid(True)
    plt.legend()

    out_path = graph_dir / f"{benchmark}_SMALL_vs_load.png"

    plt.tight_layout()
    plt.savefig(out_path, dpi=300)
    plt.close()

    print(f"Saved: {out_path}")

    # ==================================================
    # LARGE FLOWS
    # ==================================================

    plt.figure(figsize=(8, 5))

    for algo in algorithms:

        plt.plot(
            load_vals,
            large_results[algo],
            marker=marker_map[algo],
            color=color_map[algo],
            linestyle="--" if algo.endswith("_false") else "-",
            linewidth=2,
            label=label_map[algo]
        )

    plt.xlabel("Network Load")
    plt.ylabel("Average FCT (s)")
    plt.title(f"{benchmark}: Large Flows (>1 MB)")
    #plt.ylim(large_ylim)
    plt.grid(True)
    plt.legend()

    out_path = graph_dir / f"{benchmark}_LARGE_vs_load.png"

    plt.tight_layout()
    plt.savefig(out_path, dpi=300)
    plt.close()

    print(f"Saved: {out_path}")

print("\nDone: Small vs Large flow comparison for all algorithms.")
# Out:
# ===== private_enterprise =====
# Missing: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/private_enterprise_load_7_full.csv
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/private_enterprise_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/private_enterprise_LARGE_vs_load.png
#
# ===== social_media_cloud =====
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/social_media_cloud_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/social_media_cloud_LARGE_vs_load.png
#
# ===== commercial_cloud =====
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/commercial_cloud_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/commercial_cloud_LARGE_vs_load.png
#
# ===== university =====
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/university_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/university_LARGE_vs_load.png
#
# Done: Small vs Large flow comparison for all algorithms.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

# ============================================================
# CONFIG
# ============================================================

save_dir = Path(
    "/home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results"
)

baseline = "ecmp"

graph_dir = save_dir / "graph" / f"normalised_vs_{baseline}"
graph_dir.mkdir(parents=True, exist_ok=True)

benchmarks = [
    "private_enterprise",
    "social_media_cloud",
    "commercial_cloud",
    "university"
]

# ------------------------------------------------------------
# Loads
# ------------------------------------------------------------

loads = range(1, 8)

# ------------------------------------------------------------
# Flow size thresholds
# ------------------------------------------------------------

SMALL = 100 * 1024          # 100 KB
LARGE = 1 * 1024 * 1024     # 1 MB


# ============================================================
# ALGORITHMS
#
# Comment/uncomment algorithms here as required.
# ECMP is the baseline and therefore does NOT need to be here.
# ============================================================

algorithms = [

    "conga",

    # "lrtt_true",
    # "lrtt_false",

    "weighted_true",
    "weighted_false",

    "random_true",
    "random_false",

    # "top2_true",
    # "top2_false",

    # "weighted",
    # "random",
    # "top2",
]


# ============================================================
# LABELS
# ============================================================

label_map = {

    "conga":
        "Conga",

    "lrtt_true":
        "Lowest RTT (Timeout)",

    "lrtt_false":
        "Lowest RTT (No Timeout)",

    "weighted":
        "Weighted ECMP",

    "random":
        "Power-of-2 Random",

    "top2":
        "Power-of-2 Top2",

    "weighted_true":
        "Weighted ECMP (Timeout)",

    "weighted_false":
        "Weighted ECMP (No Timeout)",

    "random_true":
        "Power-of-2 Random (Timeout)",

    "random_false":
        "Power-of-2 Random (No Timeout)",

    "top2_true":
        "Power-of-2 Top2 (Timeout)",

    "top2_false":
        "Power-of-2 Top2 (No Timeout)",
}


# ============================================================
# COLORS
# ============================================================

color_map = {

    "conga":
        "tab:blue",

    "lrtt_true":
        "tab:cyan",

    "lrtt_false":
        "tab:cyan",

    "weighted":
        "tab:purple",

    "random":
        "tab:gray",

    "top2":
        "tab:olive",

    "weighted_true":
        "tab:brown",

    "weighted_false":
        "tab:brown",

    "random_true":
        "tab:orange",

    "random_false":
        "tab:orange",

    "top2_true":
        "tab:gray",

    "top2_false":
        "tab:gray",
}


# ============================================================
# MARKERS
# ============================================================

marker_map = {

    "conga":
        "o",

    "lrtt_true":
        "1",

    "lrtt_false":
        "2",

    "weighted":
        "^",

    "random":
        "D",

    "top2":
        "P",

    "weighted_true":
        "D",

    "weighted_false":
        "d",

    "random_true":
        "^",

    "random_false":
        "v",

    "top2_true":
        "P",

    "top2_false":
        "X",
}


# ============================================================
# RESULT STORAGE
# ============================================================

summary_results = {}


# ============================================================
# MAIN ANALYSIS
# ============================================================

for benchmark in benchmarks:

    print()
    print("=" * 80)
    print(f"BENCHMARK: {benchmark}")
    print("=" * 80)

    # --------------------------------------------------------
    # Store load values
    # --------------------------------------------------------

    load_vals = []

    # --------------------------------------------------------
    # Results for each algorithm
    #
    # Each entry will contain one value per network load.
    # --------------------------------------------------------

    small_results = {
        algo: []
        for algo in algorithms
    }

    large_results = {
        algo: []
        for algo in algorithms
    }

    # ========================================================
    # PROCESS EACH LOAD
    # ========================================================

    for load in loads:

        print()
        print(
            f"Processing {benchmark} | Load 0.{load}"
        )

        csv_path = (
            save_dir /
            f"{benchmark}_load_{load}_full.csv"
        )

        # ----------------------------------------------------
        # Check file
        # ----------------------------------------------------

        if not csv_path.exists():

            print(
                f"Missing: {csv_path}"
            )

            continue

        # ----------------------------------------------------
        # Read CSV
        # ----------------------------------------------------

        df = pd.read_csv(
            csv_path
        )

        if df.empty:

            print(
                "Empty dataframe."
            )

            continue

        # ====================================================
        # CHECK REQUIRED COLUMNS
        # ====================================================

        baseline_col = (
            f"FCT(s)_{baseline}"
        )

        if baseline_col not in df.columns:

            print(
                f"ERROR: Missing baseline column "
                f"{baseline_col}"
            )

            continue

        missing_algorithms = []

        for algo in algorithms:

            col = f"FCT(s)_{algo}"

            if col not in df.columns:

                missing_algorithms.append(
                    col
                )

        if missing_algorithms:

            print(
                "ERROR: Missing algorithm columns:"
            )

            for col in missing_algorithms:

                print(
                    f"    {col}"
                )

            continue

        # ====================================================
        # REMOVE INVALID BASELINE FCT VALUES
        # ====================================================

        df = df[
            df[baseline_col] > 0
        ].copy()

        if df.empty:

            print(
                "No valid flows after removing "
                "zero/negative ECMP FCT."
            )

            continue

        # ====================================================
        # FLOW SIZE SPLIT
        # ====================================================

        small_df = df[
            df["flow_size"] < SMALL
        ].copy()

        large_df = df[
            df["flow_size"] > LARGE
        ].copy()

        print(
            f"Small flows: {len(small_df):,}"
        )

        print(
            f"Large flows: {len(large_df):,}"
        )

        # ====================================================
        # BASELINE AVERAGES
        #
        # IMPORTANT:
        #
        # We calculate:
        #
        #     mean(FCT_algorithm)
        #     --------------------
        #     mean(FCT_ECMP)
        #
        # NOT:
        #
        #     mean(FCT_algorithm / FCT_ECMP)
        #
        # This makes the normalized graph consistent with
        # the Average FCT graph.
        # ====================================================

        # ----------------------------------------------------
        # SMALL FLOWS
        # ----------------------------------------------------

        if not small_df.empty:

            baseline_small_avg = (
                small_df[baseline_col].mean()
            )

        else:

            baseline_small_avg = np.nan

        # ----------------------------------------------------
        # LARGE FLOWS
        # ----------------------------------------------------

        if not large_df.empty:

            baseline_large_avg = (
                large_df[baseline_col].mean()
            )

        else:

            baseline_large_avg = np.nan

        # ====================================================
        # NORMALIZED RESULTS
        # ====================================================

        for algo in algorithms:

            algo_col = (
                f"FCT(s)_{algo}"
            )

            # ------------------------------------------------
            # SMALL FLOWS
            # ------------------------------------------------

            if (
                not small_df.empty
                and baseline_small_avg > 0
            ):

                algo_small_avg = (
                    small_df[algo_col].mean()
                )

                normalized_small = (
                    algo_small_avg /
                    baseline_small_avg
                )

                small_results[algo].append(
                    normalized_small
                )

            else:

                small_results[algo].append(
                    np.nan
                )

            # ------------------------------------------------
            # LARGE FLOWS
            # ------------------------------------------------

            if (
                not large_df.empty
                and baseline_large_avg > 0
            ):

                algo_large_avg = (
                    large_df[algo_col].mean()
                )

                normalized_large = (
                    algo_large_avg /
                    baseline_large_avg
                )

                large_results[algo].append(
                    normalized_large
                )

            else:

                large_results[algo].append(
                    np.nan
                )

        # ----------------------------------------------------
        # Store load
        # ----------------------------------------------------

        load_vals.append(
            load / 10
        )

        # ====================================================
        # PRINT NORMALIZED VALUES
        # ====================================================

        print()
        print(
            "Normalized Average FCT:"
        )

        if not small_df.empty:

            print(
                f"  Small flows "
                f"(ECMP avg = "
                f"{baseline_small_avg:.6f}s)"
            )

            for algo in algorithms:

                value = (
                    small_results[algo][-1]
                )

                print(
                    f"    {label_map[algo]:35s}: "
                    f"{value:.4f}"
                )

        if not large_df.empty:

            print(
                f"  Large flows "
                f"(ECMP avg = "
                f"{baseline_large_avg:.6f}s)"
            )

            for algo in algorithms:

                value = (
                    large_results[algo][-1]
                )

                print(
                    f"    {label_map[algo]:35s}: "
                    f"{value:.4f}"
                )


    # ========================================================
    # STORE RESULTS
    # ========================================================

    summary_results[benchmark] = {

        "loads":
            load_vals,

        "small":
            small_results,

        "large":
            large_results
    }


    # ========================================================
    # SMALL FLOWS PLOT
    # ========================================================

    plt.figure(
        figsize=(10, 7),
        dpi=120
    )

    for algo in algorithms:

        plt.plot(

            load_vals,

            small_results[algo],

            marker=marker_map[algo],

            color=color_map[algo],

            linestyle=(
                "--"
                if algo.endswith("_false")
                else "-"
            ),

            linewidth=2,

            markersize=7,

            label=(
                f"{label_map[algo]} / ECMP"
            )
        )

    # --------------------------------------------------------
    # ECMP baseline
    # --------------------------------------------------------

    plt.axhline(
        y=1,
        linestyle="--",
        color="black",
        linewidth=1.5,
        label="ECMP baseline"
    )

    # --------------------------------------------------------
    # Labels
    # --------------------------------------------------------

    plt.xlabel(
        "Network Load"
    )

    plt.ylabel(
        "Normalized Average FCT"
    )

    plt.title(
        f"{benchmark}: "
        f"Small Flows (<100 KB)"
    )

    # --------------------------------------------------------
    # Y-axis
    # --------------------------------------------------------

    plt.ylim(
        0,
        1.8
    )

    plt.yticks(
        np.arange(
            0,
            1.81,
            0.2
        )
    )

    # --------------------------------------------------------
    # Grid
    # --------------------------------------------------------

    plt.grid(
        True,
        alpha=0.3
    )

    plt.legend()

    plt.tight_layout()

    out_path = (
        graph_dir /
        f"{benchmark}_SMALL_relative_vs_load.png"
    )

    plt.savefig(
        out_path,
        dpi=300,
        bbox_inches="tight"
    )

    plt.close()

    print()
    print(
        f"Saved: {out_path}"
    )


    # ========================================================
    # LARGE FLOWS PLOT
    # ========================================================

    plt.figure(
        figsize=(10, 7),
        dpi=120
    )

    for algo in algorithms:

        plt.plot(

            load_vals,

            large_results[algo],

            marker=marker_map[algo],

            color=color_map[algo],

            linestyle=(
                "--"
                if algo.endswith("_false")
                else "-"
            ),

            linewidth=2,

            markersize=7,

            label=(
                f"{label_map[algo]} / ECMP"
            )
        )

    # --------------------------------------------------------
    # ECMP baseline
    # --------------------------------------------------------

    plt.axhline(
        y=1,
        linestyle="--",
        color="black",
        linewidth=1.5,
        label="ECMP baseline"
    )

    # --------------------------------------------------------
    # Labels
    # --------------------------------------------------------

    plt.xlabel(
        "Network Load"
    )

    plt.ylabel(
        "Normalized Average FCT"
    )

    plt.title(
        f"{benchmark}: "
        f"Large Flows (>1 MB)"
    )

    # --------------------------------------------------------
    # Y-axis
    # --------------------------------------------------------

    plt.ylim(
        0,
        1.4
    )

    plt.yticks(
        np.arange(
            0,
            1.41,
            0.2
        )
    )

    # --------------------------------------------------------
    # Grid
    # --------------------------------------------------------

    plt.grid(
        True,
        alpha=0.3
    )

    plt.legend()

    plt.tight_layout()

    out_path = (
        graph_dir /
        f"{benchmark}_LARGE_relative_vs_load.png"
    )

    plt.savefig(
        out_path,
        dpi=300,
        bbox_inches="tight"
    )

    plt.close()

    print(
        f"Saved: {out_path}"
    )


# ============================================================
# DONE
# ============================================================

print()
print("=" * 80)
print(
    "DONE: Normalized Average FCT graphs generated."
)
print("=" * 80)
# Out:
# ================================================================================
# BENCHMARK: private_enterprise
# ================================================================================
#
# Processing private_enterprise | Load 0.1
# Small flows: 5,790
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.007445s)
#     Conga                              : 0.8770
#     Weighted ECMP (Timeout)            : 0.8399
#     Weighted ECMP (No Timeout)         : 1.3392
#     Power-of-2 Random (Timeout)        : 0.8687
#     Power-of-2 Random (No Timeout)     : 0.8877
#   Large flows (ECMP avg = 0.406055s)
#     Conga                              : 1.6020
#     Weighted ECMP (Timeout)            : 1.4725
#     Weighted ECMP (No Timeout)         : 1.0602
#     Power-of-2 Random (Timeout)        : 1.4736
#     Power-of-2 Random (No Timeout)     : 0.9938
#
# Processing private_enterprise | Load 0.2
# Small flows: 5,790
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.017034s)
#     Conga                              : 0.7864
#     Weighted ECMP (Timeout)            : 0.7958
#     Weighted ECMP (No Timeout)         : 1.5605
#     Power-of-2 Random (Timeout)        : 1.4282
#     Power-of-2 Random (No Timeout)     : 0.8498
#   Large flows (ECMP avg = 0.636972s)
#     Conga                              : 2.4539
#     Weighted ECMP (Timeout)            : 2.0805
#     Weighted ECMP (No Timeout)         : 1.1167
#     Power-of-2 Random (Timeout)        : 3.8959
#     Power-of-2 Random (No Timeout)     : 0.8809
#
# Processing private_enterprise | Load 0.3
# Small flows: 5,790
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.044333s)
#     Conga                              : 0.6563
#     Weighted ECMP (Timeout)            : 0.5610
#     Weighted ECMP (No Timeout)         : 1.9922
#     Power-of-2 Random (Timeout)        : 1.4036
#     Power-of-2 Random (No Timeout)     : 0.4831
#   Large flows (ECMP avg = 0.958687s)
#     Conga                              : 3.4805
#     Weighted ECMP (Timeout)            : 2.1608
#     Weighted ECMP (No Timeout)         : 1.7194
#     Power-of-2 Random (Timeout)        : 5.2089
#     Power-of-2 Random (No Timeout)     : 0.6831
#
# Processing private_enterprise | Load 0.4
# Small flows: 5,790
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.068364s)
#     Conga                              : 0.7997
#     Weighted ECMP (Timeout)            : 1.3321
#     Weighted ECMP (No Timeout)         : 3.5377
#     Power-of-2 Random (Timeout)        : 5.7525
#     Power-of-2 Random (No Timeout)     : 0.5879
#   Large flows (ECMP avg = 1.614826s)
#     Conga                              : 3.3148
#     Weighted ECMP (Timeout)            : 2.1652
#     Weighted ECMP (No Timeout)         : 1.7803
#     Power-of-2 Random (Timeout)        : 4.7920
#     Power-of-2 Random (No Timeout)     : 0.8066
#
# Processing private_enterprise | Load 0.5
# Small flows: 5,790
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.093144s)
#     Conga                              : 0.9110
#     Weighted ECMP (Timeout)            : 2.0648
#     Weighted ECMP (No Timeout)         : 2.0906
#     Power-of-2 Random (Timeout)        : 5.3042
#     Power-of-2 Random (No Timeout)     : 1.1170
#   Large flows (ECMP avg = 2.116447s)
#     Conga                              : 2.9963
#     Weighted ECMP (Timeout)            : 1.9935
#     Weighted ECMP (No Timeout)         : 0.9924
#     Power-of-2 Random (Timeout)        : 2.9599
#     Power-of-2 Random (No Timeout)     : 0.7426
#
# Processing private_enterprise | Load 0.6
# Small flows: 5,790
# Large flows: 26
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.151218s)
#     Conga                              : 0.7262
#     Weighted ECMP (Timeout)            : 2.4387
#     Weighted ECMP (No Timeout)         : 1.0828
#     Power-of-2 Random (Timeout)        : 2.7580
#     Power-of-2 Random (No Timeout)     : 0.5542
#   Large flows (ECMP avg = 2.722502s)
#     Conga                              : 2.3370
#     Weighted ECMP (Timeout)            : 1.6820
#     Weighted ECMP (No Timeout)         : 0.7115
#     Power-of-2 Random (Timeout)        : 2.5324
#     Power-of-2 Random (No Timeout)     : 0.8517
#
# Processing private_enterprise | Load 0.7
# Missing: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/private_enterprise_load_7_full.csv
#
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/normalised_vs_ecmp/private_enterprise_SMALL_relative_vs_load.png
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/normalised_vs_ecmp/private_enterprise_LARGE_relative_vs_load.png
#
# ================================================================================
# BENCHMARK: social_media_cloud
# ================================================================================
#
# Processing social_media_cloud | Load 0.1
# Small flows: 5,369
# Large flows: 2
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.010246s)
#     Conga                              : 1.1559
#     Weighted ECMP (Timeout)            : 1.1276
#     Weighted ECMP (No Timeout)         : 1.6271
#     Power-of-2 Random (Timeout)        : 1.1251
#     Power-of-2 Random (No Timeout)     : 0.9246
#   Large flows (ECMP avg = 0.295256s)
#     Conga                              : 2.3094
#     Weighted ECMP (Timeout)            : 1.8838
#     Weighted ECMP (No Timeout)         : 0.5741
#     Power-of-2 Random (Timeout)        : 2.0121
#     Power-of-2 Random (No Timeout)     : 1.3134
#
# Processing social_media_cloud | Load 0.2
# Small flows: 5,369
# Large flows: 2
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.028229s)
#     Conga                              : 1.1104
#     Weighted ECMP (Timeout)            : 1.6269
#     Weighted ECMP (No Timeout)         : 1.1059
#     Power-of-2 Random (Timeout)        : 10.6314
#     Power-of-2 Random (No Timeout)     : 0.8225
#   Large flows (ECMP avg = 0.418475s)
#     Conga                              : 4.2595
#     Weighted ECMP (Timeout)            : 1.7039
#     Weighted ECMP (No Timeout)         : 0.9297
#     Power-of-2 Random (Timeout)        : 4.1714
#     Power-of-2 Random (No Timeout)     : 0.7717
#
# Processing social_media_cloud | Load 0.3
# Small flows: 5,369
# Large flows: 2
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.086604s)
#     Conga                              : 2.7844
#     Weighted ECMP (Timeout)            : 2.1453
#     Weighted ECMP (No Timeout)         : 2.3401
#     Power-of-2 Random (Timeout)        : 17.4835
#     Power-of-2 Random (No Timeout)     : 0.5827
#   Large flows (ECMP avg = 2.745545s)
#     Conga                              : 3.8976
#     Weighted ECMP (Timeout)            : 0.6470
#     Weighted ECMP (No Timeout)         : 0.2039
#     Power-of-2 Random (Timeout)        : 4.8707
#     Power-of-2 Random (No Timeout)     : 0.1418
#
# Processing social_media_cloud | Load 0.4
# Small flows: 5,369
# Large flows: 2
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.407749s)
#     Conga                              : 1.1447
#     Weighted ECMP (Timeout)            : 2.1205
#     Weighted ECMP (No Timeout)         : 1.8535
#     Power-of-2 Random (Timeout)        : 4.5578
#     Power-of-2 Random (No Timeout)     : 0.2541
#   Large flows (ECMP avg = 5.330205s)
#     Conga                              : 2.3622
#     Weighted ECMP (Timeout)            : 0.9838
#     Weighted ECMP (No Timeout)         : 0.4260
#     Power-of-2 Random (Timeout)        : 1.9944
#     Power-of-2 Random (No Timeout)     : 0.0849
#
# Processing social_media_cloud | Load 0.5
# Small flows: 5,369
# Large flows: 2
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 1.027697s)
#     Conga                              : 0.6200
#     Weighted ECMP (Timeout)            : 1.7153
#     Weighted ECMP (No Timeout)         : 1.1234
#     Power-of-2 Random (Timeout)        : 3.3121
#     Power-of-2 Random (No Timeout)     : 0.3500
#   Large flows (ECMP avg = 4.889805s)
#     Conga                              : 2.5523
#     Weighted ECMP (Timeout)            : 1.0692
#     Weighted ECMP (No Timeout)         : 0.3973
#     Power-of-2 Random (Timeout)        : 2.2101
#     Power-of-2 Random (No Timeout)     : 0.8996
#
# Processing social_media_cloud | Load 0.6
# Small flows: 5,369
# Large flows: 2
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 1.408379s)
#     Conga                              : 0.5437
#     Weighted ECMP (Timeout)            : 1.5274
#     Weighted ECMP (No Timeout)         : 1.1263
#     Power-of-2 Random (Timeout)        : 1.3312
#     Power-of-2 Random (No Timeout)     : 0.6256
#   Large flows (ECMP avg = 4.545872s)
#     Conga                              : 2.5912
#     Weighted ECMP (Timeout)            : 1.6280
#     Weighted ECMP (No Timeout)         : 0.1958
#     Power-of-2 Random (Timeout)        : 1.2252
#     Power-of-2 Random (No Timeout)     : 0.9021
#
# Processing social_media_cloud | Load 0.7
# Small flows: 5,369
# Large flows: 2
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 1.637286s)
#     Conga                              : 0.5965
#     Weighted ECMP (Timeout)            : 1.1779
#     Weighted ECMP (No Timeout)         : 1.0754
#     Power-of-2 Random (Timeout)        : 0.8992
#     Power-of-2 Random (No Timeout)     : 0.8737
#   Large flows (ECMP avg = 4.214317s)
#     Conga                              : 2.6963
#     Weighted ECMP (Timeout)            : 1.6318
#     Weighted ECMP (No Timeout)         : 1.7865
#     Power-of-2 Random (Timeout)        : 1.5870
#     Power-of-2 Random (No Timeout)     : 1.5915
#
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/normalised_vs_ecmp/social_media_cloud_SMALL_relative_vs_load.png
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/normalised_vs_ecmp/social_media_cloud_LARGE_relative_vs_load.png
#
# ================================================================================
# BENCHMARK: commercial_cloud
# ================================================================================
#
# Processing commercial_cloud | Load 0.1
# Small flows: 5,798
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.020238s)
#     Conga                              : 0.2597
#     Weighted ECMP (Timeout)            : 0.3132
#     Weighted ECMP (No Timeout)         : 0.8138
#     Power-of-2 Random (Timeout)        : 0.2661
#     Power-of-2 Random (No Timeout)     : 0.3188
#   Large flows (ECMP avg = 0.571561s)
#     Conga                              : 1.5697
#     Weighted ECMP (Timeout)            : 1.3055
#     Weighted ECMP (No Timeout)         : 1.2908
#     Power-of-2 Random (Timeout)        : 1.3749
#     Power-of-2 Random (No Timeout)     : 0.8377
#
# Processing commercial_cloud | Load 0.2
# Small flows: 5,798
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.018755s)
#     Conga                              : 0.7830
#     Weighted ECMP (Timeout)            : 0.7654
#     Weighted ECMP (No Timeout)         : 1.8076
#     Power-of-2 Random (Timeout)        : 1.7972
#     Power-of-2 Random (No Timeout)     : 0.6724
#   Large flows (ECMP avg = 0.693966s)
#     Conga                              : 2.7931
#     Weighted ECMP (Timeout)            : 2.2404
#     Weighted ECMP (No Timeout)         : 1.0754
#     Power-of-2 Random (Timeout)        : 4.2472
#     Power-of-2 Random (No Timeout)     : 1.0424
#
# Processing commercial_cloud | Load 0.3
# Small flows: 5,798
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.051583s)
#     Conga                              : 0.5851
#     Weighted ECMP (Timeout)            : 0.6148
#     Weighted ECMP (No Timeout)         : 1.3998
#     Power-of-2 Random (Timeout)        : 3.0344
#     Power-of-2 Random (No Timeout)     : 0.5065
#   Large flows (ECMP avg = 0.824732s)
#     Conga                              : 4.7691
#     Weighted ECMP (Timeout)            : 3.2049
#     Weighted ECMP (No Timeout)         : 1.5450
#     Power-of-2 Random (Timeout)        : 6.5483
#     Power-of-2 Random (No Timeout)     : 1.2428
#
# Processing commercial_cloud | Load 0.4
# Small flows: 5,798
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.099972s)
#     Conga                              : 0.3710
#     Weighted ECMP (Timeout)            : 0.9649
#     Weighted ECMP (No Timeout)         : 1.4507
#     Power-of-2 Random (Timeout)        : 2.1556
#     Power-of-2 Random (No Timeout)     : 0.4872
#   Large flows (ECMP avg = 2.109989s)
#     Conga                              : 2.3017
#     Weighted ECMP (Timeout)            : 1.7651
#     Weighted ECMP (No Timeout)         : 1.2483
#     Power-of-2 Random (Timeout)        : 3.2863
#     Power-of-2 Random (No Timeout)     : 0.4894
#
# Processing commercial_cloud | Load 0.5
# Small flows: 5,798
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.129755s)
#     Conga                              : 0.5146
#     Weighted ECMP (Timeout)            : 1.2113
#     Weighted ECMP (No Timeout)         : 1.0572
#     Power-of-2 Random (Timeout)        : 1.6502
#     Power-of-2 Random (No Timeout)     : 0.6036
#   Large flows (ECMP avg = 2.186494s)
#     Conga                              : 2.7075
#     Weighted ECMP (Timeout)            : 2.0928
#     Weighted ECMP (No Timeout)         : 1.3588
#     Power-of-2 Random (Timeout)        : 3.2433
#     Power-of-2 Random (No Timeout)     : 0.9377
#
# Processing commercial_cloud | Load 0.6
# Small flows: 5,798
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.160925s)
#     Conga                              : 0.5609
#     Weighted ECMP (Timeout)            : 1.3904
#     Weighted ECMP (No Timeout)         : 1.2803
#     Power-of-2 Random (Timeout)        : 2.3947
#     Power-of-2 Random (No Timeout)     : 0.6084
#   Large flows (ECMP avg = 2.422235s)
#     Conga                              : 2.5413
#     Weighted ECMP (Timeout)            : 2.0675
#     Weighted ECMP (No Timeout)         : 1.1399
#     Power-of-2 Random (Timeout)        : 2.7316
#     Power-of-2 Random (No Timeout)     : 0.8169
#
# Processing commercial_cloud | Load 0.7
# Small flows: 5,798
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.194203s)
#     Conga                              : 0.6293
#     Weighted ECMP (Timeout)            : 1.2648
#     Weighted ECMP (No Timeout)         : 1.2685
#     Power-of-2 Random (Timeout)        : 1.6058
#     Power-of-2 Random (No Timeout)     : 0.6706
#   Large flows (ECMP avg = 3.229292s)
#     Conga                              : 1.7391
#     Weighted ECMP (Timeout)            : 1.4645
#     Weighted ECMP (No Timeout)         : 0.8485
#     Power-of-2 Random (Timeout)        : 1.8316
#     Power-of-2 Random (No Timeout)     : 0.9345
#
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/normalised_vs_ecmp/commercial_cloud_SMALL_relative_vs_load.png
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/normalised_vs_ecmp/commercial_cloud_LARGE_relative_vs_load.png
#
# ================================================================================
# BENCHMARK: university
# ================================================================================
#
# Processing university | Load 0.1
# Small flows: 5,786
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.005948s)
#     Conga                              : 0.6333
#     Weighted ECMP (Timeout)            : 0.6277
#     Weighted ECMP (No Timeout)         : 2.0155
#     Power-of-2 Random (Timeout)        : 0.5950
#     Power-of-2 Random (No Timeout)     : 0.7339
#   Large flows (ECMP avg = 0.378535s)
#     Conga                              : 1.3623
#     Weighted ECMP (Timeout)            : 1.1180
#     Weighted ECMP (No Timeout)         : 1.0742
#     Power-of-2 Random (Timeout)        : 0.9392
#     Power-of-2 Random (No Timeout)     : 0.7532
#
# Processing university | Load 0.2
# Small flows: 5,786
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.013428s)
#     Conga                              : 0.7121
#     Weighted ECMP (Timeout)            : 0.7005
#     Weighted ECMP (No Timeout)         : 1.7179
#     Power-of-2 Random (Timeout)        : 1.3474
#     Power-of-2 Random (No Timeout)     : 0.7156
#   Large flows (ECMP avg = 0.558140s)
#     Conga                              : 2.1229
#     Weighted ECMP (Timeout)            : 1.5275
#     Weighted ECMP (No Timeout)         : 1.2174
#     Power-of-2 Random (Timeout)        : 4.5107
#     Power-of-2 Random (No Timeout)     : 0.6709
#
# Processing university | Load 0.3
# Small flows: 5,786
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.060884s)
#     Conga                              : 0.4243
#     Weighted ECMP (Timeout)            : 0.5177
#     Weighted ECMP (No Timeout)         : 0.3556
#     Power-of-2 Random (Timeout)        : 1.4347
#     Power-of-2 Random (No Timeout)     : 0.3549
#   Large flows (ECMP avg = 1.023093s)
#     Conga                              : 2.5321
#     Weighted ECMP (Timeout)            : 2.0477
#     Weighted ECMP (No Timeout)         : 0.5683
#     Power-of-2 Random (Timeout)        : 4.2899
#     Power-of-2 Random (No Timeout)     : 0.6716
#
# Processing university | Load 0.4
# Small flows: 5,786
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.086965s)
#     Conga                              : 0.5702
#     Weighted ECMP (Timeout)            : 0.8564
#     Weighted ECMP (No Timeout)         : 0.7881
#     Power-of-2 Random (Timeout)        : 6.2684
#     Power-of-2 Random (No Timeout)     : 0.4852
#   Large flows (ECMP avg = 1.329965s)
#     Conga                              : 3.7946
#     Weighted ECMP (Timeout)            : 2.2548
#     Weighted ECMP (No Timeout)         : 0.4909
#     Power-of-2 Random (Timeout)        : 4.1894
#     Power-of-2 Random (No Timeout)     : 1.3739
#
# Processing university | Load 0.5
# Small flows: 5,786
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.137830s)
#     Conga                              : 0.6627
#     Weighted ECMP (Timeout)            : 1.0201
#     Weighted ECMP (No Timeout)         : 1.0376
#     Power-of-2 Random (Timeout)        : 3.0450
#     Power-of-2 Random (No Timeout)     : 0.4444
#   Large flows (ECMP avg = 1.853849s)
#     Conga                              : 3.0923
#     Weighted ECMP (Timeout)            : 2.2141
#     Weighted ECMP (No Timeout)         : 0.8730
#     Power-of-2 Random (Timeout)        : 3.2686
#     Power-of-2 Random (No Timeout)     : 0.7831
#
# Processing university | Load 0.6
# Small flows: 5,786
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.214272s)
#     Conga                              : 0.6693
#     Weighted ECMP (Timeout)            : 1.1760
#     Weighted ECMP (No Timeout)         : 0.8478
#     Power-of-2 Random (Timeout)        : 1.0401
#     Power-of-2 Random (No Timeout)     : 0.5723
#   Large flows (ECMP avg = 3.016913s)
#     Conga                              : 1.8985
#     Weighted ECMP (Timeout)            : 1.4179
#     Weighted ECMP (No Timeout)         : 0.5703
#     Power-of-2 Random (Timeout)        : 1.8644
#     Power-of-2 Random (No Timeout)     : 0.7225
#
# Processing university | Load 0.7
# Small flows: 5,786
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.205099s)
#     Conga                              : 0.8043
#     Weighted ECMP (Timeout)            : 1.5606
#     Weighted ECMP (No Timeout)         : 1.5177
#     Power-of-2 Random (Timeout)        : 4.3081
#     Power-of-2 Random (No Timeout)     : 0.9782
#   Large flows (ECMP avg = 2.713353s)
#     Conga                              : 1.9126
#     Weighted ECMP (Timeout)            : 1.6526
#     Weighted ECMP (No Timeout)         : 1.0338
#     Power-of-2 Random (Timeout)        : 1.7431
#     Power-of-2 Random (No Timeout)     : 1.0069
#
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/normalised_vs_ecmp/university_SMALL_relative_vs_load.png
# Saved: /home/hsd/workspace/ns-3.45/rtt_asym_8_hosts_v9(prob1)/analysis_results/graph/normalised_vs_ecmp/university_LARGE_relative_vs_load.png
#
# ================================================================================
# DONE: Normalized Average FCT graphs generated.
# ================================================================================
