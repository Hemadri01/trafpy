# %%
import pandas as pd
from pathlib import Path
import numpy as np


# ============================================================
# CONFIG
# ============================================================

benchmarks = [
    "private_enterprise",
    "social_media_cloud",
    "commercial_cloud",
    "university"
]

# benchmarks = [
#     "private_enterprise",
#     "social_media_cloud"
# ]

loads = range(1, 10)

# Input TrafPy flow files
input_dir = "/home/hsd/workspace/trafpy/examples/comparison_generator/8_hosts_v5(no_rack)"

# CONGA / ECMP ns-3 outputs
conga_dir = "/home/hsd/workspace/ns3-load-balance/conga_asym_8_hosts_v5(no_rack)"

# RTT ns-3 outputs
rtt_dir = "/home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)"

# Output directory
save_dir = "/home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results"

Path(save_dir).mkdir(
    parents=True,
    exist_ok=True
)


# ============================================================
# MATCHING CONFIG
# ============================================================

PORT_START = 10000
PORT_END = 50000

ip_pattern = r'^\d+\.\d+\.\d+\.\d+$'


# ============================================================
# FUNCTIONS
# ============================================================

def clean(df):
    """
    Keep only rows that contain valid IP addresses.
    """

    required = [
        "Src",
        "Dest"
    ]

    for col in required:

        if col not in df.columns:

            raise ValueError(
                f"Required column '{col}' not found."
            )

    return df[
        df["Src"].astype(str).str.match(
            ip_pattern,
            na=False
        )
        &
        df["Dest"].astype(str).str.match(
            ip_pattern,
            na=False
        )
    ].copy()


# ============================================================

def ip_to_node(ip):
    """
    Convert ns-3 server IP to input trace node ID.

    Leaf 0:
        10.1.1.2 -> 0
        10.1.1.4 -> 1
        10.1.1.6 -> 2
        10.1.1.8 -> 3

    Leaf 1:
        10.1.2.2 -> 4
        10.1.2.4 -> 5
        10.1.2.6 -> 6
        10.1.2.8 -> 7
    """

    parts = ip.split(".")

    subnet = int(parts[-2])
    host = int(parts[-1])

    base = (host // 2) - 1

    if subnet == 1:

        return base

    elif subnet == 2:

        return base + 4

    else:

        raise ValueError(
            f"Unexpected IP address: {ip}"
        )


# ============================================================

def add_time(df):
    """
    Convert ns-3 TimeFirstTxPacket to seconds.
    """

    df = df.copy()

    df["start_time"] = (
        df["TimeFirstTxPacket"]
        .astype(str)
        .str.replace("+", "", regex=False)
        .str.replace("ns", "", regex=False)
        .astype(float)
        / 1e9
    )

    return df


# ============================================================

def expected_port(flow_index):
    """
    Reproduce the C++ destination-port calculation.

        port = PORT_START + flow.index

    with wrapping after PORT_END.
    """

    port = PORT_START + int(flow_index)

    if port > PORT_END:

        port = port - (
            PORT_END - PORT_START
        )

    return port


# ============================================================
# FLOW COLUMNS
# ============================================================

flow_columns = [
    "FlowID",
    "Src",
    "Dest",
    "TimeFirstRxPacket",
    "TimeFirstTxPacket",
    "TimeLastRxPacket",
    "TimeLastTxPacket",
    "FCT(s)",
    "TxPackets",
    "RxPackets",
    "LostPackets",
    "LossRate",
    "PDR",
    "LossPercent",
    "TxBytes",
    "RxBytes",
    "Throughput(Kbps)",
    "MeanDelay(ms)",
    "Jitter(ms)",
    "HopCount"
]


# ============================================================
# MATCHING FUNCTION
# ============================================================

def match_df(output_df, input_df, label):
    """
    Match input TrafPy flows to ns-3 flows.

    Matching is based on:

        1. source node
        2. destination node
        3. destination port

    If multiple ns-3 flows have the same tuple, the candidate
    with the closest start time to the input event time is used.

    Time is NOT a hard matching criterion.
    """

    matches = []

    # --------------------------------------------------------
    # Make copies
    # --------------------------------------------------------

    output_df = output_df.copy()
    input_df = input_df.copy()

    # --------------------------------------------------------
    # Numeric conversion
    # --------------------------------------------------------

    for col in [
        "SrcPort",
        "DestPort",
        "TxPackets",
        "RxPackets",
        "TxBytes",
        "RxBytes",
        "start_time",
        "sn",
        "dn"
    ]:

        if col in output_df.columns:

            output_df[col] = pd.to_numeric(
                output_df[col],
                errors="coerce"
            )

    for col in [
        "sn",
        "dn",
        "index",
        "flow_size",
        "event_time"
    ]:

        input_df[col] = pd.to_numeric(
            input_df[col],
            errors="coerce"
        )

    # --------------------------------------------------------
    # Remove invalid rows
    # --------------------------------------------------------

    output_df = output_df.dropna(
        subset=[
            "SrcPort",
            "DestPort",
            "TxPackets",
            "RxPackets",
            "TxBytes",
            "RxBytes",
            "start_time",
            "sn",
            "dn"
        ]
    ).copy()

    input_df = input_df.dropna(
        subset=[
            "sn",
            "dn",
            "index",
            "flow_size",
            "event_time"
        ]
    ).copy()

    # --------------------------------------------------------
    # Sort input by event time
    # --------------------------------------------------------

    input_df = input_df.sort_values(
        "event_time"
    ).reset_index(
        drop=True
    )

    # --------------------------------------------------------
    # Create lookup key
    #
    # (source node, destination node, destination port)
    # --------------------------------------------------------

    output_df["_match_key"] = list(
        zip(
            output_df["sn"].astype(int),
            output_df["dn"].astype(int),
            output_df["DestPort"].astype(int)
        )
    )

    # --------------------------------------------------------
    # Group ns-3 flows by matching key
    # --------------------------------------------------------

    grouped = {
        key: group
        for key, group in output_df.groupby(
            "_match_key",
            sort=False
        )
    }

    # --------------------------------------------------------
    # Process every input flow
    # --------------------------------------------------------

    for _, in_row in input_df.iterrows():

        input_flow_id = in_row["flow_id"]

        input_index = int(
            in_row["index"]
        )

        input_src = int(
            in_row["sn"]
        )

        input_dst = int(
            in_row["dn"]
        )

        input_time = float(
            in_row["event_time"]
        )

        input_size = float(
            in_row["flow_size"]
        )

        # ----------------------------------------------------
        # Expected destination port
        # ----------------------------------------------------

        expected_dst_port = expected_port(
            input_index
        )

        # ----------------------------------------------------
        # Lookup
        # ----------------------------------------------------

        key = (
            input_src,
            input_dst,
            expected_dst_port
        )

        candidates = grouped.get(
            key
        )

        # ----------------------------------------------------
        # No matching ns-3 flow
        # ----------------------------------------------------

        if candidates is None or len(candidates) == 0:

            continue

        # ----------------------------------------------------
        # Find closest start time
        # ----------------------------------------------------

        if len(candidates) == 1:

            best = candidates.iloc[0]

            time_diff = abs(
                best["start_time"]
                - input_time
            )

        else:

            time_diffs = (
                candidates["start_time"]
                - input_time
            ).abs()

            best_index = time_diffs.idxmin()

            best = candidates.loc[
                best_index
            ]

            time_diff = time_diffs.loc[
                best_index
            ]

        # ----------------------------------------------------
        # Size difference
        # ----------------------------------------------------

        if input_size > 0:

            size_diff = (
                abs(
                    best["TxBytes"]
                    - input_size
                )
                /
                max(
                    input_size,
                    best["TxBytes"],
                    1
                )
            )

        else:

            size_diff = np.nan

        # ----------------------------------------------------
        # Combined result
        # ----------------------------------------------------

        combined = {

            "flow_id":
                input_flow_id,

            "sn":
                input_src,

            "dn":
                input_dst,

            "input_time":
                input_time,

            "flow_size":
                input_size,

            #"expected_dest_port":
            #    expected_dst_port,

            f"time_diff_{label}":
                time_diff,

            f"size_diff_{label}":
                size_diff,

            f"TxPackets_{label}":
                best["TxPackets"],

            f"RxPackets_{label}":
                best["RxPackets"],

            f"TxBytes_calc_{label}":
                best["TxPackets"] * 1400,

            f"RxBytes_calc_{label}":
                best["RxPackets"] * 1400
        }

        # ----------------------------------------------------
        # Add all FlowMonitor columns
        # ----------------------------------------------------

        for col in flow_columns:

            combined[
                f"{col}_{label}"
            ] = best[col]

        matches.append(
            combined
        )

    return pd.DataFrame(
        matches
    )


# ============================================================
# MAIN
# ============================================================

for benchmark in benchmarks:

    for load in loads:

        print()
        print(
            "=" * 80
        )

        print(
            f"{benchmark} | Load 0.{load}"
        )

        print(
            "=" * 80
        )

        # ====================================================
        # INPUT TRACE
        # ====================================================

        input_path = (
            f"{input_dir}/"
            f"{benchmark}_load_{load}.csv"
        )

        try:

            input_df = pd.read_csv(
                input_path
            )

            print(
                f"Input flows: "
                f"{len(input_df):,}"
            )

        except Exception as e:

            print(
                f"Could not read input: {e}"
            )

            continue

        # ====================================================
        # ALGORITHMS
        #
        # COMMENT / UNCOMMENT ANYTHING YOU WANT
        # ====================================================

        try:

            algorithms = {

                # ------------------------------------------------
                # CONGA
                # ------------------------------------------------

                "conga": pd.read_csv(
                    f"{conga_dir}/"
                    f"{benchmark}_load_{load}_Conga.csv",
                    nrows=12000
                ),

                # ------------------------------------------------
                # CONGA variants
                # ------------------------------------------------

                # "conga_new": pd.read_csv(
                #     f"{conga_dir}/"
                #     f"{benchmark}_load_{load}_Conga_new.csv",
                #     nrows=12000
                # ),

                # "conga-ecmp": pd.read_csv(
                #     f"{conga_dir}/"
                #     f"{benchmark}_load_{load}_Conga-ECMP_new.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # ECMP
                # ------------------------------------------------

                "ecmp": pd.read_csv(
                    f"{conga_dir}/"
                    f"{benchmark}_load_{load}_ECMP.csv",
                    nrows=12000
                ),

                # ------------------------------------------------
                # ECMP variants
                # ------------------------------------------------

                # "ecmp_new": pd.read_csv(
                #     f"{conga_dir}/"
                #     f"{benchmark}_load_{load}_ECMP_new.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # Basic RTT
                # ------------------------------------------------

                # "rtt": pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_RTT.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # Weighted ECMP
                # ------------------------------------------------

                # "weighted": pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_WEIGHTED_ECMP_RTT.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # Power-of-2 Random
                # ------------------------------------------------

                # "random": pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_POWER_OF_2_RANDOM_RTT.csv",
                #     nrows=12000
                # ),

                # ------------------------------------------------
                # Power-of-2 Top2
                # ------------------------------------------------

                # "top2": pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_POWER_OF_2_TOP2_RTT.csv",
                #     nrows=12000
                # ),
            }

            # ====================================================
            # TIMEOUT VARIANTS
            # ====================================================

            timeout_values = [
                "true",
                "false"
            ]

            for timeout in timeout_values:

                # ------------------------------------------------
                # Weighted ECMP + timeout
                # ------------------------------------------------

                algorithms[
                    f"weighted_{timeout}"
                    ] = pd.read_csv(
                    f"{rtt_dir}/"
                    f"{benchmark}_load_{load}_"
                    f"WEIGHTED_ECMP_timeout_{timeout}_RTT.csv",
                    nrows=12000
                )

                # ------------------------------------------------
                # Lowest RTT + timeout
                # ------------------------------------------------

                #algorithms[
                #    f"lrtt_{timeout}"
                #] = pd.read_csv(
                #    f"{rtt_dir}/"
                #    f"{benchmark}_load_{load}_"
                #    f"LOWEST_RTT_timeout_{timeout}_RTT.csv",
                #    nrows=12000
                #)

                # ------------------------------------------------
                # Power-of-2 Random + timeout
                # ------------------------------------------------

                algorithms[
                     f"random_{timeout}"
                     ] = pd.read_csv(
                     f"{rtt_dir}/"
                     f"{benchmark}_load_{load}_"
                     f"POWER_OF_2_RANDOM_timeout_{timeout}_RTT.csv",
                     nrows=12000
                 )

                # ------------------------------------------------
                # Power-of-2 Top2 + timeout
                # ------------------------------------------------

                # algorithms[
                #     f"top2_{timeout}"
                # ] = pd.read_csv(
                #     f"{rtt_dir}/"
                #     f"{benchmark}_load_{load}_"
                #     f"POWER_OF_2_TOP2_timeout_{timeout}_RTT.csv",
                #     nrows=12000
                # )

        except Exception as e:

            print(
                "Skipping:",
                e
            )

            continue

        # ====================================================
        # CLEAN + PREPARE
        # ====================================================

        for label, df in algorithms.items():

            try:

                df = clean(
                    df
                )

                df = add_time(
                    df
                )

                df["sn"] = df["Src"].apply(
                    ip_to_node
                )

                df["dn"] = df["Dest"].apply(
                    ip_to_node
                )

                algorithms[label] = df

                print(
                    f"{label}: "
                    f"{len(df):,} IP flows"
                )

            except Exception as e:

                print(
                    f"ERROR processing "
                    f"{label}: {e}"
                )

                algorithms[label] = (
                    pd.DataFrame()
                )

        # ====================================================
        # MATCH
        # ====================================================

        matched = {}

        for label, df in algorithms.items():

            if df.empty:

                print(
                    f"Skipping matching for "
                    f"{label}: empty dataframe"
                )

                continue

            print(
                f"Matching {label}..."
            )

            matched[label] = match_df(
                df,
                input_df,
                label
            )

            print(
                f"{label}: "
                f"{len(matched[label]):,} matches"
            )

        # ====================================================
        # REMOVE EMPTY ALGORITHMS
        # ====================================================

        matched = {
            label: df
            for label, df in matched.items()
            if not df.empty
        }

        if len(matched) == 0:

            print(
                "No matches."
            )

            continue

        # ====================================================
        # MERGE RESULTS
        # ====================================================

        merge_keys = [
            "flow_id",
            "sn",
            "dn",
            "input_time",
            "flow_size"
        ]

        algorithms_list = list(
            matched.keys()
        )

        final_df = matched[
            algorithms_list[0]
        ]

        for algo in algorithms_list[1:]:

            final_df = pd.merge(
                final_df,
                matched[algo],
                on=merge_keys,
                how="inner"
            )

        # ====================================================
        # CHECK RESULT
        # ====================================================

        if len(final_df) == 0:

            print(
                "No common matches across "
                "the selected algorithms."
            )

            continue

        print()
        print(
            f"Final matched flows: "
            f"{len(final_df):,}"
        )


        # ============================================================
        # MATCHING TIME-DIFFERENCE SANITY CHECK
        # ============================================================
        
        print("\n" + "=" * 80)
        print("MATCHING TIME-DIFFERENCE CHECK")
        print("=" * 80)
        
        for algo in algorithms:
        
            col = f"time_diff_{algo}"
        
            if col not in final_df.columns:
                continue
        
            max_diff = final_df[col].max()
            mean_diff = final_df[col].mean()
            p95_diff = final_df[col].quantile(0.95)
            p99_diff = final_df[col].quantile(0.99)
        
            max_idx = final_df[col].idxmax()
            worst = final_df.loc[max_idx]
        
            print(f"\n{algo}")
            print(f"  Maximum : {max_diff:.9f} s "
                  f"({max_diff * 1000:.6f} ms)")
            print(f"  Mean    : {mean_diff:.9f} s "
                  f"({mean_diff * 1000:.6f} ms)")
            print(f"  P95     : {p95_diff:.9f} s "
                  f"({p95_diff * 1000:.6f} ms)")
            print(f"  P99     : {p99_diff:.9f} s "
                  f"({p99_diff * 1000:.6f} ms)")
        
            print(f"  Worst matching flow:")
            print(f"    flow_id     : {worst['flow_id']}")
            print(f"    sn          : {worst['sn']}")
            print(f"    dn          : {worst['dn']}")
            print(f"    input_time  : {worst['input_time']:.9f} s")
            print(f"    time_diff   : {worst[col]:.9f} s")

        
        # ====================================================
        # DIFFERENCES
        # ====================================================

        reference = "ecmp"

        if reference in matched:

            for algo in algorithms:

                if algo == reference:
                    continue

                if (
                    f"FCT(s)_{reference}" in final_df.columns
                    and
                    f"FCT(s)_{algo}" in final_df.columns
                ):

                    final_df[
                        f"fct_diff_{reference}_{algo}"
                    ] = (
                        final_df[
                            f"FCT(s)_{reference}"
                        ]
                        -
                        final_df[
                            f"FCT(s)_{algo}"
                        ]
                    )

        # ====================================================
        # SAVE
        # ====================================================

        csv_path = (
            f"{save_dir}/"
            f"{benchmark}_load_{load}_full.csv"
        )

        final_df.to_csv(
            csv_path,
            index=False
        )

        print(
            f"Saved: {csv_path}"
        )

        # ====================================================
        # STATS
        # ====================================================

        print()
        print(
            "-" * 80
        )

        print(
            f"Statistics: "
            f"{benchmark} | Load 0.{load}"
        )

        print(
            "-" * 80
        )

        for algo in matched:

            column = (
                f"FCT(s)_{algo}"
            )

            if column not in final_df.columns:
                continue

            fct = final_df[
                column
            ]

            print(
                f"{algo:20s}"
                f"Avg: {fct.mean():.6f}  "
                f"P75: {fct.quantile(0.75):.6f}  "
                f"P90: {fct.quantile(0.90):.6f}  "
                f"P95: {fct.quantile(0.95):.6f}  "
                f"P99: {fct.quantile(0.99):.6f}"
            )


# ============================================================
# DONE
# ============================================================

print()
print(
    "=" * 80
)

print(
    "MATCHING COMPLETE"
)

print(
    "=" * 80
)
# Out:
# ================================================================================
# private_enterprise | Load 0.1
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3092
#     sn          : 7
#     dn          : 1
#     input_time  : 16.175547767 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3092
#     sn          : 7
#     dn          : 1
#     input_time  : 16.175547767 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3092
#     sn          : 7
#     dn          : 1
#     input_time  : 16.175547767 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3092
#     sn          : 7
#     dn          : 1
#     input_time  : 16.175547767 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3092
#     sn          : 7
#     dn          : 1
#     input_time  : 16.175547767 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_3092
#     sn          : 7
#     dn          : 1
#     input_time  : 16.175547767 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/private_enterprise_load_1_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.1
# --------------------------------------------------------------------------------
# conga               Avg: 0.005579  P75: 0.003322  P90: 0.015091  P95: 0.026084  P99: 0.061266
# ecmp                Avg: 0.005657  P75: 0.003424  P90: 0.015487  P95: 0.026810  P99: 0.062824
# weighted_true       Avg: 0.005638  P75: 0.003421  P90: 0.015358  P95: 0.026234  P99: 0.060647
# random_true         Avg: 0.005621  P75: 0.003480  P90: 0.015004  P95: 0.026150  P99: 0.060997
# weighted_false      Avg: 0.005468  P75: 0.003389  P90: 0.013730  P95: 0.025221  P99: 0.059140
# random_false        Avg: 0.005505  P75: 0.003402  P90: 0.014286  P95: 0.025568  P99: 0.060428
#
# ================================================================================
# private_enterprise | Load 0.2
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2152
#     sn          : 5
#     dn          : 3
#     input_time  : 1.900697712 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2152
#     sn          : 5
#     dn          : 3
#     input_time  : 1.900697712 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2152
#     sn          : 5
#     dn          : 3
#     input_time  : 1.900697712 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2152
#     sn          : 5
#     dn          : 3
#     input_time  : 1.900697712 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2152
#     sn          : 5
#     dn          : 3
#     input_time  : 1.900697712 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2152
#     sn          : 5
#     dn          : 3
#     input_time  : 1.900697712 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/private_enterprise_load_2_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.2
# --------------------------------------------------------------------------------
# conga               Avg: 0.007572  P75: 0.005437  P90: 0.018374  P95: 0.031376  P99: 0.074654
# ecmp                Avg: 0.007696  P75: 0.005717  P90: 0.019198  P95: 0.031651  P99: 0.078387
# weighted_true       Avg: 0.007533  P75: 0.005569  P90: 0.018307  P95: 0.031159  P99: 0.069198
# random_true         Avg: 0.007561  P75: 0.005438  P90: 0.018319  P95: 0.031290  P99: 0.070552
# weighted_false      Avg: 0.007458  P75: 0.005458  P90: 0.017659  P95: 0.030925  P99: 0.070107
# random_false        Avg: 0.007561  P75: 0.005621  P90: 0.019012  P95: 0.031009  P99: 0.069191
#
# ================================================================================
# private_enterprise | Load 0.3
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5265
#     sn          : 7
#     dn          : 3
#     input_time  : 6.997597060 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5265
#     sn          : 7
#     dn          : 3
#     input_time  : 6.997597060 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5265
#     sn          : 7
#     dn          : 3
#     input_time  : 6.997597060 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5265
#     sn          : 7
#     dn          : 3
#     input_time  : 6.997597060 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5265
#     sn          : 7
#     dn          : 3
#     input_time  : 6.997597060 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5265
#     sn          : 7
#     dn          : 3
#     input_time  : 6.997597060 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/private_enterprise_load_3_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.3
# --------------------------------------------------------------------------------
# conga               Avg: 0.010533  P75: 0.009967  P90: 0.029999  P95: 0.044393  P99: 0.095657
# ecmp                Avg: 0.011273  P75: 0.010333  P90: 0.031991  P95: 0.048654  P99: 0.108438
# weighted_true       Avg: 0.010542  P75: 0.010074  P90: 0.030369  P95: 0.043612  P99: 0.101167
# random_true         Avg: 0.010153  P75: 0.009414  P90: 0.028208  P95: 0.041463  P99: 0.096129
# weighted_false      Avg: 0.009915  P75: 0.009025  P90: 0.026510  P95: 0.039870  P99: 0.097389
# random_false        Avg: 0.009924  P75: 0.009036  P90: 0.026393  P95: 0.039638  P99: 0.093851
#
# ================================================================================
# private_enterprise | Load 0.4
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5746
#     sn          : 7
#     dn          : 5
#     input_time  : 1.797406885 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5746
#     sn          : 7
#     dn          : 5
#     input_time  : 1.797406885 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5746
#     sn          : 7
#     dn          : 5
#     input_time  : 1.797406885 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5746
#     sn          : 7
#     dn          : 5
#     input_time  : 1.797406885 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5746
#     sn          : 7
#     dn          : 5
#     input_time  : 1.797406885 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5746
#     sn          : 7
#     dn          : 5
#     input_time  : 1.797406885 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/private_enterprise_load_4_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.4
# --------------------------------------------------------------------------------
# conga               Avg: 0.011879  P75: 0.014445  P90: 0.032375  P95: 0.047321  P99: 0.092651
# ecmp                Avg: 0.012503  P75: 0.015471  P90: 0.033579  P95: 0.049096  P99: 0.096354
# weighted_true       Avg: 0.011990  P75: 0.014814  P90: 0.032390  P95: 0.046532  P99: 0.092268
# random_true         Avg: 0.011708  P75: 0.014451  P90: 0.031476  P95: 0.044739  P99: 0.087759
# weighted_false      Avg: 0.010826  P75: 0.012207  P90: 0.027897  P95: 0.042957  P99: 0.085921
# random_false        Avg: 0.010675  P75: 0.011881  P90: 0.027394  P95: 0.042024  P99: 0.085137
#
# ================================================================================
# private_enterprise | Load 0.5
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2650
#     sn          : 0
#     dn          : 6
#     input_time  : 2.311319739 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2650
#     sn          : 0
#     dn          : 6
#     input_time  : 2.311319739 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2650
#     sn          : 0
#     dn          : 6
#     input_time  : 2.311319739 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2650
#     sn          : 0
#     dn          : 6
#     input_time  : 2.311319739 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2650
#     sn          : 0
#     dn          : 6
#     input_time  : 2.311319739 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2650
#     sn          : 0
#     dn          : 6
#     input_time  : 2.311319739 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/private_enterprise_load_5_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.5
# --------------------------------------------------------------------------------
# conga               Avg: 0.018954  P75: 0.022336  P90: 0.048235  P95: 0.073342  P99: 0.135423
# ecmp                Avg: 0.020775  P75: 0.024381  P90: 0.052090  P95: 0.074107  P99: 0.133290
# weighted_true       Avg: 0.018728  P75: 0.023311  P90: 0.047855  P95: 0.069085  P99: 0.125991
# random_true         Avg: 0.020239  P75: 0.024915  P90: 0.055079  P95: 0.077684  P99: 0.139387
# weighted_false      Avg: 0.016999  P75: 0.021544  P90: 0.042613  P95: 0.060066  P99: 0.107115
# random_false        Avg: 0.018418  P75: 0.022018  P90: 0.046972  P95: 0.067762  P99: 0.134467
#
# ================================================================================
# private_enterprise | Load 0.6
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2458
#     sn          : 1
#     dn          : 7
#     input_time  : 3.743285334 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2458
#     sn          : 1
#     dn          : 7
#     input_time  : 3.743285334 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2458
#     sn          : 1
#     dn          : 7
#     input_time  : 3.743285334 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2458
#     sn          : 1
#     dn          : 7
#     input_time  : 3.743285334 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2458
#     sn          : 1
#     dn          : 7
#     input_time  : 3.743285334 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2458
#     sn          : 1
#     dn          : 7
#     input_time  : 3.743285334 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/private_enterprise_load_6_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.6
# --------------------------------------------------------------------------------
# conga               Avg: 0.019396  P75: 0.025226  P90: 0.047926  P95: 0.068942  P99: 0.144468
# ecmp                Avg: 0.020676  P75: 0.027234  P90: 0.051971  P95: 0.074774  P99: 0.144896
# weighted_true       Avg: 0.018603  P75: 0.023658  P90: 0.045932  P95: 0.064388  P99: 0.131386
# random_true         Avg: 0.018654  P75: 0.024285  P90: 0.046485  P95: 0.064690  P99: 0.126156
# weighted_false      Avg: 0.016632  P75: 0.019958  P90: 0.040841  P95: 0.059151  P99: 0.122251
# random_false        Avg: 0.016730  P75: 0.021291  P90: 0.041941  P95: 0.058140  P99: 0.116781
#
# ================================================================================
# private_enterprise | Load 0.7
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2504
#     sn          : 1
#     dn          : 5
#     input_time  : 1.297979481 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2504
#     sn          : 1
#     dn          : 5
#     input_time  : 1.297979481 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2504
#     sn          : 1
#     dn          : 5
#     input_time  : 1.297979481 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2504
#     sn          : 1
#     dn          : 5
#     input_time  : 1.297979481 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2504
#     sn          : 1
#     dn          : 5
#     input_time  : 1.297979481 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2504
#     sn          : 1
#     dn          : 5
#     input_time  : 1.297979481 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/private_enterprise_load_7_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.7
# --------------------------------------------------------------------------------
# conga               Avg: 0.025581  P75: 0.033745  P90: 0.067183  P95: 0.093793  P99: 0.177941
# ecmp                Avg: 0.025905  P75: 0.033696  P90: 0.064177  P95: 0.087702  P99: 0.176640
# weighted_true       Avg: 0.024952  P75: 0.032530  P90: 0.062958  P95: 0.089807  P99: 0.166646
# random_true         Avg: 0.024383  P75: 0.032535  P90: 0.062099  P95: 0.084415  P99: 0.155395
# weighted_false      Avg: 0.021222  P75: 0.026950  P90: 0.052994  P95: 0.073747  P99: 0.140660
# random_false        Avg: 0.022112  P75: 0.027110  P90: 0.056810  P95: 0.078988  P99: 0.156179
#
# ================================================================================
# private_enterprise | Load 0.8
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2527
#     sn          : 0
#     dn          : 5
#     input_time  : 0.084446137 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2527
#     sn          : 0
#     dn          : 5
#     input_time  : 0.084446137 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2527
#     sn          : 0
#     dn          : 5
#     input_time  : 0.084446137 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2527
#     sn          : 0
#     dn          : 5
#     input_time  : 0.084446137 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2527
#     sn          : 0
#     dn          : 5
#     input_time  : 0.084446137 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2527
#     sn          : 0
#     dn          : 5
#     input_time  : 0.084446137 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/private_enterprise_load_8_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.8
# --------------------------------------------------------------------------------
# conga               Avg: 0.020603  P75: 0.026745  P90: 0.046054  P95: 0.063815  P99: 0.138926
# ecmp                Avg: 0.020915  P75: 0.026155  P90: 0.047991  P95: 0.066928  P99: 0.139641
# weighted_true       Avg: 0.020800  P75: 0.026109  P90: 0.046787  P95: 0.067276  P99: 0.143964
# random_true         Avg: 0.022514  P75: 0.028101  P90: 0.050075  P95: 0.070280  P99: 0.154125
# weighted_false      Avg: 0.019809  P75: 0.024112  P90: 0.043248  P95: 0.059143  P99: 0.139650
# random_false        Avg: 0.019632  P75: 0.021525  P90: 0.041345  P95: 0.061215  P99: 0.147122
#
# ================================================================================
# private_enterprise | Load 0.9
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4240
#     sn          : 3
#     dn          : 0
#     input_time  : 2.515383162 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4240
#     sn          : 3
#     dn          : 0
#     input_time  : 2.515383162 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4240
#     sn          : 3
#     dn          : 0
#     input_time  : 2.515383162 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4240
#     sn          : 3
#     dn          : 0
#     input_time  : 2.515383162 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4240
#     sn          : 3
#     dn          : 0
#     input_time  : 2.515383162 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4240
#     sn          : 3
#     dn          : 0
#     input_time  : 2.515383162 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/private_enterprise_load_9_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: private_enterprise | Load 0.9
# --------------------------------------------------------------------------------
# conga               Avg: 0.031642  P75: 0.041061  P90: 0.069008  P95: 0.092186  P99: 0.174007
# ecmp                Avg: 0.035846  P75: 0.044543  P90: 0.074971  P95: 0.097937  P99: 0.178107
# weighted_true       Avg: 0.030832  P75: 0.039651  P90: 0.068510  P95: 0.093113  P99: 0.175628
# random_true         Avg: 0.030572  P75: 0.040019  P90: 0.067161  P95: 0.088470  P99: 0.170855
# weighted_false      Avg: 0.026741  P75: 0.034094  P90: 0.058432  P95: 0.078477  P99: 0.154324
# random_false        Avg: 0.028599  P75: 0.035858  P90: 0.061695  P95: 0.083083  P99: 0.175028
#
# ================================================================================
# social_media_cloud | Load 0.1
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1868
#     sn          : 6
#     dn          : 4
#     input_time  : 30.573630292 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1868
#     sn          : 6
#     dn          : 4
#     input_time  : 30.573630292 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1868
#     sn          : 6
#     dn          : 4
#     input_time  : 30.573630292 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1868
#     sn          : 6
#     dn          : 4
#     input_time  : 30.573630292 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1868
#     sn          : 6
#     dn          : 4
#     input_time  : 30.573630292 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1868
#     sn          : 6
#     dn          : 4
#     input_time  : 30.573630292 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/social_media_cloud_load_1_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.1
# --------------------------------------------------------------------------------
# conga               Avg: 0.007825  P75: 0.009177  P90: 0.021143  P95: 0.031376  P99: 0.059769
# ecmp                Avg: 0.008080  P75: 0.009574  P90: 0.022111  P95: 0.032553  P99: 0.060223
# weighted_true       Avg: 0.007980  P75: 0.009305  P90: 0.021360  P95: 0.032382  P99: 0.061275
# random_true         Avg: 0.007900  P75: 0.009347  P90: 0.021418  P95: 0.031724  P99: 0.059680
# weighted_false      Avg: 0.007881  P75: 0.009221  P90: 0.021135  P95: 0.031322  P99: 0.060942
# random_false        Avg: 0.007961  P75: 0.009193  P90: 0.021380  P95: 0.032159  P99: 0.060555
#
# ================================================================================
# social_media_cloud | Load 0.2
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4839
#     sn          : 2
#     dn          : 6
#     input_time  : 15.234335110 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4839
#     sn          : 2
#     dn          : 6
#     input_time  : 15.234335110 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4839
#     sn          : 2
#     dn          : 6
#     input_time  : 15.234335110 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4839
#     sn          : 2
#     dn          : 6
#     input_time  : 15.234335110 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4839
#     sn          : 2
#     dn          : 6
#     input_time  : 15.234335110 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4839
#     sn          : 2
#     dn          : 6
#     input_time  : 15.234335110 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/social_media_cloud_load_2_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.2
# --------------------------------------------------------------------------------
# conga               Avg: 0.010321  P75: 0.013262  P90: 0.027281  P95: 0.039297  P99: 0.066923
# ecmp                Avg: 0.010620  P75: 0.013725  P90: 0.027606  P95: 0.039087  P99: 0.072141
# weighted_true       Avg: 0.010465  P75: 0.013435  P90: 0.027527  P95: 0.038987  P99: 0.067564
# random_true         Avg: 0.010640  P75: 0.013874  P90: 0.027739  P95: 0.039255  P99: 0.070102
# weighted_false      Avg: 0.010203  P75: 0.012977  P90: 0.026729  P95: 0.038126  P99: 0.066571
# random_false        Avg: 0.010250  P75: 0.013161  P90: 0.027004  P95: 0.038246  P99: 0.065618
#
# ================================================================================
# social_media_cloud | Load 0.3
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5773
#     sn          : 4
#     dn          : 3
#     input_time  : 16.863537600 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5773
#     sn          : 4
#     dn          : 3
#     input_time  : 16.863537600 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5773
#     sn          : 4
#     dn          : 3
#     input_time  : 16.863537600 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5773
#     sn          : 4
#     dn          : 3
#     input_time  : 16.863537600 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5773
#     sn          : 4
#     dn          : 3
#     input_time  : 16.863537600 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000000 s (0.000000 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5773
#     sn          : 4
#     dn          : 3
#     input_time  : 16.863537600 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/social_media_cloud_load_3_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: social_media_cloud | Load 0.3
# --------------------------------------------------------------------------------
# conga               Avg: 0.014574  P75: 0.019376  P90: 0.036262  P95: 0.049145  P99: 0.080613
# ecmp                Avg: 0.015269  P75: 0.020605  P90: 0.038312  P95: 0.051621  P99: 0.084496
# weighted_true       Avg: 0.015066  P75: 0.020134  P90: 0.036677  P95: 0.050545  P99: 0.087778
# random_true         Avg: 0.014759  P75: 0.019690  P90: 0.036000  P95: 0.049162  P99: 0.085401
# weighted_false      Avg: 0.015250  P75: 0.019673  P90: 0.037831  P95: 0.053356  P99: 0.096490
# random_false        Avg: 0.015223  P75: 0.019633  P90: 0.037931  P95: 0.052694  P99: 0.095191
#
# ================================================================================
# social_media_cloud | Load 0.4
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5563
#     sn          : 5
#     dn          : 2
#     input_time  : 2.373665763 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5563
#     sn          : 5
#     dn          : 2
#     input_time  : 2.373665763 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5563
#     sn          : 5
#     dn          : 2
#     input_time  : 2.373665763 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5563
#     sn          : 5
#     dn          : 2
#     input_time  : 2.373665763 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5563
#     sn          : 5
#     dn          : 2
#     input_time  : 2.373665763 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_5563
#     sn          : 5
#     dn          : 2
#     input_time  : 2.373665763 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/social_media_cloud_load_4_full.csv
#
# ...
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/university_load_5_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.5
# --------------------------------------------------------------------------------
# conga               Avg: 0.014418  P75: 0.016446  P90: 0.041160  P95: 0.058041  P99: 0.107672
# ecmp                Avg: 0.015121  P75: 0.018215  P90: 0.043405  P95: 0.060311  P99: 0.109815
# weighted_true       Avg: 0.014627  P75: 0.017291  P90: 0.040736  P95: 0.057487  P99: 0.114055
# random_true         Avg: 0.014741  P75: 0.017975  P90: 0.040898  P95: 0.057771  P99: 0.108081
# weighted_false      Avg: 0.013312  P75: 0.014240  P90: 0.035784  P95: 0.052063  P99: 0.101791
# random_false        Avg: 0.013357  P75: 0.014868  P90: 0.034858  P95: 0.052483  P99: 0.101643
#
# ================================================================================
# university | Load 0.6
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2981
#     sn          : 1
#     dn          : 2
#     input_time  : 2.642275690 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2981
#     sn          : 1
#     dn          : 2
#     input_time  : 2.642275690 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2981
#     sn          : 1
#     dn          : 2
#     input_time  : 2.642275690 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2981
#     sn          : 1
#     dn          : 2
#     input_time  : 2.642275690 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2981
#     sn          : 1
#     dn          : 2
#     input_time  : 2.642275690 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_2981
#     sn          : 1
#     dn          : 2
#     input_time  : 2.642275690 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/university_load_6_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.6
# --------------------------------------------------------------------------------
# conga               Avg: 0.012856  P75: 0.015221  P90: 0.031898  P95: 0.047654  P99: 0.104537
# ecmp                Avg: 0.014549  P75: 0.016429  P90: 0.036855  P95: 0.058287  P99: 0.113965
# weighted_true       Avg: 0.012992  P75: 0.015261  P90: 0.032773  P95: 0.047452  P99: 0.099379
# random_true         Avg: 0.013503  P75: 0.016240  P90: 0.034688  P95: 0.051306  P99: 0.096484
# weighted_false      Avg: 0.012998  P75: 0.014640  P90: 0.031852  P95: 0.048101  P99: 0.104585
# random_false        Avg: 0.013310  P75: 0.014803  P90: 0.033178  P95: 0.048604  P99: 0.108655
#
# ================================================================================
# university | Load 0.7
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1
#     sn          : 3
#     dn          : 0
#     input_time  : 1.172255452 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1
#     sn          : 3
#     dn          : 0
#     input_time  : 1.172255452 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1
#     sn          : 3
#     dn          : 0
#     input_time  : 1.172255452 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1
#     sn          : 3
#     dn          : 0
#     input_time  : 1.172255452 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1
#     sn          : 3
#     dn          : 0
#     input_time  : 1.172255452 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_1
#     sn          : 3
#     dn          : 0
#     input_time  : 1.172255452 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/university_load_7_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.7
# --------------------------------------------------------------------------------
# conga               Avg: 0.021560  P75: 0.029517  P90: 0.053321  P95: 0.071454  P99: 0.140625
# ecmp                Avg: 0.021597  P75: 0.029943  P90: 0.052037  P95: 0.071732  P99: 0.138761
# weighted_true       Avg: 0.022923  P75: 0.031557  P90: 0.057265  P95: 0.077748  P99: 0.162977
# random_true         Avg: 0.021385  P75: 0.029083  P90: 0.051115  P95: 0.069191  P99: 0.143329
# weighted_false      Avg: 0.019672  P75: 0.024757  P90: 0.047403  P95: 0.065840  P99: 0.144624
# random_false        Avg: 0.020361  P75: 0.026047  P90: 0.049173  P95: 0.068260  P99: 0.141387
#
# ================================================================================
# university | Load 0.8
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4555
#     sn          : 1
#     dn          : 4
#     input_time  : 3.195659600 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4555
#     sn          : 1
#     dn          : 4
#     input_time  : 3.195659600 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4555
#     sn          : 1
#     dn          : 4
#     input_time  : 3.195659600 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4555
#     sn          : 1
#     dn          : 4
#     input_time  : 3.195659600 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4555
#     sn          : 1
#     dn          : 4
#     input_time  : 3.195659600 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4555
#     sn          : 1
#     dn          : 4
#     input_time  : 3.195659600 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/university_load_8_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.8
# --------------------------------------------------------------------------------
# conga               Avg: 0.023906  P75: 0.032139  P90: 0.056676  P95: 0.079304  P99: 0.147403
# ecmp                Avg: 0.025472  P75: 0.032414  P90: 0.057305  P95: 0.080904  P99: 0.169212
# weighted_true       Avg: 0.024182  P75: 0.032269  P90: 0.056538  P95: 0.077991  P99: 0.141110
# random_true         Avg: 0.024296  P75: 0.029789  P90: 0.053818  P95: 0.079831  P99: 0.168569
# weighted_false      Avg: 0.021135  P75: 0.026919  P90: 0.049364  P95: 0.071208  P99: 0.144081
# random_false        Avg: 0.022259  P75: 0.027928  P90: 0.052982  P95: 0.075522  P99: 0.151758
#
# ================================================================================
# university | Load 0.9
# ================================================================================
# Input flows: 6,000
# conga: 12,000 IP flows
# ecmp: 12,000 IP flows
# weighted_true: 12,000 IP flows
# random_true: 12,000 IP flows
# weighted_false: 12,000 IP flows
# random_false: 12,000 IP flows
# Matching conga...
# conga: 6,000 matches
# Matching ecmp...
# ecmp: 6,000 matches
# Matching weighted_true...
# weighted_true: 6,000 matches
# Matching random_true...
# random_true: 6,000 matches
# Matching weighted_false...
# weighted_false: 6,000 matches
# Matching random_false...
# random_false: 6,000 matches
#
# Final matched flows: 6,000
#
# ================================================================================
# MATCHING TIME-DIFFERENCE CHECK
# ================================================================================
#
# conga
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4542
#     sn          : 2
#     dn          : 4
#     input_time  : 1.087844466 s
#     time_diff   : 0.000000001 s
#
# ecmp
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4542
#     sn          : 2
#     dn          : 4
#     input_time  : 1.087844466 s
#     time_diff   : 0.000000001 s
#
# weighted_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4542
#     sn          : 2
#     dn          : 4
#     input_time  : 1.087844466 s
#     time_diff   : 0.000000001 s
#
# random_true
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4542
#     sn          : 2
#     dn          : 4
#     input_time  : 1.087844466 s
#     time_diff   : 0.000000001 s
#
# weighted_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4542
#     sn          : 2
#     dn          : 4
#     input_time  : 1.087844466 s
#     time_diff   : 0.000000001 s
#
# random_false
#   Maximum : 0.000000001 s (0.000001 ms)
#   Mean    : 0.000000001 s (0.000001 ms)
#   P95     : 0.000000001 s (0.000001 ms)
#   P99     : 0.000000001 s (0.000001 ms)
#   Worst matching flow:
#     flow_id     : flow_4542
#     sn          : 2
#     dn          : 4
#     input_time  : 1.087844466 s
#     time_diff   : 0.000000001 s
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/university_load_9_full.csv
#
# --------------------------------------------------------------------------------
# Statistics: university | Load 0.9
# --------------------------------------------------------------------------------
# conga               Avg: 0.027737  P75: 0.037146  P90: 0.060628  P95: 0.079984  P99: 0.154309
# ecmp                Avg: 0.034951  P75: 0.041160  P90: 0.070158  P95: 0.096790  P99: 0.203915
# weighted_true       Avg: 0.027409  P75: 0.036415  P90: 0.059784  P95: 0.079134  P99: 0.155757
# random_true         Avg: 0.028128  P75: 0.037442  P90: 0.060171  P95: 0.078497  P99: 0.170849
# weighted_false      Avg: 0.024706  P75: 0.031586  P90: 0.053367  P95: 0.073621  P99: 0.170796
# random_false        Avg: 0.024044  P75: 0.030713  P90: 0.051849  P95: 0.071139  P99: 0.157589
#
# ================================================================================
# MATCHING COMPLETE
# ================================================================================

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

# ------------------ CONFIG ------------------

save_dir = Path(
    "/home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results"
)

graph_dir = save_dir / "graph"
graph_dir.mkdir(parents=True, exist_ok=True)

benchmarks = [
    "private_enterprise",
    "social_media_cloud",
    "commercial_cloud",
    "university"
]

loads = range(1, 10)

SMALL = 100 * 1024        # 100 KB
LARGE = 1 * 1024 * 1024   # 1 MB

algorithms = [
    "conga",
    #"conga_new",
    #"conga-ecmp",
    "ecmp",
    #"ecmp_new",
    
    #"lrtt_true",
    #"lrtt_false",
    
    #"weighted",
    #"random",
    #"top2"
    
    "weighted_true",
    "weighted_false",

    "random_true",
    "random_false",

    #"top2_true",
    #"top2_false"
]

label_map = {
    "conga": "Conga",
    #"conga_new": "Conga_New",
    #"conga-ecmp": "Conga-ECMP",
    "ecmp": "ECMP",
    #"ecmp_new": "ECMP_New",
    #"rtt": "RTT",

    "lrtt_true": "Lowest RTT (Timeout)",
    "lrtt_false": "Lowest RTT (No Timeout)",
    
    "weighted": "Weighted ECMP",
    "random": "Power-of-2 Random",
    "top2": "Power-of-2 Top2",
    
    "weighted_true": "Weighted ECMP (Timeout)",
    "weighted_false": "Weighted ECMP (No Timeout)",

    "random_true": "Power-of-2 Random (Timeout)",
    "random_false": "Power-of-2 Random (No Timeout)",

    "top2_true": "Power-of-2 Top2 (Timeout)",
    "top2_false": "Power-of-2 Top2 (No Timeout)"
}

color_map = {
    "conga": "tab:blue",
    #"conga_new": "tab:orange",
    #"conga-ecmp": "tab:green",
    "ecmp": "tab:red",
    #"ecmp_new": "tab:purple",
    #"rtt": "tab:brown",

    "lrtt_true": "tab:cyan",
    "lrtt_false": "tab:cyan",
    
    "weighted": "tab:pink",
    "random": "tab:gray",
    "top2": "tab:olive",
    
    "weighted_true": "tab:brown",
    "weighted_false": "tab:brown",

    "random_true": "tab:orange",
    "random_false": "tab:orange",

    "top2_true": "tab:gray",
    "top2_false": "tab:gray",
}

marker_map = {
    "conga": "o",
    #"conga_new": "x",
    #"conga-ecmp": "X",
    "ecmp": "s",
    #"ecmp_new": "*",
    #"rtt": "^",

    "lrtt_true": "1",
    "lrtt_false": "2",
    
    "weighted": "D",
    "random": "v",
    "top2": "P",
    
    "weighted_true": "D",
    "weighted_false": "d",

    "random_true": "^",
    "random_false": "v",

    "top2_true": "P",
    "top2_false": "X"
}

# ------------------ GLOBAL Y-LIMITS ------------------

small_global = []
large_global = []

for benchmark in benchmarks:
    for load in loads:

        csv_path = save_dir / f"{benchmark}_load_{load}_full.csv"

        if not csv_path.exists():
            continue

        df = pd.read_csv(csv_path)

        if df.empty:
            continue

        small_df = df[df["flow_size"] < SMALL]
        large_df = df[df["flow_size"] > LARGE]

        for algo in algorithms:
            col = f"FCT(s)_{algo}"

            if not small_df.empty:
                small_global.append(small_df[col].mean())

            if not large_df.empty:
                large_global.append(large_df[col].mean())

small_min = min(small_global)
small_max = max(small_global)

large_min = min(large_global)
large_max = max(large_global)

small_margin = 0.05 * (small_max - small_min)
large_margin = 0.05 * (large_max - large_min)

small_ylim = (small_min - small_margin, small_max + small_margin)
large_ylim = (large_min - large_margin, large_max + large_margin)

# ------------------ ANALYSIS ------------------

for benchmark in benchmarks:

    print(f"\n===== {benchmark} =====")

    load_vals = []

    small_results = {algo: [] for algo in algorithms}
    large_results = {algo: [] for algo in algorithms}

    for load in loads:

        csv_path = save_dir / f"{benchmark}_load_{load}_full.csv"

        if not csv_path.exists():
            print(f"Missing: {csv_path}")
            continue

        df = pd.read_csv(csv_path)

        if df.empty:
            continue

        small_df = df[df["flow_size"] < SMALL]
        large_df = df[df["flow_size"] > LARGE]

        # ---------- Small Flows ----------

        for algo in algorithms:

            col = f"FCT(s)_{algo}"

            if not small_df.empty:
                small_results[algo].append(
                    small_df[col].mean()
                )
            else:
                small_results[algo].append(np.nan)

        # ---------- Large Flows ----------

        for algo in algorithms:

            col = f"FCT(s)_{algo}"

            if not large_df.empty:
                large_results[algo].append(
                    large_df[col].mean()
                )
            else:
                large_results[algo].append(np.nan)

        load_vals.append(load / 10)

    # ==================================================
    # SMALL FLOWS
    # ==================================================

    plt.figure(figsize=(8, 5))

    for algo in algorithms:

        plt.plot(
            load_vals,
            small_results[algo],
            marker=marker_map[algo],
            color=color_map[algo],
            linestyle="--" if algo.endswith("_false") else "-",
            linewidth=2,
            label=label_map[algo]
        )

    plt.xlabel("Network Load")
    plt.ylabel("Average FCT (s)")
    plt.title(f"{benchmark}: Small Flows (<100 KB)")
    #plt.ylim(small_ylim)
    plt.grid(True)
    plt.legend()

    out_path = graph_dir / f"{benchmark}_SMALL_vs_load.png"

    plt.tight_layout()
    plt.savefig(out_path, dpi=300)
    plt.close()

    print(f"Saved: {out_path}")

    # ==================================================
    # LARGE FLOWS
    # ==================================================

    plt.figure(figsize=(8, 5))

    for algo in algorithms:

        plt.plot(
            load_vals,
            large_results[algo],
            marker=marker_map[algo],
            color=color_map[algo],
            linestyle="--" if algo.endswith("_false") else "-",
            linewidth=2,
            label=label_map[algo]
        )

    plt.xlabel("Network Load")
    plt.ylabel("Average FCT (s)")
    plt.title(f"{benchmark}: Large Flows (>1 MB)")
    #plt.ylim(large_ylim)
    plt.grid(True)
    plt.legend()

    out_path = graph_dir / f"{benchmark}_LARGE_vs_load.png"

    plt.tight_layout()
    plt.savefig(out_path, dpi=300)
    plt.close()

    print(f"Saved: {out_path}")

print("\nDone: Small vs Large flow comparison for all algorithms.")
# Out:
# ===== private_enterprise =====
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/graph/private_enterprise_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/graph/private_enterprise_LARGE_vs_load.png
#
# ===== social_media_cloud =====
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/graph/social_media_cloud_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/graph/social_media_cloud_LARGE_vs_load.png
#
# ===== commercial_cloud =====
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/graph/commercial_cloud_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/graph/commercial_cloud_LARGE_vs_load.png
#
# ===== university =====
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/graph/university_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/graph/university_LARGE_vs_load.png
#
# Done: Small vs Large flow comparison for all algorithms.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

# ============================================================
# CONFIG
# ============================================================

save_dir = Path(
    "/home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results"
)

baseline = "ecmp"

graph_dir = save_dir / "graph" / f"normalised_vs_{baseline}"
graph_dir.mkdir(parents=True, exist_ok=True)

benchmarks = [
    "private_enterprise",
    "social_media_cloud",
    "commercial_cloud",
    "university"
]

# ------------------------------------------------------------
# Loads
# ------------------------------------------------------------

loads = range(1, 8)

# ------------------------------------------------------------
# Flow size thresholds
# ------------------------------------------------------------

SMALL = 100 * 1024          # 100 KB
LARGE = 1 * 1024 * 1024     # 1 MB


# ============================================================
# ALGORITHMS
#
# Comment/uncomment algorithms here as required.
# ECMP is the baseline and therefore does NOT need to be here.
# ============================================================

algorithms = [

    "conga",

    # "lrtt_true",
    # "lrtt_false",

    "weighted_true",
    "weighted_false",

    "random_true",
    "random_false",

    # "top2_true",
    # "top2_false",

    # "weighted",
    # "random",
    # "top2",
]


# ============================================================
# LABELS
# ============================================================

label_map = {

    "conga":
        "Conga",

    "lrtt_true":
        "Lowest RTT (Timeout)",

    "lrtt_false":
        "Lowest RTT (No Timeout)",

    "weighted":
        "Weighted ECMP",

    "random":
        "Power-of-2 Random",

    "top2":
        "Power-of-2 Top2",

    "weighted_true":
        "Weighted ECMP (Timeout)",

    "weighted_false":
        "Weighted ECMP (No Timeout)",

    "random_true":
        "Power-of-2 Random (Timeout)",

    "random_false":
        "Power-of-2 Random (No Timeout)",

    "top2_true":
        "Power-of-2 Top2 (Timeout)",

    "top2_false":
        "Power-of-2 Top2 (No Timeout)",
}


# ============================================================
# COLORS
# ============================================================

color_map = {

    "conga":
        "tab:blue",

    "lrtt_true":
        "tab:cyan",

    "lrtt_false":
        "tab:cyan",

    "weighted":
        "tab:purple",

    "random":
        "tab:gray",

    "top2":
        "tab:olive",

    "weighted_true":
        "tab:brown",

    "weighted_false":
        "tab:brown",

    "random_true":
        "tab:orange",

    "random_false":
        "tab:orange",

    "top2_true":
        "tab:gray",

    "top2_false":
        "tab:gray",
}


# ============================================================
# MARKERS
# ============================================================

marker_map = {

    "conga":
        "o",

    "lrtt_true":
        "1",

    "lrtt_false":
        "2",

    "weighted":
        "^",

    "random":
        "D",

    "top2":
        "P",

    "weighted_true":
        "D",

    "weighted_false":
        "d",

    "random_true":
        "^",

    "random_false":
        "v",

    "top2_true":
        "P",

    "top2_false":
        "X",
}


# ============================================================
# RESULT STORAGE
# ============================================================

summary_results = {}


# ============================================================
# MAIN ANALYSIS
# ============================================================

for benchmark in benchmarks:

    print()
    print("=" * 80)
    print(f"BENCHMARK: {benchmark}")
    print("=" * 80)

    # --------------------------------------------------------
    # Store load values
    # --------------------------------------------------------

    load_vals = []

    # --------------------------------------------------------
    # Results for each algorithm
    #
    # Each entry will contain one value per network load.
    # --------------------------------------------------------

    small_results = {
        algo: []
        for algo in algorithms
    }

    large_results = {
        algo: []
        for algo in algorithms
    }

    # ========================================================
    # PROCESS EACH LOAD
    # ========================================================

    for load in loads:

        print()
        print(
            f"Processing {benchmark} | Load 0.{load}"
        )

        csv_path = (
            save_dir /
            f"{benchmark}_load_{load}_full.csv"
        )

        # ----------------------------------------------------
        # Check file
        # ----------------------------------------------------

        if not csv_path.exists():

            print(
                f"Missing: {csv_path}"
            )

            continue

        # ----------------------------------------------------
        # Read CSV
        # ----------------------------------------------------

        df = pd.read_csv(
            csv_path
        )

        if df.empty:

            print(
                "Empty dataframe."
            )

            continue

        # ====================================================
        # CHECK REQUIRED COLUMNS
        # ====================================================

        baseline_col = (
            f"FCT(s)_{baseline}"
        )

        if baseline_col not in df.columns:

            print(
                f"ERROR: Missing baseline column "
                f"{baseline_col}"
            )

            continue

        missing_algorithms = []

        for algo in algorithms:

            col = f"FCT(s)_{algo}"

            if col not in df.columns:

                missing_algorithms.append(
                    col
                )

        if missing_algorithms:

            print(
                "ERROR: Missing algorithm columns:"
            )

            for col in missing_algorithms:

                print(
                    f"    {col}"
                )

            continue

        # ====================================================
        # REMOVE INVALID BASELINE FCT VALUES
        # ====================================================

        df = df[
            df[baseline_col] > 0
        ].copy()

        if df.empty:

            print(
                "No valid flows after removing "
                "zero/negative ECMP FCT."
            )

            continue

        # ====================================================
        # FLOW SIZE SPLIT
        # ====================================================

        small_df = df[
            df["flow_size"] < SMALL
        ].copy()

        large_df = df[
            df["flow_size"] > LARGE
        ].copy()

        print(
            f"Small flows: {len(small_df):,}"
        )

        print(
            f"Large flows: {len(large_df):,}"
        )

        # ====================================================
        # BASELINE AVERAGES
        #
        # IMPORTANT:
        #
        # We calculate:
        #
        #     mean(FCT_algorithm)
        #     --------------------
        #     mean(FCT_ECMP)
        #
        # NOT:
        #
        #     mean(FCT_algorithm / FCT_ECMP)
        #
        # This makes the normalized graph consistent with
        # the Average FCT graph.
        # ====================================================

        # ----------------------------------------------------
        # SMALL FLOWS
        # ----------------------------------------------------

        if not small_df.empty:

            baseline_small_avg = (
                small_df[baseline_col].mean()
            )

        else:

            baseline_small_avg = np.nan

        # ----------------------------------------------------
        # LARGE FLOWS
        # ----------------------------------------------------

        if not large_df.empty:

            baseline_large_avg = (
                large_df[baseline_col].mean()
            )

        else:

            baseline_large_avg = np.nan

        # ====================================================
        # NORMALIZED RESULTS
        # ====================================================

        for algo in algorithms:

            algo_col = (
                f"FCT(s)_{algo}"
            )

            # ------------------------------------------------
            # SMALL FLOWS
            # ------------------------------------------------

            if (
                not small_df.empty
                and baseline_small_avg > 0
            ):

                algo_small_avg = (
                    small_df[algo_col].mean()
                )

                normalized_small = (
                    algo_small_avg /
                    baseline_small_avg
                )

                small_results[algo].append(
                    normalized_small
                )

            else:

                small_results[algo].append(
                    np.nan
                )

            # ------------------------------------------------
            # LARGE FLOWS
            # ------------------------------------------------

            if (
                not large_df.empty
                and baseline_large_avg > 0
            ):

                algo_large_avg = (
                    large_df[algo_col].mean()
                )

                normalized_large = (
                    algo_large_avg /
                    baseline_large_avg
                )

                large_results[algo].append(
                    normalized_large
                )

            else:

                large_results[algo].append(
                    np.nan
                )

        # ----------------------------------------------------
        # Store load
        # ----------------------------------------------------

        load_vals.append(
            load / 10
        )

        # ====================================================
        # PRINT NORMALIZED VALUES
        # ====================================================

        print()
        print(
            "Normalized Average FCT:"
        )

        if not small_df.empty:

            print(
                f"  Small flows "
                f"(ECMP avg = "
                f"{baseline_small_avg:.6f}s)"
            )

            for algo in algorithms:

                value = (
                    small_results[algo][-1]
                )

                print(
                    f"    {label_map[algo]:35s}: "
                    f"{value:.4f}"
                )

        if not large_df.empty:

            print(
                f"  Large flows "
                f"(ECMP avg = "
                f"{baseline_large_avg:.6f}s)"
            )

            for algo in algorithms:

                value = (
                    large_results[algo][-1]
                )

                print(
                    f"    {label_map[algo]:35s}: "
                    f"{value:.4f}"
                )


    # ========================================================
    # STORE RESULTS
    # ========================================================

    summary_results[benchmark] = {

        "loads":
            load_vals,

        "small":
            small_results,

        "large":
            large_results
    }


    # ========================================================
    # SMALL FLOWS PLOT
    # ========================================================

    plt.figure(
        figsize=(10, 7),
        dpi=120
    )

    for algo in algorithms:

        plt.plot(

            load_vals,

            small_results[algo],

            marker=marker_map[algo],

            color=color_map[algo],

            linestyle=(
                "--"
                if algo.endswith("_false")
                else "-"
            ),

            linewidth=2,

            markersize=7,

            label=(
                f"{label_map[algo]} / ECMP"
            )
        )

    # --------------------------------------------------------
    # ECMP baseline
    # --------------------------------------------------------

    plt.axhline(
        y=1,
        linestyle="--",
        color="black",
        linewidth=1.5,
        label="ECMP baseline"
    )

    # --------------------------------------------------------
    # Labels
    # --------------------------------------------------------

    plt.xlabel(
        "Network Load"
    )

    plt.ylabel(
        "Normalized Average FCT"
    )

    plt.title(
        f"{benchmark}: "
        f"Small Flows (<100 KB)"
    )

    # --------------------------------------------------------
    # Y-axis
    # --------------------------------------------------------

    plt.ylim(
        0,
        1.8
    )

    plt.yticks(
        np.arange(
            0,
            1.81,
            0.2
        )
    )

    # --------------------------------------------------------
    # Grid
    # --------------------------------------------------------

    plt.grid(
        True,
        alpha=0.3
    )

    plt.legend()

    plt.tight_layout()

    out_path = (
        graph_dir /
        f"{benchmark}_SMALL_relative_vs_load.png"
    )

    plt.savefig(
        out_path,
        dpi=300,
        bbox_inches="tight"
    )

    plt.close()

    print()
    print(
        f"Saved: {out_path}"
    )


    # ========================================================
    # LARGE FLOWS PLOT
    # ========================================================

    plt.figure(
        figsize=(10, 7),
        dpi=120
    )

    for algo in algorithms:

        plt.plot(

            load_vals,

            large_results[algo],

            marker=marker_map[algo],

            color=color_map[algo],

            linestyle=(
                "--"
                if algo.endswith("_false")
                else "-"
            ),

            linewidth=2,

            markersize=7,

            label=(
                f"{label_map[algo]} / ECMP"
            )
        )

    # --------------------------------------------------------
    # ECMP baseline
    # --------------------------------------------------------

    plt.axhline(
        y=1,
        linestyle="--",
        color="black",
        linewidth=1.5,
        label="ECMP baseline"
    )

    # --------------------------------------------------------
    # Labels
    # --------------------------------------------------------

    plt.xlabel(
        "Network Load"
    )

    plt.ylabel(
        "Normalized Average FCT"
    )

    plt.title(
        f"{benchmark}: "
        f"Large Flows (>1 MB)"
    )

    # --------------------------------------------------------
    # Y-axis
    # --------------------------------------------------------

    plt.ylim(
        0,
        1.4
    )

    plt.yticks(
        np.arange(
            0,
            1.41,
            0.2
        )
    )

    # --------------------------------------------------------
    # Grid
    # --------------------------------------------------------

    plt.grid(
        True,
        alpha=0.3
    )

    plt.legend()

    plt.tight_layout()

    out_path = (
        graph_dir /
        f"{benchmark}_LARGE_relative_vs_load.png"
    )

    plt.savefig(
        out_path,
        dpi=300,
        bbox_inches="tight"
    )

    plt.close()

    print(
        f"Saved: {out_path}"
    )


# ============================================================
# DONE
# ============================================================

print()
print("=" * 80)
print(
    "DONE: Normalized Average FCT graphs generated."
)
print("=" * 80)
# Out:
# ================================================================================
# BENCHMARK: private_enterprise
# ================================================================================
#
# Processing private_enterprise | Load 0.1
# Small flows: 5,803
# Large flows: 20
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.004021s)
#     Conga                              : 0.9843
#     Weighted ECMP (Timeout)            : 0.9957
#     Weighted ECMP (No Timeout)         : 0.9521
#     Power-of-2 Random (Timeout)        : 0.9922
#     Power-of-2 Random (No Timeout)     : 0.9634
#   Large flows (ECMP avg = 0.236031s)
#     Conga                              : 0.9928
#     Weighted ECMP (Timeout)            : 0.9968
#     Weighted ECMP (No Timeout)         : 0.9992
#     Power-of-2 Random (Timeout)        : 0.9946
#     Power-of-2 Random (No Timeout)     : 1.0007
#
# Processing private_enterprise | Load 0.2
# Small flows: 5,791
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.005543s)
#     Conga                              : 0.9745
#     Weighted ECMP (Timeout)            : 0.9691
#     Weighted ECMP (No Timeout)         : 0.9557
#     Power-of-2 Random (Timeout)        : 0.9622
#     Power-of-2 Random (No Timeout)     : 0.9668
#   Large flows (ECMP avg = 0.409365s)
#     Conga                              : 1.0026
#     Weighted ECMP (Timeout)            : 1.0130
#     Weighted ECMP (No Timeout)         : 1.0134
#     Power-of-2 Random (Timeout)        : 1.0380
#     Power-of-2 Random (No Timeout)     : 1.0467
#
# Processing private_enterprise | Load 0.3
# Small flows: 5,776
# Large flows: 23
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.009035s)
#     Conga                              : 0.9186
#     Weighted ECMP (Timeout)            : 0.9194
#     Weighted ECMP (No Timeout)         : 0.8294
#     Power-of-2 Random (Timeout)        : 0.8734
#     Power-of-2 Random (No Timeout)     : 0.8331
#   Large flows (ECMP avg = 0.282611s)
#     Conga                              : 0.9946
#     Weighted ECMP (Timeout)            : 0.9772
#     Weighted ECMP (No Timeout)         : 1.0692
#     Power-of-2 Random (Timeout)        : 1.0034
#     Power-of-2 Random (No Timeout)     : 1.0778
#
# Processing private_enterprise | Load 0.4
# Small flows: 5,761
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.010171s)
#     Conga                              : 0.9478
#     Weighted ECMP (Timeout)            : 0.9586
#     Weighted ECMP (No Timeout)         : 0.8363
#     Power-of-2 Random (Timeout)        : 0.9322
#     Power-of-2 Random (No Timeout)     : 0.8202
#   Large flows (ECMP avg = 0.299082s)
#     Conga                              : 0.9908
#     Weighted ECMP (Timeout)            : 0.9957
#     Weighted ECMP (No Timeout)         : 1.0756
#     Power-of-2 Random (Timeout)        : 1.0049
#     Power-of-2 Random (No Timeout)     : 1.0944
#
# Processing private_enterprise | Load 0.5
# Small flows: 5,771
# Large flows: 18
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.017455s)
#     Conga                              : 0.8974
#     Weighted ECMP (Timeout)            : 0.8956
#     Weighted ECMP (No Timeout)         : 0.7831
#     Power-of-2 Random (Timeout)        : 0.9612
#     Power-of-2 Random (No Timeout)     : 0.8502
#   Large flows (ECMP avg = 0.565422s)
#     Conga                              : 1.0123
#     Weighted ECMP (Timeout)            : 0.8948
#     Weighted ECMP (No Timeout)         : 0.9958
#     Power-of-2 Random (Timeout)        : 0.9376
#     Power-of-2 Random (No Timeout)     : 1.0913
#
# Processing private_enterprise | Load 0.6
# Small flows: 5,792
# Large flows: 22
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.017930s)
#     Conga                              : 0.9304
#     Weighted ECMP (Timeout)            : 0.8860
#     Weighted ECMP (No Timeout)         : 0.7695
#     Power-of-2 Random (Timeout)        : 0.8865
#     Power-of-2 Random (No Timeout)     : 0.7768
#   Large flows (ECMP avg = 0.350151s)
#     Conga                              : 1.0052
#     Weighted ECMP (Timeout)            : 1.0603
#     Weighted ECMP (No Timeout)         : 1.0623
#     Power-of-2 Random (Timeout)        : 1.0875
#     Power-of-2 Random (No Timeout)     : 1.1118
#
# Processing private_enterprise | Load 0.7
# Small flows: 5,783
# Large flows: 21
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.022272s)
#     Conga                              : 0.9896
#     Weighted ECMP (Timeout)            : 0.9436
#     Weighted ECMP (No Timeout)         : 0.7760
#     Power-of-2 Random (Timeout)        : 0.9271
#     Power-of-2 Random (No Timeout)     : 0.8131
#   Large flows (ECMP avg = 0.470985s)
#     Conga                              : 1.0333
#     Weighted ECMP (Timeout)            : 1.1170
#     Weighted ECMP (No Timeout)         : 1.1498
#     Power-of-2 Random (Timeout)        : 1.0873
#     Power-of-2 Random (No Timeout)     : 1.2274
#
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/graph/normalised_vs_ecmp/private_enterprise_SMALL_relative_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/graph/normalised_vs_ecmp/private_enterprise_LARGE_relative_vs_load.png
#
# ================================================================================
# BENCHMARK: social_media_cloud
# ================================================================================
#
# Processing social_media_cloud | Load 0.1
# Small flows: 5,358
# Large flows: 6
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.005675s)
#     Conga                              : 0.9563
#     Weighted ECMP (Timeout)            : 0.9758
#     Weighted ECMP (No Timeout)         : 0.9577
#     Power-of-2 Random (Timeout)        : 0.9676
#     Power-of-2 Random (No Timeout)     : 0.9707
#   Large flows (ECMP avg = 0.121078s)
#     Conga                              : 0.9888
#     Weighted ECMP (Timeout)            : 0.9876
#     Weighted ECMP (No Timeout)         : 1.0551
#     Power-of-2 Random (Timeout)        : 0.9882
#     Power-of-2 Random (No Timeout)     : 1.0447
#
# Processing social_media_cloud | Load 0.2
# Small flows: 5,356
# Large flows: 3
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.007923s)
#     Conga                              : 0.9697
#     Weighted ECMP (Timeout)            : 0.9848
#     Weighted ECMP (No Timeout)         : 0.9373
#     Power-of-2 Random (Timeout)        : 1.0006
#     Power-of-2 Random (No Timeout)     : 0.9485
#   Large flows (ECMP avg = 0.124505s)
#     Conga                              : 1.0002
#     Weighted ECMP (Timeout)            : 1.0005
#     Weighted ECMP (No Timeout)         : 1.0272
#     Power-of-2 Random (Timeout)        : 1.0062
#     Power-of-2 Random (No Timeout)     : 1.0737
#
# Processing social_media_cloud | Load 0.3
# Small flows: 5,331
# Large flows: 5
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.011995s)
#     Conga                              : 0.9499
#     Weighted ECMP (Timeout)            : 0.9828
#     Weighted ECMP (No Timeout)         : 0.9743
#     Power-of-2 Random (Timeout)        : 0.9575
#     Power-of-2 Random (No Timeout)     : 0.9693
#   Large flows (ECMP avg = 0.187212s)
#     Conga                              : 0.9384
#     Weighted ECMP (Timeout)            : 1.0393
#     Weighted ECMP (No Timeout)         : 1.1431
#     Power-of-2 Random (Timeout)        : 1.0140
#     Power-of-2 Random (No Timeout)     : 1.2707
#
# Processing social_media_cloud | Load 0.4
# Small flows: 5,340
# Large flows: 2
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.014609s)
#     Conga                              : 0.9870
#     Weighted ECMP (Timeout)            : 0.9910
#     Weighted ECMP (No Timeout)         : 0.9271
#     Power-of-2 Random (Timeout)        : 0.9983
#     Power-of-2 Random (No Timeout)     : 0.9281
#   Large flows (ECMP avg = 0.143842s)
#     Conga                              : 1.0150
#     Weighted ECMP (Timeout)            : 1.0060
#     Weighted ECMP (No Timeout)         : 1.0318
#     Power-of-2 Random (Timeout)        : 0.9982
#     Power-of-2 Random (No Timeout)     : 1.1605
#
# Processing social_media_cloud | Load 0.5
# Small flows: 5,313
# Large flows: 4
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.016741s)
#     Conga                              : 0.9612
#     Weighted ECMP (Timeout)            : 1.0098
#     Weighted ECMP (No Timeout)         : 0.8880
#     Power-of-2 Random (Timeout)        : 0.9776
#     Power-of-2 Random (No Timeout)     : 0.8795
#   Large flows (ECMP avg = 0.192020s)
#     Conga                              : 1.0512
#     Weighted ECMP (Timeout)            : 1.3048
#     Weighted ECMP (No Timeout)         : 1.3887
#     Power-of-2 Random (Timeout)        : 1.3256
#     Power-of-2 Random (No Timeout)     : 1.3949
#
# Processing social_media_cloud | Load 0.6
# Small flows: 5,359
# Large flows: 9
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.018067s)
#     Conga                              : 0.9902
#     Weighted ECMP (Timeout)            : 1.0132
#     Weighted ECMP (No Timeout)         : 0.8956
#     Power-of-2 Random (Timeout)        : 0.9878
#     Power-of-2 Random (No Timeout)     : 0.9192
#   Large flows (ECMP avg = 0.238752s)
#     Conga                              : 0.9637
#     Weighted ECMP (Timeout)            : 1.0213
#     Weighted ECMP (No Timeout)         : 1.2372
#     Power-of-2 Random (Timeout)        : 1.0088
#     Power-of-2 Random (No Timeout)     : 1.1941
#
# Processing social_media_cloud | Load 0.7
# Small flows: 5,354
# Large flows: 6
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.026125s)
#     Conga                              : 0.9290
#     Weighted ECMP (Timeout)            : 0.9330
#     Weighted ECMP (No Timeout)         : 0.8809
#     Power-of-2 Random (Timeout)        : 0.9458
#     Power-of-2 Random (No Timeout)     : 0.8402
#   Large flows (ECMP avg = 0.288617s)
#     Conga                              : 1.2000
#     Weighted ECMP (Timeout)            : 1.3503
#     Weighted ECMP (No Timeout)         : 1.2254
#     Power-of-2 Random (Timeout)        : 1.2170
#     Power-of-2 Random (No Timeout)     : 1.1986
#
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/graph/normalised_vs_ecmp/social_media_cloud_SMALL_relative_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/graph/normalised_vs_ecmp/social_media_cloud_LARGE_relative_vs_load.png
#
# ================================================================================
# BENCHMARK: commercial_cloud
# ================================================================================
#
# Processing commercial_cloud | Load 0.1
# Small flows: 5,818
# Large flows: 11
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.003876s)
#     Conga                              : 0.9964
#     Weighted ECMP (Timeout)            : 1.0011
#     Weighted ECMP (No Timeout)         : 0.9714
#     Power-of-2 Random (Timeout)        : 1.0037
#     Power-of-2 Random (No Timeout)     : 0.9779
#   Large flows (ECMP avg = 0.281728s)
#     Conga                              : 1.0115
#     Weighted ECMP (Timeout)            : 1.0145
#     Weighted ECMP (No Timeout)         : 1.0462
#     Power-of-2 Random (Timeout)        : 1.0106
#     Power-of-2 Random (No Timeout)     : 1.0384
#
# Processing commercial_cloud | Load 0.2
# Small flows: 5,787
# Large flows: 20
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.007972s)
#     Conga                              : 0.9771
#     Weighted ECMP (Timeout)            : 0.9894
#     Weighted ECMP (No Timeout)         : 0.9027
#     Power-of-2 Random (Timeout)        : 0.9608
#     Power-of-2 Random (No Timeout)     : 0.9157
#   Large flows (ECMP avg = 0.252976s)
#     Conga                              : 0.9902
#     Weighted ECMP (Timeout)            : 0.9969
#     Weighted ECMP (No Timeout)         : 0.9568
#     Power-of-2 Random (Timeout)        : 0.9970
#     Power-of-2 Random (No Timeout)     : 0.9683
#
# Processing commercial_cloud | Load 0.3
# Small flows: 5,807
# Large flows: 16
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.010158s)
#     Conga                              : 0.9395
#     Weighted ECMP (Timeout)            : 0.9486
#     Weighted ECMP (No Timeout)         : 0.8591
#     Power-of-2 Random (Timeout)        : 0.9701
#     Power-of-2 Random (No Timeout)     : 0.8539
#   Large flows (ECMP avg = 0.249668s)
#     Conga                              : 0.9642
#     Weighted ECMP (Timeout)            : 0.9725
#     Weighted ECMP (No Timeout)         : 1.0334
#     Power-of-2 Random (Timeout)        : 0.9928
#     Power-of-2 Random (No Timeout)     : 1.0302
#
# Processing commercial_cloud | Load 0.4
# Small flows: 5,807
# Large flows: 13
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.011488s)
#     Conga                              : 1.0057
#     Weighted ECMP (Timeout)            : 0.9518
#     Weighted ECMP (No Timeout)         : 0.8382
#     Power-of-2 Random (Timeout)        : 0.9963
#     Power-of-2 Random (No Timeout)     : 0.8449
#   Large flows (ECMP avg = 0.330652s)
#     Conga                              : 0.9889
#     Weighted ECMP (Timeout)            : 1.0092
#     Weighted ECMP (No Timeout)         : 1.0578
#     Power-of-2 Random (Timeout)        : 1.0547
#     Power-of-2 Random (No Timeout)     : 1.0461
#
# Processing commercial_cloud | Load 0.5
# Small flows: 5,812
# Large flows: 21
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.014573s)
#     Conga                              : 0.8793
#     Weighted ECMP (Timeout)            : 0.8910
#     Weighted ECMP (No Timeout)         : 0.7470
#     Power-of-2 Random (Timeout)        : 0.8973
#     Power-of-2 Random (No Timeout)     : 0.7856
#   Large flows (ECMP avg = 0.381062s)
#     Conga                              : 0.9319
#     Weighted ECMP (Timeout)            : 0.9485
#     Weighted ECMP (No Timeout)         : 0.9830
#     Power-of-2 Random (Timeout)        : 0.9560
#     Power-of-2 Random (No Timeout)     : 0.9675
#
# Processing commercial_cloud | Load 0.6
# Small flows: 5,777
# Large flows: 19
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.019175s)
#     Conga                              : 0.9326
#     Weighted ECMP (Timeout)            : 0.8917
#     Weighted ECMP (No Timeout)         : 0.8084
#     Power-of-2 Random (Timeout)        : 0.9145
#     Power-of-2 Random (No Timeout)     : 0.8113
#   Large flows (ECMP avg = 0.492423s)
#     Conga                              : 1.0300
#     Weighted ECMP (Timeout)            : 0.9111
#     Weighted ECMP (No Timeout)         : 1.1167
#     Power-of-2 Random (Timeout)        : 0.9538
#     Power-of-2 Random (No Timeout)     : 1.1403
#
# Processing commercial_cloud | Load 0.7
# Small flows: 5,808
# Large flows: 14
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.022204s)
#     Conga                              : 0.8919
#     Weighted ECMP (Timeout)            : 0.8440
#     Weighted ECMP (No Timeout)         : 0.6965
#     Power-of-2 Random (Timeout)        : 0.8908
#     Power-of-2 Random (No Timeout)     : 0.6463
#   Large flows (ECMP avg = 0.473239s)
#     Conga                              : 1.1106
#     Weighted ECMP (Timeout)            : 1.1336
#     Weighted ECMP (No Timeout)         : 1.0984
#     Power-of-2 Random (Timeout)        : 1.0655
#     Power-of-2 Random (No Timeout)     : 1.0816
#
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/graph/normalised_vs_ecmp/commercial_cloud_SMALL_relative_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/graph/normalised_vs_ecmp/commercial_cloud_LARGE_relative_vs_load.png
#
# ================================================================================
# BENCHMARK: university
# ================================================================================
#
# Processing university | Load 0.1
# Small flows: 5,797
# Large flows: 15
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.002787s)
#     Conga                              : 0.9778
#     Weighted ECMP (Timeout)            : 0.9822
#     Weighted ECMP (No Timeout)         : 0.9480
#     Power-of-2 Random (Timeout)        : 0.9800
#     Power-of-2 Random (No Timeout)     : 0.9467
#   Large flows (ECMP avg = 0.286305s)
#     Conga                              : 0.9857
#     Weighted ECMP (Timeout)            : 0.9863
#     Weighted ECMP (No Timeout)         : 0.9937
#     Power-of-2 Random (Timeout)        : 0.9914
#     Power-of-2 Random (No Timeout)     : 0.9963
#
# Processing university | Load 0.2
# Small flows: 5,786
# Large flows: 12
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.004278s)
#     Conga                              : 0.9808
#     Weighted ECMP (Timeout)            : 0.9913
#     Weighted ECMP (No Timeout)         : 0.9595
#     Power-of-2 Random (Timeout)        : 0.9837
#     Power-of-2 Random (No Timeout)     : 0.9597
#   Large flows (ECMP avg = 0.272917s)
#     Conga                              : 0.9891
#     Weighted ECMP (Timeout)            : 0.9955
#     Weighted ECMP (No Timeout)         : 1.0049
#     Power-of-2 Random (Timeout)        : 0.9888
#     Power-of-2 Random (No Timeout)     : 1.0153
#
# Processing university | Load 0.3
# Small flows: 5,792
# Large flows: 28
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.008592s)
#     Conga                              : 0.9676
#     Weighted ECMP (Timeout)            : 0.9814
#     Weighted ECMP (No Timeout)         : 0.9267
#     Power-of-2 Random (Timeout)        : 1.0083
#     Power-of-2 Random (No Timeout)     : 0.9412
#   Large flows (ECMP avg = 0.519226s)
#     Conga                              : 0.9948
#     Weighted ECMP (Timeout)            : 0.9991
#     Weighted ECMP (No Timeout)         : 1.0091
#     Power-of-2 Random (Timeout)        : 1.0163
#     Power-of-2 Random (No Timeout)     : 1.0177
#
# Processing university | Load 0.4
# Small flows: 5,774
# Large flows: 19
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.009501s)
#     Conga                              : 0.9397
#     Weighted ECMP (Timeout)            : 0.9390
#     Weighted ECMP (No Timeout)         : 0.8395
#     Power-of-2 Random (Timeout)        : 0.9486
#     Power-of-2 Random (No Timeout)     : 0.8601
#   Large flows (ECMP avg = 0.310809s)
#     Conga                              : 0.9871
#     Weighted ECMP (Timeout)            : 1.0330
#     Weighted ECMP (No Timeout)         : 1.0858
#     Power-of-2 Random (Timeout)        : 1.0159
#     Power-of-2 Random (No Timeout)     : 1.0827
#
# Processing university | Load 0.5
# Small flows: 5,788
# Large flows: 17
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.012309s)
#     Conga                              : 0.9441
#     Weighted ECMP (Timeout)            : 0.9517
#     Weighted ECMP (No Timeout)         : 0.8538
#     Power-of-2 Random (Timeout)        : 0.9704
#     Power-of-2 Random (No Timeout)     : 0.8508
#   Large flows (ECMP avg = 0.518247s)
#     Conga                              : 0.9845
#     Weighted ECMP (Timeout)            : 1.0274
#     Weighted ECMP (No Timeout)         : 1.0384
#     Power-of-2 Random (Timeout)        : 0.9694
#     Power-of-2 Random (No Timeout)     : 1.0421
#
# Processing university | Load 0.6
# Small flows: 5,782
# Large flows: 13
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.011682s)
#     Conga                              : 0.8750
#     Weighted ECMP (Timeout)            : 0.8736
#     Weighted ECMP (No Timeout)         : 0.8532
#     Power-of-2 Random (Timeout)        : 0.9289
#     Power-of-2 Random (No Timeout)     : 0.8754
#   Large flows (ECMP avg = 0.594440s)
#     Conga                              : 0.9210
#     Weighted ECMP (Timeout)            : 1.0308
#     Weighted ECMP (No Timeout)         : 1.0616
#     Power-of-2 Random (Timeout)        : 0.9663
#     Power-of-2 Random (No Timeout)     : 1.1006
#
# Processing university | Load 0.7
# Small flows: 5,763
# Large flows: 20
#
# Normalized Average FCT:
#   Small flows (ECMP avg = 0.018193s)
#     Conga                              : 0.9913
#     Weighted ECMP (Timeout)            : 1.0541
#     Weighted ECMP (No Timeout)         : 0.8639
#     Power-of-2 Random (Timeout)        : 0.9800
#     Power-of-2 Random (No Timeout)     : 0.9048
#   Large flows (ECMP avg = 0.417700s)
#     Conga                              : 1.0648
#     Weighted ECMP (Timeout)            : 1.0063
#     Weighted ECMP (No Timeout)         : 1.2254
#     Power-of-2 Random (Timeout)        : 1.0461
#     Power-of-2 Random (No Timeout)     : 1.1173
#
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/graph/normalised_vs_ecmp/university_SMALL_relative_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/rtt_asym_8_hosts_v5(no_rack)/analysis_results/graph/normalised_vs_ecmp/university_LARGE_relative_vs_load.png
#
# ================================================================================
# DONE: Normalized Average FCT graphs generated.
# ================================================================================
