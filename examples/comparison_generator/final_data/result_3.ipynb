# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# ------------------ CONFIG ------------------

benchmarks = [
    "private_enterprise",
    "social_media_cloud",
    "commercial_cloud",
    "university"
]

#benchmarks = [
#    "private_enterprise",
#    "social_media_cloud"
#]

loads = range(1, 10)

link = 3

input_dir = "/home/hsd/workspace/trafpy/examples/comparison_generator/final_data"

# Existing ns3 outputs
output_dir = f"/home/hsd/workspace/ns3-load-balance/results_asym_link_fail/asym_link_{link}"

# RTT outputs (change this)
#rtt_dir = "/home/hsd/workspace/ns3-load-balance/results_rtt_fix"

new_rtt_dir = f"/home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_{link}"

save_dir = f"/home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_{link}/analysis_results"
Path(save_dir).mkdir(exist_ok=True)

ip_pattern = r'^\d+\.\d+\.\d+\.\d+$'

summary_results = {}

# ------------------ FUNCTIONS ------------------

def clean(df):
    return df[
        df['Src'].str.match(ip_pattern, na=False) &
        df['Dest'].str.match(ip_pattern, na=False)
    ].copy()


def ip_to_node(ip):
    last = int(ip.split('.')[-1])
    last1 = int(ip.split('.')[-2])

    leafcount = 2
    leaf = 0

    if last1 == 2:
        leaf = 1

    return ((last // 2) - 1 + (leaf * leafcount))


def add_time(df):

    df['start_time'] = (
        df['TimeFirstTxPacket']
        .astype(str)
        .str.replace('+', '', regex=False)
        .str.replace('ns', '', regex=False)
        .astype(float) / 1e9
    )

    return df


flow_columns = [
    "FlowID",
    "Src",
    "Dest",
    "TimeFirstRxPacket",
    "TimeFirstTxPacket",
    "TimeLastRxPacket",
    "TimeLastTxPacket",
    "FCT(s)",
    "TxPackets",
    "RxPackets",
    "LostPackets",
    "LossRate",
    "PDR",
    "LossPercent",
    "TxBytes",
    "RxBytes",
    "Throughput(Kbps)",
    "MeanDelay(ms)",
    "Jitter(ms)",
    "HopCount"
]


# ------------------ MATCH ------------------

def match_df(output_df, input_df, label):

    matches = []

    for _, in_row in input_df.iterrows():

        cand = output_df[
            (output_df.sn == in_row.sn) &
            (output_df.dn == in_row.dn)
        ].copy()

        if len(cand) == 0:
            continue

        cand['time_diff'] = abs(
            cand['start_time'] - in_row.event_time
        )

        best = cand.loc[cand['time_diff'].idxmin()]

        combined = {
            'flow_id': in_row.flow_id,
            'sn': in_row.sn,
            'dn': in_row.dn,
            'input_time': in_row.event_time,
            'flow_size': in_row.flow_size,

            f'time_diff_{label}': best['time_diff'],

            f'TxPackets_{label}': best['TxPackets'],
            f'RxPackets_{label}': best['RxPackets'],

            f'TxBytes_calc_{label}': best['TxPackets'] * 1400,
            f'RxBytes_calc_{label}': best['RxPackets'] * 1400,
        }

        for col in flow_columns:
            combined[f"{col}_{label}"] = best[col]

        matches.append(combined)

    return pd.DataFrame(matches)


# ------------------ MAIN ------------------

for benchmark in benchmarks:

    for load in loads:

        print(f"\n=== {benchmark} | Load 0.{load} ===")

        input_path = (
            f"{input_dir}/{benchmark}_load_{load}.csv"
        )

        try:

            input_df = pd.read_csv(input_path)

            timeout_values = ["true", "false"]

            algorithms = {
                "conga": pd.read_csv(
                    f"{output_dir}/{benchmark}_load_{load}_Conga_asym{link}.csv",
                    nrows=12000
                ),

                "ecmp": pd.read_csv(
                    f"{output_dir}/{benchmark}_load_{load}_ECMP_asym{link}.csv",
                    nrows=12000
                ),
            }

            for timeout in timeout_values:
            
                algorithms[f"weighted_{timeout}"] = pd.read_csv(
                    f"{new_rtt_dir}/{benchmark}_load_{load}_WEIGHTED_ECMP_timeout_{timeout}_RTT.csv",
                    nrows=12000
                )

                algorithms[f"random_{timeout}"] = pd.read_csv(
                    f"{new_rtt_dir}/{benchmark}_load_{load}_POWER_OF_2_RANDOM_timeout_{timeout}_RTT.csv",
                    nrows=12000
                )

                algorithms[f"top2_{timeout}"] = pd.read_csv(
                    f"{new_rtt_dir}/{benchmark}_load_{load}_POWER_OF_2_TOP2_timeout_{timeout}_RTT.csv",
                    nrows=12000
                )

        except Exception as e:
            print("Skipping:", e)
            continue

        # ------------------ CLEAN ------------------

        for label, df in algorithms.items():

            df = add_time(clean(df))

            df['sn'] = df['Src'].apply(ip_to_node)
            df['dn'] = df['Dest'].apply(ip_to_node)

            algorithms[label] = df

        # ------------------ MATCH ------------------

        matched = {}

        for label, df in algorithms.items():
            matched[label] = match_df(df, input_df, label)

        merge_keys = [
            'flow_id',
            'sn',
            'dn',
            'input_time',
            'flow_size'
        ]

        algorithms_list = list(algorithms.keys())

        final_df = matched[algorithms_list[0]]

        for algo in algorithms_list[1:]:
            final_df = pd.merge(
                final_df,
                matched[algo],
                on=merge_keys,
                how='inner'
            )

        if len(final_df) == 0:
            print("No matches.")
            continue


        # ------------------ SAVE CSV ------------------

        csv_path = (
            f"{save_dir}/{benchmark}_load_{load}_full.csv"
        )

        final_df.to_csv(csv_path, index=False)

        # ------------------ STATS ------------------

        stats = {}

        for algo in algorithms:
            fct = final_df[f"FCT(s)_{algo}"]

            stats[algo] = {
                "avg": fct.mean(),
                "p75": fct.quantile(0.75),
                "p90": fct.quantile(0.90),
                "p95": fct.quantile(0.95),
                "p99": fct.quantile(0.99),
            }

        
        for algo in stats:
            print(
                algo,
                "Avg:", stats[algo]["avg"],
                "P75:", stats[algo]["p75"],
                "P90:", stats[algo]["p90"],
                "P95:", stats[algo]["p95"],
                "P99:", stats[algo]["p99"],
            )

        if benchmark not in summary_results:

            summary_results[benchmark] = {
                "loads": []
            }

            for algo in algorithms:
                summary_results[benchmark][algo] = {
                "avg": [],
                "p75": [],
                "p90": [],
                "p95": [],
                "p99": []
                }

        summary_results[benchmark]["loads"].append(load / 10)

        for algo in algorithms:
            for metric in ["avg", "p75", "p90", "p95", "p99"]:
                summary_results[benchmark][algo][metric].append(
                    stats[algo][metric]
                )
        

# ------------------ FINAL SUMMARY PLOTS ------------------

metrics = ["avg", "p75", "p90", "p95", "p99"]

metric_titles = {
    "avg": "Average FCT",
    "p75": "75th Percentile FCT",
    "p90": "90th Percentile FCT",
    "p95": "95th Percentile FCT",
    "p99": "99th Percentile FCT"
}

marker_map = {
    "conga": "o",
    "ecmp": "s",

    "weighted_true": "D",
    "weighted_false": "d",

    "random_true": "^",
    "random_false": "v",

    "top2_true": "P",
    "top2_false": "X",
}

label_map = {
    "conga": "Conga",
    "ecmp": "ECMP",

    "weighted_true": "Weighted ECMP (Timeout)",
    "weighted_false": "Weighted ECMP (No Timeout)",

    "random_true": "Power-of-2 Random (Timeout)",
    "random_false": "Power-of-2 Random (No Timeout)",

    "top2_true": "Power-of-2 Top2 (Timeout)",
    "top2_false": "Power-of-2 Top2 (No Timeout)",
}

for benchmark in summary_results:

    loads_x = summary_results[benchmark]["loads"]

    for metric in metrics:

        plt.figure(figsize=(8, 5))

        for algo in [k for k in summary_results[benchmark] if k != "loads"]:

            plt.plot(
                loads_x,
                summary_results[benchmark][algo][metric],
                marker=marker_map.get(algo, "o"),
                linewidth=2,
                label=label_map.get(algo, algo.upper())
            )

        plt.xlabel("Load")
        plt.ylabel(metric_titles[metric])
        plt.title(f"{benchmark} {metric_titles[metric]} vs Load")

        plt.grid(True)
        plt.legend()

        plt.tight_layout()

        plt.savefig(
            f"{save_dir}/{benchmark}_{metric}_vs_load.png",
            dpi=300
        )

        plt.close()

print("\nDONE: All comparison plots generated!")
# Out:
# === private_enterprise | Load 0.1 ===
# conga Avg: 0.006470806166666667 P75: 0.0050445 P90: 0.01783350000000001 P95: 0.028511050000000003 P99: 0.06013106000000005
# ecmp Avg: 0.007590055500000001 P75: 0.005858250000000001 P90: 0.020881200000000003 P95: 0.03339145000000001 P99: 0.07102732000000012
# weighted_true Avg: 0.006728116833333334 P75: 0.00554 P90: 0.01875440000000001 P95: 0.030071550000000006 P99: 0.06006374000000006
# random_true Avg: 0.006930710333333334 P75: 0.005614 P90: 0.020182000000000005 P95: 0.030693550000000003 P99: 0.06054160000000018
# top2_true Avg: 0.006728116833333334 P75: 0.00554 P90: 0.01875440000000001 P95: 0.030071550000000006 P99: 0.06006374000000006
# weighted_false Avg: 0.006186155333333333 P75: 0.004878250000000001 P90: 0.01550970000000001 P95: 0.025676800000000014 P99: 0.05876687000000002
# random_false Avg: 0.0061672935000000005 P75: 0.004914 P90: 0.015086500000000004 P95: 0.025096000000000004 P99: 0.05782260000000006
# top2_false Avg: 0.006186155333333333 P75: 0.004878250000000001 P90: 0.01550970000000001 P95: 0.025676800000000014 P99: 0.05876687000000002
#
# === private_enterprise | Load 0.2 ===
# conga Avg: 0.009549923166666667 P75: 0.00911175 P90: 0.026634400000000003 P95: 0.03943015000000001 P99: 0.08805958000000007
# ecmp Avg: 0.011347224166666668 P75: 0.01094875 P90: 0.03236800000000001 P95: 0.048572700000000024 P99: 0.10415046000000008
# weighted_true Avg: 0.010045823166666665 P75: 0.0099095 P90: 0.02736630000000001 P95: 0.041148300000000027 P99: 0.09609821000000011
# random_true Avg: 0.010144192 P75: 0.01050775 P90: 0.026975100000000012 P95: 0.04031255000000002 P99: 0.08756340000000015
# top2_true Avg: 0.010045823166666665 P75: 0.0099095 P90: 0.02736630000000001 P95: 0.041148300000000027 P99: 0.09609821000000011
# weighted_false Avg: 0.009027921833333332 P75: 0.00771875 P90: 0.023722700000000013 P95: 0.03778825000000001 P99: 0.08863879000000018
# random_false Avg: 0.009089297 P75: 0.00787525 P90: 0.023595400000000006 P95: 0.03737805 P99: 0.08675426000000017
# top2_false Avg: 0.009027921833333332 P75: 0.00771875 P90: 0.023722700000000013 P95: 0.03778825000000001 P99: 0.08863879000000018
/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results"
)

graph_dir = save_dir / "graph"
graph_dir.mkdir(parents=True, exist_ok=True)

benchmarks = [
    "private_enterprise",
    "social_media_cloud",
    "commercial_cloud",
    "university"
]

loads = range(1, 10)

SMALL = 100 * 1024        # 100 KB
LARGE = 1 * 1024 * 1024   # 1 MB

algorithms = [
    "conga",
    "ecmp",

    "weighted_true",
    "weighted_false",

    "random_true",
    "random_false",

    "top2_true",
    "top2_false"
]

label_map = {
    "conga": "Conga",
    "ecmp": "ECMP",

    "weighted_true": "Weighted ECMP (Timeout)",
    "weighted_false": "Weighted ECMP (No Timeout)",

    "random_true": "Power-of-2 Random (Timeout)",
    "random_false": "Power-of-2 Random (No Timeout)",

    "top2_true": "Power-of-2 Top2 (Timeout)",
    "top2_false": "Power-of-2 Top2 (No Timeout)"
}

marker_map = {
    "conga": "o",
    "ecmp": "s",

    "weighted_true": "D",
    "weighted_false": "d",

    "random_true": "^",
    "random_false": "v",

    "top2_true": "P",
    "top2_false": "X"
}

# ------------------ ANALYSIS ------------------

for benchmark in benchmarks:

    print(f"\n===== {benchmark} =====")

    load_vals = []

    small_results = {algo: [] for algo in algorithms}
    large_results = {algo: [] for algo in algorithms}

    for load in loads:

        csv_path = save_dir / f"{benchmark}_load_{load}_full.csv"

        if not csv_path.exists():
            print(f"Missing: {csv_path}")
            continue

        df = pd.read_csv(csv_path)

        if df.empty:
            continue

        small_df = df[df["flow_size"] < SMALL]
        large_df = df[df["flow_size"] > LARGE]

        # ---------- Small Flows ----------

        for algo in algorithms:

            col = f"FCT(s)_{algo}"

            if col not in df.columns:
                small_results[algo].append(np.nan)
                large_results[algo].append(np.nan)
                continue

            if not small_df.empty:
                small_results[algo].append(
                    small_df[col].mean()
                )
            else:
                small_results[algo].append(np.nan)

        # ---------- Large Flows ----------

        for algo in algorithms:

            col = f"FCT(s)_{algo}"

            if col not in df.columns:
                small_results[algo].append(np.nan)
                large_results[algo].append(np.nan)
                continue

            if not large_df.empty:
                large_results[algo].append(
                    large_df[col].mean()
                )
            else:
                large_results[algo].append(np.nan)

        load_vals.append(load / 10)

    # ==================================================
    # SMALL FLOWS
    # ==================================================

    plt.figure(figsize=(8, 5))

    for algo in algorithms:

        plt.plot(
            load_vals,
            small_results[algo],
            marker=marker_map[algo],
            linewidth=2,
            label=label_map[algo]
        )

    plt.xlabel("Network Load")
    plt.ylabel("Average FCT (s)")
    plt.title(f"{benchmark}: Small Flows (<100 KB)")
    plt.grid(True)
    plt.legend()

    out_path = graph_dir / f"{benchmark}_SMALL_vs_load.png"

    plt.tight_layout()
    plt.savefig(out_path, dpi=300)
    plt.close()

    print(f"Saved: {out_path}")

    # ==================================================
    # LARGE FLOWS
    # ==================================================

    plt.figure(figsize=(8, 5))

    for algo in algorithms:

        plt.plot(
            load_vals,
            large_results[algo],
            marker=marker_map[algo],
            linewidth=2,
            label=label_map[algo]
        )

    plt.xlabel("Network Load")
    plt.ylabel("Average FCT (s)")
    plt.title(f"{benchmark}: Large Flows (>1 MB)")
    plt.grid(True)
    plt.legend()

    out_path = graph_dir / f"{benchmark}_LARGE_vs_load.png"

    plt.tight_layout()
    plt.savefig(out_path, dpi=300)
    plt.close()

    print(f"Saved: {out_path}")

print("\nDone: Small vs Large flow comparison for all algorithms.")
# Out:
# ===== private_enterprise =====
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_LARGE_vs_load.png
#
# ===== social_media_cloud =====
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_LARGE_vs_load.png
#
# ===== commercial_cloud =====
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/commercial_cloud_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/commercial_cloud_LARGE_vs_load.png
#
# ===== university =====
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_SMALL_vs_load.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_LARGE_vs_load.png
#
# Done: Small vs Large flow comparison for all algorithms.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np
from itertools import combinations

# ------------------ CONFIG ------------------

save_dir = Path(
    "/home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results"
)

graph_dir = save_dir / "graph"
graph_dir.mkdir(parents=True, exist_ok=True)

benchmarks = [
    "private_enterprise",
    "social_media_cloud",
    "commercial_cloud",
    "university"
]

loads = range(1, 10)

SMALL = 100 * 1024       # 100 KB
LARGE = 1 * 1024 * 1024  # 1 MB

# ------------------ UPDATED (8 CURVES) ------------------

algorithms = [
    "conga",
    "ecmp",

    "weighted_true",
    "weighted_false",

    "random_true",
    "random_false",

    "top2_true",
    "top2_false"
]

label_map = {
    "conga": "Conga",
    "ecmp": "ECMP",

    "weighted_true": "Weighted ECMP (Timeout)",
    "weighted_false": "Weighted ECMP (No Timeout)",

    "random_true": "Power-of-2 Random (Timeout)",
    "random_false": "Power-of-2 Random (No Timeout)",

    "top2_true": "Power-of-2 Top2 (Timeout)",
    "top2_false": "Power-of-2 Top2 (No Timeout)"
}

# ------------------ MAIN ------------------

for benchmark in benchmarks:

    print(f"\n===== {benchmark} =====")

    load_vals = []

    small_results = {algo: [] for algo in algorithms}
    large_results = {algo: [] for algo in algorithms}

    for load in loads:

        csv_path = save_dir / f"{benchmark}_load_{load}_full.csv"

        if not csv_path.exists():
            print(f"Missing: {csv_path}")
            continue

        df = pd.read_csv(csv_path)

        if df.empty:
            continue

        # ------------------ FLOW SPLIT ------------------

        small_df = df[df["flow_size"] < SMALL]
        large_df = df[df["flow_size"] > LARGE]
        mid_df = ~(df["flow_size"] < SMALL) & ~(df["flow_size"] > LARGE)

        # ------------------ METRICS ------------------

        for algo in algorithms:

            col = f"FCT(s)_{algo}"

            if col not in df.columns:
                small_results[algo].append(np.nan)
                large_results[algo].append(np.nan)
                continue

            # small flows
            if not small_df.empty:
                small_results[algo].append(small_df[col].mean())
            else:
                small_results[algo].append(np.nan)

            # large flows
            if not large_df.empty:
                large_results[algo].append(large_df[col].mean())
            else:
                large_results[algo].append(np.nan)

        load_vals.append(load / 10)

        # ------------------ PAIRWISE SCATTER ------------------

        for a, b in combinations(algorithms, 2):

            col_a = f"FCT(s)_{a}"
            col_b = f"FCT(s)_{b}"

            if col_a not in df.columns or col_b not in df.columns:
                continue

            plt.figure(figsize=(7, 7))

            plt.scatter(
                df.loc[df["flow_size"] < SMALL, col_a],
                df.loc[df["flow_size"] < SMALL, col_b],
                alpha=0.5,
                label="Small (<100 KB)"
            )

            plt.scatter(
                df.loc[(df["flow_size"] >= SMALL) & (df["flow_size"] <= LARGE), col_a],
                df.loc[(df["flow_size"] >= SMALL) & (df["flow_size"] <= LARGE), col_b],
                alpha=0.5,
                label="Medium (100 KB - 1 MB)"
            )

            plt.scatter(
                df.loc[df["flow_size"] > LARGE, col_a],
                df.loc[df["flow_size"] > LARGE, col_b],
                alpha=0.5,
                label="Large (>1 MB)"
            )

            max_val = max(
                df[col_a].max(),
                df[col_b].max()
            )

            plt.plot(
                [0, max_val],
                [0, max_val],
                "--",
                color="black",
                label="y=x"
            )

            plt.xlabel(f"{label_map[a]} FCT (s)")
            plt.ylabel(f"{label_map[b]} FCT (s)")
            plt.title(
                f"{benchmark} Load 0.{load}\n"
                f"{label_map[b]} vs {label_map[a]}"
            )

            plt.grid(True)
            plt.legend()

            out_file = (
                graph_dir /
                f"{benchmark}_load_{load}_{a}_{b}_colored_scatter.png"
            )

            plt.tight_layout()
            plt.savefig(out_file, dpi=300)
            plt.close()

            print(f"Saved: {out_file}")

print("\nDone: Pairwise colored scatter plots generated for all algorithms.")
# Out:
# ===== private_enterprise =====
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_conga_ecmp_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_conga_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_conga_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_conga_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_conga_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_conga_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_conga_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_ecmp_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_ecmp_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_ecmp_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_ecmp_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_ecmp_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_ecmp_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_weighted_true_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_weighted_true_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_weighted_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_weighted_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_weighted_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_weighted_false_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_weighted_false_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_weighted_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_weighted_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_random_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_random_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_random_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_random_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_random_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_1_top2_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_conga_ecmp_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_conga_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_conga_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_conga_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_conga_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_conga_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_conga_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_ecmp_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_ecmp_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_ecmp_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_ecmp_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_ecmp_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_ecmp_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_weighted_true_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_weighted_true_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_weighted_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_weighted_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_weighted_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_weighted_false_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_weighted_false_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_weighted_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_weighted_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_random_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_random_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_random_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_random_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_random_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_2_top2_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_conga_ecmp_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_conga_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_conga_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_conga_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_conga_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_conga_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_conga_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_ecmp_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_ecmp_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_ecmp_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_ecmp_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_ecmp_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_ecmp_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_weighted_true_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_weighted_true_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_weighted_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_weighted_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_weighted_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_weighted_false_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_weighted_false_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_weighted_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_weighted_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_random_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_random_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_random_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_random_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_random_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_3_top2_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_conga_ecmp_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_conga_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_conga_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_conga_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_conga_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_conga_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_conga_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_ecmp_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_ecmp_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_ecmp_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_ecmp_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_ecmp_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_ecmp_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_weighted_true_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_weighted_true_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_weighted_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_weighted_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_weighted_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_weighted_false_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_weighted_false_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_weighted_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_weighted_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_random_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_random_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_random_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_random_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_random_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_4_top2_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_conga_ecmp_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_conga_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_conga_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_conga_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_conga_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_conga_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_conga_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_ecmp_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_ecmp_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_ecmp_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_ecmp_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_ecmp_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_ecmp_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_weighted_true_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_weighted_true_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_weighted_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_weighted_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_weighted_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_weighted_false_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_weighted_false_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_weighted_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_weighted_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_random_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_random_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_random_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_random_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_random_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_5_top2_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_conga_ecmp_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_conga_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_conga_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_conga_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_conga_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_conga_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_conga_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_ecmp_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_ecmp_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_ecmp_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_ecmp_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_ecmp_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_ecmp_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_weighted_true_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_weighted_true_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_weighted_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_weighted_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_weighted_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_weighted_false_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_weighted_false_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_weighted_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_weighted_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_random_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_random_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_random_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_random_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_random_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_6_top2_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_conga_ecmp_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_conga_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_conga_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_conga_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_conga_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_conga_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_conga_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_ecmp_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_ecmp_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_ecmp_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_ecmp_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_ecmp_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_ecmp_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_weighted_true_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_weighted_true_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_weighted_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_weighted_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_weighted_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_weighted_false_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_weighted_false_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_weighted_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_weighted_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_random_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_random_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_random_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_random_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_random_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_7_top2_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_conga_ecmp_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_conga_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_conga_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_conga_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_conga_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_conga_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_conga_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_ecmp_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_ecmp_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_ecmp_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_ecmp_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_ecmp_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_ecmp_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_weighted_true_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_weighted_true_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_weighted_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_weighted_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_weighted_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_weighted_false_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_weighted_false_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_weighted_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_weighted_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_random_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_random_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_random_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_random_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_random_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_8_top2_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_conga_ecmp_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_conga_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_conga_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_conga_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_conga_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_conga_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_conga_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_ecmp_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_ecmp_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_ecmp_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_ecmp_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_ecmp_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_ecmp_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_weighted_true_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_weighted_true_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_weighted_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_weighted_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_weighted_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_weighted_false_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_weighted_false_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_weighted_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_weighted_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_random_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_random_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_random_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_random_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_random_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/private_enterprise_load_9_top2_true_top2_false_colored_scatter.png
#
# ===== social_media_cloud =====
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_conga_ecmp_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_conga_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_conga_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_conga_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_conga_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_conga_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_conga_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_ecmp_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_ecmp_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_ecmp_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_ecmp_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_ecmp_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_ecmp_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_weighted_true_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_weighted_true_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_weighted_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_weighted_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_weighted_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_weighted_false_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_weighted_false_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_weighted_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_weighted_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_random_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_random_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_random_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_random_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_random_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_1_top2_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_2_conga_ecmp_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_2_conga_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_2_conga_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_2_conga_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_2_conga_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_2_conga_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_2_conga_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_2_ecmp_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_2_ecmp_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_2_ecmp_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_2_ecmp_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_2_ecmp_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_2_ecmp_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_2_weighted_true_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_2_weighted_true_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_2_weighted_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_2_weighted_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_2_weighted_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_2_weighted_false_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_2_weighted_false_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_2_weighted_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/social_media_cloud_load_2_weighted_false_top2_false_colored_scatter.png
# ...
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_6_ecmp_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_6_ecmp_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_6_ecmp_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_6_ecmp_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_6_ecmp_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_6_ecmp_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_6_weighted_true_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_6_weighted_true_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_6_weighted_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_6_weighted_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_6_weighted_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_6_weighted_false_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_6_weighted_false_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_6_weighted_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_6_weighted_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_6_random_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_6_random_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_6_random_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_6_random_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_6_random_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_6_top2_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_conga_ecmp_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_conga_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_conga_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_conga_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_conga_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_conga_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_conga_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_ecmp_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_ecmp_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_ecmp_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_ecmp_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_ecmp_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_ecmp_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_weighted_true_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_weighted_true_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_weighted_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_weighted_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_weighted_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_weighted_false_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_weighted_false_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_weighted_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_weighted_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_random_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_random_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_random_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_random_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_random_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_7_top2_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_conga_ecmp_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_conga_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_conga_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_conga_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_conga_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_conga_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_conga_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_ecmp_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_ecmp_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_ecmp_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_ecmp_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_ecmp_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_ecmp_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_weighted_true_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_weighted_true_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_weighted_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_weighted_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_weighted_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_weighted_false_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_weighted_false_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_weighted_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_weighted_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_random_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_random_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_random_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_random_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_random_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_8_top2_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_conga_ecmp_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_conga_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_conga_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_conga_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_conga_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_conga_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_conga_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_ecmp_weighted_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_ecmp_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_ecmp_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_ecmp_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_ecmp_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_ecmp_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_weighted_true_weighted_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_weighted_true_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_weighted_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_weighted_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_weighted_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_weighted_false_random_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_weighted_false_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_weighted_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_weighted_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_random_true_random_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_random_true_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_random_true_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_random_false_top2_true_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_random_false_top2_false_colored_scatter.png
# Saved: /home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results/graph/university_load_9_top2_true_top2_false_colored_scatter.png
#
# Done: Pairwise colored scatter plots generated for all algorithms.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

# ------------------ CONFIG ------------------

save_dir = Path(
    "/home/hsd/workspace/ns3-load-balance/results_rtt_fix1_link_3/analysis_results"
)

baseline = "conga"

graph_dir = save_dir / f"graph/fct/normalised_vs_{baseline}"
graph_dir.mkdir(parents=True, exist_ok=True)


benchmarks = [
    "private_enterprise",
    "social_media_cloud",
    "commercial_cloud",
    "university"
]

loads = range(1, 10)

SMALL = 100 * 1024
LARGE = 1 * 1024 * 1024



# ------------------ UPDATED (8 CURVES) ------------------

algorithms = [
    "ecmp",

    "weighted_true",
    "weighted_false",

    "random_true",
    "random_false",

    "top2_true",
    "top2_false"
]

label_map = {
    "ecmp": "ECMP",

    "weighted_true": "Weighted ECMP (Timeout)",
    "weighted_false": "Weighted ECMP (No Timeout)",

    "random_true": "Power-of-2 Random (Timeout)",
    "random_false": "Power-of-2 Random (No Timeout)",

    "top2_true": "Power-of-2 Top2 (Timeout)",
    "top2_false": "Power-of-2 Top2 (No Timeout)"
}

marker_map = {
    "ecmp": "o",

    "weighted_true": "^",
    "weighted_false": "v",

    "random_true": "D",
    "random_false": "X",

    "top2_true": "P",
    "top2_false": "s"
}

# =========================================================
# MAIN
# =========================================================

for benchmark in benchmarks:

    print(f"\n===== {benchmark} =====")

    load_vals = []

    small_results = {algo: [] for algo in algorithms}
    large_results = {algo: [] for algo in algorithms}

    for load in loads:

        csv_path = save_dir / f"{benchmark}_load_{load}_full.csv"

        if not csv_path.exists():
            continue

        df = pd.read_csv(csv_path)

        if df.empty:
            continue

        # -------------------------------------------------
        # Avoid divide-by-zero
        # -------------------------------------------------

        base_col = f"FCT(s)_{baseline}"
        if base_col not in df.columns:
            continue

        df = df[df[base_col] > 0]

        if df.empty:
            continue

        # -------------------------------------------------
        # NORMALIZED FCT
        # -------------------------------------------------

        #for algo in algorithms:

         #   col = f"FCT(s)_{algo}"

          #  if col not in df.columns:
           #     df[f"{algo}_vs_{baseline}"] = np.nan
            #    continue

            #df[f"{algo}_vs_{baseline}"] = (
             #   df[col] / df[base_col]
            #)

        # -------------------------------------------------
        # FLOW SIZE SPLIT
        # -------------------------------------------------

        small_df = df[df["flow_size"] < SMALL]
        large_df = df[df["flow_size"] > LARGE]

        #for algo in algorithms:

         #   col = f"{algo}_vs_{baseline}"

          #  if not small_df.empty:
           #     small_results[algo].append(small_df[col].mean())
            #else:
             #   small_results[algo].append(np.nan)

            #if not large_df.empty:
             #   large_results[algo].append(large_df[col].mean())
            #else:
             #   large_results[algo].append(np.nan)

        for algo in algorithms:

            algo_col = f"FCT(s)_{algo}"

            # Skip if algorithm column is missing
            if algo_col not in df.columns:
                small_results[algo].append(np.nan)
                large_results[algo].append(np.nan)
                continue
        
            # ----- Small flows -----
            if not small_df.empty:
                algo_mean = small_df[algo_col].mean()
                baseline_mean = small_df[base_col].mean()
        
                small_results[algo].append(
                    algo_mean / baseline_mean if baseline_mean > 0 else np.nan
                )
            else:
                small_results[algo].append(np.nan)
        
            # ----- Large flows -----
            if not large_df.empty:
                algo_mean = large_df[algo_col].mean()
                baseline_mean = large_df[base_col].mean()
        
                large_results[algo].append(
                    algo_mean / baseline_mean if baseline_mean > 0 else np.nan
                )
            else:
                large_results[algo].append(np.nan)

        load_vals.append(load / 10)

    # =====================================================
    # SMALL FLOWS
    # =====================================================

    plt.figure(figsize=(8, 6), dpi=120)

    for algo in algorithms:

        plt.plot(
            load_vals,
            small_results[algo],
            marker=marker_map[algo],
            linewidth=2,
            label=f"{label_map[algo]} / Conga"
        )

    plt.axhline(
        y=1,
        linestyle="--",
        color="black"
    )

    plt.xlabel("Network Load")
    plt.ylabel("Normalized FCT (vs Conga)")
    plt.title(f"{benchmark}: Small Flows (<100 KB)")

    plt.grid(True)
    plt.legend()
    plt.tight_layout()

    plt.savefig(
        graph_dir / f"{benchmark}_SMALL_relative_vs_load.png",
        dpi=300
    )

    plt.close()

    # =====================================================
    # LARGE FLOWS
    # =====================================================

    plt.figure(figsize=(8, 6), dpi=120)

    for algo in algorithms:

        plt.plot(
            load_vals,
            large_results[algo],
            marker=marker_map[algo],
            linewidth=2,
            label=f"{label_map[algo]} / Conga"
        )

    plt.axhline(
        y=1,
        linestyle="--",
        color="black"
    )

    plt.xlabel("Network Load")
    plt.ylabel("Normalized FCT (vs Conga)")
    plt.title(f"{benchmark}: Large Flows (>1 MB)")

    plt.grid(True)
    plt.legend()
    plt.tight_layout()

    plt.savefig(
        graph_dir / f"{benchmark}_LARGE_relative_vs_load.png",
        dpi=300
    )

    plt.close()

    print(f"Finished {benchmark}")

print("\nDone: Normalized FCT graphs generated.")
# Out:
# ===== private_enterprise =====
# Finished private_enterprise
#
# ===== social_media_cloud =====
# Finished social_media_cloud
#
# ===== commercial_cloud =====
# Finished commercial_cloud
#
# ===== university =====
# Finished university
#
# Done: Normalized FCT graphs generated.
