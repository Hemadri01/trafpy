# %%
import trafpy.generator as tpg
from trafpy.benchmarker import BenchmarkImporter

from pathlib import Path
import time

# ------------------ NETWORK SETUP ------------------
num_eps = 8
num_racks = 2

racks_dict = {}
eps_per_rack = int(num_eps / num_racks)

for rack in range(num_racks):
    racks_dict[rack] = [
        ep for ep in range(rack * eps_per_rack,
                           (rack * eps_per_rack) + eps_per_rack)
    ]

print("racks_dict:", racks_dict)

# 100 Mbps → Bytes/sec
ep_capacity = 100000000 / 8

net = tpg.gen_arbitrary_network(
    num_eps=num_eps,
    ep_capacity=ep_capacity,
    racks_dict=racks_dict
)

# ------------------ NETWORK INFO ------------------
print("\n--- NETWORK INFO ---")
print("topology_type:", net.graph['topology_type'])
print("max_nw_capacity:", net.graph['max_nw_capacity'])
print("endpoints:", net.graph['endpoints'])

# ------------------ BENCHMARK SETUP ------------------
importer = BenchmarkImporter(
    benchmark_version='v001',
    load_prev_dists=False
)

# Add/remove benchmarks here
benchmark_names = [
    'private_enterprise',
    'social_media_cloud',
    'commercial_cloud',
    'university'    
]

# ------------------ OUTPUT DIR ------------------
path_to_data = "8_hosts_v4/"
Path(path_to_data).mkdir(exist_ok=True, parents=True)

# ------------------ PARAMETERS ------------------
jsd_threshold = 0.9
loads = [i / 10 for i in range(1, 10)]  # 0.1 → 0.9

# ------------------ MAIN LOOP ------------------
for benchmark_name in benchmark_names:
    print(f"\n==============================")
    print(f"Benchmark: {benchmark_name}")
    print(f"==============================")

    # Load distributions for this benchmark
    dists = importer.get_benchmark_dists(
        benchmark_name=benchmark_name,
        eps=net.graph['endpoints'],
        racks_dict=net.graph['rack_to_ep_dict']
    )

    print("Loaded distributions:", list(dists.keys()))

    # Loop over loads
    for load in loads:
        print(f"\n--- Load {load} ---")
        start_time = time.time()

        network_load_config = {
            'network_rate_capacity': net.graph['max_nw_capacity'],
            'ep_link_capacity': net.graph['ep_link_capacity'],
            'target_load_fraction': load
        }

        demand_data = tpg.create_demand_data(
            eps=net.graph['endpoints'],
            node_dist=dists['node_dist'],
            flow_size_dist=dists['flow_size_dist'],
            interarrival_time_dist=dists['interarrival_time_dist'],
            #min_num_demands=40000,
            network_load_config=network_load_config,
            jensen_shannon_distance_threshold=jsd_threshold
        )

        # ------------------ SAVE ------------------
        filename = f"{path_to_data}{benchmark_name}_load_{int(load*10)}.csv"

        tpg.save_data_as_csv(
            data=demand_data,
            path_to_save=filename,
            overwrite=True
        )

        print(f"Saved: {filename}")
        print(f"Time: {time.time() - start_time:.2f}s")

print("\n All datasets generated!")
# Out:
# racks_dict: {0: [0, 1, 2, 3], 1: [4, 5, 6, 7]}
#
# --- NETWORK INFO ---
# topology_type: arbitrary_endpoints_8_chancap_12500000.0_channels_1
# max_nw_capacity: 50000000.0
# endpoints: ['0', '1', '2', '3', '4', '5', '6', '7']
# load_prev_dist=False. Will re-generate dists with given network params and override any previously saved distributions.
#
# ==============================
# Benchmark: private_enterprise
# ==============================
# Set to save benchmark private_enterprise distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/private_enterprise/
# Saved node_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/private_enterprise/
# Saved flow_size_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/private_enterprise/
# Saved interarrival_time_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/private_enterprise/
# Loaded distributions: ['node_dist', 'flow_size_dist', 'interarrival_time_dist', 'num_ops_dist']
#
# --- Load 0.1 ---
# Packed 6000 flows in 0.379 s | Node distribution Jensen Shannon distance from target achieved: 0.06363263719394997
# Time to save data to 8_hosts_v4/private_enterprise_load_1.csv: 0.02325439453125 s
# Saved: 8_hosts_v4/private_enterprise_load_1.csv
# Time: 0.43s
#
# --- Load 0.2 ---
# Packed 6000 flows in 0.395 s | Node distribution Jensen Shannon distance from target achieved: 0.05332527369084339
# Time to save data to 8_hosts_v4/private_enterprise_load_2.csv: 0.024712085723876953 s
# Saved: 8_hosts_v4/private_enterprise_load_2.csv
# Time: 0.45s
#
# --- Load 0.3 ---
# Packed 6000 flows in 0.395 s | Node distribution Jensen Shannon distance from target achieved: 0.09200513060208719
# Time to save data to 8_hosts_v4/private_enterprise_load_3.csv: 0.024233579635620117 s
# Saved: 8_hosts_v4/private_enterprise_load_3.csv
# Time: 0.46s
#
# --- Load 0.4 ---
# Packed 6000 flows in 0.406 s | Node distribution Jensen Shannon distance from target achieved: 0.08521047617437372
# Time to save data to 8_hosts_v4/private_enterprise_load_4.csv: 0.02306675910949707 s
# Saved: 8_hosts_v4/private_enterprise_load_4.csv
# Time: 0.46s
#
# --- Load 0.5 ---
# Packed 6000 flows in 0.428 s | Node distribution Jensen Shannon distance from target achieved: 0.023200278754873998
# Time to save data to 8_hosts_v4/private_enterprise_load_5.csv: 0.02370166778564453 s
# Saved: 8_hosts_v4/private_enterprise_load_5.csv
# Time: 0.49s
#
# --- Load 0.6 ---
# Packed 6000 flows in 0.444 s | Node distribution Jensen Shannon distance from target achieved: 0.0640977483107171
# Time to save data to 8_hosts_v4/private_enterprise_load_6.csv: 0.026354551315307617 s
# Saved: 8_hosts_v4/private_enterprise_load_6.csv
# Time: 0.51s
#
# --- Load 0.7 ---
# Packed 6000 flows in 0.448 s | Node distribution Jensen Shannon distance from target achieved: 0.06597478101410922
# Time to save data to 8_hosts_v4/private_enterprise_load_7.csv: 0.02656388282775879 s
# Saved: 8_hosts_v4/private_enterprise_load_7.csv
# Time: 0.51s
#
# --- Load 0.8 ---
# Packed 6000 flows in 0.485 s | Node distribution Jensen Shannon distance from target achieved: 0.016267490944346066
# Time to save data to 8_hosts_v4/private_enterprise_load_8.csv: 0.029774904251098633 s
# Saved: 8_hosts_v4/private_enterprise_load_8.csv
# Time: 0.56s
#
# --- Load 0.9 ---
# Packed 6000 flows in 0.472 s | Node distribution Jensen Shannon distance from target achieved: 0.2645014035621679
# Time to save data to 8_hosts_v4/private_enterprise_load_9.csv: 0.028154850006103516 s
# Saved: 8_hosts_v4/private_enterprise_load_9.csv
# Time: 0.54s
#
# ==============================
# Benchmark: social_media_cloud
# ==============================
# Set to save benchmark social_media_cloud distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/social_media_cloud/
# Saved node_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/social_media_cloud/
# Saved flow_size_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/social_media_cloud/
# Saved interarrival_time_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/social_media_cloud/
# Loaded distributions: ['node_dist', 'flow_size_dist', 'interarrival_time_dist', 'num_ops_dist']
#
# --- Load 0.1 ---
# Packed 6000 flows in 0.427 s | Node distribution Jensen Shannon distance from target achieved: inf
# Time to save data to 8_hosts_v4/social_media_cloud_load_1.csv: 0.02395796775817871 s
# Saved: 8_hosts_v4/social_media_cloud_load_1.csv
# Time: 0.50s
#
# --- Load 0.2 ---
# Packed 6000 flows in 0.433 s | Node distribution Jensen Shannon distance from target achieved: inf
# Time to save data to 8_hosts_v4/social_media_cloud_load_2.csv: 0.02364349365234375 s
# Saved: 8_hosts_v4/social_media_cloud_load_2.csv
# Time: 0.50s
#
# --- Load 0.3 ---
# Packed 6000 flows in 0.412 s | Node distribution Jensen Shannon distance from target achieved: inf
# Time to save data to 8_hosts_v4/social_media_cloud_load_3.csv: 0.030886173248291016 s
# Saved: 8_hosts_v4/social_media_cloud_load_3.csv
# Time: 0.49s
#
# --- Load 0.4 ---
# Packed 6000 flows in 0.443 s | Node distribution Jensen Shannon distance from target achieved: inf
# Time to save data to 8_hosts_v4/social_media_cloud_load_4.csv: 0.028572559356689453 s
# Saved: 8_hosts_v4/social_media_cloud_load_4.csv
# Time: 0.52s
#
# --- Load 0.5 ---
# Packed 6000 flows in 0.461 s | Node distribution Jensen Shannon distance from target achieved: inf
# Time to save data to 8_hosts_v4/social_media_cloud_load_5.csv: 0.025710105895996094 s
# Saved: 8_hosts_v4/social_media_cloud_load_5.csv
# Time: 0.54s
#
# --- Load 0.6 ---
# Packed 6000 flows in 0.460 s | Node distribution Jensen Shannon distance from target achieved: inf
# Time to save data to 8_hosts_v4/social_media_cloud_load_6.csv: 0.02722334861755371 s
# Saved: 8_hosts_v4/social_media_cloud_load_6.csv
# Time: 0.54s
#
# --- Load 0.7 ---
# Packed 6000 flows in 0.433 s | Node distribution Jensen Shannon distance from target achieved: inf
# Time to save data to 8_hosts_v4/social_media_cloud_load_7.csv: 0.025292396545410156 s
# Saved: 8_hosts_v4/social_media_cloud_load_7.csv
# Time: 0.51s
#
# --- Load 0.8 ---
# Packed 6000 flows in 0.442 s | Node distribution Jensen Shannon distance from target achieved: inf
# Time to save data to 8_hosts_v4/social_media_cloud_load_8.csv: 0.02634143829345703 s
# Saved: 8_hosts_v4/social_media_cloud_load_8.csv
# Time: 0.52s
#
# --- Load 0.9 ---
# Packed 6000 flows in 0.456 s | Node distribution Jensen Shannon distance from target achieved: inf
# Time to save data to 8_hosts_v4/social_media_cloud_load_9.csv: 0.02708292007446289 s
# Saved: 8_hosts_v4/social_media_cloud_load_9.csv
# Time: 0.53s
#
# ==============================
# Benchmark: commercial_cloud
# ==============================
# Set to save benchmark commercial_cloud distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/commercial_cloud/
# Saved node_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/commercial_cloud/
# Saved flow_size_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/commercial_cloud/
# Saved interarrival_time_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/commercial_cloud/
# Loaded distributions: ['node_dist', 'flow_size_dist', 'interarrival_time_dist', 'num_ops_dist']
#
# --- Load 0.1 ---
# Packed 6000 flows in 0.411 s | Node distribution Jensen Shannon distance from target achieved: 0.0789084851104986
# Time to save data to 8_hosts_v4/commercial_cloud_load_1.csv: 0.027741432189941406 s
# Saved: 8_hosts_v4/commercial_cloud_load_1.csv
# Time: 0.47s
#
# --- Load 0.2 ---
# Packed 6000 flows in 0.402 s | Node distribution Jensen Shannon distance from target achieved: 0.16112474842225918
# Time to save data to 8_hosts_v4/commercial_cloud_load_2.csv: 0.02539205551147461 s
# Saved: 8_hosts_v4/commercial_cloud_load_2.csv
# Time: 0.46s
#
# --- Load 0.3 ---
# Packed 6000 flows in 0.468 s | Node distribution Jensen Shannon distance from target achieved: 1.6907897636955009e-06
# Time to save data to 8_hosts_v4/commercial_cloud_load_3.csv: 0.029403209686279297 s
# Saved: 8_hosts_v4/commercial_cloud_load_3.csv
# Time: 0.53s
#
# --- Load 0.4 ---
# Packed 6000 flows in 0.474 s | Node distribution Jensen Shannon distance from target achieved: 0.04594893090619969
# Time to save data to 8_hosts_v4/commercial_cloud_load_4.csv: 0.02792048454284668 s
# Saved: 8_hosts_v4/commercial_cloud_load_4.csv
# Time: 0.54s
#
# --- Load 0.5 ---
# Packed 6000 flows in 0.435 s | Node distribution Jensen Shannon distance from target achieved: 0.024534667424003086
# Time to save data to 8_hosts_v4/commercial_cloud_load_5.csv: 0.027028322219848633 s
# Saved: 8_hosts_v4/commercial_cloud_load_5.csv
# Time: 0.50s
#
# --- Load 0.6 ---
# Packed 6000 flows in 0.429 s | Node distribution Jensen Shannon distance from target achieved: 0.1393598041561292
# Time to save data to 8_hosts_v4/commercial_cloud_load_6.csv: 0.02381587028503418 s
# Saved: 8_hosts_v4/commercial_cloud_load_6.csv
# Time: 0.49s
#
# --- Load 0.7 ---
# Packed 6000 flows in 0.438 s | Node distribution Jensen Shannon distance from target achieved: 0.07948718316998783
# Time to save data to 8_hosts_v4/commercial_cloud_load_7.csv: 0.02622675895690918 s
# Saved: 8_hosts_v4/commercial_cloud_load_7.csv
# Time: 0.50s
#
# --- Load 0.8 ---
# Packed 6000 flows in 0.432 s | Node distribution Jensen Shannon distance from target achieved: 0.22432262519561294
# Time to save data to 8_hosts_v4/commercial_cloud_load_8.csv: 0.024962663650512695 s
# Saved: 8_hosts_v4/commercial_cloud_load_8.csv
# Time: 0.50s
#
# --- Load 0.9 ---
# Packed 6000 flows in 0.397 s | Node distribution Jensen Shannon distance from target achieved: 0.21168657905482735
# Time to save data to 8_hosts_v4/commercial_cloud_load_9.csv: 0.024219512939453125 s
# Saved: 8_hosts_v4/commercial_cloud_load_9.csv
# Time: 0.46s
#
# ==============================
# Benchmark: university
# ==============================
# Set to save benchmark university distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/university/
# Saved node_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/university/
# Saved flow_size_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/university/
# Saved interarrival_time_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/university/
# Loaded distributions: ['node_dist', 'flow_size_dist', 'interarrival_time_dist', 'num_ops_dist']
#
# --- Load 0.1 ---
# Packed 6000 flows in 0.404 s | Node distribution Jensen Shannon distance from target achieved: 0.052710462103812084
# Time to save data to 8_hosts_v4/university_load_1.csv: 0.0247495174407959 s
# Saved: 8_hosts_v4/university_load_1.csv
# Time: 0.46s
#
# --- Load 0.2 ---
# Packed 6000 flows in 0.409 s | Node distribution Jensen Shannon distance from target achieved: 0.051588230180685576
# Time to save data to 8_hosts_v4/university_load_2.csv: 0.023888349533081055 s
# Saved: 8_hosts_v4/university_load_2.csv
# Time: 0.47s
#
# --- Load 0.3 ---
# Packed 6000 flows in 0.398 s | Node distribution Jensen Shannon distance from target achieved: 0.016719799232319553
# Time to save data to 8_hosts_v4/university_load_3.csv: 0.024451494216918945 s
# Saved: 8_hosts_v4/university_load_3.csv
# Time: 0.46s
#
# --- Load 0.4 ---
# Packed 6000 flows in 0.466 s | Node distribution Jensen Shannon distance from target achieved: 0.06629780788731267
# Time to save data to 8_hosts_v4/university_load_4.csv: 0.02761387825012207 s
# Saved: 8_hosts_v4/university_load_4.csv
# Time: 0.53s
#
# --- Load 0.5 ---
# Packed 6000 flows in 0.461 s | Node distribution Jensen Shannon distance from target achieved: 0.1468499145699952
# Time to save data to 8_hosts_v4/university_load_5.csv: 0.02574634552001953 s
# Saved: 8_hosts_v4/university_load_5.csv
# Time: 0.53s
#
# --- Load 0.6 ---
# Packed 6000 flows in 0.472 s | Node distribution Jensen Shannon distance from target achieved: 7.86952189222128e-07
# Time to save data to 8_hosts_v4/university_load_6.csv: 0.027074575424194336 s
# Saved: 8_hosts_v4/university_load_6.csv
# Time: 0.54s
#
# --- Load 0.7 ---
# Packed 6000 flows in 0.452 s | Node distribution Jensen Shannon distance from target achieved: 0.2022382256987015
# Time to save data to 8_hosts_v4/university_load_7.csv: 0.02740335464477539 s
# Saved: 8_hosts_v4/university_load_7.csv
# Time: 0.52s
#
# --- Load 0.8 ---
# Packed 6000 flows in 0.441 s | Node distribution Jensen Shannon distance from target achieved: 0.06360130176102832
# Time to save data to 8_hosts_v4/university_load_8.csv: 0.025612592697143555 s
# Saved: 8_hosts_v4/university_load_8.csv
# Time: 0.51s
#
# --- Load 0.9 ---
# Packed 6000 flows in 0.403 s | Node distribution Jensen Shannon distance from target achieved: 0.30287707836519717
# Time to save data to 8_hosts_v4/university_load_9.csv: 0.024051666259765625 s
# Saved: 8_hosts_v4/university_load_9.csv
# Time: 0.47s
#
#  All datasets generated!
