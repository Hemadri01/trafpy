# %%
import trafpy.generator as tpg
from trafpy.benchmarker import BenchmarkImporter

from pathlib import Path
import time

# ------------------ NETWORK SETUP ------------------
num_eps = 4
num_racks = 2

racks_dict = {}
eps_per_rack = int(num_eps / num_racks)

for rack in range(num_racks):
    racks_dict[rack] = [
        ep for ep in range(rack * eps_per_rack,
                           (rack * eps_per_rack) + eps_per_rack)
    ]

print("racks_dict:", racks_dict)

# 100 Mbps → Bytes/sec
ep_capacity = 100000000 / 8

net = tpg.gen_arbitrary_network(
    num_eps=num_eps,
    ep_capacity=ep_capacity,
    racks_dict=racks_dict
)

# ------------------ NETWORK INFO ------------------
print("\n--- NETWORK INFO ---")
print("topology_type:", net.graph['topology_type'])
print("max_nw_capacity:", net.graph['max_nw_capacity'])
print("endpoints:", net.graph['endpoints'])

# ------------------ BENCHMARK SETUP ------------------
importer = BenchmarkImporter(
    benchmark_version='v001',
    load_prev_dists=False
)

# 👉 Add/remove benchmarks here
benchmark_names = [
    'private_enterprise',
    'social_media_cloud',
    'commercial_cloud',
    'university'    
]

# ------------------ OUTPUT DIR ------------------
path_to_data = "final_data/"
Path(path_to_data).mkdir(exist_ok=True, parents=True)

# ------------------ PARAMETERS ------------------
jsd_threshold = 0.9
loads = [i / 10 for i in range(1, 10)]  # 0.1 → 0.9

# ------------------ MAIN LOOP ------------------
for benchmark_name in benchmark_names:
    print(f"\n==============================")
    print(f"Benchmark: {benchmark_name}")
    print(f"==============================")

    # Load distributions for this benchmark
    dists = importer.get_benchmark_dists(
        benchmark_name=benchmark_name,
        eps=net.graph['endpoints'],
        racks_dict=net.graph['rack_to_ep_dict']
    )

    print("Loaded distributions:", list(dists.keys()))

    # Loop over loads
    for load in loads:
        print(f"\n--- Load {load} ---")
        start_time = time.time()

        network_load_config = {
            'network_rate_capacity': net.graph['max_nw_capacity'],
            'ep_link_capacity': net.graph['ep_link_capacity'],
            'target_load_fraction': load
        }

        demand_data = tpg.create_demand_data(
            eps=net.graph['endpoints'],
            node_dist=dists['node_dist'],
            flow_size_dist=dists['flow_size_dist'],
            interarrival_time_dist=dists['interarrival_time_dist'],
            network_load_config=network_load_config,
            jensen_shannon_distance_threshold=jsd_threshold
        )

        # ------------------ SAVE ------------------
        filename = f"{path_to_data}{benchmark_name}_load_{int(load*10)}.csv"

        tpg.save_data_as_csv(
            data=demand_data,
            path_to_save=filename,
            overwrite=True
        )

        print(f"Saved: {filename}")
        print(f"Time: {time.time() - start_time:.2f}s")

print("\n All datasets generated!")
# Out:
# racks_dict: {0: [0, 1], 1: [2, 3]}
#
# --- NETWORK INFO ---
# topology_type: arbitrary_endpoints_4_chancap_12500000.0_channels_1
# max_nw_capacity: 25000000.0
# endpoints: ['0', '1', '2', '3']
# load_prev_dist=False. Will re-generate dists with given network params and override any previously saved distributions.
#
# ==============================
# Benchmark: private_enterprise
# ==============================
# Set to save benchmark private_enterprise distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/private_enterprise/
# Saved node_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/private_enterprise/
# Saved flow_size_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/private_enterprise/
# Saved interarrival_time_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/private_enterprise/
# Loaded distributions: ['node_dist', 'flow_size_dist', 'interarrival_time_dist', 'num_ops_dist']
#
# --- Load 0.1 ---
# Packed 6000 flows in 0.287 s | Node distribution Jensen Shannon distance from target achieved: 1.7931568354397423e-09
# Time to save data to final_data/private_enterprise_load_1.csv: 0.10100340843200684 s
# Saved: final_data/private_enterprise_load_1.csv
# Time: 0.46s
#
# --- Load 0.2 ---
# Packed 6000 flows in 0.235 s | Node distribution Jensen Shannon distance from target achieved: 1.6941528897837522e-08
# Time to save data to final_data/private_enterprise_load_2.csv: 0.02063465118408203 s
# Saved: final_data/private_enterprise_load_2.csv
# Time: 0.28s
#
# --- Load 0.3 ---
# Packed 6000 flows in 0.239 s | Node distribution Jensen Shannon distance from target achieved: 8.130925329885266e-09
# Time to save data to final_data/private_enterprise_load_3.csv: 0.01930403709411621 s
# Saved: final_data/private_enterprise_load_3.csv
# Time: 0.28s
#
# --- Load 0.4 ---
# Packed 6000 flows in 0.239 s | Node distribution Jensen Shannon distance from target achieved: 1.33898239375633e-08
# Time to save data to final_data/private_enterprise_load_4.csv: 0.016559839248657227 s
# Saved: final_data/private_enterprise_load_4.csv
# Time: 0.28s
#
# --- Load 0.5 ---
# Packed 6000 flows in 0.232 s | Node distribution Jensen Shannon distance from target achieved: nan
# Time to save data to final_data/private_enterprise_load_5.csv: 0.017330408096313477 s
# Saved: final_data/private_enterprise_load_5.csv
# Time: 0.27s
#
# --- Load 0.6 ---
# Packed 6000 flows in 0.227 s | Node distribution Jensen Shannon distance from target achieved: 1.5822835928019907e-08
# Time to save data to final_data/private_enterprise_load_6.csv: 0.016231060028076172 s
# Saved: final_data/private_enterprise_load_6.csv
# Time: 0.27s
#
# --- Load 0.7 ---
# Packed 6000 flows in 0.231 s | Node distribution Jensen Shannon distance from target achieved: 1.7316688975144158e-08
# Time to save data to final_data/private_enterprise_load_7.csv: 0.016954660415649414 s
# Saved: final_data/private_enterprise_load_7.csv
# Time: 0.27s
#
# --- Load 0.8 ---
# Packed 6000 flows in 0.247 s | Node distribution Jensen Shannon distance from target achieved: 1.9027469357285713e-08
# Time to save data to final_data/private_enterprise_load_8.csv: 0.01687455177307129 s
# Saved: final_data/private_enterprise_load_8.csv
# Time: 0.29s
#
# --- Load 0.9 ---
# Packed 6000 flows in 0.229 s | Node distribution Jensen Shannon distance from target achieved: 1.0833440060452334e-08
# Time to save data to final_data/private_enterprise_load_9.csv: 0.016846895217895508 s
# Saved: final_data/private_enterprise_load_9.csv
# Time: 0.27s
#
# ==============================
# Benchmark: social_media_cloud
# ==============================
# Set to save benchmark social_media_cloud distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/social_media_cloud/
# Saved node_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/social_media_cloud/
# Saved flow_size_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/social_media_cloud/
# Saved interarrival_time_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/social_media_cloud/
# Loaded distributions: ['node_dist', 'flow_size_dist', 'interarrival_time_dist', 'num_ops_dist']
#
# --- Load 0.1 ---
# Packed 6000 flows in 0.236 s | Node distribution Jensen Shannon distance from target achieved: 7.51430586057224e-08
# Time to save data to final_data/social_media_cloud_load_1.csv: 0.016659975051879883 s
# Saved: final_data/social_media_cloud_load_1.csv
# Time: 0.28s
#
# --- Load 0.2 ---
# Packed 6000 flows in 0.240 s | Node distribution Jensen Shannon distance from target achieved: 1.6580361361259926e-07
# Time to save data to final_data/social_media_cloud_load_2.csv: 0.018268108367919922 s
# Saved: final_data/social_media_cloud_load_2.csv
# Time: 0.29s
#
# --- Load 0.3 ---
# Packed 6000 flows in 0.259 s | Node distribution Jensen Shannon distance from target achieved: 1.7824592244721018e-07
# Time to save data to final_data/social_media_cloud_load_3.csv: 0.018171310424804688 s
# Saved: final_data/social_media_cloud_load_3.csv
# Time: 0.31s
#
# --- Load 0.4 ---
# Packed 6000 flows in 0.248 s | Node distribution Jensen Shannon distance from target achieved: 2.2783103882726247e-08
# Time to save data to final_data/social_media_cloud_load_4.csv: 0.017500877380371094 s
# Saved: final_data/social_media_cloud_load_4.csv
# Time: 0.29s
#
# --- Load 0.5 ---
# Packed 6000 flows in 0.237 s | Node distribution Jensen Shannon distance from target achieved: 4.991166345752373e-09
# Time to save data to final_data/social_media_cloud_load_5.csv: 0.016939401626586914 s
# Saved: final_data/social_media_cloud_load_5.csv
# Time: 0.28s
#
# --- Load 0.6 ---
# Packed 6000 flows in 0.247 s | Node distribution Jensen Shannon distance from target achieved: 2.8719369497991987e-08
# Time to save data to final_data/social_media_cloud_load_6.csv: 0.01786661148071289 s
# Saved: final_data/social_media_cloud_load_6.csv
# Time: 0.29s
#
# --- Load 0.7 ---
# Packed 6000 flows in 0.233 s | Node distribution Jensen Shannon distance from target achieved: 8.280514040682485e-09
# Time to save data to final_data/social_media_cloud_load_7.csv: 0.016232013702392578 s
# Saved: final_data/social_media_cloud_load_7.csv
# Time: 0.28s
#
# --- Load 0.8 ---
# Packed 6000 flows in 0.241 s | Node distribution Jensen Shannon distance from target achieved: 5.996870604600635e-08
# Time to save data to final_data/social_media_cloud_load_8.csv: 0.016885757446289062 s
# Saved: final_data/social_media_cloud_load_8.csv
# Time: 0.29s
#
# --- Load 0.9 ---
# Packed 6000 flows in 0.232 s | Node distribution Jensen Shannon distance from target achieved: 2.4170788623726704e-08
# Time to save data to final_data/social_media_cloud_load_9.csv: 0.016622543334960938 s
# Saved: final_data/social_media_cloud_load_9.csv
# Time: 0.28s
#
# ==============================
# Benchmark: commercial_cloud
# ==============================
# Set to save benchmark commercial_cloud distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/commercial_cloud/
# Saved node_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/commercial_cloud/
# Saved flow_size_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/commercial_cloud/
# Saved interarrival_time_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/commercial_cloud/
# Loaded distributions: ['node_dist', 'flow_size_dist', 'interarrival_time_dist', 'num_ops_dist']
#
# --- Load 0.1 ---
# Packed 6000 flows in 0.244 s | Node distribution Jensen Shannon distance from target achieved: 1.3173421804265493e-08
# Time to save data to final_data/commercial_cloud_load_1.csv: 0.016982555389404297 s
# Saved: final_data/commercial_cloud_load_1.csv
# Time: 0.29s
#
# --- Load 0.2 ---
# Packed 6000 flows in 0.242 s | Node distribution Jensen Shannon distance from target achieved: 2.285749992394083e-08
# Time to save data to final_data/commercial_cloud_load_2.csv: 0.01652383804321289 s
# Saved: final_data/commercial_cloud_load_2.csv
# Time: 0.28s
#
# --- Load 0.3 ---
# Packed 6000 flows in 0.254 s | Node distribution Jensen Shannon distance from target achieved: 2.2270046833012476e-08
# Time to save data to final_data/commercial_cloud_load_3.csv: 0.016238689422607422 s
# Saved: final_data/commercial_cloud_load_3.csv
# Time: 0.29s
#
# --- Load 0.4 ---
# Packed 6000 flows in 0.237 s | Node distribution Jensen Shannon distance from target achieved: 1.7821172840601734e-08
# Time to save data to final_data/commercial_cloud_load_4.csv: 0.017220020294189453 s
# Saved: final_data/commercial_cloud_load_4.csv
# Time: 0.28s
#
# --- Load 0.5 ---
# Packed 6000 flows in 0.244 s | Node distribution Jensen Shannon distance from target achieved: 2.0293751509622544e-08
# Time to save data to final_data/commercial_cloud_load_5.csv: 0.01743602752685547 s
# Saved: final_data/commercial_cloud_load_5.csv
# Time: 0.29s
#
# --- Load 0.6 ---
# Packed 6000 flows in 0.239 s | Node distribution Jensen Shannon distance from target achieved: 1.4075935085832423e-08
# Time to save data to final_data/commercial_cloud_load_6.csv: 0.015652179718017578 s
# Saved: final_data/commercial_cloud_load_6.csv
# Time: 0.28s
#
# --- Load 0.7 ---
# Packed 6000 flows in 0.239 s | Node distribution Jensen Shannon distance from target achieved: 1.1661885127328769e-08
# Time to save data to final_data/commercial_cloud_load_7.csv: 0.015548944473266602 s
# Saved: final_data/commercial_cloud_load_7.csv
# Time: 0.28s
#
# --- Load 0.8 ---
# Packed 6000 flows in 0.254 s | Node distribution Jensen Shannon distance from target achieved: 1.4630584544782032e-08
# Time to save data to final_data/commercial_cloud_load_8.csv: 0.017997026443481445 s
# Saved: final_data/commercial_cloud_load_8.csv
# Time: 0.30s
#
# --- Load 0.9 ---
# Packed 6000 flows in 0.249 s | Node distribution Jensen Shannon distance from target achieved: 1.0620897643476908e-08
# Time to save data to final_data/commercial_cloud_load_9.csv: 0.017122507095336914 s
# Saved: final_data/commercial_cloud_load_9.csv
# Time: 0.29s
#
# ==============================
# Benchmark: university
# ==============================
# Set to save benchmark university distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/university/
# Saved node_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/university/
# Saved flow_size_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/university/
# Saved interarrival_time_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/university/
# Loaded distributions: ['node_dist', 'flow_size_dist', 'interarrival_time_dist', 'num_ops_dist']
#
# --- Load 0.1 ---
# Packed 6000 flows in 0.260 s | Node distribution Jensen Shannon distance from target achieved: 1.722503122614072e-08
# Time to save data to final_data/university_load_1.csv: 0.01992654800415039 s
# Saved: final_data/university_load_1.csv
# Time: 0.30s
#
# --- Load 0.2 ---
# Packed 6000 flows in 0.258 s | Node distribution Jensen Shannon distance from target achieved: 0.03933014555176705
# Time to save data to final_data/university_load_2.csv: 0.01650834083557129 s
# Saved: final_data/university_load_2.csv
# Time: 0.30s
#
# --- Load 0.3 ---
# Packed 6000 flows in 0.251 s | Node distribution Jensen Shannon distance from target achieved: 2.187307208504267e-08
# Time to save data to final_data/university_load_3.csv: 0.018060684204101562 s
# Saved: final_data/university_load_3.csv
# Time: 0.29s
#
# --- Load 0.4 ---
# Packed 6000 flows in 0.254 s | Node distribution Jensen Shannon distance from target achieved: 1.8604506005793376e-08
# Time to save data to final_data/university_load_4.csv: 0.01803755760192871 s
# Saved: final_data/university_load_4.csv
# Time: 0.30s
#
# --- Load 0.5 ---
# Packed 6000 flows in 0.256 s | Node distribution Jensen Shannon distance from target achieved: 1.1667461572846563e-08
# Time to save data to final_data/university_load_5.csv: 0.017773866653442383 s
# Saved: final_data/university_load_5.csv
# Time: 0.30s
#
# --- Load 0.6 ---
# Packed 6000 flows in 0.240 s | Node distribution Jensen Shannon distance from target achieved: 1.6360009595885685e-08
# Time to save data to final_data/university_load_6.csv: 0.01718425750732422 s
# Saved: final_data/university_load_6.csv
# Time: 0.28s
#
# --- Load 0.7 ---
# Packed 6000 flows in 0.243 s | Node distribution Jensen Shannon distance from target achieved: 0.045322995794469356
# Time to save data to final_data/university_load_7.csv: 0.016524791717529297 s
# Saved: final_data/university_load_7.csv
# Time: 0.29s
#
# --- Load 0.8 ---
# Packed 6000 flows in 0.241 s | Node distribution Jensen Shannon distance from target achieved: 7.531137204785702e-09
# Time to save data to final_data/university_load_8.csv: 0.017676353454589844 s
# Saved: final_data/university_load_8.csv
# Time: 0.28s
#
# --- Load 0.9 ---
# Packed 6000 flows in 0.275 s | Node distribution Jensen Shannon distance from target achieved: 0.06604378737717101
# Time to save data to final_data/university_load_9.csv: 0.020172595977783203 s
# Saved: final_data/university_load_9.csv
# Time: 0.32s
#
#  All datasets generated!
