# %%
import trafpy.generator as tpg
from trafpy.benchmarker import BenchmarkImporter

from pathlib import Path
import time

# ------------------ NETWORK SETUP ------------------
num_eps = 8
'''
num_racks = 2

racks_dict = {}
eps_per_rack = int(num_eps / num_racks)

for rack in range(num_racks):
    racks_dict[rack] = [
        ep for ep in range(rack * eps_per_rack,
                           (rack * eps_per_rack) + eps_per_rack)
    ]

print("racks_dict:", racks_dict)
'''

# 100 Mbps → Bytes/sec
ep_capacity = 100000000 / 8

net = tpg.gen_arbitrary_network(
    num_eps=num_eps,
    ep_capacity=ep_capacity)
    #racks_dict=racks_dict
#)

# ------------------ NETWORK INFO ------------------
print("\n--- NETWORK INFO ---")
print("topology_type:", net.graph['topology_type'])
print("max_nw_capacity:", net.graph['max_nw_capacity'])
print("endpoints:", net.graph['endpoints'])

# ------------------ BENCHMARK SETUP ------------------
importer = BenchmarkImporter(
    benchmark_version='v001',
    load_prev_dists=False
)

# Add/remove benchmarks here
benchmark_names = [
    'private_enterprise',
    'social_media_cloud',
    'commercial_cloud',
    'university'    
]

# ------------------ OUTPUT DIR ------------------
path_to_data = "8_hosts_v5(no_rack)/"
Path(path_to_data).mkdir(exist_ok=True, parents=True)

# ------------------ PARAMETERS ------------------
jsd_threshold = 0.9
loads = [i / 10 for i in range(1, 10)]  # 0.1 → 0.9

# ------------------ MAIN LOOP ------------------
for benchmark_name in benchmark_names:
    print(f"\n==============================")
    print(f"Benchmark: {benchmark_name}")
    print(f"==============================")

    # Load distributions for this benchmark
    dists = importer.get_benchmark_dists(
        benchmark_name=benchmark_name,
        eps=net.graph['endpoints'],
        racks_dict=net.graph['rack_to_ep_dict']
    )

    print("Loaded distributions:", list(dists.keys()))

    # Loop over loads
    for load in loads:
        print(f"\n--- Load {load} ---")
        start_time = time.time()

        network_load_config = {
            'network_rate_capacity': net.graph['max_nw_capacity'],
            'ep_link_capacity': net.graph['ep_link_capacity'],
            'target_load_fraction': load
        }

        demand_data = tpg.create_demand_data(
            eps=net.graph['endpoints'],
            node_dist=dists['node_dist'],
            flow_size_dist=dists['flow_size_dist'],
            interarrival_time_dist=dists['interarrival_time_dist'],
            #min_num_demands=40000,
            network_load_config=network_load_config,
            jensen_shannon_distance_threshold=jsd_threshold
        )

        # ------------------ SAVE ------------------
        filename = f"{path_to_data}{benchmark_name}_load_{int(load*10)}.csv"

        tpg.save_data_as_csv(
            data=demand_data,
            path_to_save=filename,
            overwrite=True
        )

        print(f"Saved: {filename}")
        print(f"Time: {time.time() - start_time:.2f}s")

print("\n All datasets generated!")
# Out:
# /home/hsd/anaconda3/envs/trafpy-env/lib/python3.13/site-packages/nxviz/__init__.py:18: UserWarning:
# nxviz has a new API! Version 0.7.3 onwards, the old class-based API is being
# deprecated in favour of a new API focused on advancing a grammar of network
# graphics. If your plotting code depends on the old API, please consider
# pinning nxviz at version 0.7.3, as the new API will break your old code.
#
# To check out the new API, please head over to the docs at
# https://ericmjl.github.io/nxviz/ to learn more. We hope you enjoy using it!
#
# (This deprecation message will go away in version 1.0.)
#
#   warnings.warn(
# --- NETWORK INFO ---
# topology_type: arbitrary_endpoints_8_chancap_12500000.0_channels_1
# max_nw_capacity: 50000000.0
# endpoints: ['0', '1', '2', '3', '4', '5', '6', '7']
# load_prev_dist=False. Will re-generate dists with given network params and override any previously saved distributions.
#
# ==============================
# Benchmark: social_media_cloud
# ==============================
# Set to save benchmark social_media_cloud distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/social_media_cloud/
# Saved node_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/social_media_cloud/
# Saved flow_size_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/social_media_cloud/
# Saved interarrival_time_dist distribution data to /home/hsd/workspace/trafpy/trafpy/benchmarker/versions/benchmark_v001/benchmarks/social_media_cloud/
# Loaded distributions: ['node_dist', 'flow_size_dist', 'interarrival_time_dist', 'num_ops_dist']
#
# --- Load 0.1 ---
# Packed 6000 flows in 0.437 s | Node distribution Jensen Shannon distance from target achieved: 4.645330108488475e-07
# Time to save data to 8_hosts_v5(no_rack)/social_media_cloud_load_1.csv: 0.030500411987304688 s
# Saved: 8_hosts_v5(no_rack)/social_media_cloud_load_1.csv
# Time: 0.52s
#
# --- Load 0.2 ---
# Packed 6000 flows in 0.419 s | Node distribution Jensen Shannon distance from target achieved: 6.248522022063929e-07
# Time to save data to 8_hosts_v5(no_rack)/social_media_cloud_load_2.csv: 0.025814294815063477 s
# Saved: 8_hosts_v5(no_rack)/social_media_cloud_load_2.csv
# Time: 0.50s
#
# --- Load 0.3 ---
# Packed 6000 flows in 0.421 s | Node distribution Jensen Shannon distance from target achieved: 2.0307512468516475e-07
# Time to save data to 8_hosts_v5(no_rack)/social_media_cloud_load_3.csv: 0.024880647659301758 s
# Saved: 8_hosts_v5(no_rack)/social_media_cloud_load_3.csv
# Time: 0.49s
#
# --- Load 0.4 ---
# Packed 6000 flows in 0.443 s | Node distribution Jensen Shannon distance from target achieved: 5.22589369105789e-07
# Time to save data to 8_hosts_v5(no_rack)/social_media_cloud_load_4.csv: 0.029578208923339844 s
# Saved: 8_hosts_v5(no_rack)/social_media_cloud_load_4.csv
# Time: 0.52s
#
# --- Load 0.5 ---
# Packed 6000 flows in 0.450 s | Node distribution Jensen Shannon distance from target achieved: 2.740185026457397e-07
# Time to save data to 8_hosts_v5(no_rack)/social_media_cloud_load_5.csv: 0.027495861053466797 s
# Saved: 8_hosts_v5(no_rack)/social_media_cloud_load_5.csv
# Time: 0.53s
#
# --- Load 0.6 ---
# Packed 6000 flows in 0.443 s | Node distribution Jensen Shannon distance from target achieved: 1.8303496654454926e-07
# Time to save data to 8_hosts_v5(no_rack)/social_media_cloud_load_6.csv: 0.024360179901123047 s
# Saved: 8_hosts_v5(no_rack)/social_media_cloud_load_6.csv
# Time: 0.51s
#
# --- Load 0.7 ---
# Packed 6000 flows in 0.545 s | Node distribution Jensen Shannon distance from target achieved: 5.612632221143365e-07
# Time to save data to 8_hosts_v5(no_rack)/social_media_cloud_load_7.csv: 0.024762868881225586 s
# Saved: 8_hosts_v5(no_rack)/social_media_cloud_load_7.csv
# Time: 0.62s
#
# --- Load 0.8 ---
# Packed 6000 flows in 0.448 s | Node distribution Jensen Shannon distance from target achieved: 0.002374619594527372
# Time to save data to 8_hosts_v5(no_rack)/social_media_cloud_load_8.csv: 0.029263019561767578 s
# Saved: 8_hosts_v5(no_rack)/social_media_cloud_load_8.csv
# Time: 0.52s
#
# --- Load 0.9 ---
# Packed 6000 flows in 0.406 s | Node distribution Jensen Shannon distance from target achieved: 0.04861836924514008
# Time to save data to 8_hosts_v5(no_rack)/social_media_cloud_load_9.csv: 0.027066707611083984 s
# Saved: 8_hosts_v5(no_rack)/social_media_cloud_load_9.csv
# Time: 0.48s
#
#  All datasets generated!
